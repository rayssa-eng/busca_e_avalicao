# %%
from collections import Counter
import configparser
import numpy as np
import csv
from tqdm import tqdm

# %% [markdown]
# ### Lendo arquivo de configuração

# %%
config = configparser.ConfigParser()
config.read('INDEX.cfg')

li_path = config.get('DEFAULT', 'LEIA')

li = {}
with open(li_path, 'r', newline='') as file:
    reader = csv.reader(file, delimiter=';')
    
    # Iterate over each row in the CSV file
    for row in reader:
        key = row[0].strip()
        value = eval(row[1].strip())
        li[key] = value

type_of_tf = config.get('DEFAULT', 'FREQUENCIA')
modelo_path = config.get('DEFAULT', 'ESCREVA')

# %%
print("alo\n", "realengo")
# Out:
# alo
#  realengo

# %% [markdown]
# ### Criando a matriz termo-documento

# %%
def term_document_matrix(inverted_index):
    tdm = {}
    for word in inverted_index.keys():
        tdm[word] = len([rec_num for rec_num in inverted_index[word]])
    return tdm

# %%
tdm = term_document_matrix(li)
tdm
# Out:
# {'SIGNIFICANCE': 26,
#  'PSEUDOMONAS': 124,
#  'AERUGINOSA': 194,
#  'INFECTION': 225,
#  'RESPIRATORY': 149,
#  'TRACT': 73,
#  'CYSTIC': 2042,
#  'FIBROSIS': 2058,
#  'PATIENT': 2168,
#  'STUDIED': 153,
#  'MEAN': 218,
#  'IMMUNOELECTROPHORETICAL': 1,
#  'ANALYSIS': 96,
#  'SERUM': 778,
#  'NUMBER': 150,
#  'PRECIPITIN': 86,
#  'CONCENTRATION': 316,
#  'PROTEIN': 290,
#  'ADDITION': 65,
#  'CLINICAL': 274,
#  'RADIOGRAPHICAL': 1,
#  'STATUS': 42,
#  'LUNG': 249,
#  'EVALUATED': 43,
#  'USING': 124,
#  'SCORING': 5,
#  'SYSTEM': 110,
#  'DEMONSTRATED': 81,
#  'MAXIMUM': 27,
#  'ONE': 330,
#  'SIGNIFICANTLY': 177,
#  'CHANGED': 7,
#  'COMPARED': 192,
#  'MATCHED': 40,
#  'CONTROL': 568,
#  'PERSON': 33,
#  'NOTABLY': 5,
#  'IGG': 86,
#  'IGA': 37,
#  'ELEVATED': 90,
#  'ACUTE': 62,
#  'PHASE': 45,
#  'LATTER': 25,
#  'SUGGESTING': 24,
#  'ACTIVE': 42,
#  'TISSUE': 83,
#  'DAMAGE': 26,
#  'HAPTOGLOBIN': 5,
#  'CORRELATED': 52,
#  'MANY': 94,
#  'ACCOMPANIED': 14,
#  'RESULT': 332,
#  'INDICATE': 54,
#  'PROTECTIVE': 7,
#  'VALUE': 248,
#  'SALIVARY': 75,
#  'AMYLASE': 94,
#  'LEVEL': 337,
#  'DETERMINED': 65,
#  'NORMAL': 719,
#  'SUBJECT': 253,
#  'BIRTH': 63,
#  'ADULT': 147,
#  'LIFE': 66,
#  'CHILD': 718,
#  'CONDITION': 147,
#  'SOMETIMES': 9,
#  'ASSOCIATED': 135,
#  'LOW': 115,
#  'PANCREATIC': 328,
#  'MALNUTRITION': 28,
#  'COELIAC': 21,
#  'DISEASE': 692,
#  'MIXED': 19,
#  'SALIVA': 109,
#  'COLLECTED': 25,
#  'CAREFULLY': 9,
#  'STANDARDISED': 1,
#  'MEASURED': 108,
#  'METHOD': 195,
#  'DAHLQVIST': 1,
#  'WIDE': 24,
#  'SCATTER': 3,
#  'ROSE': 8,
#  'REACH': 8,
#  'AGE': 285,
#  'MONTH': 85,
#  'YEAR': 290,
#  'ACTIVITY': 462,
#  'NORMALLY': 18,
#  'TEN': 24,
#  'WEEK': 46,
#  'PREMATURE': 12,
#  'INFANT': 194,
#  'FED': 5,
#  'MILK': 13,
#  'GASTROSTOMY': 1,
#  'THIRTEEN': 3,
#  'MOSTLY': 6,
#  'SIX': 73,
#  'MALNOURISHED': 8,
#  'JEJUNAL': 11,
#  'VILLOUS': 4,
#  'ATROPHY': 10,
#  'UNCERTAIN': 3,
#  'AETIOLOGY': 7,
#  'RECOVERY': 22,
#  'BEGAN': 5,
#  'ARTICLE': 33,
#  'REPORT': 106,
#  'POSSIBILITY': 42,
#  'INSTRUMENTAL': 2,
#  'NEUTRON': 5,
#  'ACTIVATION': 27,
#  'INAA': 5,
#  'SODIUM': 116,
#  'NAIL': 25,
#  'CLIPPING': 10,
#  'DIAGNOSING': 3,
#  'CF': 1412,
#  'DETECTING': 27,
#  'HETEROZYGOTE': 217,
#  'SCREENING': 133,
#  'NEONATAL': 20,
#  'PERIOD': 99,
#  'NEWBORN': 64,
#  'TWO': 289,
#  'HEALTHY': 88,
#  'ANALYZED': 21,
#  'DISCRIMINATION': 3,
#  'FOUND': 368,
#  'PRECISE': 7,
#  'INDIVIDUAL': 160,
#  'ACCEPTED': 11,
#  'DIAGNOSTIC': 64,
#  'TEST': 436,
#  'COULD': 144,
#  'DETECTED': 83,
#  'FIRST': 105,
#  'FIVE': 70,
#  'DAY': 100,
#  'BIG': 1,
#  'OVERLAP': 18,
#  'MAKE': 34,
#  'INVALUABLE': 1,
#  'EARLY': 91,
#  'USED': 141,
#  'DEVELOPMENT': 80,
#  'THREE': 170,
#  'OLD': 48,
#  'SAMPLED': 1,
#  'DIFFERENT': 118,
#  'ERROR': 36,
#  'STUDY': 398,
#  'COLLECTION': 21,
#  'ROUTINE': 29,
#  'OUTLINED': 9,
#  'EASILY': 13,
#  'WASHED': 2,
#  'RISK': 44,
#  'CONTAMINATION': 3,
#  'SEEMS': 43,
#  'SMALL': 96,
#  'DISTRIBUTION': 50,
#  'INHOMOGENEOUS': 1,
#  'CONTENT': 107,
#  'VARIES': 5,
#  'ALSO': 233,
#  'GOOD': 28,
#  'EVIDENCE': 101,
#  'INCREASED': 251,
#  'COME': 6,
#  'SWEAT': 279,
#  'BASIC': 47,
#  'INTRINSIC': 16,
#  'PRECISION': 6,
#  'ACCURACY': 8,
#  'DETERMINING': 13,
#  'CONSIDERED': 67,
#  'SATISFACTORY': 8,
#  'CONCLUDED': 31,
#  'SUITABLE': 21,
#  'AID': 10,
#  'DIAGNOSIS': 237,
#  'CAPACITY': 80,
#  'DUODENAL': 31,
#  'JUICE': 10,
#  'HYDROLYSE': 1,
#  'CASEIN': 2,
#  'TRICHLOROACETIC': 2,
#  'ACID': 318,
#  'SOLUBLE': 16,
#  'PEPTIDE': 7,
#  'INVESTIGATED': 67,
#  'GROUP': 420,
#  'ENTEROGENIC': 2,
#  'MALABSORPTION': 52,
#  'COW': 6,
#  'INTOLERANCE': 10,
#  'PROTEOLYTIC': 27,
#  'PER': 188,
#  'ML': 63,
#  'FASTING': 2,
#  'GREAT': 34,
#  'MG': 94,
#  'HOUR': 57,
#  'CORRELATION': 76,
#  'TRYPSIN': 89,
#  'INSUFFICIENCY': 82,
#  'EXTREMELY': 15,
#  'MEASURABLE': 9,
#  'WHEREAS': 68,
#  'WITHIN': 82,
#  'RANGE': 79,
#  'INFLUENCE': 36,
#  'CHRONIC': 226,
#  'P': 30,
#  'OCCURRENCE': 36,
#  'BONE': 21,
#  'MARROW': 9,
#  'DERIVED': 57,
#  'LYMPHOCYTE': 45,
#  'CELL': 434,
#  'THYMUS': 3,
#  'PERIPHERAL': 19,
#  'BLOOD': 156,
#  'SUFFERED': 5,
#  'PRODUCED': 52,
#  'MULTIPLE': 26,
#  'CROSSED': 15,
#  'IMMUNOELECTROPHORESIS': 22,
#  'NEVER': 14,
#  'HARBOURED': 3,
#  'PRESENTED': 59,
#  'DEMONSTRABLE': 10,
#  'BACTERIA': 32,
#  'EXAMINED': 91,
#  'PRESENCE': 107,
#  'SURFACE': 45,
#  'MARKER': 24,
#  'RECEPTOR': 12,
#  'COMPLEMENT': 51,
#  'COMPONENT': 81,
#  'EAC': 2,
#  'ROSETTE': 3,
#  'FORMATION': 27,
#  'IMMUNOGLOBULIN': 44,
#  'IMMUNOFLUORESCENT': 2,
#  'STAINING': 11,
#  'SPONTANEOUS': 6,
#  'BINDING': 60,
#  'SHEEP': 2,
#  'RED': 18,
#  'RATIO': 93,
#  'NEARLY': 13,
#  'IDENTICAL': 26,
#  'TOTAL': 138,
#  'SIGNIFICANT': 238,
#  'HIGHER': 149,
#  'POSITIVELY': 8,
#  'WHERAS': 1,
#  'INSIGNIFICANT': 3,
#  'MONTHLY': 5,
#  'BACTERIOLOGICAL': 13,
#  'EXAMINATION': 39,
#  'TRACHEAL': 51,
#  'SECRETION': 200,
#  'POLYVALENT': 4,
#  'ANTIGEN': 74,
#  'PREVALENCE': 37,
#  'RATE': 153,
#  'HARBOURING': 1,
#  'CENT': 106,
#  'NEWLY': 6,
#  'COLONIZED': 12,
#  'INTERMITTENTLY': 3,
#  'NON': 71,
#  'MUCOID': 84,
#  'STRAIN': 162,
#  'PREDOMINATING': 6,
#  'CHRONICALLY': 31,
#  'ESPECIALLY': 38,
#  'MALE': 53,
#  'FEMALE': 35,
#  'DURATION': 14,
#  'COLONIZATION': 26,
#  'CONTRAST': 41,
#  'ACCORDANCE': 5,
#  'HYPOTHESIS': 48,
#  'SUBSTANCE': 37,
#  'VIRULENCE': 3,
#  'FACTOR': 245,
#  'MIGHT': 69,
#  'INHIBIT': 12,
#  'OPSONIZING': 1,
#  'EFFECT': 224,
#  'DEPENDENT': 30,
#  'LYSIS': 1,
#  'HEREBY': 1,
#  'FAVOURING': 1,
#  'EXPENSE': 1,
#  'SEVENTY': 4,
#  'TREATED': 90,
#  'CLINIC': 17,
#  'FOLLOWED': 28,
#  'DAILY': 19,
#  'IMPRESSION': 12,
#  'OBTAINED': 132,
#  'LABORATORY': 51,
#  'EXPRESSED': 29,
#  'POINT': 42,
#  'STAPHYLOCOCCUS': 29,
#  'AUREUS': 52,
#  'HAEMOPHILUS': 13,
#  'INFLUENZAE': 22,
#  'DIPLOCOCCUS': 1,
#  'PNEUMONIAE': 10,
#  'MISCELLANEOUS': 5,
#  'MAINLY': 13,
#  'ENTEROBACTERIACEAE': 7,
#  'FLUCTUATION': 4,
#  'BACTERIOLOGY': 4,
#  'DESCRIBED': 84,
#  'ADDITIONAL': 38,
#  'EPIDEMIOLOGICAL': 2,
#  'TERM': 60,
#  'ST': 14,
#  'PATTERN': 83,
#  'MINOR': 25,
#  'MODIFICATION': 18,
#  'REGARD': 42,
#  'REFLECTS': 6,
#  'DIFFICULT': 20,
#  'THERAPEUTIC': 37,
#  'PROBLEM': 96,
#  'NEW': 59,
#  'RECOLONIZATION': 2,
#  'REFLECT': 22,
#  'PREVENTION': 17,
#  'INCIDENCE': 86,
#  'SHOW': 86,
#  'STILL': 31,
#  'CONSIDERABLE': 26,
#  'THERAPY': 194,
#  'WELL': 125,
#  'ALTHOUGH': 114,
#  'SPECIE': 19,
#  'MAY': 423,
#  'COLONIZE': 1,
#  'MAIN': 29,
#  'CONCERN': 10,
#  'REASON': 46,
#  'DISCUSSED': 113,
#  'FAMILY': 111,
#  'CELIAC': 14,
#  'SPRUE': 2,
#  'OCCURRED': 41,
#  'SIBSHIP': 2,
#  'COUSIN': 5,
#  'INDEX': 43,
#  'CASE': 237,
#  'DISCOVERED': 5,
#  'GENETICS': 11,
#  'REVIEWED': 29,
#  'ESTIMATED': 12,
#  'LIKELIHOOD': 6,
#  'ASSOCIATION': 32,
#  'OCCURRING': 22,
#  'BASIS': 58,
#  'CHANCE': 9,
#  'EXHIBITED': 9,
#  'FEATURE': 36,
#  'KARTAGENER': 3,
#  'SYNDROME': 74,
#  'AUTHOR': 28,
#  'KNOWLEDGE': 28,
#  'REPRESENTS': 11,
#  'THIRD': 24,
#  'COMBINATION': 36,
#  'EXCLUDED': 12,
#  'MADE': 69,
#  'ALLERGY': 33,
#  'COURSE': 66,
#  'FIFTEEN': 5,
#  'DEFINED': 28,
#  'HISTORY': 46,
#  'PHYSICAL': 43,
#  'POSITIVE': 138,
#  'SKIN': 148,
#  'NASAL': 41,
#  'EOSINOPHILIA': 3,
#  'REVERSIBLE': 8,
#  'AIRWAY': 82,
#  'OBSTRUCTION': 78,
#  'ALLERGIC': 32,
#  'NONALLERGIC': 5,
#  'IGE': 40,
#  'INTERNATIONAL': 2,
#  'UNIT': 28,
#  'IU': 4,
#  'IGM': 25,
#  'SIMILAR': 136,
#  'SHWACHMAN': 25,
#  'SCORE': 59,
#  'BETTER': 25,
#  'MODULATING': 1,
#  'SEVERITY': 68,
#  'TAUSSIG': 4,
#  'ET': 69,
#  'AL': 69,
#  'REPORTED': 125,
#  'BOY': 11,
#  'RUSSELL': 3,
#  'VARIANT': 22,
#  'SILVER': 3,
#  'CONCOMITANT': 6,
#  'WOULD': 97,
#  'LIKE': 67,
#  'DESCRIBE': 12,
#  'ANOTHER': 32,
#  'FINDING': 150,
#  'POSSIBLE': 116,
#  'ENTIRELY': 8,
#  'ACCIDENTAL': 3,
#  'COINCIDENCE': 1,
#  'STATISTICALLY': 27,
#  'RARE': 29,
#  'EVENT': 14,
#  'ESTABLISHMENT': 7,
#  'RELATIONSHIP': 52,
#  'DEPEND': 8,
#  'INTENSIVE': 11,
#  'SEARCH': 8,
#  'BLACK': 21,
#  'WASHINGTON': 2,
#  'DC': 1,
#  'DISCLOSED': 4,
#  'EIGHT': 40,
#  'BORN': 10,
#  'DISTRICT': 2,
#  'COLUMBIA': 2,
#  'DECADE': 6,
#  'CALCULATED': 10,
#  'LEAST': 55,
#  'PATHOLOGICAL': 18,
#  'CHANGE': 174,
#  'WHITE': 40,
#  'GENETIC': 135,
#  'CONSIDERATION': 10,
#  'AUTOSOMAL': 32,
#  'RECESSIVE': 38,
#  'INHERITANCE': 7,
#  'GENERALLY': 32,
#  'PRENATAL': 32,
#  'DISORDER': 118,
#  'RECEIVED': 29,
#  'INCREASING': 48,
#  'ATTENTION': 27,
#  'PAST': 28,
#  'SEVERAL': 96,
#  'RAPID': 36,
#  'EXPANSION': 2,
#  'RELIABLE': 29,
#  'LED': 28,
#  'ADVANCE': 10,
#  'INTRAUTERINE': 10,
#  'LARGE': 71,
#  'INHERITED': 38,
#  'INITIALLY': 15,
#  'DETERMINE': 51,
#  'CHROMOSOMAL': 7,
#  'ABNORMALITY': 145,
#  'DETERMINATION': 29,
#  'FETAL': 19,
#  'SEX': 51,
#  'PREGNANCY': 10,
#  'SEVERE': 83,
#  'LINKED': 11,
#  'SHORTLY': 3,
#  'THEREAFTER': 4,
#  'BECAME': 11,
#  'CLEAR': 16,
#  'TECHNIQUE': 123,
#  'APPLIED': 19,
#  'INBORN': 24,
#  'METABOLISM': 59,
#  'RECENTLY': 33,
#  'DEVELOPED': 62,
#  'PROVE': 11,
#  'CONGENITAL': 29,
#  'MALFORMATION': 9,
#  'DIAGNOSED': 44,
#  'PRIOR': 15,
#  'GOAL': 7,
#  'REVIEW': 68,
#  'DEFINE': 6,
#  'ACHIEVEMENT': 5,
#  'FUTURE': 31,
#  'PRESENT': 226,
#  'LIMITATION': 13,
#  'SECTION': 14,
#  'DEAL': 13,
#  'GENERAL': 55,
#  'APPROACH': 49,
#  'DISCUSSION': 15,
#  'SPECIFIC': 131,
#  'APPLICATION': 21,
#  'INCLUDE': 54,
#  'AMNIOCENTESIS': 8,
#  'DIRECT': 14,
#  'INDIRECT': 10,
#  'VISUALIZATION': 4,
#  'FETUS': 13,
#  'MATERNAL': 10,
#  'URINE': 27,
#  'SAMPLING': 4,
#  'LIPID': 42,
#  'CARBOHYDRATE': 35,
#  'MUCOPOLYSACCHARIDE': 18,
#  'AMINO': 18,
#  'PROVIDE': 40,
#  'PARENT': 106,
#  'WITHOUT': 122,
#  'FEAR': 2,
#  'DEFORMITY': 3,
#  'INCREASE': 163,
#  'DETECTABLE': 13,
#  'UTERO': 5,
#  'POTENTIAL': 45,
#  'TREATMENT': 228,
#  'UNLIMITED': 1,
#  'WOMAN': 27,
#  'COMBINED': 21,
#  'FORM': 69,
#  'ORAL': 39,
#  'CONTRACEPTIVE': 1,
#  'POLYPOID': 1,
#  'CERVICITIS': 1,
#  'POLYP': 39,
#  'RECURRED': 2,
#  'REINSTITUTION': 1,
#  'MEDICATION': 15,
#  'RESOLUTION': 11,
#  'INSTANCE': 23,
#  'DISCONTINUATION': 3,
#  'DRUG': 64,
#  'AFFECTED': 73,
#  'COINCIDENTAL': 2,
#  'DETERIORATION': 16,
#  'THEREFORE': 63,
#  'SUGGESTED': 67,
#  'CONTRACEPTION': 1,
#  'OBSERVED': 182,
#  'CLOSELY': 21,
#  'REGARDING': 15,
#  'PULMONARY': 262,
#  'GYNECOLOGIC': 1,
#  'ATAXIA': 4,
#  'TELANGIECTASIA': 3,
#  'CHARACTERIZED': 25,
#  'PROGRESSIVE': 20,
#  'NEUROLOGIC': 3,
#  'DEGENERATION': 4,
#  'CUTANEOUS': 2,
#  'CONJUNCTIVAL': 3,
#  'TELANGIECTASIS': 1,
#  'IMMUNOLOGIC': 6,
#  'DEFICIENCY': 129,
#  'ROENTGENOLOGIC': 1,
#  'SINUS': 10,
#  'DECREASED': 82,
#  'LYMPHOID': 10,
#  'USUALLY': 36,
#  'SINOPULMONARY': 1,
#  'RESEMBLE': 8,
#  'ADENOIDAL': 1,
#  'MASS': 22,
#  'DIFFERENTIAL': 13,
#  'LONGER': 18,
#  'TARGET': 4,
#  'ORGAN': 37,
#  'LESION': 36,
#  'BRONCHIAL': 107,
#  'LEADING': 12,
#  'BRONCHIECTASIS': 39,
#  'INTERSTITIAL': 5,
#  'INFILTRATES': 2,
#  'CYST': 6,
#  'CHARACTERISTIC': 60,
#  'ROENTGENOGRAPHY': 1,
#  'COMPLICATION': 51,
#  'HYPERTENSION': 13,
#  'PNEUMONITIS': 4,
#  'HEMORRHAGE': 10,
#  'PNEUMOTHORAX': 23,
#  'LITTLE': 39,
#  'EXISTS': 10,
#  'GASTROINTESTINAL': 40,
#  'INVOLVEMENT': 64,
#  'DESPITE': 26,
#  'SIMILARITY': 5,
#  'PATHOGENESIS': 44,
#  'ALWAYS': 21,
#  'MUST': 53,
#  'DIFFERENTIATED': 2,
#  'FAR': 19,
#  'RABBIT': 39,
#  'ALVEOLAR': 25,
#  'MACROPHAGE': 15,
#  'CONCERNED': 7,
#  'HOMOZYGOUS': 31,
#  'EXPERIMENT': 30,
#  'EVEN': 48,
#  'GREATER': 101,
#  'FOURFOLD': 1,
#  'BIGGAR': 2,
#  'ASSOCIATE': 10,
#  'STATE': 76,
#  'REQUIRED': 24,
#  'PHAGOCYTOSIS': 8,
#  'DILUTION': 10,
#  'EITHER': 82,
#  'HANK': 1,
#  'BALANCED': 1,
#  'SALT': 38,
#  'SOLUTION': 30,
#  'HUMAN': 112,
#  'THUS': 68,
#  'DECREASING': 8,
#  'PHAGOCYTIZE': 1,
#  'KILL': 3,
#  'OPPOSITE': 4,
#  'SUSPENSION': 11,
#  'REDUCED': 74,
#  'PHAGOCYTIC': 3,
#  'UNEXPECTED': 4,
#  'HIGH': 166,
#  'LIKELY': 32,
#  'TOXIC': 10,
#  'INHIBITION': 51,
#  'ABSENT': 26,
#  'PREVIOUSLY': 58,
#  'HEATED': 2,
#  'FROZEN': 2,
#  'OBSERVATION': 92,
#  'ABILITY': 32,
#  'FEEL': 17,
#  'DATA': 119,
#  'DEMONSTRATE': 32,
#  'LABILE': 7,
#  'INHIBITOR': 46,
#  'RATHER': 40,
#  'SINCE': 111,
#  'KNOWN': 79,
#  'INCLUDING': 51,
#  'RESPOND': 6,
#  'SHOWN': 76,
#  'ESSENTIAL': 54,
#  'AGREE': 15,
#  'DUE': 107,
#  'NOTE': 6,
#  'STORED': 5,
#  'DEGREE': 102,
#  'PERHAPS': 30,
#  'ACCOUNT': 21,
#  'DIFFERENCE': 307,
#  'ASSAYED': 23,
#  'ARGININE': 59,
#  'RECEIVING': 25,
#  'ESTERASE': 39,
#  'UNTREATED': 16,
#  'LOWER': 116,
#  'CARRIER': 94,
#  'ESTERASES': 3,
#  'PLASMA': 224,
#  'ELECTROFUSING': 1,
#  'POLYACRYLAMIDE': 24,
#  'GEL': 71,
#  'BAND': 43,
#  'WORK': 43,
#  'REPRODUCED': 5,
#  'COBURN': 1,
#  'CONFIRMED': 37,
#  'WORKING': 5,
#  'UNDERSTAND': 11,
#  'DEFECT': 131,
#  'VARIATION': 40,
#  'PH': 89,
#  'CHLORIDE': 109,
#  'EMPLOYED': 29,
#  'TESTED': 49,
#  'ALTER': 9,
#  'MAJOR': 70,
#  'RESULTED': 32,
#  'DR': 27,
#  'RAO': 5,
#  'NEGLECT': 4,
#  'MENTION': 3,
#  'UNABLE': 10,
#  'CONFIRM': 29,
#  'DETECT': 33,
#  'FUNCTION': 220,
#  'ASTHMA': 95,
#  'MEASUREMENT': 76,
#  'CLOSING': 7,
#  'VOLUME': 153,
#  'FLOW': 117,
#  'SPIROMETRY': 5,
#  'BODY': 79,
#  'PLETHYSMOGRAPHY': 2,
#  'ARTERIALIZED': 2,
#  'OXYGEN': 31,
#  'TENSION': 7,
#  'COMPARISON': 56,
#  'LE': 160,
#  'SENSITIVE': 42,
#  'RESIDUAL': 22,
#  'EXPIRATORY': 67,
#  'CURVE': 37,
#  'GAS': 27,
#  'BRONCHOSPASM': 10,
#  'INHALING': 3,
#  'EXTRACT': 31,
#  'SPRINKLED': 1,
#  'FOOD': 17,
#  'RESPONDED': 5,
#  'BRONCHODILATOR': 13,
#  'USE': 95,
#  'FACE': 3,
#  'MASK': 2,
#  'PREPARATION': 51,
#  'MEAL': 12,
#  'PREVENTED': 6,
#  'RECURRENCE': 12,
#  'DATE': 7,
#  'PRECIPITATE': 5,
#  'INHALATION': 21,
#  'SEEN': 70,
#  'RESISTANCE': 44,
#  'PLETHYSMOGRAPHIC': 1,
#  'BRISCOE': 1,
#  'DUBOIS': 1,
#  'CALCULATE': 2,
#  'SRAW': 6,
#  'RANGING': 5,
#  'LOWEST': 9,
#  'RAPIDLY': 14,
#  'SEC': 16,
#  'CM': 20,
#  'DECREASE': 66,
#  'PARALLELED': 2,
#  'SEXUAL': 14,
#  'MATURATION': 5,
#  'YOUNG': 51,
#  'VARIOUS': 81,
#  'CILIATED': 17,
#  'EPITHELIUM': 36,
#  'RHINITIS': 7,
#  'MAINTAINED': 20,
#  'CULTURE': 173,
#  'EXPLANTED': 2,
#  'RETAINED': 8,
#  'MORPHOLOGIC': 5,
#  'INCORPORATED': 13,
#  'GLYCOPROTEIN': 107,
#  'SECRETED': 10,
#  'MEDIUM': 95,
#  'THROUGHOUT': 16,
#  'LABELED': 23,
#  'MUCOUS': 57,
#  'SOLUBILIZED': 3,
#  'REDUCTION': 40,
#  'ALKYLATION': 2,
#  'PURIFIED': 37,
#  'FILTRATION': 17,
#  'CHROMATOGRAPHY': 21,
#  'SEPARATED': 19,
#  'DIETHYLAMINOETHYL': 2,
#  'DEAE': 8,
#  'CELLULOSE': 11,
#  'COLUMN': 7,
#  'FRACTION': 108,
#  'COMPOSITION': 53,
#  'DIFFERED': 13,
#  'ACETYL': 11,
#  'NEURAMINIC': 2,
#  'FUCOSE': 15,
#  'RELATIVE': 60,
#  'INCORPORATION': 26,
#  'GLUCOSAMINE': 12,
#  'INDISTINGUISHABLE': 7,
#  'RESPECT': 17,
#  'HOWEVER': 133,
#  'EXCEEDED': 2,
#  'CORRESPONDING': 16,
#  'PRESSURE': 37,
#  'BEHAVIOR': 13,
#  'ISOVOLUME': 1,
#  'DETECTION': 72,
#  'SEPARATE': 10,
#  'GROSSLY': 7,
#  'ABNORMAL': 113,
#  'EXCESSIVE': 21,
#  'STIFFNESS': 1,
#  'NEAR': 13,
#  'LOSS': 65,
#  'RECOIL': 5,
#  'OFTEN': 66,
#  'ENOUGH': 16,
#  'CAUSE': 102,
#  'DISTURBANCE': 27,
#  'EXCHANGE': 20,
#  'QUANTITATIVELY': 10,
#  'EXPLAINED': 18,
#  'ELASTIC': 4,
#  'MODIFIED': 19,
#  'MILD': 44,
#  'OTHERWISE': 10,
#  'SE': 10,
#  'UPSTREAM': 2,
#  'EFFORT': 12,
#  'SHOWING': 9,
#  'TIME': 136,
#  'CONSTANT': 27,
#  'EMPTYING': 4,
#  'VARIED': 10,
#  'WIDELY': 12,
#  'INVOLVES': 9,
#  'WORSENING': 2,
#  'TRAPPING': 1,
#  'BLAND': 2,
#  'AEROSOL': 27,
#  'PARTICULARLY': 37,
#  'MIST': 16,
#  'TENT': 15,
#  'CONVINCING': 2,
#  'EFFICACY': 7,
#  'SURPRISING': 3,
#  'DEPOSIT': 11,
#  'WATER': 58,
#  'DETRIMENTAL': 4,
#  'BACTERIAL': 29,
#  'ENZYME': 212,
#  'ACTIVATED': 19,
#  'TREATING': 7,
#  'CHLOROFORM': 5,
#  'ELLAGIC': 6,
#  'MANNER': 13,
#  'INHIBITED': 36,
#  'SOYBEAN': 12,
#  'SPITE': 12,
#  'WIDESPREAD': 8,
#  'BREATHING': 17,
#  'EXERCISE': 43,
#  'HELPFUL': 17,
#  'PEDIATRIC': 33,
#  'OBJECTIVE': 13,
#  'DEMONSTRATION': 14,
#  'MANEUVER': 5,
#  'PART': 43,
#  'LACKING': 6,
#  'SPUTUM': 183,
#  'SHORT': 29,
#  'COUGH': 17,
#  'POSTURAL': 18,
#  'DRAINAGE': 37,
#  'LONG': 48,
#  'REMAINS': 28,
#  'UNKNOWN': 35,
#  'SIMPLICITY': 6,
#  'EASE': 2,
#  'FINGERNAIL': 2,
#  'TOENAIL': 1,
#  'MEASURE': 31,
#  'ELECTROLYTE': 69,
#  'PROCEDURE': 66,
#  'CATEGORY': 13,
#  'DISEASED': 7,
#  'INDICATED': 49,
#  'EAR': 11,
#  'NOSE': 5,
#  'THROAT': 7,
#  'SURVEY': 9,
#  'CARRIED': 28,
#  'AGED': 28,
#  'TRANSIENTLY': 1,
#  'DEAF': 1,
#  'EUSTACHIAN': 2,
#  'TUBE': 17,
#  'DYSFUNCTION': 26,
#  'SECRETORY': 36,
#  'OTITIS': 8,
#  'GAVE': 31,
#  'POLYPECTOMY': 1,
#  'THOUGH': 16,
#  'MIDDLE': 14,
#  'NEITHER': 15,
#  'DEAFNESS': 1,
#  'TOCOPHEROL': 25,
#  'PRESUMABLY': 12,
#  'STEATORRHOEA': 8,
#  'MUSCULAR': 7,
#  'WEAKNESS': 4,
#  'WASTING': 3,
#  'BIOCHEMICAL': 56,
#  'CREATINURIA': 1,
#  'CREATINE': 7,
#  'POOR': 26,
#  'DIET': 57,
#  'REVERSAL': 2,
#  'INGESTION': 9,
#  'ESTER': 9,
#  'MUSCLE': 18,
#  'FOCAL': 11,
#  'SKELETAL': 3,
#  'RESEMBLING': 6,
#  'NUTRITIONAL': 38,
#  'DYSTROPHY': 3,
#  'CEROID': 1,
#  'PIGMENT': 5,
#  'SMOOTH': 2,
#  'STRENGTH': 8,
#  'BULB': 1,
#  'ERGOGRAPH': 1,
#  'ATTENDING': 4,
#  'BABY': 40,
#  'HOSPITAL': 64,
#  'PRESBYTERIAN': 1,
#  'MEDICAL': 44,
#  'CENTER': 34,
#  'YORK': 5,
#  'DOUBLE': 23,
#  'BLIND': 16,
#  'HALF': 34,
#  'ORALLY': 8,
#  'REMAINDER': 5,
#  'PLACEBO': 9,
#  'RETURNED': 5,
#  'VISCOSITY': 37,
#  'LIQUEFACTION': 2,
#  'NIGHT': 2,
#  'SLEPT': 1,
#  'MORNING': 2,
#  'FOLLOWING': 46,
#  'RANDOMLY': 5,
#  'ALLOCATED': 1,
#  'SUPPLIED': 3,
#  'JET': 1,
#  'ULTRASONIC': 3,
#  'NEBULIZER': 3,
#  'ANALYSED': 9,
#  'DNA': 30,
#  'PURULENCE': 2,
#  'RELATION': 23,
#  'FURTHERMORE': 21,
#  'CONSISTENT': 46,
#  'EXPECTORATED': 3,
#  'ABSENCE': 47,
#  'STAY': 2,
#  'NEBULIZATION': 3,
#  'SUGGEST': 116,
#  'CONSISTENTLY': 16,
#  'SISTER': 3,
#  'FATAL': 15,
#  'OBSTRUCTIVE': 38,
#  'ORIGIN': 27,
#  'CLINICALLY': 30,
#  'HISTOLOGICALLY': 4,
#  'GLAND': 137,
#  'SHOWED': 128,
#  'EXPECTED': 27,
#  'BOWEL': 29,
#  'SYMPTOM': 99,
#  'PANCREAS': 113,
#  'NECROPSY': 4,
#  'ACETATE': 4,
#  'STRIP': 17,
#  'ELECTROPHORESIS': 33,
#  'SUFFICIENTLY': 6,
#  'DIFFERENTIATE': 9,
#  'MECONIUM': 171,
#  'MARKED': 27,
#  'QUANTITATIVE': 40,
#  'IMMUNOELECTROPHORETIC': 4,
#  'CONTAIN': 10,
#  'ALPHA': 193,
#  'ANTITRYPSIN': 24,
#  'ANTICHYMOTRYPSIN': 3,
#  'SAMPLE': 149,
#  'CONTAINED': 29,
#  'ALBUMIN': 75,
#  'AMOUNT': 83,
#  'VARIETY': 42,
#  'CONFIRMING': 5,
#  'SPECIMEN': 59,
#  'SCREENED': 10,
#  'COEXISTENCE': 4,
#  'PREDISPOSE': 6,
#  'LATER': 24,
#  'LARGELY': 5,
#  ...}

# %% [markdown]
# ### Pesos TF-IDF

# %%
# %store -r n_words
N = len(n_words.keys())

# %%
def compute_tfidf(li, type_of_tf='relative'):
    tf = {}
    idf = {}
    tfidf = {}
    for word, list_of_docs in li.items():
        word_occurrence = Counter(list_of_docs)
        df = len(set(li[word]))
        idf[word] = np.log(N / df)
        for doc in list_of_docs:
            tf[doc, word] = word_occurrence[doc]
            if type_of_tf == 'relative':
                tf[doc, word] = tf[doc, word] / n_words[doc]
                tfidf[doc, word] = tf[doc, word] * idf[word]
            elif type_of_tf == 'absolute':
                tfidf[doc, word] = tf[doc, word] * idf[word]
    return tfidf

# %%
tfidf = compute_tfidf(li)
tfidf
# Out:
# {('00001 ', 'SIGNIFICANCE'): 0.04154799294201786,
#  ('00074 ', 'SIGNIFICANCE'): 0.08781734871835592,
#  ('00078 ', 'SIGNIFICANCE'): 0.07576398712956198,
#  ('00121 ', 'SIGNIFICANCE'): 0.034194365872634164,
#  ('00147 ', 'SIGNIFICANCE'): 0.04067329835376485,
#  ('00157 ', 'SIGNIFICANCE'): 0.14310975346695037,
#  ('00179', 'SIGNIFICANCE'): 0.034194365872634164,
#  ('00185', 'SIGNIFICANCE'): 0.028621950693390078,
#  ('00195', 'SIGNIFICANCE'): 0.0536661575501064,
#  ('00205', 'SIGNIFICANCE'): 0.03018721362193485,
#  ('00223', 'SIGNIFICANCE'): 0.058544899145570616,
#  ('00258', 'SIGNIFICANCE'): 0.019514966381856874,
#  ('00319', 'SIGNIFICANCE'): 0.052215720859562983,
#  ('00355', 'SIGNIFICANCE'): 0.04246113564404023,
#  ('00402 ', 'SIGNIFICANCE'): 0.12879877812025536,
#  ('00411 ', 'SIGNIFICANCE'): 0.031933581352129425,
#  ('00412 ', 'SIGNIFICANCE'): 0.08221198603420554,
#  ('00485 ', 'SIGNIFICANCE'): 0.0633436613706174,
#  ('00526 ', 'SIGNIFICANCE'): 0.0330253277231424,
#  ('00555 ', 'SIGNIFICANCE'): 0.06899934542156537,
#  ('00593 ', 'SIGNIFICANCE'): 0.07576398712956198,
#  ('00631 ', 'SIGNIFICANCE'): 0.03219969453006384,
#  ('00809 ', 'SIGNIFICANCE'): 0.09659908359019152,
#  ('00858 ', 'SIGNIFICANCE'): 0.0434153184675018,
#  ('00923 ', 'SIGNIFICANCE'): 0.07025387897468473,
#  ('01151 ', 'SIGNIFICANCE'): 0.031414336126891554,
#  ('00001 ', 'PSEUDOMONAS'): 0.09178689556816409,
#  ('00007 ', 'PSEUDOMONAS'): 0.020922012960390344,
#  ('00008 ', 'PSEUDOMONAS'): 0.01580774312562826,
#  ('00018 ', 'PSEUDOMONAS'): 0.03897799674812448,
#  ('00061 ', 'PSEUDOMONAS'): 0.05126835608311869,
#  ('00062 ', 'PSEUDOMONAS'): 0.1305226496611508,
#  ('00079 ', 'PSEUDOMONAS'): 0.040075968487508266,
#  ('00080 ', 'PSEUDOMONAS'): 0.05690787525226174,
#  ('00081 ', 'PSEUDOMONAS'): 0.15380506824935605,
#  ('00082 ', 'PSEUDOMONAS'): 0.1816208784646651,
#  ('00123 ', 'PSEUDOMONAS'): 0.098117026297003,
#  ('00135 ', 'PSEUDOMONAS'): 0.03161548625125652,
#  ('00148 ', 'PSEUDOMONAS'): 0.03647940721298829,
#  ('00152 ', 'PSEUDOMONAS'): 0.0406484823230441,
#  ('00159 ', 'PSEUDOMONAS'): 0.042468563621090846,
#  ('00160 ', 'PSEUDOMONAS'): 0.043775288655585956,
#  ('00161 ', 'PSEUDOMONAS'): 0.047423229376884785,
#  ('00176', 'PSEUDOMONAS'): 0.03695316574822191,
#  ('00177', 'PSEUDOMONAS'): 0.0669504414732491,
#  ('00178', 'PSEUDOMONAS'): 0.025634178041559343,
#  ('00188', 'PSEUDOMONAS'): 0.11613852092298313,
#  ('00200', 'PSEUDOMONAS'): 0.08368805184156138,
#  ('00250', 'PSEUDOMONAS'): 0.026592465071150345,
#  ('00260', 'PSEUDOMONAS'): 0.018969291750753913,
#  ('00265', 'PSEUDOMONAS'): 0.05173443204751067,
#  ('00271', 'PSEUDOMONAS'): 0.05368667476628466,
#  ('00282', 'PSEUDOMONAS'): 0.21887644327792977,
#  ('00384 ', 'PSEUDOMONAS'): 0.11855807344221195,
#  ('00394 ', 'PSEUDOMONAS'): 0.050810602903805124,
#  ('00427 ', 'PSEUDOMONAS'): 0.13549494107681365,
#  ('00447 ', 'PSEUDOMONAS'): 0.02845393762613087,
#  ('00458 ', 'PSEUDOMONAS'): 0.024319604808658864,
#  ('00459 ', 'PSEUDOMONAS'): 0.06054029282155504,
#  ('00460 ', 'PSEUDOMONAS'): 0.03897799674812448,
#  ('00469 ', 'PSEUDOMONAS'): 0.043775288655585956,
#  ('00479 ', 'PSEUDOMONAS'): 0.0490585131485015,
#  ('00505 ', 'PSEUDOMONAS'): 0.021076990834171014,
#  ('00550 ', 'PSEUDOMONAS'): 0.03768733460414685,
#  ('00556 ', 'PSEUDOMONAS'): 0.098117026297003,
#  ('00590 ', 'PSEUDOMONAS'): 0.09645402585129108,
#  ('00611 ', 'PSEUDOMONAS'): 0.028741351137505932,
#  ('00668 ', 'PSEUDOMONAS'): 0.04516498035893789,
#  ('00696 ', 'PSEUDOMONAS'): 0.037938583501507826,
#  ('00753 ', 'PSEUDOMONAS'): 0.05126835608311869,
#  ('00778 ', 'PSEUDOMONAS'): 0.1580774312562826,
#  ('00800 ', 'PSEUDOMONAS'): 0.08451664641425011,
#  ('00802 ', 'PSEUDOMONAS'): 0.10943822163896488,
#  ('00842 ', 'PSEUDOMONAS'): 0.03347522073662455,
#  ('00865 ', 'PSEUDOMONAS'): 0.03428185256160346,
#  ('00884 ', 'PSEUDOMONAS'): 0.05471911081948244,
#  ('00890 ', 'PSEUDOMONAS'): 0.04094091744767032,
#  ('00905 ', 'PSEUDOMONAS'): 0.194004120178165,
#  ('00912 ', 'PSEUDOMONAS'): 0.0812969646460882,
#  ('00913 ', 'PSEUDOMONAS'): 0.03197071643385491,
#  ('00922 ', 'PSEUDOMONAS'): 0.02735955540974122,
#  ('00987 ', 'PSEUDOMONAS'): 0.03387373526920341,
#  ('00989 ', 'PSEUDOMONAS'): 0.017564159028475846,
#  ('01000 ', 'PSEUDOMONAS'): 0.01625939292921764,
#  ('01010 ', 'PSEUDOMONAS'): 0.05690787525226174,
#  ('01042 ', 'PSEUDOMONAS'): 0.07203528512944524,
#  ('01065 ', 'PSEUDOMONAS'): 0.14591762885195317,
#  ('01071 ', 'PSEUDOMONAS'): 0.098117026297003,
#  ('01077 ', 'PSEUDOMONAS'): 0.09032996071787577,
#  ('01086 ', 'PSEUDOMONAS'): 0.021076990834171014,
#  ('01090 ', 'PSEUDOMONAS'): 0.03161548625125652,
#  ('01091 ', 'PSEUDOMONAS'): 0.13132586596675785,
#  ('01112 ', 'PSEUDOMONAS'): 0.023711614688442392,
#  ('01171 ', 'PSEUDOMONAS'): 0.026346238542713767,
#  ('01180 ', 'PSEUDOMONAS'): 0.0406484823230441,
#  ('01192 ', 'PSEUDOMONAS'): 0.045893447784082046,
#  ('01203 ', 'PSEUDOMONAS'): 0.07487878322666018,
#  ('01227 ', 'PSEUDOMONAS'): 0.03347522073662455,
#  ('00001 ', 'AERUGINOSA'): 0.09134194969292746,
#  ('00006 ', 'AERUGINOSA'): 0.14646209174900437,
#  ('00007 ', 'AERUGINOSA'): 0.12492354884473904,
#  ('00008 ', 'AERUGINOSA'): 0.07865556779113198,
#  ('00018 ', 'AERUGINOSA'): 0.03878904712987331,
#  ('00062 ', 'AERUGINOSA'): 0.025977985692483958,
#  ('00079 ', 'AERUGINOSA'): 0.039881696344799315,
#  ('00080 ', 'AERUGINOSA'): 0.11326401761923005,
#  ('00081 ', 'AERUGINOSA'): 0.03826487081730745,
#  ('00110 ', 'AERUGINOSA'): 0.04882069724966812,
#  ('00123 ', 'AERUGINOSA'): 0.0650942629995575,
#  ('00135 ', 'AERUGINOSA'): 0.031462227116452794,
#  ('00148 ', 'AERUGINOSA'): 0.03630256974975322,
#  ('00159 ', 'AERUGINOSA'): 0.12678807942451126,
#  ('00160 ', 'AERUGINOSA'): 0.04356308369970387,
#  ('00161 ', 'AERUGINOSA'): 0.14158002202403758,
#  ('00176', 'AERUGINOSA'): 0.03677403169455522,
#  ('00177', 'AERUGINOSA'): 0.06662589271719414,
#  ('00178', 'AERUGINOSA'): 0.12754956939102483,
#  ('00200', 'AERUGINOSA'): 0.04164118294824634,
#  ('00250', 'AERUGINOSA'): 0.02646355551851169,
#  ('00260', 'AERUGINOSA'): 0.0755093450794867,
#  ('00265', 'AERUGINOSA'): 0.1029672887447546,
#  ('00271', 'AERUGINOSA'): 0.05342642340529719,
#  ('00282', 'AERUGINOSA'): 0.10890770924925967,
#  ('00346', 'AERUGINOSA'): 0.056071295851103986,
#  ('00394 ', 'AERUGINOSA'): 0.050564293580013416,
#  ('00447 ', 'AERUGINOSA'): 0.14158002202403758,
#  ('00451 ', 'AERUGINOSA'): 0.08941896127833952,
#  ('00458 ', 'AERUGINOSA'): 0.07260513949950644,
#  ('00459 ', 'AERUGINOSA'): 0.06024681788256918,
#  ('00460 ', 'AERUGINOSA'): 0.15515618851949323,
#  ('00469 ', 'AERUGINOSA'): 0.34850466959763093,
#  ('00479 ', 'AERUGINOSA'): 0.09764139449933625,
#  ('00505 ', 'AERUGINOSA'): 0.020974818077635196,
#  ('00550 ', 'AERUGINOSA'): 0.01875232079788577,
#  ('00588 ', 'AERUGINOSA'): 0.18877336269871675,
#  ('00589 ', 'AERUGINOSA'): 0.1427697701082732,
#  ('00590 ', 'AERUGINOSA'): 0.09598645560951699,
#  ('00591 ', 'AERUGINOSA'): 0.09764139449933625,
#  ('00611 ', 'AERUGINOSA'): 0.028602024651320723,
#  ('00668 ', 'AERUGINOSA'): 0.0898920774755794,
#  ('00696 ', 'AERUGINOSA'): 0.03775467253974335,
#  ('00753 ', 'AERUGINOSA'): 0.0765297416346149,
#  ('00778 ', 'AERUGINOSA'): 0.15731113558226395,
#  ('00790 ', 'AERUGINOSA'): 0.18877336269871675,
#  ('00800 ', 'AERUGINOSA'): 0.056071295851103986,
#  ('00802 ', 'AERUGINOSA'): 0.10890770924925967,
#  ('00842 ', 'AERUGINOSA'): 0.03331294635859707,
#  ('00874 ', 'AERUGINOSA'): 0.05899167584334898,
#  ('00884 ', 'AERUGINOSA'): 0.1633615638738895,
#  ('00890 ', 'AERUGINOSA'): 0.101856130952545,
#  ('00905 ', 'AERUGINOSA'): 0.032177277732735814,
#  ('00912 ', 'AERUGINOSA'): 0.28316004404807515,
#  ('00917 ', 'AERUGINOSA'): 0.08757527135507479,
#  ('00922 ', 'AERUGINOSA'): 0.08168078193694475,
#  ('00945 ', 'AERUGINOSA'): 0.07168608710077852,
#  ('00983 ', 'AERUGINOSA'): 0.15558244178465666,
#  ('00987 ', 'AERUGINOSA'): 0.10112858716002683,
#  ('00988 ', 'AERUGINOSA'): 0.07939066655553509,
#  ('00989 ', 'AERUGINOSA'): 0.08739507532347997,
#  ('01000 ', 'AERUGINOSA'): 0.016180573945604293,
#  ('01065 ', 'AERUGINOSA'): 0.03630256974975322,
#  ('01071 ', 'AERUGINOSA'): 0.03254713149977875,
#  ('01077 ', 'AERUGINOSA'): 0.0449460387377897,
#  ('01078 ', 'AERUGINOSA'): 0.03254713149977875,
#  ('01086 ', 'AERUGINOSA'): 0.08389927231054078,
#  ('01091 ', 'AERUGINOSA'): 0.08712616739940773,
#  ('01112 ', 'AERUGINOSA'): 0.07079001101201879,
#  ('01171 ', 'AERUGINOSA'): 0.07865556779113198,
#  ('01173 ', 'AERUGINOSA'): 0.086461082152084,
#  ('01203 ', 'AERUGINOSA'): 0.03725790053264146,
#  ('01227 ', 'AERUGINOSA'): 0.03331294635859707,
#  ('00001 ', 'INFECTION'): 0.07530864964022892,
#  ('00006 ', 'INFECTION'): 0.06037676221156284,
#  ('00016 ', 'INFECTION'): 0.06670194682420276,
#  ('00018 ', 'INFECTION'): 0.015990192731829427,
#  ('00048 ', 'INFECTION'): 0.0481354255432391,
#  ('00057 ', 'INFECTION'): 0.09727367245196235,
#  ('00058 ', 'INFECTION'): 0.04716299270398175,
#  ('00061 ', 'INFECTION'): 0.021032145395018888,
#  ('00062 ', 'INFECTION'): 0.19276250687728322,
#  ('00079 ', 'INFECTION'): 0.03288124139221263,
#  ('00081 ', 'INFECTION'): 0.031548218092528335,
#  ('00104 ', 'INFECTION'): 0.014410914437327756,
#  ('00111 ', 'INFECTION'): 0.1485634270175425,
#  ('00123 ', 'INFECTION'): 0.026834116538472372,
#  ('00133 ', 'INFECTION'): 0.03890946898078494,
#  ('00146 ', 'INFECTION'): 0.04669136277694193,
#  ('00159 ', 'INFECTION'): 0.03484430057980741,
#  ('00160 ', 'INFECTION'): 0.10774929871601985,
#  ('00176', 'INFECTION'): 0.030319066738273982,
#  ('00179', 'INFECTION'): 0.0206598950340451,
#  ('00187', 'INFECTION'): 0.031127575184627956,
#  ('00188', 'INFECTION'): 0.11911061932893349,
#  ('00200', 'INFECTION'): 0.10299565318443073,
#  ('00202', 'INFECTION'): 0.02406771277161955,
#  ('00212', 'INFECTION'): 0.04323274331198326,
#  ('00213', 'INFECTION'): 0.029930360754449954,
#  ('00238', 'INFECTION'): 0.029182101735588706,
#  ('00247', 'INFECTION'): 0.03335097341210138,
#  ('00253', 'INFECTION'): 0.02406771277161955,
#  ('00262', 'INFECTION'): 0.08979108226334986,
#  ('00270', 'INFECTION'): 0.0409573357692473,
#  ('00271', 'INFECTION'): 0.04404845544994521,
#  ('00276', 'INFECTION'): 0.033834320852856474,
#  ('00282', 'INFECTION'): 0.08979108226334986,
#  ('00326', 'INFECTION'): 0.020300592511713882,
#  ('00331', 'INFECTION'): 0.0481354255432391,
#  ('00333', 'INFECTION'): 0.011614766859935803,
#  ('00347', 'INFECTION'): 0.01852831856227854,
#  ('00377 ', 'INFECTION'): 0.02510288321340964,
#  ('00382 ', 'INFECTION'): 0.03956895150588299,
#  ('00396 ', 'INFECTION'): 0.05075148127928471,
#  ('00417 ', 'INFECTION'): 0.03242455748398745,
#  ('00427 ', 'INFECTION'): 0.16675486706050688,
#  ('00429 ', 'INFECTION'): 0.01716594219740512,
#  ('00432 ', 'INFECTION'): 0.1255144160670482,
#  ('00437 ', 'INFECTION'): 0.023114536028189074,
#  ('00438 ', 'INFECTION'): 0.031548218092528335,
#  ('00452 ', 'INFECTION'): 0.07869330805102571,
#  ('00457 ', 'INFECTION'): 0.03484430057980741,
#  ('00458 ', 'INFECTION'): 0.039907147672599945,
#  ('00459 ', 'INFECTION'): 0.09934332505732325,
#  ('00463 ', 'INFECTION'): 0.01961821965417728,
#  ('00475 ', 'INFECTION'): 0.03335097341210138,
#  ('00487 ', 'INFECTION'): 0.15061729928045783,
#  ('00499 ', 'INFECTION'): 0.04669136277694193,
#  ('00505 ', 'INFECTION'): 0.017293097324793307,
#  ('00510 ', 'INFECTION'): 0.03242455748398745,
#  ('00517 ', 'INFECTION'): 0.10733646615388949,
#  ('00550 ', 'INFECTION'): 0.03092143230261055,
#  ('00556 ', 'INFECTION'): 0.04025117480770856,
#  ('00588 ', 'INFECTION'): 0.06917238929917323,
#  ('00590 ', 'INFECTION'): 0.15827580602353197,
#  ('00592 ', 'INFECTION'): 0.06968860115961482,
#  ('00598 ', 'INFECTION'): 0.04764424773157339,
#  ('00600 ', 'INFECTION'): 0.04489554113167493,
#  ('00609 ', 'INFECTION'): 0.13340389364840552,
#  ('00611 ', 'INFECTION'): 0.023581496351990874,
#  ('00618 ', 'INFECTION'): 0.06309643618505667,
#  ('00643 ', 'INFECTION'): 0.014869860756987876,
#  ('00670 ', 'INFECTION'): 0.04967166252866163,
#  ('00680 ', 'INFECTION'): 0.026834116538472372,
#  ('00682 ', 'INFECTION'): 0.06143600365387095,
#  ('00696 ', 'INFECTION'): 0.031127575184627956,
#  ('00733 ', 'INFECTION'): 0.04323274331198326,
#  ('00745 ', 'INFECTION'): 0.010960413797404209,
#  ('00753 ', 'INFECTION'): 0.042064290790037775,
#  ('00754 ', 'INFECTION'): 0.025375740639642354,
#  ('00761 ', 'INFECTION'): 0.30718001826935476,
#  ('00767 ', 'INFECTION'): 0.02847034315667191,
#  ('00768 ', 'INFECTION'): 0.03705663712455708,
#  ('00769 ', 'INFECTION'): 0.13896238921708906,
#  ('00776 ', 'INFECTION'): 0.020300592511713882,
#  ('00782 ', 'INFECTION'): 0.018676545110776772,
#  ('00784 ', 'INFECTION'): 0.10150296255856942,
#  ('00790 ', 'INFECTION'): 0.09338272555388386,
#  ('00800 ', 'INFECTION'): 0.0924581441127563,
#  ('00804 ', 'INFECTION'): 0.01525861528658233,
#  ('00812 ', 'INFECTION'): 0.07781893796156988,
#  ('00863 ', 'INFECTION'): 0.06309643618505667,
#  ('00865 ', 'INFECTION'): 0.028127326974061406,
#  ('00874 ', 'INFECTION'): 0.09727367245196235,
#  ('00879 ', 'INFECTION'): 0.02084435838256336,
#  ('00887 ', 'INFECTION'): 0.029930360754449954,
#  ('00890 ', 'INFECTION'): 0.03359090847262009,
#  ('00903 ', 'INFECTION'): 0.13732753757924096,
#  ('00905 ', 'INFECTION'): 0.026529183395989732,
#  ('00917 ', 'INFECTION'): 0.02406771277161955,
#  ('00922 ', 'INFECTION'): 0.04489554113167493,
#  ('00945 ', 'INFECTION'): 0.02955149542844426,
#  ('00983 ', 'INFECTION'): 0.02565459493238568,
#  ('00987 ', 'INFECTION'): 0.027792477843417814,
#  ('00988 ', 'INFECTION'): 0.0436367876420018,
#  ('00989 ', 'INFECTION'): 0.057643657749311024,
#  ('01021 ', 'INFECTION'): 0.028821828874655512,
#  ('01042 ', 'INFECTION'): 0.02955149542844426,
#  ('01063 ', 'INFECTION'): 0.06309643618505667,
#  ('01065 ', 'INFECTION'): 0.11972144301779981,
#  ('01071 ', 'INFECTION'): 0.026834116538472372,
#  ('01080 ', 'INFECTION'): 0.09338272555388386,
#  ('01082 ', 'INFECTION'): 0.10150296255856942,
#  ('01090 ', 'INFECTION'): 0.07781893796156988,
#  ('01091 ', 'INFECTION'): 0.1436657316213598,
#  ('01095 ', 'INFECTION'): 0.05429228229876969,
#  ('01102 ', 'INFECTION'): 0.10858456459753937,
#  ('01143 ', 'INFECTION'): 0.02510288321340964,
#  ('01169 ', 'INFECTION'): 0.03537224452798631,
#  ('01170 ', 'INFECTION'): 0.12474791581625706,
#  ('01171 ', 'INFECTION'): 0.0648491149679749,
#  ('01173 ', 'INFECTION'): 0.017821130830893865,
#  ('01228 ', 'INFECTION'): 0.05694068631334382,
#  ('00001 ', 'RESPIRATORY'): 0.07961611391843933,
#  ('00006 ', 'RESPIRATORY'): 0.042553440197786535,
#  ('00007 ', 'RESPIRATORY'): 0.03629558134517087,
#  ('00008 ', 'RESPIRATORY'): 0.013711664063731218,
#  ('00011 ', 'RESPIRATORY'): 0.09492690505660074,
#  ('00015 ', 'RESPIRATORY'): 0.05484665625492487,
#  ('00017 ', 'RESPIRATORY'): 0.04656791568814376,
#  ('00025 ', 'RESPIRATORY'): 0.14518232538068349,
#  ('00031 ', 'RESPIRATORY'): 0.025444325066717722,
#  ('00037 ', 'RESPIRATORY'): 0.021276720098893268,
#  ('00056 ', 'RESPIRATORY'): 0.029036465076136695,
#  ('00080 ', 'RESPIRATORY'): 0.04936199062943238,
#  ('00099 ', 'RESPIRATORY'): 0.04329999178020384,
#  ('00103 ', 'RESPIRATORY'): 0.026827168820343687,
#  ('00110 ', 'RESPIRATORY'): 0.042553440197786535,
#  ('00118 ', 'RESPIRATORY'): 0.02164999589010192,
#  ('00133 ', 'RESPIRATORY'): 0.04113499219119365,
#  ('00135 ', 'RESPIRATORY'): 0.027423328127462437,
#  ('00148 ', 'RESPIRATORY'): 0.06328460337106716,
#  ('00159 ', 'RESPIRATORY'): 0.036837306439874914,
#  ('00160 ', 'RESPIRATORY'): 0.1898538101132015,
#  ('00176', 'RESPIRATORY'): 0.03205324066846259,
#  ('00177', 'RESPIRATORY'): 0.029036465076136695,
#  ('00179', 'RESPIRATORY'): 0.021841588774085124,
#  ('00187', 'RESPIRATORY'): 0.032907993752954924,
#  ('00206', 'RESPIRATORY'): 0.0333526963712381,
#  ('00212', 'RESPIRATORY'): 0.04570554687910406,
#  ('00219', 'RESPIRATORY'): 0.019433854578516686,
#  ('00223', 'RESPIRATORY'): 0.037395447446539685,
#  ('00243', 'RESPIRATORY'): 0.025444325066717722,
#  ('00265', 'RESPIRATORY'): 0.04487453693584762,
#  ('00271', 'RESPIRATORY'): 0.04656791568814376,
#  ('00297', 'RESPIRATORY'): 0.04046064805691179,
#  ('00307', 'RESPIRATORY'): 0.009007662523619047,
#  ('00322', 'RESPIRATORY'): 0.020230324028455895,
#  ('00325', 'RESPIRATORY'): 0.020397516789021648,
#  ('00331', 'RESPIRATORY'): 0.025444325066717722,
#  ('00333', 'RESPIRATORY'): 0.024558204293249942,
#  ('00346', 'RESPIRATORY'): 0.04887325804894296,
#  ('00358 ', 'RESPIRATORY'): 0.018557139334373075,
#  ('00370 ', 'RESPIRATORY'): 0.014103425894123538,
#  ('00403 ', 'RESPIRATORY'): 0.05141874023899207,
#  ('00417 ', 'RESPIRATORY'): 0.03427916015932804,
#  ('00439 ', 'RESPIRATORY'): 0.029736138933393004,
#  ('00447 ', 'RESPIRATORY'): 0.02468099531471619,
#  ('00452 ', 'RESPIRATORY'): 0.055462910819586944,
#  ('00457 ', 'RESPIRATORY'): 0.07367461287974983,
#  ('00459 ', 'RESPIRATORY'): 0.052512755988757855,
#  ('00473 ', 'RESPIRATORY'): 0.024930298297693124,
#  ('00511 ', 'RESPIRATORY'): 0.025979995068122305,
#  ('00550 ', 'RESPIRATORY'): 0.016345030009745822,
#  ('00552 ', 'RESPIRATORY'): 0.029036465076136695,
#  ('00555 ', 'RESPIRATORY'): 0.08814641183827211,
#  ('00556 ', 'RESPIRATORY'): 0.042553440197786535,
#  ('00571 ', 'RESPIRATORY'): 0.03085124414339524,
#  ('00589 ', 'RESPIRATORY'): 0.020740332197240495,
#  ('00590 ', 'RESPIRATORY'): 0.08366439089734302,
#  ('00598 ', 'RESPIRATORY'): 0.05036937819329835,
#  ('00606 ', 'RESPIRATORY'): 0.03404275215822923,
#  ('00614 ', 'RESPIRATORY'): 0.048394108460227826,
#  ('00627 ', 'RESPIRATORY'): 0.02468099531471619,
#  ('00682 ', 'RESPIRATORY'): 0.06494998767030577,
#  ('00711 ', 'RESPIRATORY'): 0.04487453693584762,
#  ('00716 ', 'RESPIRATORY'): 0.027121972873314498,
#  ('00726 ', 'RESPIRATORY'): 0.01582115084276679,
#  ('00731 ', 'RESPIRATORY'): 0.04570554687910406,
#  ('00733 ', 'RESPIRATORY'): 0.09141109375820812,
#  ('00736 ', 'RESPIRATORY'): 0.12340497657358096,
#  ('00754 ', 'RESPIRATORY'): 0.026827168820343687,
#  ('00761 ', 'RESPIRATORY'): 0.22732495684607018,
#  ('00767 ', 'RESPIRATORY'): 0.030098774774044136,
#  ('00768 ', 'RESPIRATORY'): 0.0783523660784641,
#  ('00769 ', 'RESPIRATORY'): 0.05876427455884807,
#  ('00778 ', 'RESPIRATORY'): 0.019588091519616026,
#  ('00787 ', 'RESPIRATORY'): 0.07259116269034174,
#  ('00820 ', 'RESPIRATORY'): 0.04570554687910406,
#  ('00821 ', 'RESPIRATORY'): 0.03629558134517087,
#  ('00822 ', 'RESPIRATORY'): 0.026256377994378927,
#  ('00842 ', 'RESPIRATORY'): 0.029036465076136695,
#  ('00860 ', 'RESPIRATORY'): 0.01738098261599732,
#  ('00879 ', 'RESPIRATORY'): 0.022036602959568028,
#  ('00887 ', 'RESPIRATORY'): 0.03164230168553358,
#  ('00910 ', 'RESPIRATORY'): 0.0705171294706177,
#  ('00912 ', 'RESPIRATORY'): 0.10577569420592654,
#  ('00913 ', 'RESPIRATORY'): 0.027731455409793472,
#  ('00914 ', 'RESPIRATORY'): 0.03047036458606937,
#  ('00969 ', 'RESPIRATORY'): 0.023066350761417,
#  ('00980 ', 'RESPIRATORY'): 0.089208416800179,
#  ('00985 ', 'RESPIRATORY'): 0.021276720098893268,
#  ('01019 ', 'RESPIRATORY'): 0.04046064805691179,
#  ('01039 ', 'RESPIRATORY'): 0.03476196523199464,
#  ('01067 ', 'RESPIRATORY'): 0.08814641183827211,
#  ('01073 ', 'RESPIRATORY'): 0.03525856473530885,
#  ('01078 ', 'RESPIRATORY'): 0.02836896013185769,
#  ('01079 ', 'RESPIRATORY'): 0.037395447446539685,
#  ('01080 ', 'RESPIRATORY'): 0.09872398125886477,
#  ('01091 ', 'RESPIRATORY'): 0.0379707620226403,
#  ('01112 ', 'RESPIRATORY'): 0.06170248828679048,
#  ('01169 ', 'RESPIRATORY'): 0.037395447446539685,
#  ('01170 ', 'RESPIRATORY'): 0.0753618177548586,
#  ('01173 ', 'RESPIRATORY'): 0.0376809088774293,
#  ('01192 ', 'RESPIRATORY'): 0.03980805695921966,
#  ('01197 ', 'RESPIRATORY'): 0.01713958007966402,
#  ('01216 ', 'RESPIRATORY'): 0.02223513091415873,
#  ('01234 ', 'RESPIRATORY'): 0.025184689096649174,
#  ('00001 ', 'TRACT'): 0.10106696242144736,
#  ('00006 ', 'TRACT'): 0.054018548880428764,
#  ('00007 ', 'TRACT'): 0.046074644633306884,
#  ('00008 ', 'TRACT'): 0.01740597686147149,
#  ('00017 ', 'TRACT'): 0.05911463839745034,
#  ('00025 ', 'TRACT'): 0.09214928926661377,
#  ('00031 ', 'TRACT'): 0.032299750876957405,
#  ('00048 ', 'TRACT'): 0.032299750876957405,
#  ('00056 ', 'TRACT'): 0.03685971570664551,
#  ('00080 ', 'TRACT'): 0.06266151670129737,
#  ('00134 ', 'TRACT'): 0.03333059399005179,
#  ('00135 ', 'TRACT'): 0.03481195372294298,
#  ('00139 ', 'TRACT'): 0.021169431318005867,
#  ('00152 ', 'TRACT'): 0.0447582262152124,
#  ('00159 ', 'TRACT'): 0.04676232589649057,
#  ('00160 ', 'TRACT'): 0.048201166693305666,
#  ('00176', 'TRACT'): 0.04068929655928401,
#  ('00177', 'TRACT'): 0.03685971570664551,
#  ('00179', 'TRACT'): 0.027726334823582905,
#  ('00202', 'TRACT'): 0.032299750876957405,
#  ('00223', 'TRACT'): 0.04747084598583134,
#  ('00265', 'TRACT'): 0.056965015182997604,
#  ('00271', 'TRACT'): 0.11822927679490068,
#  ('00297', 'TRACT'): 0.025680949467744824,
#  ('00322', 'TRACT'): 0.025680949467744824,
#  ('00325', 'TRACT'): 0.025893188719544366,
#  ('00333', 'TRACT'): 0.031174883930993713,
#  ('00345', 'TRACT'): 0.025472161260689987,
#  ('00417 ', 'TRACT'): 0.04351494215367872,
#  ('00439 ', 'TRACT'): 0.03774790162728757,
#  ('00447 ', 'TRACT'): 0.031330758350648684,
#  ('00497 ', 'TRACT'): 0.053102980255336746,
#  ('00511 ', 'TRACT'): 0.03297974563226177,
#  ('00555 ', 'TRACT'): 0.111895565538031,
#  ('00589 ', 'TRACT'): 0.026328368361889648,
#  ('00590 ', 'TRACT'): 0.10620596051067349,
#  ('00614 ', 'TRACT'): 0.06143285951107585,
#  ('00733 ', 'TRACT'): 0.05801992287157163,
#  ('00754 ', 'TRACT'): 0.0340551721202703,
#  ('00761 ', 'TRACT'): 0.20612341020163605,
#  ('00769 ', 'TRACT'): 0.07459704369202066,
#  ('00778 ', 'TRACT'): 0.024865681230673557,
#  ('00872 ', 'TRACT'): 0.06025145836663209,
#  ('00912 ', 'TRACT'): 0.13427467864563722,
#  ('00935 ', 'TRACT'): 0.05496624272043628,
#  ('00969 ', 'TRACT'): 0.0292810825706997,
#  ('00980 ', 'TRACT'): 0.03774790162728757,
#  ('01019 ', 'TRACT'): 0.05136189893548965,
#  ('01078 ', 'TRACT'): 0.03601236592028584,
#  ('01079 ', 'TRACT'): 0.04747084598583134,
#  ('01170 ', 'TRACT'): 0.09566643771190436,
#  ('01173 ', 'TRACT'): 0.02391660942797609,
#  ('01192 ', 'TRACT'): 0.05053348121072368,
#  ('01197 ', 'TRACT'): 0.02175747107683936,
#  ('00001 ', 'CYSTIC'): 0.0016373033519091694,
#  ('00002 ', 'CYSTIC'): 0.0035411444587802967,
#  ('00003 ', 'CYSTIC'): 0.002085879612706202,
#  ('00004 ', 'CYSTIC'): 0.00160283380765845,
#  ('00006 ', 'CYSTIC'): 0.001312665618340972,
#  ('00007 ', 'CYSTIC'): 0.0022392531136404817,
#  ('00008 ', 'CYSTIC'): 0.0025378201954592127,
#  ('00009 ', 'CYSTIC'): 0.005639600434353805,
#  ('00010 ', 'CYSTIC'): 0.015226921172755276,
#  ('00011 ', 'CYSTIC'): 0.0019521693811224712,
#  ('00012 ', 'CYSTIC'): 0.005537062244638282,
#  ('00013 ', 'CYSTIC'): 0.0035411444587802967,
#  ('00014 ', 'CYSTIC'): 0.0008230768201489339,
#  ('00015 ', 'CYSTIC'): 0.006767520521224567,
#  ('00016 ', 'CYSTIC'): 0.004350548906501507,
#  ('00017 ', 'CYSTIC'): 0.005746007989718972,
#  ('00019 ', 'CYSTIC'): 0.01131730627704784,
#  ('00020 ', 'CYSTIC'): 0.0031722752443240155,
#  ('00021 ', 'CYSTIC'): 0.007427766425734281,
#  ('00022 ', 'CYSTIC'): 0.001927458376298136,
#  ('00023 ', 'CYSTIC'): 0.0049653003824201986,
#  ('00024 ', 'CYSTIC'): 0.0022726748019037723,
#  ('00026 ', 'CYSTIC'): 0.008619011984578458,
#  ('00027 ', 'CYSTIC'): 0.003045384234551055,
#  ('00028 ', 'CYSTIC'): 0.005438186133126884,
#  ('00029 ', 'CYSTIC'): 0.006344550488648031,
#  ('00030 ', 'CYSTIC'): 0.004614218537198568,
#  ('00031 ', 'CYSTIC'): 0.001569785687912915,
#  ('00032 ', 'CYSTIC'): 0.008701097813003014,
#  ('00034 ', 'CYSTIC'): 0.005132670058232115,
#  ('00037 ', 'CYSTIC'): 0.002625331236681944,
#  ('00038 ', 'CYSTIC'): 0.003045384234551055,
#  ('00039 ', 'CYSTIC'): 0.0024962165856975862,
#  ('00040 ', 'CYSTIC'): 0.0046852065146939315,
#  ('00041 ', 'CYSTIC'): 0.002455955027863754,
#  ('00043 ', 'CYSTIC'): 0.0035688096498645177,
#  ('00044 ', 'CYSTIC'): 0.009823820111455016,
#  ('00045 ', 'CYSTIC'): 0.006215069866430724,
#  ('00047 ', 'CYSTIC'): 0.002956683722865102,
#  ('00049 ', 'CYSTIC'): 0.002719093066563442,
#  ('00050 ', 'CYSTIC'): 0.006767520521224567,
#  ('00051 ', 'CYSTIC'): 0.010876372266253768,
#  ('00052 ', 'CYSTIC'): 0.006620400509893598,
#  ('00053 ', 'CYSTIC'): 0.008459400651530708,
#  ('00054 ', 'CYSTIC'): 0.004478506227280963,
#  ('00055 ', 'CYSTIC'): 0.0011279200868707612,
#  ('00056 ', 'CYSTIC'): 0.0017914024909123853,
#  ('00057 ', 'CYSTIC'): 0.012689100977296062,
#  ('00058 ', 'CYSTIC'): 0.0015380728457328563,
#  ('00059 ', 'CYSTIC'): 0.0022726748019037723,
#  ('00061 ', 'CYSTIC'): 0.001371794700248223,
#  ('00062 ', 'CYSTIC'): 0.001396965245206906,
#  ('00063 ', 'CYSTIC'): 0.0013475151480314403,
#  ('00064 ', 'CYSTIC'): 0.009930600764840397,
#  ('00065 ', 'CYSTIC'): 0.005639600434353805,
#  ('00066 ', 'CYSTIC'): 0.0022392531136404817,
#  ('00067 ', 'CYSTIC'): 0.004229700325765354,
#  ('00068 ', 'CYSTIC'): 0.0037138832128671404,
#  ('00069 ', 'CYSTIC'): 0.007338275263978447,
#  ('00070 ', 'CYSTIC'): 0.004478506227280963,
#  ('00071 ', 'CYSTIC'): 0.0019033651465944095,
#  ('00072 ', 'CYSTIC'): 0.0023426032573469657,
#  ('00073 ', 'CYSTIC'): 0.0029003659376676716,
#  ('00074 ', 'CYSTIC'): 0.006921327805797853,
#  ('00075 ', 'CYSTIC'): 0.0020302561563673703,
#  ('00076 ', 'CYSTIC'): 0.002455955027863754,
#  ('00077 ', 'CYSTIC'): 0.004350548906501507,
#  ('00078 ', 'CYSTIC'): 0.002985670818187309,
#  ('00080 ', 'CYSTIC'): 0.00609076846910211,
#  ('00082 ', 'CYSTIC'): 0.0032397704622883564,
#  ('00083 ', 'CYSTIC'): 0.002768531122319141,
#  ('00084 ', 'CYSTIC'): 0.0033837602606122835,
#  ('00085 ', 'CYSTIC'): 0.0022392531136404817,
#  ('00088 ', 'CYSTIC'): 0.005537062244638282,
#  ('00089 ', 'CYSTIC'): 0.0013240801019787196,
#  ('00090 ', 'CYSTIC'): 0.002768531122319141,
#  ('00091 ', 'CYSTIC'): 0.0020035422595730623,
#  ('00092 ', 'CYSTIC'): 0.003045384234551055,
#  ('00093 ', 'CYSTIC'): 0.003107534933215362,
#  ('00094 ', 'CYSTIC'): 0.008230768201489339,
#  ('00095 ', 'CYSTIC'): 0.00627914275165166,
#  ('00096 ', 'CYSTIC'): 0.008957012454561927,
#  ('00097 ', 'CYSTIC'): 0.004614218537198568,
#  ('00098 ', 'CYSTIC'): 0.0046852065146939315,
#  ('00099 ', 'CYSTIC'): 0.00801416903829225,
#  ('00100 ', 'CYSTIC'): 0.001553767466607681,
#  ('00101 ', 'CYSTIC'): 0.002625331236681944,
#  ('00102 ', 'CYSTIC'): 0.0015861376221620077,
#  ('00103 ', 'CYSTIC'): 0.008275500637366998,
#  ('00104 ', 'CYSTIC'): 0.0009399334057256342,
#  ('00105 ', 'CYSTIC'): 0.002625331236681944,
#  ('00108 ', 'CYSTIC'): 0.0022068001699645325,
#  ('00109 ', 'CYSTIC'): 0.005639600434353805,
#  ('00110 ', 'CYSTIC'): 0.002625331236681944,
#  ('00111 ', 'CYSTIC'): 0.002768531122319141,
#  ('00112 ', 'CYSTIC'): 0.009172844079973057,
#  ('00113 ', 'CYSTIC'): 0.005075640390918425,
#  ('00115 ', 'CYSTIC'): 0.002379206433243012,
#  ('00116 ', 'CYSTIC'): 0.0053427793588615,
#  ('00118 ', 'CYSTIC'): 0.001335694839715375,
#  ('00119 ', 'CYSTIC'): 0.0031722752443240155,
#  ('00121 ', 'CYSTIC'): 0.0026950302960628805,
#  ('00122 ', 'CYSTIC'): 0.0029003659376676716,
#  ('00123 ', 'CYSTIC'): 0.0017502208244546294,
#  ('00125 ', 'CYSTIC'): 0.005856508143367414,
#  ('00126 ', 'CYSTIC'): 0.00232472078973363,
#  ('00127 ', 'CYSTIC'): 0.003045384234551055,
#  ('00129 ', 'CYSTIC'): 0.007613460586377638,
#  ('00130 ', 'CYSTIC'): 0.012689100977296062,
#  ('00133 ', 'CYSTIC'): 0.01015128078183685,
#  ('00135 ', 'CYSTIC'): 0.006767520521224567,
#  ('00137 ', 'CYSTIC'): 0.0011196265568202408,
#  ('00138 ', 'CYSTIC'): 0.005971341636374618,
#  ('00139 ', 'CYSTIC'): 0.0010288460251861673,
#  ('00140 ', 'CYSTIC'): 0.0012904170485385827,
#  ('00141 ', 'CYSTIC'): 0.0017705722293901484,
#  ('00143 ', 'CYSTIC'): 0.005800731875335343,
#  ('00144 ', 'CYSTIC'): 0.001079923487429452,
#  ('00146 ', 'CYSTIC'): 0.00609076846910211,
#  ('00148 ', 'CYSTIC'): 0.0019521693811224712,
#  ('00150 ', 'CYSTIC'): 0.001359546533281721,
#  ('00151 ', 'CYSTIC'): 0.003045384234551055,
#  ('00153 ', 'CYSTIC'): 0.002873003994859486,
#  ('00154 ', 'CYSTIC'): 0.008957012454561927,
#  ('00155 ', 'CYSTIC'): 0.004115384100744669,
#  ('00157 ', 'CYSTIC'): 0.005639600434353805,
#  ('00158 ', 'CYSTIC'): 0.005075640390918425,
#  ('00159 ', 'CYSTIC'): 0.0022726748019037723,
#  ('00160 ', 'CYSTIC'): 0.0046852065146939315,
#  ('00161 ', 'CYSTIC'): 0.0025378201954592127,
#  ('00163 ', 'CYSTIC'): 0.0075505394245067485,
#  ('00164 ', 'CYSTIC'): 0.003107534933215362,
#  ('00165 ', 'CYSTIC'): 0.0012584232374177914,
#  ('00166 ', 'CYSTIC'): 0.00801416903829225,
#  ('00167 ', 'CYSTIC'): 0.004115384100744669,
#  ('00169', 'CYSTIC'): 0.0032397704622883564,
#  ('00170', 'CYSTIC'): 0.004350548906501507,
#  ('00172', 'CYSTIC'): 0.001312665618340972,
#  ('00173', 'CYSTIC'): 0.008366440204810591,
#  ('00174', 'CYSTIC'): 0.0025808340970771655,
#  ('00175', 'CYSTIC'): 0.00160283380765845,
#  ('00176', 'CYSTIC'): 0.001977522230227958,
#  ('00177', 'CYSTIC'): 0.007165609963649541,
#  ('00179', 'CYSTIC'): 0.0013475151480314403,
#  ('00181', 'CYSTIC'): 0.0019033651465944095,
#  ('00182', 'CYSTIC'): 0.014735730167182524,
#  ('00183', 'CYSTIC'): 0.005639600434353805,
#  ('00184', 'CYSTIC'): 0.005438186133126884,
#  ('00185', 'CYSTIC'): 0.0011279200868707612,
#  ('00186', 'CYSTIC'): 0.006479540924576713,
#  ('00187', 'CYSTIC'): 0.0020302561563673703,
#  ('00188', 'CYSTIC'): 0.004661302399823044,
#  ('00189', 'CYSTIC'): 0.002144636784895109,
#  ('00190', 'CYSTIC'): 0.0018798668114512684,
#  ('00191', 'CYSTIC'): 0.014164577835121187,
#  ('00192', 'CYSTIC'): 0.0024169716147230593,
#  ('00193', 'CYSTIC'): 0.002928254071683707,
#  ('00194', 'CYSTIC'): 0.005438186133126884,
#  ('00195', 'CYSTIC'): 0.006344550488648031,
#  ('00196', 'CYSTIC'): 0.004229700325765354,
#  ('00197', 'CYSTIC'): 0.0014641270358418535,
#  ('00198', 'CYSTIC'): 0.008459400651530708,
#  ('00199', 'CYSTIC'): 0.007613460586377638,
#  ('00200', 'CYSTIC'): 0.0022392531136404817,
#  ('00201', 'CYSTIC'): 0.0021002649893455553,
#  ('00204', 'CYSTIC'): 0.011713016286734828,
#  ('00205', 'CYSTIC'): 0.001189603216621506,
#  ('00207', 'CYSTIC'): 0.008230768201489339,
#  ('00208', 'CYSTIC'): 0.004269230235351946,
#  ('00209', 'CYSTIC'): 0.0036691376319892234,
#  ('00210', 'CYSTIC'): 0.009516825732972047,
#  ('00211', 'CYSTIC'): 0.0025378201954592127,
#  ('00212', 'CYSTIC'): 0.0028198002171769027,
#  ('00213', 'CYSTIC'): 0.0019521693811224712,
#  ('00214', 'CYSTIC'): 0.0077425022912314964,
#  ('00216', 'CYSTIC'): 0.0040605123127347405,
#  ('00217', 'CYSTIC'): 0.004115384100744669,
#  ('00218', 'CYSTIC'): 0.003806730293188819,
#  ('00219', 'CYSTIC'): 0.005994850855415463,
#  ('00220', 'CYSTIC'): 0.002625331236681944,
#  ('00221', 'CYSTIC'): 0.002985670818187309,
#  ('00222', 'CYSTIC'): 0.01114164963860142,
#  ('00223', 'CYSTIC'): 0.002307109268599284,
#  ('00225', 'CYSTIC'): 0.00342178003882141,
#  ('00226', 'CYSTIC'): 0.006921327805797853,
#  ('00227', 'CYSTIC'): 0.006344550488648031,
#  ('00228', 'CYSTIC'): 0.0039043387622449423,
#  ('00229', 'CYSTIC'): 0.003310200254946799,
#  ('00230', 'CYSTIC'): 0.009516825732972047,
#  ('00231', 'CYSTIC'): 0.008957012454561927,
#  ('00232', 'CYSTIC'): 0.002455955027863754,
#  ('00233', 'CYSTIC'): 0.003806730293188819,
#  ('00234', 'CYSTIC'): 0.0040786395998451625,
#  ('00235', 'CYSTIC'): 0.0019521693811224712,
#  ('00236', 'CYSTIC'): 0.0031722752443240155,
#  ('00237', 'CYSTIC'): 0.0034606639028989263,
#  ('00238', 'CYSTIC'): 0.005710095439783228,
#  ('00239', 'CYSTIC'): 0.004478506227280963,
#  ('00240', 'CYSTIC'): 0.01427523859945807,
#  ('00242', 'CYSTIC'): 0.0015380728457328563,
#  ('00243', 'CYSTIC'): 0.00313957137582583,
#  ('00244', 'CYSTIC'): 0.000988761115113979,
#  ('00245', 'CYSTIC'): 0.002455955027863754,
#  ('00246', 'CYSTIC'): 0.002516846474835583,
#  ('00248', 'CYSTIC'): 0.0016918801303061417,
#  ('00249', 'CYSTIC'): 0.004478506227280963,
#  ('00250', 'CYSTIC'): 0.0014230767451173154,
#  ('00252', 'CYSTIC'): 0.002928254071683707,
#  ('00253', 'CYSTIC'): 0.00313957137582583,
#  ('00254', 'CYSTIC'): 0.011713016286734828,
#  ('00255', 'CYSTIC'): 0.004350548906501507,
#  ('00256', 'CYSTIC'): 0.0020302561563673703,
#  ('00258', 'CYSTIC'): 0.002307109268599284,
#  ('00259', 'CYSTIC'): 0.004911910055727508,
#  ('00260', 'CYSTIC'): 0.0010151280781836851,
#  ('00261', 'CYSTIC'): 0.0029003659376676716,
#  ('00262', 'CYSTIC'): 0.005856508143367414,
#  ('00264', 'CYSTIC'): 0.007427766425734281,
#  ('00265', 'CYSTIC'): 0.002768531122319141,
#  ('00266', 'CYSTIC'): 0.002379206433243012,
#  ('00267', 'CYSTIC'): 0.007367865083591262,
#  ('00268', 'CYSTIC'): 0.006499295622517496,
#  ('00272', 'CYSTIC'): 0.003045384234551055,
#  ('00273', 'CYSTIC'): 0.008957012454561927,
#  ('00274', 'CYSTIC'): 0.004478506227280963,
#  ('00275', 'CYSTIC'): 0.0034606639028989263,
#  ('00276', 'CYSTIC'): 0.004413600339929065,
#  ('00277', 'CYSTIC'): 0.003806730293188819,
#  ('00279', 'CYSTIC'): 0.0015076159576985421,
#  ('00280', 'CYSTIC'): 0.0019033651465944095,
#  ('00281', 'CYSTIC'): 0.004087764073222893,
#  ('00282', 'CYSTIC'): 0.005856508143367414,
#  ('00283', 'CYSTIC'): 0.0024169716147230593,
#  ('00285', 'CYSTIC'): 0.004115384100744669,
#  ('00286', 'CYSTIC'): 0.004911910055727508,
#  ('00287', 'CYSTIC'): 0.0022392531136404817,
#  ('00289', 'CYSTIC'): 0.005438186133126884,
#  ('00290', 'CYSTIC'): 0.005710095439783228,
#  ('00291', 'CYSTIC'): 0.001927458376298136,
#  ('00292', 'CYSTIC'): 0.0036254574220845894,
#  ('00293', 'CYSTIC'): 0.0035411444587802967,
#  ('00294', 'CYSTIC'): 0.007488649757092758,
#  ('00295', 'CYSTIC'): 0.0012689100977296064,
#  ('00297', 'CYSTIC'): 0.0049924331713951725,
#  ('00299', 'CYSTIC'): 0.001710890019410705,
#  ('00301', 'CYSTIC'): 0.0048596556934325345,
#  ('00302', 'CYSTIC'): 0.003045384234551055,
#  ('00303', 'CYSTIC'): 0.001553767466607681,
#  ('00304', 'CYSTIC'): 0.003310200254946799,
#  ('00305', 'CYSTIC'): 0.006717759340921446,
#  ('00306', 'CYSTIC'): 0.0008904632264769166,
#  ('00307', 'CYSTIC'): 0.0005557270501005575,
#  ('00308', 'CYSTIC'): 0.005250662473363888,
#  ('00309', 'CYSTIC'): 0.004614218537198568,
#  ('00311', 'CYSTIC'): 0.006767520521224567,
#  ('00312', 'CYSTIC'): 0.0012689100977296064,
#  ('00313', 'CYSTIC'): 0.0013842655611595704,
#  ('00314', 'CYSTIC'): 0.0008852861146950742,
#  ('00315', 'CYSTIC'): 0.002743589400496446,
#  ('00316', 'CYSTIC'): 0.0025808340970771655,
#  ('00317', 'CYSTIC'): 0.007613460586377638,
#  ('00318', 'CYSTIC'): 0.016918801303061417,
#  ('00319', 'CYSTIC'): 0.008230768201489339,
#  ('00320', 'CYSTIC'): 0.001396965245206906,
#  ('00321', 'CYSTIC'): 0.010501324946727775,
#  ('00322', 'CYSTIC'): 0.0012481082928487931,
#  ('00323', 'CYSTIC'): 0.001977522230227958,
#  ('00324', 'CYSTIC'): 0.010501324946727775,
#  ('00325', 'CYSTIC'): 0.0075505394245067485,
#  ('00326', 'CYSTIC'): 0.0013240801019787196,
#  ('00327', 'CYSTIC'): 0.002625331236681944,
#  ('00328', 'CYSTIC'): 0.01436501997429743,
#  ('00331', 'CYSTIC'): 0.007848928439564574,
#  ('00332', 'CYSTIC'): 0.006921327805797853,
#  ('00333', 'CYSTIC'): 0.0037877913365062877,
#  ('00335', 'CYSTIC'): 0.0018345688159946117,
#  ('00336', 'CYSTIC'): 0.002114850162882677,
#  ('00337', 'CYSTIC'): 0.0028198002171769027,
#  ('00338', 'CYSTIC'): 0.013240801019787196,
#  ('00339', 'CYSTIC'): 0.005639600434353805,
#  ('00340', 'CYSTIC'): 0.0053427793588615,
#  ('00341', 'CYSTIC'): 0.0020576920503723346,
#  ('00342', 'CYSTIC'): 0.0018798668114512684,
#  ('00343', 'CYSTIC'): 0.0040605123127347405,
#  ('00344', 'CYSTIC'): 0.003107534933215362,
#  ('00345', 'CYSTIC'): 0.0012379610709557136,
#  ('00346', 'CYSTIC'): 0.007538079788492711,
#  ('00347', 'CYSTIC'): 0.004833943229446119,
#  ('00348', 'CYSTIC'): 0.0013014462540816476,
#  ('00349', 'CYSTIC'): 0.008366440204810591,
#  ('00350', 'CYSTIC'): 0.005075640390918425,
#  ('00351', 'CYSTIC'): 0.00801416903829225,
#  ('00352', 'CYSTIC'): 0.013051646719504522,
#  ('00354', 'CYSTIC'): 0.005075640390918425,
#  ('00355', 'CYSTIC'): 0.0016732880409621182,
#  ('00357 ', 'CYSTIC'): 0.0039043387622449423,
#  ('00358 ', 'CYSTIC'): 0.0011448812911846072,
#  ('00359 ', 'CYSTIC'): 0.003683932541795631,
#  ('00361 ', 'CYSTIC'): 0.008957012454561927,
#  ('00362 ', 'CYSTIC'): 0.0022726748019037723,
#  ('00363 ', 'CYSTIC'): 0.00267138967943075,
#  ('00364 ', 'CYSTIC'): 0.0039043387622449423,
#  ('00365 ', 'CYSTIC'): 0.009823820111455016,
#  ('00366 ', 'CYSTIC'): 0.003107534933215362,
#  ('00367 ', 'CYSTIC'): 0.004911910055727508,
#  ('00368 ', 'CYSTIC'): 0.001312665618340972,
#  ('00369 ', 'CYSTIC'): 0.00801416903829225,
#  ('00370 ', 'CYSTIC'): 0.009571207594303317,
#  ('00371 ', 'CYSTIC'): 0.003955044460455916,
#  ('00372 ', 'CYSTIC'): 0.00160283380765845,
#  ('00374 ', 'CYSTIC'): 0.001478341861432551,
#  ('00375 ', 'CYSTIC'): 0.0009698675906213552,
#  ('00376 ', 'CYSTIC'): 0.006921327805797853,
#  ('00377 ', 'CYSTIC'): 0.0016373033519091694,
#  ('00379 ', 'CYSTIC'): 0.007875993710045832,
#  ('00380 ', 'CYSTIC'): 0.0022392531136404817,
#  ('00381 ', 'CYSTIC'): 0.0160283380765845,
#  ('00382 ', 'CYSTIC'): 0.0025808340970771655,
#  ('00383 ', 'CYSTIC'): 0.0016551001274733995,
#  ('00384 ', 'CYSTIC'): 0.006344550488648031,
#  ('00385 ', 'CYSTIC'): 0.002625331236681944,
#  ('00386 ', 'CYSTIC'): 0.0022392531136404817,
#  ('00387 ', 'CYSTIC'): 0.0018127287110422947,
#  ('00388 ', 'CYSTIC'): 0.006215069866430724,
#  ('00390 ', 'CYSTIC'): 0.0039043387622449423,
#  ('00391 ', 'CYSTIC'): 0.011713016286734828,
#  ('00392 ', 'CYSTIC'): 0.0012689100977296064,
#  ('00393 ', 'CYSTIC'): 0.002956683722865102,
#  ('00394 ', 'CYSTIC'): 0.002719093066563442,
#  ('00395 ', 'CYSTIC'): 0.0045453496038075445,
#  ('00396 ', 'CYSTIC'): 0.003310200254946799,
#  ('00397 ', 'CYSTIC'): 0.001111454100201115,
#  ('00398 ', 'CYSTIC'): 0.0020302561563673703,
#  ('00400 ', 'CYSTIC'): 0.004229700325765354,
#  ('00401 ', 'CYSTIC'): 0.0018798668114512684,
#  ('00402 ', 'CYSTIC'): 0.005075640390918425,
#  ('00403 ', 'CYSTIC'): 0.006344550488648031,
#  ('00404 ', 'CYSTIC'): 0.002379206433243012,
#  ('00406 ', 'CYSTIC'): 0.008157279199690325,
#  ('00407 ', 'CYSTIC'): 0.010501324946727775,
#  ('00408 ', 'CYSTIC'): 0.002625331236681944,
#  ('00409 ', 'CYSTIC'): 0.007808677524489885,
#  ('00410 ', 'CYSTIC'): 0.0050198641228863545,
#  ('00411 ', 'CYSTIC'): 0.002516846474835583,
#  ('00412 ', 'CYSTIC'): 0.006479540924576713,
#  ('00413 ', 'CYSTIC'): 0.006344550488648031,
#  ('00414 ', 'CYSTIC'): 0.004007084519146125,
#  ('00415 ', 'CYSTIC'): 0.0010574250814413386,
#  ('00416 ', 'CYSTIC'): 0.0028198002171769027,
#  ('00417 ', 'CYSTIC'): 0.002114850162882677,
#  ('00418 ', 'CYSTIC'): 0.002625331236681944,
#  ('00419 ', 'CYSTIC'): 0.005438186133126884,
#  ('00420 ', 'CYSTIC'): 0.009516825732972047,
#  ('00421 ', 'CYSTIC'): 0.001371794700248223,
#  ('00422 ', 'CYSTIC'): 0.005503706447983835,
#  ('00424 ', 'CYSTIC'): 0.001189603216621506,
#  ('00425 ', 'CYSTIC'): 0.0024962165856975862,
#  ('00426 ', 'CYSTIC'): 0.003107534933215362,
#  ('00427 ', 'CYSTIC'): 0.0036254574220845894,
#  ('00429 ', 'CYSTIC'): 0.003358879670460723,
#  ('00430 ', 'CYSTIC'): 0.0013240801019787196,
#  ('00431 ', 'CYSTIC'): 0.0013842655611595704,
#  ('00432 ', 'CYSTIC'): 0.004911910055727508,
#  ('00433 ', 'CYSTIC'): 0.013435518681842892,
#  ('00434 ', 'CYSTIC'): 0.00267138967943075,
#  ('00435 ', 'CYSTIC'): 0.006921327805797853,
#  ('00436 ', 'CYSTIC'): 0.0018345688159946117,
#  ('00437 ', 'CYSTIC'): 0.009045695746191252,
#  ('00438 ', 'CYSTIC'): 0.0020576920503723346,
#  ('00439 ', 'CYSTIC'): 0.0018345688159946117,
#  ('00440 ', 'CYSTIC'): 0.005746007989718972,
#  ('00441 ', 'CYSTIC'): 0.0010723183924475545,
#  ('00442 ', 'CYSTIC'): 0.00801416903829225,
#  ('00443 ', 'CYSTIC'): 0.004478506227280963,
#  ('00444 ', 'CYSTIC'): 0.006525823359752261,
#  ('00445 ', 'CYSTIC'): 0.004522847873095626,
#  ('00446 ', 'CYSTIC'): 0.006921327805797853,
#  ('00447 ', 'CYSTIC'): 0.0045680763518265825,
#  ('00448 ', 'CYSTIC'): 0.0028198002171769027,
#  ('00452 ', 'CYSTIC'): 0.00684356007764282,
#  ('00453 ', 'CYSTIC'): 0.002719093066563442,
#  ('00454 ', 'CYSTIC'): 0.004758412866486024,
#  ('00455 ', 'CYSTIC'): 0.0033837602606122835,
#  ('00456 ', 'CYSTIC'): 0.003806730293188819,
#  ('00457 ', 'CYSTIC'): 0.0045453496038075445,
#  ('00458 ', 'CYSTIC'): 0.0013014462540816476,
#  ('00459 ', 'CYSTIC'): 0.0032397704622883564,
#  ('00460 ', 'CYSTIC'): 0.004171759225412404,
#  ('00461 ', 'CYSTIC'): 0.007613460586377638,
#  ('00462 ', 'CYSTIC'): 0.0013014462540816476,
#  ('00463 ', 'CYSTIC'): 0.006397866038972805,
#  ('00464 ', 'CYSTIC'): 0.006921327805797853,
#  ('00465 ', 'CYSTIC'): 0.013842655611595705,
#  ('00466 ', 'CYSTIC'): 0.0020302561563673703,
#  ('00467 ', 'CYSTIC'): 0.004661302399823044,
#  ('00468 ', 'CYSTIC'): 0.004758412866486024,
#  ('00469 ', 'CYSTIC'): 0.0023426032573469657,
#  ('00470 ', 'CYSTIC'): 0.007338275263978447,
#  ('00471 ', 'CYSTIC'): 0.002144636784895109,
#  ('00472 ', 'CYSTIC'): 0.002768531122319141,
#  ('00473 ', 'CYSTIC'): 0.004614218537198568,
#  ('00475 ', 'CYSTIC'): 0.0021752744532507534,
#  ('00477 ', 'CYSTIC'): 0.008230768201489339,
#  ('00478 ', 'CYSTIC'): 0.010501324946727775,
#  ('00479 ', 'CYSTIC'): 0.010501324946727775,
#  ('00480 ', 'CYSTIC'): 0.009516825732972047,
#  ('00481 ', 'CYSTIC'): 0.004808501422975351,
#  ('00482 ', 'CYSTIC'): 0.0017914024909123853,
#  ('00483 ', 'CYSTIC'): 0.004709357063738745,
#  ('00484 ', 'CYSTIC'): 0.0010574250814413386,
#  ('00485 ', 'CYSTIC'): 0.0024962165856975862,
#  ('00486 ', 'CYSTIC'): 0.0023426032573469657,
#  ('00487 ', 'CYSTIC'): 0.004911910055727508,
#  ('00488 ', 'CYSTIC'): 0.006620400509893598,
#  ('00489 ', 'CYSTIC'): 0.002985670818187309,
#  ('00490 ', 'CYSTIC'): 0.0077425022912314964,
#  ('00491 ', 'CYSTIC'): 0.0032397704622883564,
#  ('00492 ', 'CYSTIC'): 0.013842655611595705,
#  ('00494 ', 'CYSTIC'): 0.006479540924576713,
#  ('00495 ', 'CYSTIC'): 0.0020576920503723346,
#  ('00496 ', 'CYSTIC'): 0.0020035422595730623,
#  ('00497 ', 'CYSTIC'): 0.0025808340970771655,
#  ('00498 ', 'CYSTIC'): 0.006767520521224567,
#  ('00499 ', 'CYSTIC'): 0.003045384234551055,
#  ('00500 ', 'CYSTIC'): 0.003806730293188819,
#  ('00501 ', 'CYSTIC'): 0.0015226921172755276,
#  ('00502 ', 'CYSTIC'): 0.0020035422595730623,
#  ('00503 ', 'CYSTIC'): 0.010017711297865313,
#  ('00504 ', 'CYSTIC'): 0.008186516759545848,
#  ('00505 ', 'CYSTIC'): 0.005639600434353805,
#  ('00506 ', 'CYSTIC'): 0.005639600434353805,
#  ('00507 ', 'CYSTIC'): 0.0046852065146939315,
#  ('00508 ', 'CYSTIC'): 0.007367865083591262,
#  ('00509 ', 'CYSTIC'): 0.0016732880409621182,
#  ('00510 ', 'CYSTIC'): 0.010574250814413386,
#  ('00513 ', 'CYSTIC'): 0.007250914844169179,
#  ('00514 ', 'CYSTIC'): 0.00878476221505112,
#  ('00518 ', 'CYSTIC'): 0.002873003994859486,
#  ('00519 ', 'CYSTIC'): 0.004115384100744669,
#  ('00520 ', 'CYSTIC'): 0.0012181536938204222,
#  ('00521 ', 'CYSTIC'): 0.006852114527739874,
#  ('00522 ', 'CYSTIC'): 0.0010219410183057232,
#  ('00523 ', 'CYSTIC'): 0.0053427793588615,
#  ('00524 ', 'CYSTIC'): 0.008305593366957423,
#  ('00525 ', 'CYSTIC'): 0.0019521693811224712,
#  ('00526 ', 'CYSTIC'): 0.002602892508163295,
#  ('00527 ', 'CYSTIC'): 0.001396965245206906,
#  ('00528 ', 'CYSTIC'): 0.0070008832978185175,
#  ('00530 ', 'CYSTIC'): 0.0009399334057256342,
#  ('00531 ', 'CYSTIC'): 0.006549213407636678,
#  ('00532 ', 'CYSTIC'): 0.0007930688110810039,
#  ('00533 ', 'CYSTIC'): 0.0016373033519091694,
#  ('00534 ', 'CYSTIC'): 0.0015076159576985421,
#  ('00535 ', 'CYSTIC'): 0.0013014462540816476,
#  ('00536 ', 'CYSTIC'): 0.002085879612706202,
#  ('00538 ', 'CYSTIC'): 0.001927458376298136,
#  ('00539 ', 'CYSTIC'): 0.0018127287110422947,
#  ('00540 ', 'CYSTIC'): 0.00267138967943075,
#  ('00541 ', 'CYSTIC'): 0.001553767466607681,
#  ('00542 ', 'CYSTIC'): 0.003310200254946799,
#  ('00543 ', 'CYSTIC'): 0.0014501829688338358,
#  ('00546 ', 'CYSTIC'): 0.0018345688159946117,
#  ('00548 ', 'CYSTIC'): 0.009063643555211474,
#  ('00550 ', 'CYSTIC'): 0.0020168107513583145,
#  ('00552 ', 'CYSTIC'): 0.0017914024909123853,
#  ('00553 ', 'CYSTIC'): 0.0032397704622883564,
#  ('00554 ', 'CYSTIC'): 0.008957012454561927,
#  ('00555 ', 'CYSTIC'): 0.002719093066563442,
#  ('00556 ', 'CYSTIC'): 0.002625331236681944,
#  ('00557 ', 'CYSTIC'): 0.006717759340921446,
#  ('00559 ', 'CYSTIC'): 0.003310200254946799,
#  ('00560 ', 'CYSTIC'): 0.011420190879566456,
#  ('00561 ', 'CYSTIC'): 0.0023426032573469657,
#  ('00562 ', 'CYSTIC'): 0.004229700325765354,
#  ('00563 ', 'CYSTIC'): 0.003082372707035481,
#  ('00564 ', 'CYSTIC'): 0.0011196265568202408,
#  ('00565 ', 'CYSTIC'): 0.004721525945040396,
#  ('00566 ', 'CYSTIC'): 0.004007084519146125,
#  ('00567 ', 'CYSTIC'): 0.0010219410183057232,
#  ('00568 ', 'CYSTIC'): 0.005782375128894408,
#  ('00569 ', 'CYSTIC'): 0.006767520521224567,
#  ('00570 ', 'CYSTIC'): 0.011034000849822664,
#  ('00571 ', 'CYSTIC'): 0.0019033651465944095,
#  ('00572 ', 'CYSTIC'): 0.0013475151480314403,
#  ('00573 ', 'CYSTIC'): 0.0022392531136404817,
#  ('00574 ', 'CYSTIC'): 0.002846153490234631,
#  ('00575 ', 'CYSTIC'): 0.00609076846910211,
#  ('00576 ', 'CYSTIC'): 0.0053427793588615,
#  ('00577 ', 'CYSTIC'): 0.005118292831178243,
#  ('00578 ', 'CYSTIC'): 0.0015226921172755276,
#  ('00579 ', 'CYSTIC'): 0.006767520521224567,
#  ('00582 ', 'CYSTIC'): 0.007027809772040897,
#  ('00583 ', 'CYSTIC'): 0.002768531122319141,
#  ('00585 ', 'CYSTIC'): 0.0028198002171769027,
#  ('00586 ', 'CYSTIC'): 0.002873003994859486,
#  ('00587 ', 'CYSTIC'): 0.0014641270358418535,
#  ('00588 ', 'CYSTIC'): 0.0011279200868707612,
#  ('00589 ', 'CYSTIC'): 0.0012795732077945609,
#  ('00590 ', 'CYSTIC'): 0.0077425022912314964,
#  ('00591 ', 'CYSTIC'): 0.002625331236681944,
#  ('00592 ', 'CYSTIC'): 0.0022726748019037723,
#  ('00593 ', 'CYSTIC'): 0.008957012454561927,
#  ('00594 ', 'CYSTIC'): 0.005856508143367414,
#  ('00597 ', 'CYSTIC'): 0.001553767466607681,
#  ('00598 ', 'CYSTIC'): 0.006215069866430724,
#  ('00599 ', 'CYSTIC'): 0.0037597336229025368,
#  ('00600 ', 'CYSTIC'): 0.005856508143367414,
#  ('00601 ', 'CYSTIC'): 0.005161668194154331,
#  ('00602 ', 'CYSTIC'): 0.004115384100744669,
#  ('00603 ', 'CYSTIC'): 0.004115384100744669,
#  ('00604 ', 'CYSTIC'): 0.00609076846910211,
#  ('00605 ', 'CYSTIC'): 0.002625331236681944,
#  ('00606 ', 'CYSTIC'): 0.006300794968036666,
#  ('00607 ', 'CYSTIC'): 0.013842655611595705,
#  ('00608 ', 'CYSTIC'): 0.01127920086870761,
#  ('00609 ', 'CYSTIC'): 0.008701097813003014,
#  ('00611 ', 'CYSTIC'): 0.004614218537198568,
#  ('00612 ', 'CYSTIC'): 0.003744324878546379,
#  ('00613 ', 'CYSTIC'): 0.006344550488648031,
#  ('00614 ', 'CYSTIC'): 0.002985670818187309,
#  ('00615 ', 'CYSTIC'): 0.004808501422975351,
#  ('00616 ', 'CYSTIC'): 0.0020035422595730623,
#  ('00618 ', 'CYSTIC'): 0.004115384100744669,
#  ('00619 ', 'CYSTIC'): 0.005075640390918425,
#  ('00621 ', 'CYSTIC'): 0.00609076846910211,
#  ('00622 ', 'CYSTIC'): 0.010706428949593554,
#  ('00623 ', 'CYSTIC'): 0.01062343337634089,
#  ('00624 ', 'CYSTIC'): 0.0039043387622449423,
#  ('00625 ', 'CYSTIC'): 0.001977522230227958,
#  ('00626 ', 'CYSTIC'): 0.007427766425734281,
#  ('00627 ', 'CYSTIC'): 0.0015226921172755276,
#  ('00628 ', 'CYSTIC'): 0.002985670818187309,
#  ('00629 ', 'CYSTIC'): 0.002768531122319141,
#  ('00630 ', 'CYSTIC'): 0.0037597336229025368,
#  ('00631 ', 'CYSTIC'): 0.0012689100977296064,
#  ('00632 ', 'CYSTIC'): 0.002114850162882677,
#  ('00633 ', 'CYSTIC'): 0.0024962165856975862,
#  ('00634 ', 'CYSTIC'): 0.0019033651465944095,
#  ('00636 ', 'CYSTIC'): 0.007427766425734281,
#  ('00638 ', 'CYSTIC'): 0.002625331236681944,
#  ('00639 ', 'CYSTIC'): 0.0077425022912314964,
#  ('00640 ', 'CYSTIC'): 0.005639600434353805,
#  ('00643 ', 'CYSTIC'): 0.0019397351812427104,
#  ('00644 ', 'CYSTIC'): 0.002114850162882677,
#  ('00645 ', 'CYSTIC'): 0.006525823359752261,
#  ('00646 ', 'CYSTIC'): 0.002360762972520198,
#  ('00647 ', 'CYSTIC'): 0.001553767466607681,
#  ('00648 ', 'CYSTIC'): 0.0025378201954592127,
#  ('00649 ', 'CYSTIC'): 0.006215069866430724,
#  ('00650 ', 'CYSTIC'): 0.0034606639028989263,
#  ...}

# %%
with open(modelo_path, 'w', newline='') as file:
    writer = csv.writer(file, delimiter=';')
    
    # Write rows
    for key, value in tfidf.items():
        writer.writerow([key, value])
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
