# %%
import configparser
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import xml.etree.ElementTree as ET
import unicodedata
import re
from tqdm import tqdm
import numpy as np

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rayss\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
cfg_PC = configparser.ConfigParser()

# %% [markdown]
# ### Reading file

# %%
f = open("data/cf74.xml", "r")        
doc_tree = ET.parse(f)
cf74_root = doc_tree.getroot()

def get_doc_data(doc_root):
    doc_data = {}
    for rec_element in doc_root.findall('RECORD'):
        rec_num = rec_element.find('RECORDNUM').text
        abstract_element = rec_element.find('ABSTRACT')
        if abstract_element is not None:
            abstract_content = abstract_element.text
        else:
            abstract_element = rec_element.find('EXTRACT')
            abstract_content = abstract_element.text if abstract_element is not None else "None"
        doc_data[rec_num] = abstract_content
    return doc_data

# %%
cf74_data = get_doc_data(cf74_root)
cf74_data
# Out:
# {'00001 ': 'The significance of Pseudomonas aeruginosa infection in the\nrespiratory tract of 9 cystic fibrosis patients have been studied\nby means of immunoelectrophoretical analysis of patients\' sera for\nthe number of precipitins against Pseudomonas aeruginosa and the\nconcentrations of 16 serum proteins.  In addition, the clinical and\nradiographical status of the lungs have been evaluated using 2\nscoring systems.  Precipitins against Pseudomonas aeruginosa were\ndemonstrated in all sera, the maximum number in one serum was 22.\nThe concentrations of 12 of the serum proteins were significantly\nchanged compared with matched control persons.  Notably IgG and IgA\nwere elevated and the "acute phase proteins" were changed, the\nlatter suggesting active tissue damage.  The concentrations of 3 of\nthe acute phase proteins, notably haptoglobin, were correlated to\nthe number of precipitins suggesting that the respiratory tract\ninfection in patients with many precipitins is accompanied by more\ntissue damage than the infection in patients with few precipitins.\nThe results indicate no protective value of the many precipitins on\nthe tissue of the respiratory tract.',
#  '00002 ': 'Salivary amylase levels were determined in normal subjects from\nbirth until adult life and in children with conditions sometimes\nassociated with low pancreatic amylase such as malnutrition, coeliac\ndisease and cystic fibrosis.  Mixed saliva was collected under\ncarefully standardised conditions and amylase was measured by the\nmethod of Dahlqvist.  There was a wide scatter of values in the 84\nnormal subjects, but concentrations rose from very low levels at\nbirth to reach adult levels by the age of 6 months to 1 year.\nSalivary amylase activity rose normally over ten weeks in one\npremature infant fed milk by gastrostomy.  Thirteen children with\ncoeliac disease and 9 children with cystic fibrosis mostly had\nnormal salivary amylase concentrations.  Six out of 12 malnourished\nchildren with jejunal villous atrophy of uncertain aetiology had low\nlevels which rose to normal as recovery began.',
#  '00003 ': 'This article reports on the possibility of using instrumental\nneutron activation analysis (INAA) of sodium in nail clippings for\ndiagnosing cystic fibrosis (CF) in children and adults, for\ndetecting heterozygotes and for screening in the neonatal period.\nNail clippings from 1322 newborns, 22 CF patients (two of them\nnewborns), 52 healthy controls and 22 heterozygotes were analyzed.\nThe discrimination between CF patients and controls was found to be\nprecise for individuals above one year of age and INAA of nail\nclippings should be accepted as a diagnostic test for CF after this\nage.  Heterozygotes could not be detected by the method.  During the\nfirst five days of life there is a big overlap between the values\nfrom normal newborns and those of CF children, which makes the\nmethod invaluable for early screening for CF.',
#  '00004 ': 'Instrumental neutron activation analysis (INAA) of nail clippings\nwas used in the development of a diagnostic method for cystic\nfibrosis (CF).  From CF patients and controls more than three years\nold, nail clippings were sampled for tests of different errors.  As\na result of this study a precise collection routine was outlined.\nSodium is easily washed out from nail clippings.  The risk of sodium\ncontamination of the nails seems to be small.  The sodium\ndistribution in the nail is inhomogeneous, and the sodium content\nvaries also from nail to nail in the same person.  There is good\nevidence that the increased sodium in the nails of CF patients comes\nfrom the sweat.  There seems to be a basic "intrinsic" sodium level,\nwhich is about the same in the nails of CF patients as in controls.\nThe precision and accuracy of INAA for determining sodium in nails\nis considered satisfactory.  It is concluded that INAA of the sodium\nconcentration in nail clippings is a suitable method as an aid in\nthe diagnosis of CF if a precise collection routine is used.',
#  '00005 ': "The capacity of duodenal juice to hydrolyse casein to\ntrichloroacetic acid-soluble peptides was investigated: in a control\ngroup (11 infants and children and 7 adults); in 5 children with\npancreatic disease; in 10 children with enterogenic malabsorption\n(coeliac disease and cow's milk protein intolerance).  The\nproteolytic activity per ml duodenal juice in fasting condition was\nas great in healthy infants and children as healthy adults (500-600\nmg casein/ml/hour).  There was a good correlation between trypsin\ncontent and proteolytic activity of duodenal juice.  In pancreatic\ninsufficiency, the proteolytic activity was extremely low (not\nmeasurable in 3 patients) as was the trypsin activity whereas in\nenterogenic malabsorption, it was within the ranges of the controls.",
#  '00006 ': 'The influence of chronic Ps. aeruginosa infection on the occurrence\nof bone marrow-derived lymphocytes (B cells) and thymus-derived\nlymphocytes (T cells) in peripheral blood have been studied in 2\ngroups of patients with cystic fibrosis.  One group (9 patients)\nsuffered from chronic Ps. aeruginosa infection in the respiratory\ntract and produced multiple Ps. aeruginosa precipitins which were\ndemonstrated by means of crossed immunoelectrophoresis.  The other\ngroup (9 patients) had never harboured Ps. aeruginosa in the\nrespiratory tract and presented no demonstrable precipitins against\nthis bacteria.  The lymphocytes were examined for the presence of\n2 surface markers for B cells: receptor for C3 complement component\n(EAC rosette-formation) and surface immunoglobulins\n(immunofluorescent staining), and for the presence of 1 surface\nmarker for T cells: spontaneous binding of sheep red blood cells (E\nrosette-formation).  The B:T cell ratio was nearly identical in the\n2 groups of patients whereas the total numbers of B and T cells were\nsignificant higher in patients with chronic Ps. aeruginosa\ninfection.  The number of Ps. aeruginosa precipitins per serum was\nsignificantly positively correlated to the total number of T cells,\nwheras the correlation with the total number of B cells was\ninsignificant.',
#  '00007 ': 'The occurrence of Pseudomonas aeruginosa in the respiratory tract\nof 70 cystic fibrosis patients and the occurrence of precipitins\nagainst Ps. aeruginosa in sera from the same patients have been\ninvestigated during one year by means of monthly bacteriological\nexaminations of tracheal secretions and by means of crossed\nimmunoelectrophoresis of a polyvalent Ps. aeruginosa antigen\nagainst sera from the patients.  The one-year period prevalence\nrate of patients harbouring Ps. aeruginosa was 64 per cent.  In\nnewly colonized patients and in intermittently colonized patients\nnon-mucoid strains were predominating, whereas mucoid strains were\npredominating in chronically colonized patients.  The occurrence of\nmucoid strains, especially in chronically colonized patients, was\nassociated with a significantly higher number of precipitins against\nPs. aeruginosa than the occurrence of non-mucoid strains.  Males\nchronically colonized with mucoid strains presented a significantly\nhigher number of precipitins than females chronically colonized\nwith mucoid strains and the number of precipitins was correlated\nwith the duration of the chronic colonization with Ps. aeruginosa\nin males in contrast to females.  The results are in accordance\nwith the hypothesis that mucoid substance could be a virulence\nfactor because it might inhibit the opsonizing effect of the\nprecipitins on the mucoid cells and the complement dependent lysis of\nthe cells hereby favouring mucoid strains at the expense on\nnon-mucoid strains in the respiratory tract of cystic fibrosis\npatients.',
#  '00008 ': 'Seventy patients with cystic fibrosis treated as out-patients in a\ncystic fibrosis clinic have been followed during one year by\nmonthly bacteriological examinations of tracheal secretions.  The\ndaily impression obtained in the laboratory is expressed by the\nmean point prevalence rate of Pseudomonas aeruginosa: 44 per cent,\nStaphylococcus aureus: 39 per cent, Haemophilus influenzae: 17 per\ncent, Diplococcus pneumoniae: 8 per cent, and miscellaneous other\nbacteria, mainly Enterobacteriaceae: 8 per cent.  The fluctuations\nof the bacteriology are described by additional epidemiological\nterms: At one or more examinations during the study (period\nprevalence rate), 90 per cent of the patients harboured St. aureus,\n64 per cent Ps. aeruginosa (mainly mucoid strains), 64 per cent H.\ninfluenzae, 37 per cent D. pneumoniae, and 30 per cent miscellaneous\nother bacteria, mainly Enterobacteriaceae.  This pattern was found\nin all age groups with minor age-dependent modifications, especially\nas regards Enterobacteriaceae.  Ps. aeruginosa was predominating as\nregards chronic colonization which reflects the most difficult\ntherapeutic problems, the period prevalence rate being 39 per cent\nin contrast to St. aureus: 10 per cent, and H. influenzae: 1 per\ncent.  St. aureus was predominating as regards new colonization and\nrecolonization which reflect the problems of prevention, the\nincidence rate of new colonization and recolonization per risk group\nbeing 84 per cent, followed by H. influenzae: 62 per cent, Ps.\naeruginosa: 43 per cent, and D. pneumoniae: 30 per cent.  The\nresults show that the bacteriological problems in cystic fibrosis\nare still considerable as regards therapy as well as prevention.\nAlthough many species may colonize the respiratory tracts of these\npatients, the main clinical problems concern Ps. aeruginosa and St.\naureus; the reason why is discussed.',
#  '00009 ': 'A family is presented in which celiac sprue and cystic fibrosis\noccurred within the same sibship.  A cousin of the index case was\nalso discovered to have celiac sprue.  The genetics and incidence of\nboth conditions is reviewed.  It is estimated that the likelihood of\nthis association occurring on the basis of chance in this family is\n1 in 50,000.',
#  '00010 ': "A patient exhibited the features of both Kartagener syndrome and\ncystic fibrosis.  At most, to the authors' knowledge, this\nrepresents the third such report of the combination.  Cystic\nfibrosis should be excluded before a diagnosis of Kartagener\nsyndrome is made.",
#  '00011 ': 'The prevalence of respiratory allergies and their effects on the\ncourse of cystic fibrosis (CF) were studied in 63 patients.  Fifteen\npatients (24%) had respiratory allergies as defined by history,\nphysical examination, positive allergy skin tests, nasal and\nperipheral eosinophilia, and reversible airway obstruction.  Serum\nimmunoglobulins on these 15 allergic CF and 22 nonallergic CF\npatients were elevated when compared with those in normal age-matched\ncontrols.  The allergic CF patients had significantly higher IgE\nlevels (mean 598 international units [IU] compared to 281 IU); IgG,\nIgM, and IgA levels were similar in the two CF groups.  The clinical\ncondition of the allergic CF patients, (Shwachman score) was better\nthan the nonallergic, suggesting some modulating effect of\nrespiratory allergy on the severity of the disease.',
#  '00012 ': 'Taussig et al reported a case of a 6-year-old boy with the Russell\nvariant of the Silver-Russell syndrome concomitant with cystic\nfibrosis.  We would like to describe another patient who had the\nsame combination of diseases.  The pattern of clinical findings in\nthis patient are in accordance with that of the Silver-Russell\nsyndrome.  It is, of course, possible that the development of\ncystic fibrosis in this patient is entirely accidental, although\nsuch a coincidence would be a statistically rare event.  The\nestablishment of a possible relationship between these two\nconditions would depend on reports of other similar cases.',
#  '00013 ': 'An intensive search for blacks with cystic fibrosis (CF) in\nWashington, DC, during the period 1962 to 1971 disclosed 16 black\npatients, eight of whom were born in the District of Columbia during\nthis decade.  The calculated incidence of CF is at least one in\n17,033 black newborns.  The clinical course and pathological changes\nin blacks with CF are similar to those in whites.  Genetic\nconsiderations point to autosomal recessive inheritance in blacks,\nwhich is generally accepted for whites with this disease.',
#  '00014 ': "Prenatal diagnosis of genetic disorders has received increasing\nattention during the past several years.  Rapid expansion of our\nknowledge of the basis of genetic disease and the development of\nreliable diagnostic methods have led to rapid advances in the\nintrauterine diagnosis of a large number of inherited disorders.\nPrenatal diagnosis was initially used to determine the presence of\nDown's syndrome and other chromosomal abnormalities and for the\ndetermination of fetal sex in pregnancies at risk for a number of\nsevere X-linked recessive disorders.  Shortly thereafter, it became\nclear that the same techniques could be applied to the prenatal\ndiagnosis of a number of the inborn errors of metabolism.  Most\nrecently, a number of new techniques have been developed that may\nprove to be of great value in the prenatal diagnosis of a number of\nsevere congenital malformations that before now could not be\ndiagnosed prior to birth.  The goal of this review is to define the\npast achievements, future goals, and present limitations of\nintrauterine diagnosis.  The first section will deal with the general\napproaches used in prenatal diagnosis of genetic disorders.  This\nwill be followed by a discussion of the specific applications of the\nbasic techniques to the intrauterine diagnosis of chromosomal\nabnormalities and of the inborn errors of metabolism.  Approaches to\nprenatal diagnosis of genetic disorders include amniocentesis, direct\nand indirect visualization of the fetus, analysis of maternal blood\nand urine, and sampling of fetal tissues.  Applications of prenatal\ngenetic diagnosis include X-linked recessive disorders, chromosomal\nabnormalities, inborn errors of metabolism, disorders of lipid\nmetabolism, disorders of carbohydrate metabolism, disorders of\nmucopolysaccharide metabolism, disorders of amino acid metabolism,\nand miscellaneous disorders such as cystic fibrosis.  These\ntechniques provide some parents with methods for having children\nwithout fear of having a child with a specific deformity.  In\naddition to the development of approaches which will increase the\nnumber of disorders detectable in utero, the potential for treatment\nof genetic disorders is unlimited.",
#  '00015 ': 'Three of the 4 women in a cystic fibrosis clinic who used a combined\nform of oral contraceptive developed acute polypoid cervicitis.  In\none woman, the polyp recurred on reinstitution of the medication.\nThere was resolution of the polyp in each instance on\ndiscontinuation of the drugs.  In 2 of the 3 affected women, there\nwas coincidental deterioration of respiratory status.  Therefore, it\nis suggested that cystic fibrosis patients who are using oral\ncontraception be observed closely regarding pulmonary and\ngynecologic status.',
#  '00016 ': 'The syndrome of ataxia-telangiectasia is characterized by ataxia,\nprogressive neurologic degeneration, cutaneous and conjunctival\ntelangiectasis, and immunologic deficiency.  Roentgenologic evidence\nof chronic pulmonary and sinus infections and decreased lymphoid\ntissue will usually be present.  As the sinopulmonary abnormalities\nresemble those of cystic fibrosis, a small adenoidal mass may be of\ndifferential aid.',
#  '00017 ': 'Cystic fibrosis is no longer rare in adults.  The lung is the main\ntarget organ and the basic lesion is bronchial obstruction leading to\nbronchiectasis.  Interstitial infiltrates and cyst-like changes are\ncharacteristic on roentgenography.  Complications include pulmonary\nhypertension, pneumonitis, hemorrhage, and pneumothorax.  Little\ncorrelation exists between respiratory tract and pancreatic and\ngastrointestinal involvement, despite similarities in pathogenesis.\nPulmonary cystic fibrosis in adults does not always resemble the\ncondition in children, and must be differentiated from other chronic\ninterstitial diseases.',
#  '00018 ': 'As far as rabbit alveolar macrophages are concerned,\nthe concentration of homozygous CF serum used in our experiments\nwas even greater than the fourfold concentration which Biggar and\nassociates state was required for normal phagocytosis.  Increasing\ndilutions of homozygous CF sera with either Hanks balanced salt\nsolution or normal human serum, thus decreasing its concentration,\nincreased the capacity of the rabbit alveolar macrophages to\nphagocytize and kill Pseudomonas aeruginosa.  Increasing\nconcentrations had just the opposite effect.  Suspension of rabbit\nalveolar macrophages in human serum reduced their phagocytic\nactivity, but activity was reduced more by human CF serum than by\nhuman normal serum.  This is not unexpected because high human\nserum concentrations are likely to be toxic to rabbit alveolar\nmacrophages.  Because the inhibition of phagocytosis was absent\nwhen homozygous CF serum more than 24 hours old or previously\nheated or frozen was used and because of our observations that\ndilution increased macrophage phagocytic ability, we feel our data\ndemonstrate the presence of a labile inhibitor rather than a\ndeficiency.  Since it is well known that CF patients have normal\nor elevated concentrations of immunoglobulins including IgA in\ntheir sera and pulmonary secretions and respond to infection, and\nIgA has not been shown to be essential for alveolar macrophage\nphagocytosis of Pseudomonas aeruginosa, we cannot agree that this\ninhibition is due to an IgA deficiency.  We also note that some of\nthe sera used in the experiments of Biggar and associates were\nstored at -70 degrees C.  Perhaps this may account for the\ndifference in results.',
#  '00019 ': 'We assayed the serum of a group of cystic fibrosis patients that\nwere on oral arginine therapy and that of a group of cystic\nfibrosis patients that were not receiving this treatment for total\narginine esterase activity.  The untreated cystic fibrosis patients\nhave significantly lower serum arginine esterase activity than the\nnormal controls, the cystic fibrosis carriers, and the cystic\nfibrosis patients receiving oral arginine therapy.  There is no\nsignificant difference between the arginine esterase activity of\nthe normal controls and the cystic fibrosis carriers or the cystic\nfibrosis patients treated with arginine. -  We have recently\nobserved differences in the arginine esterases in plasma of\ncontrols and patients by electrofusing on polyacrylamide gels.\nSix activity bands could be detected in plasma of controls, whereas\nonly five could be detected in plasma of patients.  Our work on the\ndeficiency of trypsin-like activity in mixed saliva of patients\nwith cystic fibrosis has been reproduced by another laboratory.\nCoburn recently confirmed our work on deficiency of arginine\nesterase in serum of patients with cystic fibrosis. At present, the\ndeficiency of arginine esterase in cystic fibrosis is a working\nhypothesis to understand the basic defect. - The variations of pH\nand sodium chloride content that I employed had been tested by me\nin 6 patients both with and without a diagnosis of cystic fibrosis\nand were found not to alter the level of arginine-esterase\nactivity.  The major differences between the two studies resulted\nfrom the control subjects.  Dr. Rao neglects to mention the few\nother laboratories that were unable to confirm his findings.',
#  '00020 ': 'The ability to detect abnormalities of lung function in children\nwith asthma and cystic fibrosis by the measurement of closing\nvolume was studied in 205 children.  Flow volume characteristics,\nroutine spirometry, body plethysmography, and arterialized\noxygen tensions were studied for comparison with closing volume.\nClosing volume was less sensitive in detecting disease than were\nthe residual volume to total lung capacity ratio, maximum expiratory\nflow volume curves, and arterialized blood gases.',
#  '00021 ': "Five parents of children with cystic fibrosis developed allergic\nbronchospasm after inhaling pancreatic extracts sprinkled on their\nchildren's food.  There was a positive history of allergy, but no\npast history of asthma in any of the 5 parents.  Asthma responded\nto bronchodilators, and use of a face mask during preparation of\nmeals prevented recurrences.  To date, asthma precipitates by\ninhalation of pancreatic extracts has not been seen in any of the\npatients with cystic fibrosis.",
#  '00022 ': 'Airway resistance and lung volume were measured by a modification of\nthe plethysmographic method of Briscoe and DuBois (1) to calculate\nspecific airway resistance (SRaw) on 263 control subjects ranging in\nage from the newborn to 54 years.  the mean SRaw was lowest in the\nnewborn period and increased rapidly to adult levels during the\nfirst years of life.  In each age group, the mean SRaw was lower for\nfemales than it was for males.  No control subject had an SRaw\ngreater than 8 sec cm H2O.  A decrease in mean SRaw from 4.2 sec cm\nH2O for females 5 to 9 years of age to 3.5 sec cm H2O for those over\n18 years of age paralleled sexual maturation, but similar changes\nwere not observed in the males.  A direct correlation of SRaw with\nclinical observations was found in young patients with various\ndegrees of pulmonary involvement because of cystic fibrosis.',
#  '00023 ': 'Ciliated nasal polyp epithelium from patients with allergic rhinitis\nand patients with cystic fibrosis was maintained in organ culture\nfor 168 hours.  Explanted epithelium retained its morphologic\ncharacteristics and incorporated 35SO4 and 3H into blood group\nspecific glycoproteins that were secreted into the medium throughout\nthe culture period.  Labeled mucous glycoprotein was solubilized by\nreduction and alkylation, then purified by gel filtration\nchromatography.  Purified glycoprotein was further separated on\ndiethylaminoethyl (DEAE) cellulose columns into 3 blood group active\nfractions.  These fractions had similar amino acid compositions but\ndiffered in N-acetyl neuraminic acid and fucose content and in\nrelative incorporation of 35SO4 and 3H-glucosamine.  Blood group\nglycoproteins from polyp epithelium of patients with allergic\nrhinitis and cystic fibrosis were indistinguishable in many\nrespects.  However, the 35SO4 per 3H ratio of all 3 glycoprotein\nfractions from patients with cystic fibrosis exceeded that of the\ncorresponding fractions from secretions of patients with allergic\nrhinitis.',
#  '00024 ': 'The pressure-volume behavior of the lung was studied in 24 patients\nwith cystic fibrosis.  Isovolume flow-pressure relationships were\nmeasured in 7 of these patients, and a modification of the\nflow-volume test was evaluated for detection of flow reduction in a\nseparate group of 63 patients.  Relative to results in a control\ngroup of 31 normal subjects, 13 of the 24 patients had grossly\nabnormal pressure-volume curves with excessive stiffness of the lung\nnear maximum volume and loss of recoil at lower volume.  Closing\nvolumes in these patients were often high enough to cause\nsignificant disturbances in gas exchange and the elevated closing\nvolumes were quantitatively explained by the low values for elastic\nrecoil.  The modified flow-volume test detected mild flow reduction\nin many patients who otherwise had normal pulmonary function tests.\nLoss of recoil per se did not account for the low maximum expiratory\nflows, since "upstream" resistances were high.  However,\npressure-flow curves were effort-dependent at high lung volumes even\nin patients with severe airway obstruction, showing that time\nconstants of emptying varied widely in these patients.  It was\nconcluded that deterioration of lung function in cystic fibrosis\ninvolves more than airway obstruction and that the worsening gas\ntrapping is explained by a progressive loss of lung elastic recoil.',
#  '00025 ': 'Use of bland aerosols, particularly mist tents, in the treatment of\nlower respiratory disease was reviewed and no convincing evidence of\nefficacy was found.  This is not surprising because there is\nevidence that mist tents deposit little water in the lower\nrespiratory tract.  Mist tents may be detrimental, in some cases,\nbecause of bacterial contamination and because they can cause\nbronchospasm.',
#  '00026 ': 'Plasma arginine esterase activity was measured in 13 young adult\npatients with cystic fibrosis and in 36 control subjects.  The\nenzyme was activated by treating the plasma with chloroform and\nellagic acid in the manner described by Rao and associates (1).  No\ndifference was found either between the arginine esterase activities\nof the patients with cystic fibrosis and the control subjects, or\nbetween the degrees of activity inhibited by soybean trypsin\ninhibitor.  Thus, the findings of Rao and associates of a deficiency\nof arginine esterase activity in the plasma of patients with cystic\nfibrosis were not confirmed.',
#  '00027 ': 'In spite of the widespread clinical impression that pulmonary\nphysical therapy, including breathing exercises, is helpful in the\npediatric age group, objective demonstration of the value of the\nvarious maneuvers is for the most part lacking.  There is evidence\nthat the volume of sputum produced over short periods of time in\npatients with cystic fibrosis is increased when cough is accompanied\nby postural drainage and pulmonary physical therapy, but the\nlong-term effect of the various maneuvers on the course of the\nchronic pulmonary disease remains unknown.',
#  '00028 ': 'The present study points out the simplicity and ease of using\nfingernails and toenails to measure electrolyte levels as a test\nfor cystic fibrosis.  Procedures and various effects on the ranges\nof values for different categories of healthy and diseased subjects\nare discussed and the limitations of the method are indicated.',
#  '00029 ': 'An ear-nose-throat survey was carried out on 50 children aged 4 to\n10 years with cystic fibrosis.  10% were shown to be transiently\ndeaf, associated with eustachian tube dysfunction.  There were no\nconfirmed cases of secretory otitis media.  10 children (20%) were\nfound to have nasal polyps or gave a history of polypectomy.  Though\na high incidence of middle ear problems in children with cystic\nfibrosis has been reported in the U.S.A., neither deafness nor\nsecretory otitis media was found to be a problem in the group\nstudied.',
#  '00030 ': "Patients with cystic fibrosis have tocopherol deficiency presumably\nas a result of steatorrhoea.  Evidence for possible muscular\ninvolvement in cystic fibrosis patients is clinical (muscular\nweakness and wasting in many patients), biochemical (creatinuria on\na creatine-poor diet, with reversal of this finding after ingestion\nof tocopherol esters, accompanied by a decrease in creatine in\nplasma and an increase in creatine in muscle), and pathological\n(focal lesions in skeletal muscle resembling nutritional muscular\ndystrophy, and ceroid pigment in smooth muscle).  Muscle strength\nwas measured with a bulb ergograph in 45 patients with cystic\nfibrosis attending the clinics at the Babies' Hospital, Columbia\nPresbyterian Medical Center, New York.  In a double-blind study, in\nwhich half the cases received tocopherol orally, and the remainder\nplacebo, no significant increase in muscle strength was found in\nthose patients receiving tocopherol over a period of 6 months as\ncompared to the placebo group.  Blood tocopherol levels in the\ntreated group returned to normal.",
#  '00031 ': 'The hypothesis that mist tent therapy decreases the viscosity of\nsputum by direct liquefaction of the sputum in the lower respiratory\ntract was tested in 6 patients with cystic fibrosis (CF).  The first\nnight all patients slept without the mist tent and the first morning\nsputum was collected for analysis.  The following 2 nights patients\nwere randomly allocated to a tent supplied by either a jet or\nultrasonic nebulizer.  The early morning sputum was analysed for\nvolume, viscosity, water content, and DNA content, an index of\npurulence.  There was no relation between sputum viscosity and DNA\ncontent, water content, or volume.  Furthermore, there was no\nconsistent relation between sputum viscosity or volume expectorated\nand the presence or absence of an 8-hour stay in the tent with\neither method of water nebulization.  These results therefore\nsuggest that mist therapy does not consistently influence sputum\nviscosity or volume in patients with CF.  Above a sputum water\ncontent of 90%, further increases in water content do not influence\nviscosity.',
#  '00032 ': 'Two sisters are described with fatal chronic obstructive lung\ndisease of unknown origin.  The lung condition was clinically and\nhistologically indistinguishable from cystic fibrosis and the\nsalivary glands showed pathological changes expected in cystic\nfibrosis.  Neither child had abnormal sweat electrolytes, they had\nno bowel symptoms, and the pancreas was normal at necropsy.',
#  '00033 ': 'Cellulose acetate strip electrophoresis was found to be not\nsufficiently reliable to differentiate between normal and CF\nmeconium, but marked differences were obtained when quantitative\nimmunoelectrophoretic methods were employed.  Normal meconium was\nshown to contain alpha1-antitrypsin and alpha1-antichymotrypsin and\nmost samples contained low concentrations of albumin, and measurable\namounts of a variety of other plasma proteins.  It is suggested that\nquantitative immunoelectrophoresis could be used as a means of\nconfirming the diagnosis of CF if positive results are obtained when\nmeconium specimens are screened with test strips.',
#  '00034 ': "The coexistence of cystic fibrosis and coeliac disease has recently\nbeen reported, and it has been suggested that cystic fibrosis may\npredispose to the later development of coeliac disease.  The\ndiagnosis of coeliac disease is largely dependent upon the\ndemonstration of histological changes in the small intestine, but\njejunal biopsy may be distressing to a small child.  It is\nsuggested that food protein antibody studies may be of value in the\ninvestigation of children with cystic fibrosis in whom gluten\nsensitivity is suspected.  In the following case the decision to\nperform a jejunal biopsy was made when these studies were positive.\nFood protein antibody to cereal antigens, wheat, oatmeal, and\ngluten, and to ruminant antigens, cow's milk, and calf serum were\npersistently detected in the patient's blood.  Jejunal biopsy\nshowed partial villous atrophy with shortening, broadening, and\nbranching of the villi.  There was a satisfactory clinical\nimprovement after gluten restriction.",
#  '00035 ': 'A simple immunochemical technique utilizing single radial\nimmunodiffusion for the demonstration of albumin in human meconium\nis described.  A comparison of this technique with the more widely\nused sulphosalicylic acid precipitation method is reported.  We also\nhave attempted to determine the normal levels of albumin in\nmeconium.',
#  '00036 ': 'None',
#  '00037 ': 'Neonatal peritonitis remains a dangerous condition.  Factors\ncomplicating diagnosis and management include its low incidence, the\ndiversity of aetiological factors found, and the severity of\nunderlying or associated disease.  28 cases presenting since 1957 at\nSouthmead General Hospital were reviewed.  Thirteen aetiological\nfactors relating to mother or baby were found.  13 infants were\npremature, 10 had severe respiratory problems at birth.  Maternal\nhydramnios was present in 7.  6 babies had had exchange transfusion.\nThe commonest findings were gangrenous volvulus and cystic fibrosis.\nCombined factors were often present.  The usual presentation is with\nbilious vomiting, abdominal distension, and failure to pass normal\nmeconium.  4 cases had distended abdomens at birth.  Plain abdominal\nx-rays are of great diagnostic value.  Pneumoperitoneum is diagnostic\nbut absent from early films.  Treatment is surgical.  Close liaison\nwith the paediatrician who sees the baby first is essential.  In\nassessing results it is pointed out that many of these babies are\nsmall and/or suffering from serious conditions such as haemolytic\ndisease, cystic fibrosis, or gangrenous volvulus.  8 cases were\nconsidered unfit for surgery.  Of 20 submitted to surgery, 12\nsurvived, mostly in the latter part of the series.',
#  '00038 ': 'The value of detecting albumin in meconium as a screening\nprocedure for cystic fibrosis (CF) has been assessed on 34,228\nsamples in South Wales and North Staffordshire over a 4-year period;\nsimultaneously, four methods of detecting albumin were evaluated.\n12 cases of CF were detected, detection rate being 60%.  The\nincidence of the disease in the population screened was 1 in 1850,\nconfirmed by clinical and other test procedures.  Cases of CF\nwithout impairment of pancreatic function are likely to be missed\nby screening methods which depend on the presence of albumin in\nmeconium.',
#  '00039 ': 'For Caucasians of European origin, cystic fibrosis (CF) remains the\ncommonest recognized autosomal recessive disorder, but it appears to\nbe a rarity among the coloured races.  For a time, records may have\nsuggested an association between CF and whiteness; in recent years,\nhowever, instance of CF children have been described whose racial\norigins are Negroid, Mongoloid, and non-European Caucasoid.  The\npresent case reports concern 3 Pakistani children born in Birmingham,\nin whom Cf has been confirmed.  2 of the 3 (Cases 1 and 2) were\nbrother and sister.  The present incidence of this disease among\nAsian immigrants in the West Midlands is approximately 1:10,000.',
#  '00040 ': 'Calcium phosphate, which precipitates in submandibular saliva of\npatients with cystic fibrosis because of elevated calcium\nconcentrations, was shown by electron microscopy to transform, on\nstanding in vitro, from amorphous calcium phosphate globules to\nstellar clusters of hydroxyapatite crystals.  Amorphous globules\nappeared to form at regular nucleation points on a fine network of\nunknown nature.  Hydroxyapatite crystal formation was confirmed by\nelectron diffraction pattern and chemical solubility.\nZymogen-granule spherules (inclusion bodies), which are present in\ngreatly increased numbers in cystic fibrosis submandibular saliva,\ndisintegrated on standing from a homogeneous appearance to beaded,\nhollow spheres.',
#  '00041 ': 'Paneth cell metaplasia is a variable feature of diverse diseases of\nthe colon and rectum.  Paneth cells are numerous in the atrophic\nmucosa of chronic ulcerative colitis, in some juvenile polyps, and\naround colloid (mucinous) carcinomas.  Moderate numbers of Paneth\ncells are found in cystic fibrosis of the pancreas, ambeic colitis,\nand in villous adenomas.  Paneth cells are sparse in diverticulitis,\nin adenomatous polyps, and around nonmucinous carcinomas.  In this\nstudy, Paneth cell metaplasia is associated with mucus\nhypersecretion and mucin deposits.  It is suggested that one\nfunction of the Paneth cell is to control gastrointestinal mucin\nviscosity.',
#  '00042 ': "The association of anomasia and hypogonadism has been reported with\nincreasing frequency over the past several years.  This case report\nof Kallman's Syndrome emphasizes the importance of testing for\nanomasia in those patients who manifest abnormalities in their\nsexual development.",
#  '00043 ': 'The effects of cystic fibrosis on 50 Victorian families with one or\nmore affected children were examined in a study carried out between\nAugust 1972 and February 1973.  The social and emotional problems\nexperienced by family members, particularly the patients and\nmothers, are reported on.  At all ages, socially embarrassing\nsymptoms and awareness of being different create major problems for\nthe patient.  The uncertainty of prognosis and doubts about the\nprospects of employment are specially relevant for the teenager.\nIt is suggested that the patient be given ample opportunity, from\nearly adolescence onward, to discuss all aspects of his disease,\nand that more appropriate provision should be made for the total\ncare of adult patients.  Many problems, such as depression, feelings\nof isolation and the physical demands of constant treatment, which\nthe parents of children with cystic fibrosis experience, are\nprobably similar to those confronting parents of other chronically\nill and handicapped children.  But special difficulties stem from\nthe genetic basis of cystic fibrosis and from the knowledge of an\neventually fatal outcome.  The roles of professional members of the\nmedical team are touched on, particularly in relation to genetic\ncounseling and the provision of practical and emotional support to\nparents.  Comments are made on the establishment of lay\norganisations.  The financial strain associated with obtaining\nregular medical attention was looked at, and suggestions are made\nfor minimizing the economic problems of certain vulnerable families.',
#  '00044 ': 'Membrane associated ATPase activities of human red blood cells were\nexamined following the addition of spent fibroblast culture media\nfrom normal and cystic fibrosis cell lines.  In comparison to normal\nand unspent media, the cystic fibrosis media consistently depressed\nthe ATPase activities.',
#  '00045 ': 'Cultured lymphoid cells of both homozygotes and heterozygotes for\ncystic fibrosis could be distinguished from those of normals by (1)\ngrowth pattern, gross clumping, and (2) a relative increase in\ndermatan sulfate, with a normal total mucopolysaccharide content.\nLines derived from the genetic mucopolysaccharidoses also had these\ncharacteristics, but their total mucopolysaccharide content was\nmarkedly increased.  These observations support the hypothesis that\nthe cellular disturbance in cystic fibrosis resides in those\ncellular regions whose functions would be altered by\nmucopolysaccharide composition.',
#  '00046 ': 'Hereditary abnormalities of intestinal transport are rare conditions\nbut are of disproportionate importance because of the information\nthey give regarding the mechanisms of intestinal absorption in man.\nThe main disability is usually diarrhoea, but there may be\nabnormalities from lack of absorption of an essential nutrient or\noccasionally from absorption of compounds in excess due to failure\nof a normal control mechanism.  These diseases are experiments of\nnature which cannot be exactly simulated in the laboratory animal,\nand thus may on occasions give information unobtainable from other\nsources.  Most often, however, they confirm that the mechanisms of\nabsorption studied in detail in smaller mammals are probably\napplicable to man.  In some of these diseases there is an associated\ndefect of transport in the proximal renal tubules as well as in the\ngut.  They furnish evidence, therefore, that transport processes are\nclosely related in the gut and in the kidney, or at least that an\nimportant step in transport is identical at the two sites.  Such\ndisorders include disorders of carbohydrate absorption, hereditary\ndefects of amino acid absorption, hereditary defects in the\nabsorption of fat, hereditary disorders of the intestinal absorption\nof electrolytes, and hereditary defects of vitamin B12 absorption.',
#  '00047 ': 'Elasticity of sputum.  Elasticity of sputum has been determined\nusing the Weissenberg rheogoniometer, by oscillatory testing, over\nfrequencies from 0.01 to 0.8 c/s.  Sputum was from patients with\neither asthma, chronic bronchitis, cystic fibrosis, or\nbronchiectasis and, macroscopically, mucoid, mucopurulent or\npurulent.  As in the viscosity plot over this shear rate range two\nZones with a junctional region can be distinguished.  In Zone 1,\nover the lowest shear rates, elasticity increases slowly, changes\nlittle over a "plateau" region and then, in Zone 2, increases\nsharply.  In contrast to the viscosity plot, the plateau does not\nshow nothing.  By 0.8 c/s some samples show decreasing elasticity.\nAlthough variance between samples is wide, there is no level of\nelasticity characteristic of each disease or of one macroscopic\nappearance.  Elasticity and viscosity are correlated, most\nsignificantly at the lowest shear rates.  Asthmatic and\nbronchiectatic sputa resemble each other in that this correlation\nis still significant at higher shear rates, cystic fibrosis and\nchronic bronchitic sputum in that it is not.  Since in these last\ntwo mucous gland hypertrophy is present, it may be that the sputum\nhas a higher mucus component.',
#  '00048 ': 'Concentrations of immunoglobulins were determined (using Mancini\nmethod and WHO standard) in 108 sera taken during long term\ntreatment of 45 children with C.F. from 2 months to 16 years old.\nThey were shown to depend markedly on the clinical state of the\nchildren particularly on the presence of pulmonary tract infectious\nprocesses.  These infections caused a rise in immunoglobulin\nconcentration with predominance of IgM in C.F. children aged up to 3\nyrs, and with predominance of IgG in older children.  Mean titer of\nisohemagglutinins in children with C.F. was higher than in healthy\nchildren.  Low titers of diphtherial and stapholococcal antibodies\nwere found.  In the case of anti diphtheria antibodies, this can be\nattributed to the fact that these children are not regularly\nvaccinated owing to their poor clinical condition.  As to the low\ntiter of antistaphylococcal antibodies this is a well known finding\nin the course of chronic staphylococcal infections of appropriate\nbacteriological tests in our C.F. children.  Furthermore their\nlymphocytes showed an increased blastic transformation when\nstimulated with staphylococcal filtrate.  Transformation of\nPHA-stimulated lymphocytes was normal.',
#  '00049 ': 'A cross-over trial of pancreatic enzyme replacement therapy has\nbeen conducted on 12 children with cystic fibrosis using Pancrex V\nforte and Nutrizym tablets in equivalent dosage.  No differences\nwere found in the effectiveness of these products as measured by\nstool volume, number of bowel actions, faecal fat excretion, and\nurine urea excretion.  Neither product eliminated the steatorrhoea.\nThough there was no laboratory evidence to support their choice nine\npatients expressed a preference for Nutrizym at the conclusion of\nthe trial.  This preference was based partly on the smaller number\nof tablets which are required.',
#  '00050 ': "In an attempt to retard deterioration of pulmonary function, a\nyoung man with cystic fibrosis underwent broncho-pulmonary\nlavage of an entire lung.  In spite of theoretical advantages, the\nlavage produced an acute deterioration in the patient's clinical and\nphysiologic status, from which he had not recovered one month later.\nWe conclude that bronchopulmonary lavage in cystic fibrosis may be\nhazardous and should be reserved for those cases in which\nconventional methods of improving tracheobronchial clearance have\nfailed.",
#  '00051 ': 'The levels of galactosyltransferase have been studied in the sera\nobtained from 59 normal individuals varying in age from 5 - 19\nyears, and from 29 cystic fibrosis patients varying in age from\n5 - 33 years.  The enzyme level found in children was lower than\nthat in adults.  The levels in the sera of cystic fibrosis patients\nwas found to be about half of that in the normal sera for the\ncorresponding age group.  In those cystic fibrosis patients over 20\nyears of age, normal levels were found.',
#  '00052 ': 'The biochemical properties of the erythrocyte membrane have been\nstudied in cystic fibrosis patients and in age-matched controls.  No\nsignificant differences could be observed in either the\nconcentration or composition of the principal membrane constituents.\nContrary to previous reports, we found normal levels of the\nMg2+-dependent and Ca2+ + Mg2+-dependent ATPase activities in CF\npreparations.  However, a qualitative difference was observed in the\nCa2+-dependent ATPase, since the enzyme had relatively greater\nactivity at lower calcium concentrations in the cystic preparations.\nThis effect on the membrane-bound Ca2+-ATPase is unlikely to\nrepresent a genetic defect in the enzyme itself but it may be\nconnected with the mechanism of pathogenesis in cystic fibrosis.',
#  '00053 ': 'The levels and properties of microsomal glycoprotein\ngalactosyltransferase of cultured skin fibroblasts from control and\ncystic fibrosis patients were investigated using bovine submaxillary\ngland mucin as the exogenous acceptor.  Although the mean specific\nactivity of this enzyme was higher tin cystic fibrosis fibroblasts,\nthe difference was not significant.  The properties of the enzyme as\nregards pH optimum, metal ion and Triton X-100 requirement, apparent\nKm, heat stability and nucleotide/sugar-nucleotide response were\nsimilar for control and cystic fibrosis fibroblasts.',
#  '00054 ': 'Ca2+-ATPase activity, high affinity Ca2+ binding in the presence and\nabsence of ATP and low affinity Ca2+ binding at added CaCl2\nconcentrations of 1 microM, 100 microM and 10 mM were measured in\nisolated erythrocyte membranes from cystic fibrosis and control\nsubjects.  No significant difference was detected between the two\ngroups for any of these measurements.',
#  '00055 ': 'Various aspects of the immune status were examined in patients with\ncystic fibrosis (CF) and the following observations were made.  Ten\nper cent of the CF patients had elevated or reduced serum IgG\nconcentrations and there seems to be a transient low serum IgA\nconcentration in the same number.  Serum IgM concentrations were\nnormal in CF patients.  Normal levels of the three serum\nimmunoglobulins (IgG, IgA and IgM) were detected in the siblings and\nheterozygotes.  Serum IgE concentrations were elevated in 32% of\npatients with CF but normal concentrations were detected in\nheterozygotes and siblings.  Precipitating antibodies to various\nantigens and allergens were detected in the sputum of most patients\nwith CF, but their sera contained lower or undetectable titres of\nthese antibodies.  The precipitating antibodies in CF sputum to\nbacteria, to agar, to seminal fluid, to urine and to human serum may\nbe related to a common antigenic determinant of the glycoproteins\npresent in all these fluids.  The total protein concentration in the\nsputum of CF patients seemed to reflect the extent of lung damage.\nThe third component (C3) of serum complement concentration was\nnormal, or moderately elevated in all CF patients tested.  Serum\ntransferrin concentrations were normal in CF patients but their\nprealbumin levels were depressed, suggesting marginal\nundernutrition.  Peripheral blood lymphocyte transformations with\nPHA and PWM appear to be normal in CF patients.',
# ...
#  '00148 ': 'The diagnosis, management and prognosis of 17 infants with cystic\nfibrosis  (CF) and severe respiratory disease were reviewed for the\nperiod 1968 to 1972.  The clinical course of these infants was\ncharacterized by a bronchiolitis-like syndrome with failure to\nthrive and malnutrition.  Arterial blood gases demonstrated marked\nhypoxemia (mean PaO2, 36.5 mm Hg).  Tracheal cultures showed a\npredominance of gram-negative microorganisms with Pseudomonas\naeruginosa, Klebsiella pneumoniae and Escherichia coli\npredominating.  Corticosteroids were used in all patients.  Despite\nvigorous therapy including antibiotics there was a 60% mortality.\nA delay in the diagnosis of CF from the onset if respiratory\nsymptoms with a mean of six weeks was considered an important factor\naffecting survival.  This data supports the need for developing a\nreliable screen test for CF at birth.',
#  '00149 ': 'Liver-spleen scans on 254 children were reviewed retrospectively\nwith regard to accuracy and yield of examination.  The scan\npredicted abnormality correctly 95% of the time and normality\ncorrectly 86% of the time.  Pitfalls in interpretation include the\nnonspecificity of abnormalities present on the scan, confusion of\nextrinsic with intrinsic defects, and normal anatomical variations\nwith pathology.  The technetium-99m-sulfur colloid scan was found to\nbe most helpful in diagnosing splenic abnormalities, in working up\nabdominal masses, and in evaluating tumor patients with a baseline\nscan.  It was found least useful in patients with fever of unknown\norigin, abdominal pain, diffuse liver disease, and most inflammatory\nconditions.  Liver abscesses were not found in febrile, otherwise\nhealthy children.  The iodine-131-rose bengal liver scan was found\nto be useful to differentiate potentially curable lesions (e.g.,\ncholedochal cysts) from those not surgically treatable.',
#  '00150 ': 'Amylase isoenzyme patterns were evaluated in serum, urine, and\nduodenal fluid from 19 patients with cystic fibrosis (CF) and normal\nsubjects.  Two thirds of the CF patients with absent pancreatic\nenzymes lacked a serum pancreatic isoamylase band, while the\nremainder had a markedly diminished pancreatic band when compared to\nthe salivary isoamylase.  In normal sera the pancreatic band is\nequal to or greater than the salivary band.  In all patients with\nabsent enzymes the diagnosis of abnormal pancreatic function could\nhave been made by evaluation of serum isoamylase patterns thereby\navoiding duodenal intubation or collection of 72-hour stools for\nproteolytic enzyme activities.  The patients with normal pancreatic\nenzyme activities had normal serum zymograms.  No CF patient had a\nlow total serum amylase concentration.  Total duodenal fluid amylase\nlevels may be misleading in the evaluation of pancreatic function\nsince the amylase may be of salivary origin.  The advantages of this\nisoamylase method include (1) simplicity and noninvasiveness,\nrequiring only a small blood sample; (2) specificity for pancreatic\nfunction; and (3) independence of pancreatic enzyme medication.',
#  '00151 ': 'Gastric mucosal biopsies from eight new untreated patients with\ncystic fibrosis (CF) and two normal subjects were studied by\nquantitative techniques of electron microscopy (EM) to determine\nwhether presecreted gastric mucus was more compact (viscid) than\nnormal.  Analysis of variance techniques show no differences between\nmeans of all groups studied.  These observations suggest that mucus\nmay not be viscid prior to secretion.  Electron microscopy of\ngastric mucus does not appear to be of diagnostic value in CF.',
#  '00152 ': 'Gentamicin is a broad-spectrum, bactericidal aminoglycoside\nantibiotic in its tenth year of use in the U.K.  League tables of\nantibiotics, ranked by disc sensitivity tests against urinary tract\npathogens and Staph. aureus confirm its remarkable effectiveness in\n1973.  Bacteriodes sp. and some streptococci are the only major\nomissions from its spectrum.  MIC of sensitive strains is usually\nless than or equal to 2 microg/ml although Pseudomonas may require\ngreater than or equal to 4 microg/ml.  The therapeutic range aimed\nfor is 2-12 microg/ml in serum and peak levels are measured 1 hr\nafter intramuscular and 20 min after intravenous injection.  Most\nworkers regard a level of 12 microg/ml as potentially toxic and try\nto avoid exceeding it.',
#  '00153 ': 'The aim of a therapeutic diet is to provide a nutritionally adequate\ndiet from a variety of natural and/or specially prepared artificial\nfood substitutes for the treatment of specific clinical disorders.\nThe role of the dietitian is to work as a member of the medical team.\nPaediatric dietetics require rather more detailed advice and help for\nthe parents, particularly when the diet involves calculation or\nrestriction of specific nutrients.  Dietary considerations in\nobesity, diabetes mellitus, coeliac disease, cystic fibrosis,\ncarbohydrate intolerance, galactosaemia, and phenylketonuria are\ndiscussed.',
#  '00154 ': 'This paper analyzes the cell cycle of cystic fibrosis-derived\nfibroblasts and statistically demonstrates their failure to support a\nnormal population doubling time in vitro and indicates that this is\ndue largely to a failure of the cystic fibrosis-derived cells to\nenter the cell cycle in normal numbers.  We have no explanation for\nthe significant difference in the behavior of these cells from\npatients with cystic fibrosis vis-a-vis either normal or disease\ncontrol fibroblasts, save to conclude that it proceeds from an\nintrinsic property of the cells themselves.',
#  '00155 ': "Twenty-five children aged 8 months to 17 years were studied to\ndetermine the usefulness of computer-assisted ventilation-perfusion\n(V-P) scanning in analysis of regional pulmonary function in cystic\nfibrosis.  Ventilation and perfusion scintiphotographs were compared\nwith the patients' radiographs.  Regional fractional exchanges of\nair and relative regional V-P ratios were obtained.  Whole-lung\nair-exchange was significantly correlated with standard pulmonary\nfunction tests and radiograph scores.  Ventilation-perfusion ratio\ngradients were reversed in pats with predominantly upper zone\ndisease, and regional V-P ratios were uneven in distribution.\nQuantitative assessment of regional ventilation and perfusion is a\nuseful technique for assessing severity of pulmonary disease in\nchildren with cystic fibrosis.",
#  '00156 ': 'The endoscopic pancreaticographic findings in 46 proved cases of\npancreatitis are analyzed.  Pathologic ductograms were demonstrated\nin approximately 60%.  Significant information was obtained in many\ncases, allowing both proper diagnosis of the primary disease process\nand complications thereof.  Because of the latter, the procedure has\nproved to be quite helpful in isolating those patients who could\nbenefit from surgery.',
#  '00157 ': 'This section considers the significance of vitamin E (tocopherol)\ndeficiency in a variety of disease states in which the effects of the\nvitamin lack are unclear.  Causes of vitamin E deficiency include\ndietary lack and intestinal malabsorption.  A case history involving\ncystic fibrosis is examined.',
#  '00158 ': 'Albumin in meconium was quantitated by means of a single radial\nimmunodiffusion technique, which is described in detail.  The method\nshows good precision and accuracy for this material, when certain\nconditions associated with collection, preparation, and analysis are\nobserved.  The method can discriminate between healthy newborns and\nnewborns with cystic fibrosis.',
#  '00159 ': 'Tobramycin treatment of chronic pulmonary infections caused by\nPseudomonas aeruginosa in 13 children with cystic fibrosis was\nevaluated.  Initially the patients received the recommended dose\nof 125 mg/m2/24 hours; the dose was then increased to 250 mg/m2/24\nhours (approximately 10 mg/kg/24 hours).  This higher dosage was\nadministered intramuscularly to 9 patients.  Eight of these\nreceived additional therapy with an aerosol containing tobramycin.\nWith this therapy it was possible to eradicate Ps. aeruginosa from\nthe respiratory tract in 5 of the patients.  After discontinuing\ntherapy Ps. aeruginosa re-occurred in all patients within one month.\nAll patients showed a clinical improvement in relation to therapy.\nNo toxic or allergic side effects were observed.',
#  '00160 ': 'Thirty-five patients with cystic fibrosis (aged 11 months to 13.5\nyears) have been investigated with regard to respiratory symptoms,\nrespiratory tract pathogens, serum immunoglobulins and serum\nprecipitins.  Haemophilus influenzae was the commonest pathogen\nbeing supplanted in advanced disease by Pseudomonas aeruginosa.  The\npatients who had no respiratory infection had levels of IgG\nsignificantly lower than normal children of comparable ages.  In\nchildren with severe respiratory infection the immunoglobulins\nwere raised and precipitins to the predominant respiratory organism\nwere present.  These findings differ from the prevalent view that\npatients with cystic fibrosis have a normal response to infection\nand that the common infecting organism is Staphylococcus aureus.',
#  '00161 ': 'To compare the in vitro susceptibility of mucoid and nonmucoid\nPseudomonas aeruginosa to gentamicin, 144 isolates of both mucoid\nand nonmucoid P aeruginosa were cultured from throat swab and\nsputum specimens from 29 patients with diagnosed cystic fibrosis.\nMucoid forms of P aeruginosa from throat swab cultures were all\nsusceptible to gentamicin, whereas only 85.5% of the mucoid strains\nfrom sputum cultures were susceptible.  Nonmucoid strains from\nthroat swab and sputum cultures were 85.1% and 77.8% susceptible,\nrespectively.  Since the differences in susceptibility between the\nfour groups of organisms were not significant (P < 0.05), it was\nconcluded that these data show no real differences in susceptibility\nto gentamicin between the mucoid and nonmucoid strains.',
#  '00162 ': 'The purpose of the present work was to study the type of inheritance\ninvolved in mucoviscidosis.  Analysis of the genetic relations in\nmucoviscidosis performed on 26 families bears witness to a monomeric\nautosomal mechanism of transmission of the character.  In contrast to\nother recessive diseases, parental consanguinity plays a secondary\nrole in mucoviscidosis, which apparently is explained by the wide\ndistribution of the mucoviscidosis gene among the population.  The\nobservations described may be utilized in medicogenetic consultations\ngiven to members of those families where there are children suffering\nfrom mucoviscidosis.',
#  '00163 ': 'It has been suggested that the development of goiter and\nhypothyroidism in patients receiving chronic iodide therapy indicates\nthat they have underlying thyroid disease.  In 1971, Dolan and\nGibson, in a retrospective study, reviewed the records of children\nwith cystic fibrosis receiving chronic expectorant therapy with\niodide and reported that approximately 85 percent had goiter and 15\npercent suggestive clinical findings of hypothyroidism.  This study,\ntogether with the fact that the thyroid, like lung and pancreas, is\nof endodermal origin raised the possibility that patients with cystic\nfibrosis might have an underlying defect in thyroid function.  As\nthyroid function in patients with cystic fibrosis has not been\nevaluated in a systematic fashion, the present study was undertaken.\nIn it, we have evaluated basal thyroid function in a large group of\npatients with cystic fibrosis and have, in addition, observed the\neffects of chronic iodide administration.  The present study strongly\nsuggests that there often occurs in patients with cystic fibrosis\nsome derangement in thyroid hormone economy.  The frequency with\nwhich iodides increased serum thyrotropin, decreased serum thyroxine\nconcentration, and induced goiter, with or without hypothyroidism, in\npatients with cystic fibrosis, points strongly to the presence of an\nintrinsic abnormality of the thyroid in this disease.  The nature of\nsuch abnormality remains unclear.',
#  '00164 ': 'This preliminary clinical study is of the ability of a multivalent\nheat-killed whole cell gram-negative bacilli vaccine to be tolerated\nand to evoke an antibody response in groups of patients who have a\nmanifest need for increased resistance to gram-negative bacilli.\nThree groups of patients were studied: 35 burn patients; seven small\nchildren with cystic fibrosis; and 35 patients who were about to\nundergo coronary vein grafts.  The results of vaccination were\ndifferent in each of the three groups of patients that were\nvaccinated.',
#  '00165 ': "The author has attempted to evaluate some of the methodology\ncurrently in use or suggested for the routine determination of\nvitamin A in blood and tissues.  Special consideration is given to\nextraneous factors which can cause erroneous results in fluorometric\nanalyses.  A review of the older and current literature on the\ndistribution of vitamin A in tissues is presented.  Special\nconsideration is given to the uptake of vitamin A by the liver and\nits storage in hepatocytes and Kupffer's cell and in subcellular\norganelles.  Data on the concentration of vitamin A in the liver of\nvictims of accidental death and the effect of diseases of several\netiologies are presented.  The mechanism by which liver stores of\nretinyl esters are mobilized and released to the plasma remains\nobscure.  Considerable information has been gained recently on the\nmechanism by which retinol is transported in blood.  Studies leading\nto the isolation and characterization of retinol transport proteins\nare summarized.  The metabolism of retinol binding protein in health\nand in disease, especially in cystic fibrosis, is discussed.\nFinally, some factors of importance to the interpretation of plasma\nlevels in terms of vitamin A are reviewed.  Special attention is\ngiven to the effect on plasma levels of retinol and the retinol\ntransport proteins of periods of rapid growth (correlations with age)\nand the influence of dietary adequacy on the distribution of plasma\nlevels of the vitamin.",
#  '00166 ': 'The pulmonary macrophages collected with bronchial mucus from\npatients with cystic fibrosis and other chronic lung diseases were\ninvestigated histochemically for acid phosphatase,\nbeta-glucuronidase and beta-glucosaminidase activity, and also for\nmucopolysaccharide content.  In macrophages from patients with\ncystic fibrosis decreased beta-glucuronidase activity was observed,\ntogether with large cytoplasmic vacuoles suggesting storage of\npartially digested material.  It thus seems very likely that apart\nfrom the increased synthesis of mucopolysaccharides described in\ncystic fibrosis by several authors, the degradation of\nmucosubstances produced can be impaired.',
#  '00167 ': 'HL-A frequencies of 28 patients with cystic fibrosis and of 240\nunrelated controls were compared.  No statistically significant\ndifference of HL-A frequencies could be observed for both groups.  A\nslightly increased HL-A 2 frequency is considered a chance\nphenomenon.  In accordance with a previously demonstrated lacking\nassociation of the ABH blood group substances no correlation with\ncertain HL-A antigens was demonstrable.'}

# %% [markdown]
# ### Pre-processing texts

# %%
WORD_MIN_LENGTH = 2
STOP_WORDS_ENG = [stop_word.lower() for stop_word in nltk.corpus.stopwords.words('english')]

def strip_accents(text):
    nfkd = unicodedata.normalize('NFKD', text)
    stripped_text = u"".join([c for c in nfkd if not unicodedata.combining(c)])
    return re.sub('[^a-zA-Z]', ' ', stripped_text)

def tokenize(text):
    text = strip_accents(text)
    text = re.sub(re.compile('\n'),' ',text)
    words = word_tokenize(text)
    words = [word.lower() for word in words]
    words = [word for word in words if word not in STOP_WORDS_ENG and len(word) >= WORD_MIN_LENGTH]
    return words

def lemmatize(text):
    lemmatized_text = []
    for (word) in text:
        lemmatizing = str(WordNetLemmatizer().lemmatize(word))
        lemmatized_text.append(lemmatizing)
    return lemmatized_text

def get_unique_words(preprocessed_data):
    all_words = []
    for rec_num, words in preprocessed_data.items():
        for word in words:
            all_words.append(word)
    
    unique_words = nltk.FreqDist(all_words).keys()
    unique_words = [word.upper() for word in unique_words]
    return unique_words

# %%
def preprocess(data):
    preprocessed_data = {}
    for rec_num, text in data.items():
        preprocessed_data[rec_num] = tokenize(text)
        preprocessed_data[rec_num] = lemmatize(preprocessed_data[rec_num])
        preprocessed_data[rec_num] = [word.upper() for word in preprocessed_data[rec_num]]
    return preprocessed_data

pp_data = preprocess(cf74_data)

# %% [markdown]
# ###### Lista de palavras encontradas nos textos

# %%
unique_words_list = get_unique_words(pp_data)

# %%
pp_data
# Out:
# {'00001 ': ['SIGNIFICANCE',
#   'PSEUDOMONAS',
#   'AERUGINOSA',
#   'INFECTION',
#   'RESPIRATORY',
#   'TRACT',
#   'CYSTIC',
#   'FIBROSIS',
#   'PATIENT',
#   'STUDIED',
#   'MEAN',
#   'IMMUNOELECTROPHORETICAL',
#   'ANALYSIS',
#   'PATIENT',
#   'SERUM',
#   'NUMBER',
#   'PRECIPITIN',
#   'PSEUDOMONAS',
#   'AERUGINOSA',
#   'CONCENTRATION',
#   'SERUM',
#   'PROTEIN',
#   'ADDITION',
#   'CLINICAL',
#   'RADIOGRAPHICAL',
#   'STATUS',
#   'LUNG',
#   'EVALUATED',
#   'USING',
#   'SCORING',
#   'SYSTEM',
#   'PRECIPITIN',
#   'PSEUDOMONAS',
#   'AERUGINOSA',
#   'DEMONSTRATED',
#   'SERUM',
#   'MAXIMUM',
#   'NUMBER',
#   'ONE',
#   'SERUM',
#   'CONCENTRATION',
#   'SERUM',
#   'PROTEIN',
#   'SIGNIFICANTLY',
#   'CHANGED',
#   'COMPARED',
#   'MATCHED',
#   'CONTROL',
#   'PERSON',
#   'NOTABLY',
#   'IGG',
#   'IGA',
#   'ELEVATED',
#   'ACUTE',
#   'PHASE',
#   'PROTEIN',
#   'CHANGED',
#   'LATTER',
#   'SUGGESTING',
#   'ACTIVE',
#   'TISSUE',
#   'DAMAGE',
#   'CONCENTRATION',
#   'ACUTE',
#   'PHASE',
#   'PROTEIN',
#   'NOTABLY',
#   'HAPTOGLOBIN',
#   'CORRELATED',
#   'NUMBER',
#   'PRECIPITIN',
#   'SUGGESTING',
#   'RESPIRATORY',
#   'TRACT',
#   'INFECTION',
#   'PATIENT',
#   'MANY',
#   'PRECIPITIN',
#   'ACCOMPANIED',
#   'TISSUE',
#   'DAMAGE',
#   'INFECTION',
#   'PATIENT',
#   'PRECIPITIN',
#   'RESULT',
#   'INDICATE',
#   'PROTECTIVE',
#   'VALUE',
#   'MANY',
#   'PRECIPITIN',
#   'TISSUE',
#   'RESPIRATORY',
#   'TRACT'],
#  '00002 ': ['SALIVARY',
#   'AMYLASE',
#   'LEVEL',
#   'DETERMINED',
#   'NORMAL',
#   'SUBJECT',
#   'BIRTH',
#   'ADULT',
#   'LIFE',
#   'CHILD',
#   'CONDITION',
#   'SOMETIMES',
#   'ASSOCIATED',
#   'LOW',
#   'PANCREATIC',
#   'AMYLASE',
#   'MALNUTRITION',
#   'COELIAC',
#   'DISEASE',
#   'CYSTIC',
#   'FIBROSIS',
#   'MIXED',
#   'SALIVA',
#   'COLLECTED',
#   'CAREFULLY',
#   'STANDARDISED',
#   'CONDITION',
#   'AMYLASE',
#   'MEASURED',
#   'METHOD',
#   'DAHLQVIST',
#   'WIDE',
#   'SCATTER',
#   'VALUE',
#   'NORMAL',
#   'SUBJECT',
#   'CONCENTRATION',
#   'ROSE',
#   'LOW',
#   'LEVEL',
#   'BIRTH',
#   'REACH',
#   'ADULT',
#   'LEVEL',
#   'AGE',
#   'MONTH',
#   'YEAR',
#   'SALIVARY',
#   'AMYLASE',
#   'ACTIVITY',
#   'ROSE',
#   'NORMALLY',
#   'TEN',
#   'WEEK',
#   'ONE',
#   'PREMATURE',
#   'INFANT',
#   'FED',
#   'MILK',
#   'GASTROSTOMY',
#   'THIRTEEN',
#   'CHILD',
#   'COELIAC',
#   'DISEASE',
#   'CHILD',
#   'CYSTIC',
#   'FIBROSIS',
#   'MOSTLY',
#   'NORMAL',
#   'SALIVARY',
#   'AMYLASE',
#   'CONCENTRATION',
#   'SIX',
#   'MALNOURISHED',
#   'CHILD',
#   'JEJUNAL',
#   'VILLOUS',
#   'ATROPHY',
#   'UNCERTAIN',
#   'AETIOLOGY',
#   'LOW',
#   'LEVEL',
#   'ROSE',
#   'NORMAL',
#   'RECOVERY',
#   'BEGAN'],
#  '00003 ': ['ARTICLE',
#   'REPORT',
#   'POSSIBILITY',
#   'USING',
#   'INSTRUMENTAL',
#   'NEUTRON',
#   'ACTIVATION',
#   'ANALYSIS',
#   'INAA',
#   'SODIUM',
#   'NAIL',
#   'CLIPPING',
#   'DIAGNOSING',
#   'CYSTIC',
#   'FIBROSIS',
#   'CF',
#   'CHILD',
#   'ADULT',
#   'DETECTING',
#   'HETEROZYGOTE',
#   'SCREENING',
#   'NEONATAL',
#   'PERIOD',
#   'NAIL',
#   'CLIPPING',
#   'NEWBORN',
#   'CF',
#   'PATIENT',
#   'TWO',
#   'NEWBORN',
#   'HEALTHY',
#   'CONTROL',
#   'HETEROZYGOTE',
#   'ANALYZED',
#   'DISCRIMINATION',
#   'CF',
#   'PATIENT',
#   'CONTROL',
#   'FOUND',
#   'PRECISE',
#   'INDIVIDUAL',
#   'ONE',
#   'YEAR',
#   'AGE',
#   'INAA',
#   'NAIL',
#   'CLIPPING',
#   'ACCEPTED',
#   'DIAGNOSTIC',
#   'TEST',
#   'CF',
#   'AGE',
#   'HETEROZYGOTE',
#   'COULD',
#   'DETECTED',
#   'METHOD',
#   'FIRST',
#   'FIVE',
#   'DAY',
#   'LIFE',
#   'BIG',
#   'OVERLAP',
#   'VALUE',
#   'NORMAL',
#   'NEWBORN',
#   'CF',
#   'CHILD',
#   'MAKE',
#   'METHOD',
#   'INVALUABLE',
#   'EARLY',
#   'SCREENING',
#   'CF'],
#  '00004 ': ['INSTRUMENTAL',
#   'NEUTRON',
#   'ACTIVATION',
#   'ANALYSIS',
#   'INAA',
#   'NAIL',
#   'CLIPPING',
#   'USED',
#   'DEVELOPMENT',
#   'DIAGNOSTIC',
#   'METHOD',
#   'CYSTIC',
#   'FIBROSIS',
#   'CF',
#   'CF',
#   'PATIENT',
#   'CONTROL',
#   'THREE',
#   'YEAR',
#   'OLD',
#   'NAIL',
#   'CLIPPING',
#   'SAMPLED',
#   'TEST',
#   'DIFFERENT',
#   'ERROR',
#   'RESULT',
#   'STUDY',
#   'PRECISE',
#   'COLLECTION',
#   'ROUTINE',
#   'OUTLINED',
#   'SODIUM',
#   'EASILY',
#   'WASHED',
#   'NAIL',
#   'CLIPPING',
#   'RISK',
#   'SODIUM',
#   'CONTAMINATION',
#   'NAIL',
#   'SEEMS',
#   'SMALL',
#   'SODIUM',
#   'DISTRIBUTION',
#   'NAIL',
#   'INHOMOGENEOUS',
#   'SODIUM',
#   'CONTENT',
#   'VARIES',
#   'ALSO',
#   'NAIL',
#   'NAIL',
#   'PERSON',
#   'GOOD',
#   'EVIDENCE',
#   'INCREASED',
#   'SODIUM',
#   'NAIL',
#   'CF',
#   'PATIENT',
#   'COME',
#   'SWEAT',
#   'SEEMS',
#   'BASIC',
#   'INTRINSIC',
#   'SODIUM',
#   'LEVEL',
#   'NAIL',
#   'CF',
#   'PATIENT',
#   'CONTROL',
#   'PRECISION',
#   'ACCURACY',
#   'INAA',
#   'DETERMINING',
#   'SODIUM',
#   'NAIL',
#   'CONSIDERED',
#   'SATISFACTORY',
#   'CONCLUDED',
#   'INAA',
#   'SODIUM',
#   'CONCENTRATION',
#   'NAIL',
#   'CLIPPING',
#   'SUITABLE',
#   'METHOD',
#   'AID',
#   'DIAGNOSIS',
#   'CF',
#   'PRECISE',
#   'COLLECTION',
#   'ROUTINE',
#   'USED'],
#  '00005 ': ['CAPACITY',
#   'DUODENAL',
#   'JUICE',
#   'HYDROLYSE',
#   'CASEIN',
#   'TRICHLOROACETIC',
#   'ACID',
#   'SOLUBLE',
#   'PEPTIDE',
#   'INVESTIGATED',
#   'CONTROL',
#   'GROUP',
#   'INFANT',
#   'CHILD',
#   'ADULT',
#   'CHILD',
#   'PANCREATIC',
#   'DISEASE',
#   'CHILD',
#   'ENTEROGENIC',
#   'MALABSORPTION',
#   'COELIAC',
#   'DISEASE',
#   'COW',
#   'MILK',
#   'PROTEIN',
#   'INTOLERANCE',
#   'PROTEOLYTIC',
#   'ACTIVITY',
#   'PER',
#   'ML',
#   'DUODENAL',
#   'JUICE',
#   'FASTING',
#   'CONDITION',
#   'GREAT',
#   'HEALTHY',
#   'INFANT',
#   'CHILD',
#   'HEALTHY',
#   'ADULT',
#   'MG',
#   'CASEIN',
#   'ML',
#   'HOUR',
#   'GOOD',
#   'CORRELATION',
#   'TRYPSIN',
#   'CONTENT',
#   'PROTEOLYTIC',
#   'ACTIVITY',
#   'DUODENAL',
#   'JUICE',
#   'PANCREATIC',
#   'INSUFFICIENCY',
#   'PROTEOLYTIC',
#   'ACTIVITY',
#   'EXTREMELY',
#   'LOW',
#   'MEASURABLE',
#   'PATIENT',
#   'TRYPSIN',
#   'ACTIVITY',
#   'WHEREAS',
#   'ENTEROGENIC',
#   'MALABSORPTION',
#   'WITHIN',
#   'RANGE',
#   'CONTROL'],
#  '00006 ': ['INFLUENCE',
#   'CHRONIC',
#   'P',
#   'AERUGINOSA',
#   'INFECTION',
#   'OCCURRENCE',
#   'BONE',
#   'MARROW',
#   'DERIVED',
#   'LYMPHOCYTE',
#   'CELL',
#   'THYMUS',
#   'DERIVED',
#   'LYMPHOCYTE',
#   'CELL',
#   'PERIPHERAL',
#   'BLOOD',
#   'STUDIED',
#   'GROUP',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'ONE',
#   'GROUP',
#   'PATIENT',
#   'SUFFERED',
#   'CHRONIC',
#   'P',
#   'AERUGINOSA',
#   'INFECTION',
#   'RESPIRATORY',
#   'TRACT',
#   'PRODUCED',
#   'MULTIPLE',
#   'P',
#   'AERUGINOSA',
#   'PRECIPITIN',
#   'DEMONSTRATED',
#   'MEAN',
#   'CROSSED',
#   'IMMUNOELECTROPHORESIS',
#   'GROUP',
#   'PATIENT',
#   'NEVER',
#   'HARBOURED',
#   'P',
#   'AERUGINOSA',
#   'RESPIRATORY',
#   'TRACT',
#   'PRESENTED',
#   'DEMONSTRABLE',
#   'PRECIPITIN',
#   'BACTERIA',
#   'LYMPHOCYTE',
#   'EXAMINED',
#   'PRESENCE',
#   'SURFACE',
#   'MARKER',
#   'CELL',
#   'RECEPTOR',
#   'COMPLEMENT',
#   'COMPONENT',
#   'EAC',
#   'ROSETTE',
#   'FORMATION',
#   'SURFACE',
#   'IMMUNOGLOBULIN',
#   'IMMUNOFLUORESCENT',
#   'STAINING',
#   'PRESENCE',
#   'SURFACE',
#   'MARKER',
#   'CELL',
#   'SPONTANEOUS',
#   'BINDING',
#   'SHEEP',
#   'RED',
#   'BLOOD',
#   'CELL',
#   'ROSETTE',
#   'FORMATION',
#   'CELL',
#   'RATIO',
#   'NEARLY',
#   'IDENTICAL',
#   'GROUP',
#   'PATIENT',
#   'WHEREAS',
#   'TOTAL',
#   'NUMBER',
#   'CELL',
#   'SIGNIFICANT',
#   'HIGHER',
#   'PATIENT',
#   'CHRONIC',
#   'P',
#   'AERUGINOSA',
#   'INFECTION',
#   'NUMBER',
#   'P',
#   'AERUGINOSA',
#   'PRECIPITIN',
#   'PER',
#   'SERUM',
#   'SIGNIFICANTLY',
#   'POSITIVELY',
#   'CORRELATED',
#   'TOTAL',
#   'NUMBER',
#   'CELL',
#   'WHERAS',
#   'CORRELATION',
#   'TOTAL',
#   'NUMBER',
#   'CELL',
#   'INSIGNIFICANT'],
#  '00007 ': ['OCCURRENCE',
#   'PSEUDOMONAS',
#   'AERUGINOSA',
#   'RESPIRATORY',
#   'TRACT',
#   'CYSTIC',
#   'FIBROSIS',
#   'PATIENT',
#   'OCCURRENCE',
#   'PRECIPITIN',
#   'P',
#   'AERUGINOSA',
#   'SERUM',
#   'PATIENT',
#   'INVESTIGATED',
#   'ONE',
#   'YEAR',
#   'MEAN',
#   'MONTHLY',
#   'BACTERIOLOGICAL',
#   'EXAMINATION',
#   'TRACHEAL',
#   'SECRETION',
#   'MEAN',
#   'CROSSED',
#   'IMMUNOELECTROPHORESIS',
#   'POLYVALENT',
#   'P',
#   'AERUGINOSA',
#   'ANTIGEN',
#   'SERUM',
#   'PATIENT',
#   'ONE',
#   'YEAR',
#   'PERIOD',
#   'PREVALENCE',
#   'RATE',
#   'PATIENT',
#   'HARBOURING',
#   'P',
#   'AERUGINOSA',
#   'PER',
#   'CENT',
#   'NEWLY',
#   'COLONIZED',
#   'PATIENT',
#   'INTERMITTENTLY',
#   'COLONIZED',
#   'PATIENT',
#   'NON',
#   'MUCOID',
#   'STRAIN',
#   'PREDOMINATING',
#   'WHEREAS',
#   'MUCOID',
#   'STRAIN',
#   'PREDOMINATING',
#   'CHRONICALLY',
#   'COLONIZED',
#   'PATIENT',
#   'OCCURRENCE',
#   'MUCOID',
#   'STRAIN',
#   'ESPECIALLY',
#   'CHRONICALLY',
#   'COLONIZED',
#   'PATIENT',
#   'ASSOCIATED',
#   'SIGNIFICANTLY',
#   'HIGHER',
#   'NUMBER',
#   'PRECIPITIN',
#   'P',
#   'AERUGINOSA',
#   'OCCURRENCE',
#   'NON',
#   'MUCOID',
#   'STRAIN',
#   'MALE',
#   'CHRONICALLY',
#   'COLONIZED',
#   'MUCOID',
#   'STRAIN',
#   'PRESENTED',
#   'SIGNIFICANTLY',
#   'HIGHER',
#   'NUMBER',
#   'PRECIPITIN',
#   'FEMALE',
#   'CHRONICALLY',
#   'COLONIZED',
#   'MUCOID',
#   'STRAIN',
#   'NUMBER',
#   'PRECIPITIN',
#   'CORRELATED',
#   'DURATION',
#   'CHRONIC',
#   'COLONIZATION',
#   'P',
#   'AERUGINOSA',
#   'MALE',
#   'CONTRAST',
#   'FEMALE',
#   'RESULT',
#   'ACCORDANCE',
#   'HYPOTHESIS',
#   'MUCOID',
#   'SUBSTANCE',
#   'COULD',
#   'VIRULENCE',
#   'FACTOR',
#   'MIGHT',
#   'INHIBIT',
#   'OPSONIZING',
#   'EFFECT',
#   'PRECIPITIN',
#   'MUCOID',
#   'CELL',
#   'COMPLEMENT',
#   'DEPENDENT',
#   'LYSIS',
#   'CELL',
#   'HEREBY',
#   'FAVOURING',
#   'MUCOID',
#   'STRAIN',
#   'EXPENSE',
#   'NON',
#   'MUCOID',
#   'STRAIN',
#   'RESPIRATORY',
#   'TRACT',
#   'CYSTIC',
#   'FIBROSIS',
#   'PATIENT'],
#  '00008 ': ['SEVENTY',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'TREATED',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'CLINIC',
#   'FOLLOWED',
#   'ONE',
#   'YEAR',
#   'MONTHLY',
#   'BACTERIOLOGICAL',
#   'EXAMINATION',
#   'TRACHEAL',
#   'SECRETION',
#   'DAILY',
#   'IMPRESSION',
#   'OBTAINED',
#   'LABORATORY',
#   'EXPRESSED',
#   'MEAN',
#   'POINT',
#   'PREVALENCE',
#   'RATE',
#   'PSEUDOMONAS',
#   'AERUGINOSA',
#   'PER',
#   'CENT',
#   'STAPHYLOCOCCUS',
#   'AUREUS',
#   'PER',
#   'CENT',
#   'HAEMOPHILUS',
#   'INFLUENZAE',
#   'PER',
#   'CENT',
#   'DIPLOCOCCUS',
#   'PNEUMONIAE',
#   'PER',
#   'CENT',
#   'MISCELLANEOUS',
#   'BACTERIA',
#   'MAINLY',
#   'ENTEROBACTERIACEAE',
#   'PER',
#   'CENT',
#   'FLUCTUATION',
#   'BACTERIOLOGY',
#   'DESCRIBED',
#   'ADDITIONAL',
#   'EPIDEMIOLOGICAL',
#   'TERM',
#   'ONE',
#   'EXAMINATION',
#   'STUDY',
#   'PERIOD',
#   'PREVALENCE',
#   'RATE',
#   'PER',
#   'CENT',
#   'PATIENT',
#   'HARBOURED',
#   'ST',
#   'AUREUS',
#   'PER',
#   'CENT',
#   'P',
#   'AERUGINOSA',
#   'MAINLY',
#   'MUCOID',
#   'STRAIN',
#   'PER',
#   'CENT',
#   'INFLUENZAE',
#   'PER',
#   'CENT',
#   'PNEUMONIAE',
#   'PER',
#   'CENT',
#   'MISCELLANEOUS',
#   'BACTERIA',
#   'MAINLY',
#   'ENTEROBACTERIACEAE',
#   'PATTERN',
#   'FOUND',
#   'AGE',
#   'GROUP',
#   'MINOR',
#   'AGE',
#   'DEPENDENT',
#   'MODIFICATION',
#   'ESPECIALLY',
#   'REGARD',
#   'ENTEROBACTERIACEAE',
#   'P',
#   'AERUGINOSA',
#   'PREDOMINATING',
#   'REGARD',
#   'CHRONIC',
#   'COLONIZATION',
#   'REFLECTS',
#   'DIFFICULT',
#   'THERAPEUTIC',
#   'PROBLEM',
#   'PERIOD',
#   'PREVALENCE',
#   'RATE',
#   'PER',
#   'CENT',
#   'CONTRAST',
#   'ST',
#   'AUREUS',
#   'PER',
#   'CENT',
#   'INFLUENZAE',
#   'PER',
#   'CENT',
#   'ST',
#   'AUREUS',
#   'PREDOMINATING',
#   'REGARD',
#   'NEW',
#   'COLONIZATION',
#   'RECOLONIZATION',
#   'REFLECT',
#   'PROBLEM',
#   'PREVENTION',
#   'INCIDENCE',
#   'RATE',
#   'NEW',
#   'COLONIZATION',
#   'RECOLONIZATION',
#   'PER',
#   'RISK',
#   'GROUP',
#   'PER',
#   'CENT',
#   'FOLLOWED',
#   'INFLUENZAE',
#   'PER',
#   'CENT',
#   'P',
#   'AERUGINOSA',
#   'PER',
#   'CENT',
#   'PNEUMONIAE',
#   'PER',
#   'CENT',
#   'RESULT',
#   'SHOW',
#   'BACTERIOLOGICAL',
#   'PROBLEM',
#   'CYSTIC',
#   'FIBROSIS',
#   'STILL',
#   'CONSIDERABLE',
#   'REGARD',
#   'THERAPY',
#   'WELL',
#   'PREVENTION',
#   'ALTHOUGH',
#   'MANY',
#   'SPECIE',
#   'MAY',
#   'COLONIZE',
#   'RESPIRATORY',
#   'TRACT',
#   'PATIENT',
#   'MAIN',
#   'CLINICAL',
#   'PROBLEM',
#   'CONCERN',
#   'P',
#   'AERUGINOSA',
#   'ST',
#   'AUREUS',
#   'REASON',
#   'DISCUSSED'],
#  '00009 ': ['FAMILY',
#   'PRESENTED',
#   'CELIAC',
#   'SPRUE',
#   'CYSTIC',
#   'FIBROSIS',
#   'OCCURRED',
#   'WITHIN',
#   'SIBSHIP',
#   'COUSIN',
#   'INDEX',
#   'CASE',
#   'ALSO',
#   'DISCOVERED',
#   'CELIAC',
#   'SPRUE',
#   'GENETICS',
#   'INCIDENCE',
#   'CONDITION',
#   'REVIEWED',
#   'ESTIMATED',
#   'LIKELIHOOD',
#   'ASSOCIATION',
#   'OCCURRING',
#   'BASIS',
#   'CHANCE',
#   'FAMILY'],
#  '00010 ': ['PATIENT',
#   'EXHIBITED',
#   'FEATURE',
#   'KARTAGENER',
#   'SYNDROME',
#   'CYSTIC',
#   'FIBROSIS',
#   'AUTHOR',
#   'KNOWLEDGE',
#   'REPRESENTS',
#   'THIRD',
#   'REPORT',
#   'COMBINATION',
#   'CYSTIC',
#   'FIBROSIS',
#   'EXCLUDED',
#   'DIAGNOSIS',
#   'KARTAGENER',
#   'SYNDROME',
#   'MADE'],
#  '00011 ': ['PREVALENCE',
#   'RESPIRATORY',
#   'ALLERGY',
#   'EFFECT',
#   'COURSE',
#   'CYSTIC',
#   'FIBROSIS',
#   'CF',
#   'STUDIED',
#   'PATIENT',
#   'FIFTEEN',
#   'PATIENT',
#   'RESPIRATORY',
#   'ALLERGY',
#   'DEFINED',
#   'HISTORY',
#   'PHYSICAL',
#   'EXAMINATION',
#   'POSITIVE',
#   'ALLERGY',
#   'SKIN',
#   'TEST',
#   'NASAL',
#   'PERIPHERAL',
#   'EOSINOPHILIA',
#   'REVERSIBLE',
#   'AIRWAY',
#   'OBSTRUCTION',
#   'SERUM',
#   'IMMUNOGLOBULIN',
#   'ALLERGIC',
#   'CF',
#   'NONALLERGIC',
#   'CF',
#   'PATIENT',
#   'ELEVATED',
#   'COMPARED',
#   'NORMAL',
#   'AGE',
#   'MATCHED',
#   'CONTROL',
#   'ALLERGIC',
#   'CF',
#   'PATIENT',
#   'SIGNIFICANTLY',
#   'HIGHER',
#   'IGE',
#   'LEVEL',
#   'MEAN',
#   'INTERNATIONAL',
#   'UNIT',
#   'IU',
#   'COMPARED',
#   'IU',
#   'IGG',
#   'IGM',
#   'IGA',
#   'LEVEL',
#   'SIMILAR',
#   'TWO',
#   'CF',
#   'GROUP',
#   'CLINICAL',
#   'CONDITION',
#   'ALLERGIC',
#   'CF',
#   'PATIENT',
#   'SHWACHMAN',
#   'SCORE',
#   'BETTER',
#   'NONALLERGIC',
#   'SUGGESTING',
#   'MODULATING',
#   'EFFECT',
#   'RESPIRATORY',
#   'ALLERGY',
#   'SEVERITY',
#   'DISEASE'],
#  '00012 ': ['TAUSSIG',
#   'ET',
#   'AL',
#   'REPORTED',
#   'CASE',
#   'YEAR',
#   'OLD',
#   'BOY',
#   'RUSSELL',
#   'VARIANT',
#   'SILVER',
#   'RUSSELL',
#   'SYNDROME',
#   'CONCOMITANT',
#   'CYSTIC',
#   'FIBROSIS',
#   'WOULD',
#   'LIKE',
#   'DESCRIBE',
#   'ANOTHER',
#   'PATIENT',
#   'COMBINATION',
#   'DISEASE',
#   'PATTERN',
#   'CLINICAL',
#   'FINDING',
#   'PATIENT',
#   'ACCORDANCE',
#   'SILVER',
#   'RUSSELL',
#   'SYNDROME',
#   'COURSE',
#   'POSSIBLE',
#   'DEVELOPMENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'PATIENT',
#   'ENTIRELY',
#   'ACCIDENTAL',
#   'ALTHOUGH',
#   'COINCIDENCE',
#   'WOULD',
#   'STATISTICALLY',
#   'RARE',
#   'EVENT',
#   'ESTABLISHMENT',
#   'POSSIBLE',
#   'RELATIONSHIP',
#   'TWO',
#   'CONDITION',
#   'WOULD',
#   'DEPEND',
#   'REPORT',
#   'SIMILAR',
#   'CASE'],
#  '00013 ': ['INTENSIVE',
#   'SEARCH',
#   'BLACK',
#   'CYSTIC',
#   'FIBROSIS',
#   'CF',
#   'WASHINGTON',
#   'DC',
#   'PERIOD',
#   'DISCLOSED',
#   'BLACK',
#   'PATIENT',
#   'EIGHT',
#   'BORN',
#   'DISTRICT',
#   'COLUMBIA',
#   'DECADE',
#   'CALCULATED',
#   'INCIDENCE',
#   'CF',
#   'LEAST',
#   'ONE',
#   'BLACK',
#   'NEWBORN',
#   'CLINICAL',
#   'COURSE',
#   'PATHOLOGICAL',
#   'CHANGE',
#   'BLACK',
#   'CF',
#   'SIMILAR',
#   'WHITE',
#   'GENETIC',
#   'CONSIDERATION',
#   'POINT',
#   'AUTOSOMAL',
#   'RECESSIVE',
#   'INHERITANCE',
#   'BLACK',
#   'GENERALLY',
#   'ACCEPTED',
#   'WHITE',
#   'DISEASE'],
#  '00014 ': ['PRENATAL',
#   'DIAGNOSIS',
#   'GENETIC',
#   'DISORDER',
#   'RECEIVED',
#   'INCREASING',
#   'ATTENTION',
#   'PAST',
#   'SEVERAL',
#   'YEAR',
#   'RAPID',
#   'EXPANSION',
#   'KNOWLEDGE',
#   'BASIS',
#   'GENETIC',
#   'DISEASE',
#   'DEVELOPMENT',
#   'RELIABLE',
#   'DIAGNOSTIC',
#   'METHOD',
#   'LED',
#   'RAPID',
#   'ADVANCE',
#   'INTRAUTERINE',
#   'DIAGNOSIS',
#   'LARGE',
#   'NUMBER',
#   'INHERITED',
#   'DISORDER',
#   'PRENATAL',
#   'DIAGNOSIS',
#   'INITIALLY',
#   'USED',
#   'DETERMINE',
#   'PRESENCE',
#   'SYNDROME',
#   'CHROMOSOMAL',
#   'ABNORMALITY',
#   'DETERMINATION',
#   'FETAL',
#   'SEX',
#   'PREGNANCY',
#   'RISK',
#   'NUMBER',
#   'SEVERE',
#   'LINKED',
#   'RECESSIVE',
#   'DISORDER',
#   'SHORTLY',
#   'THEREAFTER',
#   'BECAME',
#   'CLEAR',
#   'TECHNIQUE',
#   'COULD',
#   'APPLIED',
#   'PRENATAL',
#   'DIAGNOSIS',
#   'NUMBER',
#   'INBORN',
#   'ERROR',
#   'METABOLISM',
#   'RECENTLY',
#   'NUMBER',
#   'NEW',
#   'TECHNIQUE',
#   'DEVELOPED',
#   'MAY',
#   'PROVE',
#   'GREAT',
#   'VALUE',
#   'PRENATAL',
#   'DIAGNOSIS',
#   'NUMBER',
#   'SEVERE',
#   'CONGENITAL',
#   'MALFORMATION',
#   'COULD',
#   'DIAGNOSED',
#   'PRIOR',
#   'BIRTH',
#   'GOAL',
#   'REVIEW',
#   'DEFINE',
#   'PAST',
#   'ACHIEVEMENT',
#   'FUTURE',
#   'GOAL',
#   'PRESENT',
#   'LIMITATION',
#   'INTRAUTERINE',
#   'DIAGNOSIS',
#   'FIRST',
#   'SECTION',
#   'DEAL',
#   'GENERAL',
#   'APPROACH',
#   'USED',
#   'PRENATAL',
#   'DIAGNOSIS',
#   'GENETIC',
#   'DISORDER',
#   'FOLLOWED',
#   'DISCUSSION',
#   'SPECIFIC',
#   'APPLICATION',
#   'BASIC',
#   'TECHNIQUE',
#   'INTRAUTERINE',
#   'DIAGNOSIS',
#   'CHROMOSOMAL',
#   'ABNORMALITY',
#   'INBORN',
#   'ERROR',
#   'METABOLISM',
#   'APPROACH',
#   'PRENATAL',
#   'DIAGNOSIS',
#   'GENETIC',
#   'DISORDER',
#   'INCLUDE',
#   'AMNIOCENTESIS',
#   'DIRECT',
#   'INDIRECT',
#   'VISUALIZATION',
#   'FETUS',
#   'ANALYSIS',
#   'MATERNAL',
#   'BLOOD',
#   'URINE',
#   'SAMPLING',
#   'FETAL',
#   'TISSUE',
#   'APPLICATION',
#   'PRENATAL',
#   'GENETIC',
#   'DIAGNOSIS',
#   'INCLUDE',
#   'LINKED',
#   'RECESSIVE',
#   'DISORDER',
#   'CHROMOSOMAL',
#   'ABNORMALITY',
#   'INBORN',
#   'ERROR',
#   'METABOLISM',
#   'DISORDER',
#   'LIPID',
#   'METABOLISM',
#   'DISORDER',
#   'CARBOHYDRATE',
#   'METABOLISM',
#   'DISORDER',
#   'MUCOPOLYSACCHARIDE',
#   'METABOLISM',
#   'DISORDER',
#   'AMINO',
#   'ACID',
#   'METABOLISM',
#   'MISCELLANEOUS',
#   'DISORDER',
#   'CYSTIC',
#   'FIBROSIS',
#   'TECHNIQUE',
#   'PROVIDE',
#   'PARENT',
#   'METHOD',
#   'CHILD',
#   'WITHOUT',
#   'FEAR',
#   'CHILD',
#   'SPECIFIC',
#   'DEFORMITY',
#   'ADDITION',
#   'DEVELOPMENT',
#   'APPROACH',
#   'INCREASE',
#   'NUMBER',
#   'DISORDER',
#   'DETECTABLE',
#   'UTERO',
#   'POTENTIAL',
#   'TREATMENT',
#   'GENETIC',
#   'DISORDER',
#   'UNLIMITED'],
#  '00015 ': ['THREE',
#   'WOMAN',
#   'CYSTIC',
#   'FIBROSIS',
#   'CLINIC',
#   'USED',
#   'COMBINED',
#   'FORM',
#   'ORAL',
#   'CONTRACEPTIVE',
#   'DEVELOPED',
#   'ACUTE',
#   'POLYPOID',
#   'CERVICITIS',
#   'ONE',
#   'WOMAN',
#   'POLYP',
#   'RECURRED',
#   'REINSTITUTION',
#   'MEDICATION',
#   'RESOLUTION',
#   'POLYP',
#   'INSTANCE',
#   'DISCONTINUATION',
#   'DRUG',
#   'AFFECTED',
#   'WOMAN',
#   'COINCIDENTAL',
#   'DETERIORATION',
#   'RESPIRATORY',
#   'STATUS',
#   'THEREFORE',
#   'SUGGESTED',
#   'CYSTIC',
#   'FIBROSIS',
#   'PATIENT',
#   'USING',
#   'ORAL',
#   'CONTRACEPTION',
#   'OBSERVED',
#   'CLOSELY',
#   'REGARDING',
#   'PULMONARY',
#   'GYNECOLOGIC',
#   'STATUS'],
#  '00016 ': ['SYNDROME',
#   'ATAXIA',
#   'TELANGIECTASIA',
#   'CHARACTERIZED',
#   'ATAXIA',
#   'PROGRESSIVE',
#   'NEUROLOGIC',
#   'DEGENERATION',
#   'CUTANEOUS',
#   'CONJUNCTIVAL',
#   'TELANGIECTASIS',
#   'IMMUNOLOGIC',
#   'DEFICIENCY',
#   'ROENTGENOLOGIC',
#   'EVIDENCE',
#   'CHRONIC',
#   'PULMONARY',
#   'SINUS',
#   'INFECTION',
#   'DECREASED',
#   'LYMPHOID',
#   'TISSUE',
#   'USUALLY',
#   'PRESENT',
#   'SINOPULMONARY',
#   'ABNORMALITY',
#   'RESEMBLE',
#   'CYSTIC',
#   'FIBROSIS',
#   'SMALL',
#   'ADENOIDAL',
#   'MASS',
#   'MAY',
#   'DIFFERENTIAL',
#   'AID'],
#  '00017 ': ['CYSTIC',
#   'FIBROSIS',
#   'LONGER',
#   'RARE',
#   'ADULT',
#   'LUNG',
#   'MAIN',
#   'TARGET',
#   'ORGAN',
#   'BASIC',
#   'LESION',
#   'BRONCHIAL',
#   'OBSTRUCTION',
#   'LEADING',
#   'BRONCHIECTASIS',
#   'INTERSTITIAL',
#   'INFILTRATES',
#   'CYST',
#   'LIKE',
#   'CHANGE',
#   'CHARACTERISTIC',
#   'ROENTGENOGRAPHY',
#   'COMPLICATION',
#   'INCLUDE',
#   'PULMONARY',
#   'HYPERTENSION',
#   'PNEUMONITIS',
#   'HEMORRHAGE',
#   'PNEUMOTHORAX',
#   'LITTLE',
#   'CORRELATION',
#   'EXISTS',
#   'RESPIRATORY',
#   'TRACT',
#   'PANCREATIC',
#   'GASTROINTESTINAL',
#   'INVOLVEMENT',
#   'DESPITE',
#   'SIMILARITY',
#   'PATHOGENESIS',
#   'PULMONARY',
#   'CYSTIC',
#   'FIBROSIS',
#   'ADULT',
#   'ALWAYS',
#   'RESEMBLE',
#   'CONDITION',
#   'CHILD',
#   'MUST',
#   'DIFFERENTIATED',
#   'CHRONIC',
#   'INTERSTITIAL',
#   'DISEASE'],
#  '00018 ': ['FAR',
#   'RABBIT',
#   'ALVEOLAR',
#   'MACROPHAGE',
#   'CONCERNED',
#   'CONCENTRATION',
#   'HOMOZYGOUS',
#   'CF',
#   'SERUM',
#   'USED',
#   'EXPERIMENT',
#   'EVEN',
#   'GREATER',
#   'FOURFOLD',
#   'CONCENTRATION',
#   'BIGGAR',
#   'ASSOCIATE',
#   'STATE',
#   'REQUIRED',
#   'NORMAL',
#   'PHAGOCYTOSIS',
#   'INCREASING',
#   'DILUTION',
#   'HOMOZYGOUS',
#   'CF',
#   'SERUM',
#   'EITHER',
#   'HANK',
#   'BALANCED',
#   'SALT',
#   'SOLUTION',
#   'NORMAL',
#   'HUMAN',
#   'SERUM',
#   'THUS',
#   'DECREASING',
#   'CONCENTRATION',
#   'INCREASED',
#   'CAPACITY',
#   'RABBIT',
#   'ALVEOLAR',
#   'MACROPHAGE',
#   'PHAGOCYTIZE',
#   'KILL',
#   'PSEUDOMONAS',
#   'AERUGINOSA',
#   'INCREASING',
#   'CONCENTRATION',
#   'OPPOSITE',
#   'EFFECT',
#   'SUSPENSION',
#   'RABBIT',
#   'ALVEOLAR',
#   'MACROPHAGE',
#   'HUMAN',
#   'SERUM',
#   'REDUCED',
#   'PHAGOCYTIC',
#   'ACTIVITY',
#   'ACTIVITY',
#   'REDUCED',
#   'HUMAN',
#   'CF',
#   'SERUM',
#   'HUMAN',
#   'NORMAL',
#   'SERUM',
#   'UNEXPECTED',
#   'HIGH',
#   'HUMAN',
#   'SERUM',
#   'CONCENTRATION',
#   'LIKELY',
#   'TOXIC',
#   'RABBIT',
#   'ALVEOLAR',
#   'MACROPHAGE',
#   'INHIBITION',
#   'PHAGOCYTOSIS',
#   'ABSENT',
#   'HOMOZYGOUS',
#   'CF',
#   'SERUM',
#   'HOUR',
#   'OLD',
#   'PREVIOUSLY',
#   'HEATED',
#   'FROZEN',
#   'USED',
#   'OBSERVATION',
#   'DILUTION',
#   'INCREASED',
#   'MACROPHAGE',
#   'PHAGOCYTIC',
#   'ABILITY',
#   'FEEL',
#   'DATA',
#   'DEMONSTRATE',
#   'PRESENCE',
#   'LABILE',
#   'INHIBITOR',
#   'RATHER',
#   'DEFICIENCY',
#   'SINCE',
#   'WELL',
#   'KNOWN',
#   'CF',
#   'PATIENT',
#   'NORMAL',
#   'ELEVATED',
#   'CONCENTRATION',
#   'IMMUNOGLOBULIN',
#   'INCLUDING',
#   'IGA',
#   'SERUM',
#   'PULMONARY',
#   'SECRETION',
#   'RESPOND',
#   'INFECTION',
#   'IGA',
#   'SHOWN',
#   'ESSENTIAL',
#   'ALVEOLAR',
#   'MACROPHAGE',
#   'PHAGOCYTOSIS',
#   'PSEUDOMONAS',
#   'AERUGINOSA',
#   'AGREE',
#   'INHIBITION',
#   'DUE',
#   'IGA',
#   'DEFICIENCY',
#   'ALSO',
#   'NOTE',
#   'SERUM',
#   'USED',
#   'EXPERIMENT',
#   'BIGGAR',
#   'ASSOCIATE',
#   'STORED',
#   'DEGREE',
#   'PERHAPS',
#   'MAY',
#   'ACCOUNT',
#   'DIFFERENCE',
#   'RESULT'],
#  '00019 ': ['ASSAYED',
#   'SERUM',
#   'GROUP',
#   'CYSTIC',
#   'FIBROSIS',
#   'PATIENT',
#   'ORAL',
#   'ARGININE',
#   'THERAPY',
#   'GROUP',
#   'CYSTIC',
#   'FIBROSIS',
#   'PATIENT',
#   'RECEIVING',
#   'TREATMENT',
#   'TOTAL',
#   'ARGININE',
#   'ESTERASE',
#   'ACTIVITY',
#   'UNTREATED',
#   'CYSTIC',
#   'FIBROSIS',
#   'PATIENT',
#   'SIGNIFICANTLY',
#   'LOWER',
#   'SERUM',
#   'ARGININE',
#   'ESTERASE',
#   'ACTIVITY',
#   'NORMAL',
#   'CONTROL',
#   'CYSTIC',
#   'FIBROSIS',
#   'CARRIER',
#   'CYSTIC',
#   'FIBROSIS',
#   'PATIENT',
#   'RECEIVING',
#   'ORAL',
#   'ARGININE',
#   'THERAPY',
#   'SIGNIFICANT',
#   'DIFFERENCE',
#   'ARGININE',
#   'ESTERASE',
#   'ACTIVITY',
#   'NORMAL',
#   'CONTROL',
#   'CYSTIC',
#   'FIBROSIS',
#   'CARRIER',
#   'CYSTIC',
#   'FIBROSIS',
#   'PATIENT',
#   'TREATED',
#   'ARGININE',
#   'RECENTLY',
#   'OBSERVED',
#   'DIFFERENCE',
#   'ARGININE',
#   'ESTERASES',
#   'PLASMA',
#   'CONTROL',
#   'PATIENT',
#   'ELECTROFUSING',
#   'POLYACRYLAMIDE',
#   'GEL',
#   'SIX',
#   'ACTIVITY',
#   'BAND',
#   'COULD',
#   'DETECTED',
#   'PLASMA',
#   'CONTROL',
#   'WHEREAS',
#   'FIVE',
#   'COULD',
#   'DETECTED',
#   'PLASMA',
#   'PATIENT',
#   'WORK',
#   'DEFICIENCY',
#   'TRYPSIN',
#   'LIKE',
#   'ACTIVITY',
#   'MIXED',
#   'SALIVA',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'REPRODUCED',
#   'ANOTHER',
#   'LABORATORY',
#   'COBURN',
#   'RECENTLY',
#   'CONFIRMED',
#   'WORK',
#   'DEFICIENCY',
#   'ARGININE',
#   'ESTERASE',
#   'SERUM',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'PRESENT',
#   'DEFICIENCY',
#   'ARGININE',
#   'ESTERASE',
#   'CYSTIC',
#   'FIBROSIS',
#   'WORKING',
#   'HYPOTHESIS',
#   'UNDERSTAND',
#   'BASIC',
#   'DEFECT',
#   'VARIATION',
#   'PH',
#   'SODIUM',
#   'CHLORIDE',
#   'CONTENT',
#   'EMPLOYED',
#   'TESTED',
#   'PATIENT',
#   'WITHOUT',
#   'DIAGNOSIS',
#   'CYSTIC',
#   'FIBROSIS',
#   'FOUND',
#   'ALTER',
#   'LEVEL',
#   'ARGININE',
#   'ESTERASE',
#   'ACTIVITY',
#   'MAJOR',
#   'DIFFERENCE',
#   'TWO',
#   'STUDY',
#   'RESULTED',
#   'CONTROL',
#   'SUBJECT',
#   'DR',
#   'RAO',
#   'NEGLECT',
#   'MENTION',
#   'LABORATORY',
#   'UNABLE',
#   'CONFIRM',
#   'FINDING'],
#  '00020 ': ['ABILITY',
#   'DETECT',
#   'ABNORMALITY',
#   'LUNG',
#   'FUNCTION',
#   'CHILD',
#   'ASTHMA',
#   'CYSTIC',
#   'FIBROSIS',
#   'MEASUREMENT',
#   'CLOSING',
#   'VOLUME',
#   'STUDIED',
#   'CHILD',
#   'FLOW',
#   'VOLUME',
#   'CHARACTERISTIC',
#   'ROUTINE',
#   'SPIROMETRY',
#   'BODY',
#   'PLETHYSMOGRAPHY',
#   'ARTERIALIZED',
#   'OXYGEN',
#   'TENSION',
#   'STUDIED',
#   'COMPARISON',
#   'CLOSING',
#   'VOLUME',
#   'CLOSING',
#   'VOLUME',
#   'LE',
#   'SENSITIVE',
#   'DETECTING',
#   'DISEASE',
#   'RESIDUAL',
#   'VOLUME',
#   'TOTAL',
#   'LUNG',
#   'CAPACITY',
#   'RATIO',
#   'MAXIMUM',
#   'EXPIRATORY',
#   'FLOW',
#   'VOLUME',
#   'CURVE',
#   'ARTERIALIZED',
#   'BLOOD',
#   'GAS'],
#  '00021 ': ['FIVE',
#   'PARENT',
#   'CHILD',
#   'CYSTIC',
#   'FIBROSIS',
#   'DEVELOPED',
#   'ALLERGIC',
#   'BRONCHOSPASM',
#   'INHALING',
#   'PANCREATIC',
#   'EXTRACT',
#   'SPRINKLED',
#   'CHILD',
#   'FOOD',
#   'POSITIVE',
#   'HISTORY',
#   'ALLERGY',
#   'PAST',
#   'HISTORY',
#   'ASTHMA',
#   'PARENT',
#   'ASTHMA',
#   'RESPONDED',
#   'BRONCHODILATOR',
#   'USE',
#   'FACE',
#   'MASK',
#   'PREPARATION',
#   'MEAL',
#   'PREVENTED',
#   'RECURRENCE',
#   'DATE',
#   'ASTHMA',
#   'PRECIPITATE',
#   'INHALATION',
#   'PANCREATIC',
#   'EXTRACT',
#   'SEEN',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS'],
#  '00022 ': ['AIRWAY',
#   'RESISTANCE',
#   'LUNG',
#   'VOLUME',
#   'MEASURED',
#   'MODIFICATION',
#   'PLETHYSMOGRAPHIC',
#   'METHOD',
#   'BRISCOE',
#   'DUBOIS',
#   'CALCULATE',
#   'SPECIFIC',
#   'AIRWAY',
#   'RESISTANCE',
#   'SRAW',
#   'CONTROL',
#   'SUBJECT',
#   'RANGING',
#   'AGE',
#   'NEWBORN',
#   'YEAR',
#   'MEAN',
#   'SRAW',
#   'LOWEST',
#   'NEWBORN',
#   'PERIOD',
#   'INCREASED',
#   'RAPIDLY',
#   'ADULT',
#   'LEVEL',
#   'FIRST',
#   'YEAR',
#   'LIFE',
#   'AGE',
#   'GROUP',
#   'MEAN',
#   'SRAW',
#   'LOWER',
#   'FEMALE',
#   'MALE',
#   'CONTROL',
#   'SUBJECT',
#   'SRAW',
#   'GREATER',
#   'SEC',
#   'CM',
#   'DECREASE',
#   'MEAN',
#   'SRAW',
#   'SEC',
#   'CM',
#   'FEMALE',
#   'YEAR',
#   'AGE',
#   'SEC',
#   'CM',
#   'YEAR',
#   'AGE',
#   'PARALLELED',
#   'SEXUAL',
#   'MATURATION',
#   'SIMILAR',
#   'CHANGE',
#   'OBSERVED',
#   'MALE',
#   'DIRECT',
#   'CORRELATION',
#   'SRAW',
#   'CLINICAL',
#   'OBSERVATION',
#   'FOUND',
#   'YOUNG',
#   'PATIENT',
#   'VARIOUS',
#   'DEGREE',
#   'PULMONARY',
#   'INVOLVEMENT',
#   'CYSTIC',
#   'FIBROSIS'],
#  '00023 ': ['CILIATED',
#   'NASAL',
#   'POLYP',
#   'EPITHELIUM',
#   'PATIENT',
#   'ALLERGIC',
#   'RHINITIS',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'MAINTAINED',
#   'ORGAN',
#   'CULTURE',
#   'HOUR',
#   'EXPLANTED',
#   'EPITHELIUM',
#   'RETAINED',
#   'MORPHOLOGIC',
#   'CHARACTERISTIC',
#   'INCORPORATED',
#   'BLOOD',
#   'GROUP',
#   'SPECIFIC',
#   'GLYCOPROTEIN',
#   'SECRETED',
#   'MEDIUM',
#   'THROUGHOUT',
#   'CULTURE',
#   'PERIOD',
#   'LABELED',
#   'MUCOUS',
#   'GLYCOPROTEIN',
#   'SOLUBILIZED',
#   'REDUCTION',
#   'ALKYLATION',
#   'PURIFIED',
#   'GEL',
#   'FILTRATION',
#   'CHROMATOGRAPHY',
#   'PURIFIED',
#   'GLYCOPROTEIN',
#   'SEPARATED',
#   'DIETHYLAMINOETHYL',
#   'DEAE',
#   'CELLULOSE',
#   'COLUMN',
#   'BLOOD',
#   'GROUP',
#   'ACTIVE',
#   'FRACTION',
#   'FRACTION',
#   'SIMILAR',
#   'AMINO',
#   'ACID',
#   'COMPOSITION',
#   'DIFFERED',
#   'ACETYL',
#   'NEURAMINIC',
#   'ACID',
#   'FUCOSE',
#   'CONTENT',
#   'RELATIVE',
#   'INCORPORATION',
#   'GLUCOSAMINE',
#   'BLOOD',
#   'GROUP',
#   'GLYCOPROTEIN',
#   'POLYP',
#   'EPITHELIUM',
#   'PATIENT',
#   'ALLERGIC',
#   'RHINITIS',
#   'CYSTIC',
#   'FIBROSIS',
#   'INDISTINGUISHABLE',
#   'MANY',
#   'RESPECT',
#   'HOWEVER',
#   'PER',
#   'RATIO',
#   'GLYCOPROTEIN',
#   'FRACTION',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'EXCEEDED',
#   'CORRESPONDING',
#   'FRACTION',
#   'SECRETION',
#   'PATIENT',
#   'ALLERGIC',
#   'RHINITIS'],
#  '00024 ': ['PRESSURE',
#   'VOLUME',
#   'BEHAVIOR',
#   'LUNG',
#   'STUDIED',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'ISOVOLUME',
#   'FLOW',
#   'PRESSURE',
#   'RELATIONSHIP',
#   'MEASURED',
#   'PATIENT',
#   'MODIFICATION',
#   'FLOW',
#   'VOLUME',
#   'TEST',
#   'EVALUATED',
#   'DETECTION',
#   'FLOW',
#   'REDUCTION',
#   'SEPARATE',
#   'GROUP',
#   'PATIENT',
#   'RELATIVE',
#   'RESULT',
#   'CONTROL',
#   'GROUP',
#   'NORMAL',
#   'SUBJECT',
#   'PATIENT',
#   'GROSSLY',
#   'ABNORMAL',
#   'PRESSURE',
#   'VOLUME',
#   'CURVE',
#   'EXCESSIVE',
#   'STIFFNESS',
#   'LUNG',
#   'NEAR',
#   'MAXIMUM',
#   'VOLUME',
#   'LOSS',
#   'RECOIL',
#   'LOWER',
#   'VOLUME',
#   'CLOSING',
#   'VOLUME',
#   'PATIENT',
#   'OFTEN',
#   'HIGH',
#   'ENOUGH',
#   'CAUSE',
#   'SIGNIFICANT',
#   'DISTURBANCE',
#   'GAS',
#   'EXCHANGE',
#   'ELEVATED',
#   'CLOSING',
#   'VOLUME',
#   'QUANTITATIVELY',
#   'EXPLAINED',
#   'LOW',
#   'VALUE',
#   'ELASTIC',
#   'RECOIL',
#   'MODIFIED',
#   'FLOW',
#   'VOLUME',
#   'TEST',
#   'DETECTED',
#   'MILD',
#   'FLOW',
#   'REDUCTION',
#   'MANY',
#   'PATIENT',
#   'OTHERWISE',
#   'NORMAL',
#   'PULMONARY',
#   'FUNCTION',
#   'TEST',
#   'LOSS',
#   'RECOIL',
#   'PER',
#   'SE',
#   'ACCOUNT',
#   'LOW',
#   'MAXIMUM',
#   'EXPIRATORY',
#   'FLOW',
#   'SINCE',
#   'UPSTREAM',
#   'RESISTANCE',
#   'HIGH',
#   'HOWEVER',
#   'PRESSURE',
#   'FLOW',
#   'CURVE',
#   'EFFORT',
#   'DEPENDENT',
#   'HIGH',
#   'LUNG',
#   'VOLUME',
#   'EVEN',
#   'PATIENT',
#   'SEVERE',
#   'AIRWAY',
#   'OBSTRUCTION',
#   'SHOWING',
#   'TIME',
#   'CONSTANT',
#   'EMPTYING',
#   'VARIED',
#   'WIDELY',
#   'PATIENT',
#   'CONCLUDED',
#   'DETERIORATION',
#   'LUNG',
#   'FUNCTION',
#   'CYSTIC',
#   'FIBROSIS',
#   'INVOLVES',
#   'AIRWAY',
#   'OBSTRUCTION',
#   'WORSENING',
#   'GAS',
#   'TRAPPING',
#   'EXPLAINED',
#   'PROGRESSIVE',
#   'LOSS',
#   'LUNG',
#   'ELASTIC',
#   'RECOIL'],
#  '00025 ': ['USE',
#   'BLAND',
#   'AEROSOL',
#   'PARTICULARLY',
#   'MIST',
#   'TENT',
#   'TREATMENT',
#   'LOWER',
#   'RESPIRATORY',
#   'DISEASE',
#   'REVIEWED',
#   'CONVINCING',
#   'EVIDENCE',
#   'EFFICACY',
#   'FOUND',
#   'SURPRISING',
#   'EVIDENCE',
#   'MIST',
#   'TENT',
#   'DEPOSIT',
#   'LITTLE',
#   'WATER',
#   'LOWER',
#   'RESPIRATORY',
#   'TRACT',
#   'MIST',
#   'TENT',
#   'MAY',
#   'DETRIMENTAL',
#   'CASE',
#   'BACTERIAL',
#   'CONTAMINATION',
#   'CAUSE',
#   'BRONCHOSPASM'],
#  '00026 ': ['PLASMA',
#   'ARGININE',
#   'ESTERASE',
#   'ACTIVITY',
#   'MEASURED',
#   'YOUNG',
#   'ADULT',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'CONTROL',
#   'SUBJECT',
#   'ENZYME',
#   'ACTIVATED',
#   'TREATING',
#   'PLASMA',
#   'CHLOROFORM',
#   'ELLAGIC',
#   'ACID',
#   'MANNER',
#   'DESCRIBED',
#   'RAO',
#   'ASSOCIATE',
#   'DIFFERENCE',
#   'FOUND',
#   'EITHER',
#   'ARGININE',
#   'ESTERASE',
#   'ACTIVITY',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'CONTROL',
#   'SUBJECT',
#   'DEGREE',
#   'ACTIVITY',
#   'INHIBITED',
#   'SOYBEAN',
#   'TRYPSIN',
#   'INHIBITOR',
#   'THUS',
#   'FINDING',
#   'RAO',
#   'ASSOCIATE',
#   'DEFICIENCY',
#   'ARGININE',
#   'ESTERASE',
#   'ACTIVITY',
#   'PLASMA',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'CONFIRMED'],
#  '00027 ': ['SPITE',
#   'WIDESPREAD',
#   'CLINICAL',
#   'IMPRESSION',
#   'PULMONARY',
#   'PHYSICAL',
#   'THERAPY',
#   'INCLUDING',
#   'BREATHING',
#   'EXERCISE',
#   'HELPFUL',
#   'PEDIATRIC',
#   'AGE',
#   'GROUP',
#   'OBJECTIVE',
#   'DEMONSTRATION',
#   'VALUE',
#   'VARIOUS',
#   'MANEUVER',
#   'PART',
#   'LACKING',
#   'EVIDENCE',
#   'VOLUME',
#   'SPUTUM',
#   'PRODUCED',
#   'SHORT',
#   'PERIOD',
#   'TIME',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'INCREASED',
#   'COUGH',
#   'ACCOMPANIED',
#   'POSTURAL',
#   'DRAINAGE',
#   'PULMONARY',
#   'PHYSICAL',
#   'THERAPY',
#   'LONG',
#   'TERM',
#   'EFFECT',
#   'VARIOUS',
#   'MANEUVER',
#   'COURSE',
#   'CHRONIC',
#   'PULMONARY',
#   'DISEASE',
#   'REMAINS',
#   'UNKNOWN'],
#  '00028 ': ['PRESENT',
#   'STUDY',
#   'POINT',
#   'SIMPLICITY',
#   'EASE',
#   'USING',
#   'FINGERNAIL',
#   'TOENAIL',
#   'MEASURE',
#   'ELECTROLYTE',
#   'LEVEL',
#   'TEST',
#   'CYSTIC',
#   'FIBROSIS',
#   'PROCEDURE',
#   'VARIOUS',
#   'EFFECT',
#   'RANGE',
#   'VALUE',
#   'DIFFERENT',
#   'CATEGORY',
#   'HEALTHY',
#   'DISEASED',
#   'SUBJECT',
#   'DISCUSSED',
#   'LIMITATION',
#   'METHOD',
#   'INDICATED'],
#  '00029 ': ['EAR',
#   'NOSE',
#   'THROAT',
#   'SURVEY',
#   'CARRIED',
#   'CHILD',
#   'AGED',
#   'YEAR',
#   'CYSTIC',
#   'FIBROSIS',
#   'SHOWN',
#   'TRANSIENTLY',
#   'DEAF',
#   'ASSOCIATED',
#   'EUSTACHIAN',
#   'TUBE',
#   'DYSFUNCTION',
#   'CONFIRMED',
#   'CASE',
#   'SECRETORY',
#   'OTITIS',
#   'MEDIUM',
#   'CHILD',
#   'FOUND',
#   'NASAL',
#   'POLYP',
#   'GAVE',
#   'HISTORY',
#   'POLYPECTOMY',
#   'THOUGH',
#   'HIGH',
#   'INCIDENCE',
#   'MIDDLE',
#   'EAR',
#   'PROBLEM',
#   'CHILD',
#   'CYSTIC',
#   'FIBROSIS',
#   'REPORTED',
#   'NEITHER',
#   'DEAFNESS',
#   'SECRETORY',
#   'OTITIS',
#   'MEDIUM',
#   'FOUND',
#   'PROBLEM',
#   'GROUP',
#   'STUDIED'],
#  '00030 ': ['PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'TOCOPHEROL',
#   'DEFICIENCY',
#   'PRESUMABLY',
#   'RESULT',
#   'STEATORRHOEA',
#   'EVIDENCE',
#   'POSSIBLE',
#   'MUSCULAR',
#   'INVOLVEMENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'PATIENT',
#   'CLINICAL',
#   'MUSCULAR',
#   'WEAKNESS',
#   'WASTING',
#   'MANY',
#   'PATIENT',
#   'BIOCHEMICAL',
#   'CREATINURIA',
#   'CREATINE',
#   'POOR',
#   'DIET',
#   'REVERSAL',
#   'FINDING',
#   'INGESTION',
#   'TOCOPHEROL',
#   'ESTER',
#   'ACCOMPANIED',
#   'DECREASE',
#   'CREATINE',
#   'PLASMA',
#   'INCREASE',
#   'CREATINE',
#   'MUSCLE',
#   'PATHOLOGICAL',
#   'FOCAL',
#   'LESION',
#   'SKELETAL',
#   'MUSCLE',
#   'RESEMBLING',
#   'NUTRITIONAL',
#   'MUSCULAR',
#   'DYSTROPHY',
#   'CEROID',
#   'PIGMENT',
#   'SMOOTH',
#   'MUSCLE',
#   'MUSCLE',
#   'STRENGTH',
#   'MEASURED',
#   'BULB',
#   'ERGOGRAPH',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'ATTENDING',
#   'CLINIC',
#   'BABY',
#   'HOSPITAL',
#   'COLUMBIA',
#   'PRESBYTERIAN',
#   'MEDICAL',
#   'CENTER',
#   'NEW',
#   'YORK',
#   'DOUBLE',
#   'BLIND',
#   'STUDY',
#   'HALF',
#   'CASE',
#   'RECEIVED',
#   'TOCOPHEROL',
#   'ORALLY',
#   'REMAINDER',
#   'PLACEBO',
#   'SIGNIFICANT',
#   'INCREASE',
#   'MUSCLE',
#   'STRENGTH',
#   'FOUND',
#   'PATIENT',
#   'RECEIVING',
#   'TOCOPHEROL',
#   'PERIOD',
#   'MONTH',
#   'COMPARED',
#   'PLACEBO',
#   'GROUP',
#   'BLOOD',
#   'TOCOPHEROL',
#   'LEVEL',
#   'TREATED',
#   'GROUP',
#   'RETURNED',
#   'NORMAL'],
#  '00031 ': ['HYPOTHESIS',
#   'MIST',
#   'TENT',
#   'THERAPY',
#   'DECREASE',
#   'VISCOSITY',
#   'SPUTUM',
#   'DIRECT',
#   'LIQUEFACTION',
#   'SPUTUM',
#   'LOWER',
#   'RESPIRATORY',
#   'TRACT',
#   'TESTED',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'CF',
#   'FIRST',
#   'NIGHT',
#   'PATIENT',
#   'SLEPT',
#   'WITHOUT',
#   'MIST',
#   'TENT',
#   'FIRST',
#   'MORNING',
#   'SPUTUM',
#   'COLLECTED',
#   'ANALYSIS',
#   'FOLLOWING',
#   'NIGHT',
#   'PATIENT',
#   'RANDOMLY',
#   'ALLOCATED',
#   'TENT',
#   'SUPPLIED',
#   'EITHER',
#   'JET',
#   'ULTRASONIC',
#   'NEBULIZER',
#   'EARLY',
#   'MORNING',
#   'SPUTUM',
#   'ANALYSED',
#   'VOLUME',
#   'VISCOSITY',
#   'WATER',
#   'CONTENT',
#   'DNA',
#   'CONTENT',
#   'INDEX',
#   'PURULENCE',
#   'RELATION',
#   'SPUTUM',
#   'VISCOSITY',
#   'DNA',
#   'CONTENT',
#   'WATER',
#   'CONTENT',
#   'VOLUME',
#   'FURTHERMORE',
#   'CONSISTENT',
#   'RELATION',
#   'SPUTUM',
#   'VISCOSITY',
#   'VOLUME',
#   'EXPECTORATED',
#   'PRESENCE',
#   'ABSENCE',
#   'HOUR',
#   'STAY',
#   'TENT',
#   'EITHER',
#   'METHOD',
#   'WATER',
#   'NEBULIZATION',
#   'RESULT',
#   'THEREFORE',
#   'SUGGEST',
#   'MIST',
#   'THERAPY',
#   'CONSISTENTLY',
#   'INFLUENCE',
#   'SPUTUM',
#   'VISCOSITY',
#   'VOLUME',
#   'PATIENT',
#   'CF',
#   'SPUTUM',
#   'WATER',
#   'CONTENT',
#   'INCREASE',
#   'WATER',
#   'CONTENT',
#   'INFLUENCE',
#   'VISCOSITY'],
#  '00032 ': ['TWO',
#   'SISTER',
#   'DESCRIBED',
#   'FATAL',
#   'CHRONIC',
#   'OBSTRUCTIVE',
#   'LUNG',
#   'DISEASE',
#   'UNKNOWN',
#   'ORIGIN',
#   'LUNG',
#   'CONDITION',
#   'CLINICALLY',
#   'HISTOLOGICALLY',
#   'INDISTINGUISHABLE',
#   'CYSTIC',
#   'FIBROSIS',
#   'SALIVARY',
#   'GLAND',
#   'SHOWED',
#   'PATHOLOGICAL',
#   'CHANGE',
#   'EXPECTED',
#   'CYSTIC',
#   'FIBROSIS',
#   'NEITHER',
#   'CHILD',
#   'ABNORMAL',
#   'SWEAT',
#   'ELECTROLYTE',
#   'BOWEL',
#   'SYMPTOM',
#   'PANCREAS',
#   'NORMAL',
#   'NECROPSY'],
#  '00033 ': ['CELLULOSE',
#   'ACETATE',
#   'STRIP',
#   'ELECTROPHORESIS',
#   'FOUND',
#   'SUFFICIENTLY',
#   'RELIABLE',
#   'DIFFERENTIATE',
#   'NORMAL',
#   'CF',
#   'MECONIUM',
#   'MARKED',
#   'DIFFERENCE',
#   'OBTAINED',
#   'QUANTITATIVE',
#   'IMMUNOELECTROPHORETIC',
#   'METHOD',
#   'EMPLOYED',
#   'NORMAL',
#   'MECONIUM',
#   'SHOWN',
#   'CONTAIN',
#   'ALPHA',
#   'ANTITRYPSIN',
#   'ALPHA',
#   'ANTICHYMOTRYPSIN',
#   'SAMPLE',
#   'CONTAINED',
#   'LOW',
#   'CONCENTRATION',
#   'ALBUMIN',
#   'MEASURABLE',
#   'AMOUNT',
#   'VARIETY',
#   'PLASMA',
#   'PROTEIN',
#   'SUGGESTED',
#   'QUANTITATIVE',
#   'IMMUNOELECTROPHORESIS',
#   'COULD',
#   'USED',
#   'MEAN',
#   'CONFIRMING',
#   'DIAGNOSIS',
#   'CF',
#   'POSITIVE',
#   'RESULT',
#   'OBTAINED',
#   'MECONIUM',
#   'SPECIMEN',
#   'SCREENED',
#   'TEST',
#   'STRIP'],
#  '00034 ': ['COEXISTENCE',
#   'CYSTIC',
#   'FIBROSIS',
#   'COELIAC',
#   'DISEASE',
#   'RECENTLY',
#   'REPORTED',
#   'SUGGESTED',
#   'CYSTIC',
#   'FIBROSIS',
#   'MAY',
#   'PREDISPOSE',
#   'LATER',
#   'DEVELOPMENT',
#   'COELIAC',
#   'DISEASE',
#   'DIAGNOSIS',
#   'COELIAC',
#   'DISEASE',
#   'LARGELY',
#   'DEPENDENT',
#   'UPON',
#   'DEMONSTRATION',
#   'HISTOLOGICAL',
#   'CHANGE',
#   'SMALL',
#   'INTESTINE',
#   'JEJUNAL',
#   'BIOPSY',
#   'MAY',
#   'DISTRESSING',
#   'SMALL',
#   'CHILD',
#   'SUGGESTED',
#   'FOOD',
#   'PROTEIN',
#   'ANTIBODY',
#   'STUDY',
#   'MAY',
#   'VALUE',
#   'INVESTIGATION',
#   'CHILD',
#   'CYSTIC',
#   'FIBROSIS',
#   'GLUTEN',
#   'SENSITIVITY',
#   'SUSPECTED',
#   'FOLLOWING',
#   'CASE',
#   'DECISION',
#   'PERFORM',
#   'JEJUNAL',
#   'BIOPSY',
#   'MADE',
#   'STUDY',
#   'POSITIVE',
#   'FOOD',
#   'PROTEIN',
#   'ANTIBODY',
#   'CEREAL',
#   'ANTIGEN',
#   'WHEAT',
#   'OATMEAL',
#   'GLUTEN',
#   'RUMINANT',
#   'ANTIGEN',
#   'COW',
#   'MILK',
#   'CALF',
#   'SERUM',
#   'PERSISTENTLY',
#   'DETECTED',
#   'PATIENT',
#   'BLOOD',
#   'JEJUNAL',
#   'BIOPSY',
#   'SHOWED',
#   'PARTIAL',
#   'VILLOUS',
#   'ATROPHY',
#   'SHORTENING',
#   'BROADENING',
#   'BRANCHING',
#   'VILLUS',
#   'SATISFACTORY',
#   'CLINICAL',
#   'IMPROVEMENT',
#   'GLUTEN',
#   'RESTRICTION'],
#  '00035 ': ['SIMPLE',
#   'IMMUNOCHEMICAL',
#   'TECHNIQUE',
#   'UTILIZING',
#   'SINGLE',
#   'RADIAL',
#   'IMMUNODIFFUSION',
#   'DEMONSTRATION',
#   'ALBUMIN',
#   'HUMAN',
#   'MECONIUM',
#   'DESCRIBED',
#   'COMPARISON',
#   'TECHNIQUE',
#   'WIDELY',
#   'USED',
#   'SULPHOSALICYLIC',
#   'ACID',
#   'PRECIPITATION',
#   'METHOD',
#   'REPORTED',
#   'ALSO',
#   'ATTEMPTED',
#   'DETERMINE',
#   'NORMAL',
#   'LEVEL',
#   'ALBUMIN',
#   'MECONIUM'],
#  '00036 ': ['NONE'],
#  '00037 ': ['NEONATAL',
#   'PERITONITIS',
#   'REMAINS',
#   'DANGEROUS',
#   'CONDITION',
#   'FACTOR',
#   'COMPLICATING',
#   'DIAGNOSIS',
#   'MANAGEMENT',
#   'INCLUDE',
#   'LOW',
#   'INCIDENCE',
#   'DIVERSITY',
#   'AETIOLOGICAL',
#   'FACTOR',
#   'FOUND',
#   'SEVERITY',
#   'UNDERLYING',
#   'ASSOCIATED',
#   'DISEASE',
#   'CASE',
#   'PRESENTING',
#   'SINCE',
#   'SOUTHMEAD',
#   'GENERAL',
#   'HOSPITAL',
#   'REVIEWED',
#   'THIRTEEN',
#   'AETIOLOGICAL',
#   'FACTOR',
#   'RELATING',
#   'MOTHER',
#   'BABY',
#   'FOUND',
#   'INFANT',
#   'PREMATURE',
#   'SEVERE',
#   'RESPIRATORY',
#   'PROBLEM',
#   'BIRTH',
#   'MATERNAL',
#   'HYDRAMNIOS',
#   'PRESENT',
#   'BABY',
#   'EXCHANGE',
#   'TRANSFUSION',
#   'COMMONEST',
#   'FINDING',
#   'GANGRENOUS',
#   'VOLVULUS',
#   'CYSTIC',
#   'FIBROSIS',
#   'COMBINED',
#   'FACTOR',
#   'OFTEN',
#   'PRESENT',
#   'USUAL',
#   'PRESENTATION',
#   'BILIOUS',
#   'VOMITING',
#   'ABDOMINAL',
#   'DISTENSION',
#   'FAILURE',
#   'PAS',
#   'NORMAL',
#   'MECONIUM',
#   'CASE',
#   'DISTENDED',
#   'ABDOMEN',
#   'BIRTH',
#   'PLAIN',
#   'ABDOMINAL',
#   'RAY',
#   'GREAT',
#   'DIAGNOSTIC',
#   'VALUE',
#   'PNEUMOPERITONEUM',
#   'DIAGNOSTIC',
#   'ABSENT',
#   'EARLY',
#   'FILM',
#   'TREATMENT',
#   'SURGICAL',
#   'CLOSE',
#   'LIAISON',
#   'PAEDIATRICIAN',
#   'SEE',
#   'BABY',
#   'FIRST',
#   'ESSENTIAL',
#   'ASSESSING',
#   'RESULT',
#   'POINTED',
#   'MANY',
#   'BABY',
#   'SMALL',
#   'SUFFERING',
#   'SERIOUS',
#   'CONDITION',
#   'HAEMOLYTIC',
#   'DISEASE',
#   'CYSTIC',
#   'FIBROSIS',
#   'GANGRENOUS',
#   'VOLVULUS',
#   'CASE',
#   'CONSIDERED',
#   'UNFIT',
#   'SURGERY',
#   'SUBMITTED',
#   'SURGERY',
#   'SURVIVED',
#   'MOSTLY',
#   'LATTER',
#   'PART',
#   'SERIES'],
#  '00038 ': ['VALUE',
#   'DETECTING',
#   'ALBUMIN',
#   'MECONIUM',
#   'SCREENING',
#   'PROCEDURE',
#   'CYSTIC',
#   'FIBROSIS',
#   'CF',
#   'ASSESSED',
#   'SAMPLE',
#   'SOUTH',
#   'WALE',
#   'NORTH',
#   'STAFFORDSHIRE',
#   'YEAR',
#   'PERIOD',
#   'SIMULTANEOUSLY',
#   'FOUR',
#   'METHOD',
#   'DETECTING',
#   'ALBUMIN',
#   'EVALUATED',
#   'CASE',
#   'CF',
#   'DETECTED',
#   'DETECTION',
#   'RATE',
#   'INCIDENCE',
#   'DISEASE',
#   'POPULATION',
#   'SCREENED',
#   'CONFIRMED',
#   'CLINICAL',
#   'TEST',
#   'PROCEDURE',
#   'CASE',
#   'CF',
#   'WITHOUT',
#   'IMPAIRMENT',
#   'PANCREATIC',
#   'FUNCTION',
#   'LIKELY',
#   'MISSED',
#   'SCREENING',
#   'METHOD',
#   'DEPEND',
#   'PRESENCE',
#   'ALBUMIN',
#   'MECONIUM'],
#  '00039 ': ['CAUCASIAN',
#   'EUROPEAN',
#   'ORIGIN',
#   'CYSTIC',
#   'FIBROSIS',
#   'CF',
#   'REMAINS',
#   'COMMONEST',
#   'RECOGNIZED',
#   'AUTOSOMAL',
#   'RECESSIVE',
#   'DISORDER',
#   'APPEARS',
#   'RARITY',
#   'AMONG',
#   'COLOURED',
#   'RACE',
#   'TIME',
#   'RECORD',
#   'MAY',
#   'SUGGESTED',
#   'ASSOCIATION',
#   'CF',
#   'WHITENESS',
#   'RECENT',
#   'YEAR',
#   'HOWEVER',
#   'INSTANCE',
#   'CF',
#   'CHILD',
#   'DESCRIBED',
#   'WHOSE',
#   'RACIAL',
#   'ORIGIN',
#   'NEGROID',
#   'MONGOLOID',
#   'NON',
#   'EUROPEAN',
#   'CAUCASOID',
#   'PRESENT',
#   'CASE',
#   'REPORT',
#   'CONCERN',
#   'PAKISTANI',
#   'CHILD',
#   'BORN',
#   'BIRMINGHAM',
#   'CF',
#   'CONFIRMED',
#   'CASE',
#   'BROTHER',
#   'SISTER',
#   'PRESENT',
#   'INCIDENCE',
#   'DISEASE',
#   'AMONG',
#   'ASIAN',
#   'IMMIGRANT',
#   'WEST',
#   'MIDLAND',
#   'APPROXIMATELY'],
#  '00040 ': ['CALCIUM',
#   'PHOSPHATE',
#   'PRECIPITATE',
#   'SUBMANDIBULAR',
#   'SALIVA',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'ELEVATED',
#   'CALCIUM',
#   'CONCENTRATION',
#   'SHOWN',
#   'ELECTRON',
#   'MICROSCOPY',
#   'TRANSFORM',
#   'STANDING',
#   'VITRO',
#   'AMORPHOUS',
#   'CALCIUM',
#   'PHOSPHATE',
#   'GLOBULE',
#   'STELLAR',
#   'CLUSTER',
#   'HYDROXYAPATITE',
#   'CRYSTAL',
#   'AMORPHOUS',
#   'GLOBULE',
#   'APPEARED',
#   'FORM',
#   'REGULAR',
#   'NUCLEATION',
#   'POINT',
#   'FINE',
#   'NETWORK',
#   'UNKNOWN',
#   'NATURE',
#   'HYDROXYAPATITE',
#   'CRYSTAL',
#   'FORMATION',
#   'CONFIRMED',
#   'ELECTRON',
#   'DIFFRACTION',
#   'PATTERN',
#   'CHEMICAL',
#   'SOLUBILITY',
#   'ZYMOGEN',
#   'GRANULE',
#   'SPHERULE',
#   'INCLUSION',
#   'BODY',
#   'PRESENT',
#   'GREATLY',
#   'INCREASED',
#   'NUMBER',
#   'CYSTIC',
#   'FIBROSIS',
#   'SUBMANDIBULAR',
#   'SALIVA',
#   'DISINTEGRATED',
#   'STANDING',
#   'HOMOGENEOUS',
#   'APPEARANCE',
#   'BEADED',
#   'HOLLOW',
#   'SPHERE'],
#  '00041 ': ['PANETH',
#   'CELL',
#   'METAPLASIA',
#   'VARIABLE',
#   'FEATURE',
#   'DIVERSE',
#   'DISEASE',
#   'COLON',
#   'RECTUM',
#   'PANETH',
#   'CELL',
#   'NUMEROUS',
#   'ATROPHIC',
#   'MUCOSA',
#   'CHRONIC',
#   'ULCERATIVE',
#   'COLITIS',
#   'JUVENILE',
#   'POLYP',
#   'AROUND',
#   'COLLOID',
#   'MUCINOUS',
#   'CARCINOMA',
#   'MODERATE',
#   'NUMBER',
#   'PANETH',
#   'CELL',
#   'FOUND',
#   'CYSTIC',
#   'FIBROSIS',
#   'PANCREAS',
#   'AMBEIC',
#   'COLITIS',
#   'VILLOUS',
#   'ADENOMA',
#   'PANETH',
#   'CELL',
#   'SPARSE',
#   'DIVERTICULITIS',
#   'ADENOMATOUS',
#   'POLYP',
#   'AROUND',
#   'NONMUCINOUS',
#   'CARCINOMA',
#   'STUDY',
#   'PANETH',
#   'CELL',
#   'METAPLASIA',
#   'ASSOCIATED',
#   'MUCUS',
#   'HYPERSECRETION',
#   'MUCIN',
#   'DEPOSIT',
#   'SUGGESTED',
#   'ONE',
#   'FUNCTION',
#   'PANETH',
#   'CELL',
#   'CONTROL',
#   'GASTROINTESTINAL',
#   'MUCIN',
#   'VISCOSITY'],
#  '00042 ': ['ASSOCIATION',
#   'ANOMASIA',
#   'HYPOGONADISM',
#   'REPORTED',
#   'INCREASING',
#   'FREQUENCY',
#   'PAST',
#   'SEVERAL',
#   'YEAR',
#   'CASE',
#   'REPORT',
#   'KALLMAN',
#   'SYNDROME',
#   'EMPHASIZES',
#   'IMPORTANCE',
#   'TESTING',
#   'ANOMASIA',
#   'PATIENT',
#   'MANIFEST',
#   'ABNORMALITY',
#   'SEXUAL',
#   'DEVELOPMENT'],
#  '00043 ': ['EFFECT',
#   'CYSTIC',
#   'FIBROSIS',
#   'VICTORIAN',
#   'FAMILY',
#   'ONE',
#   'AFFECTED',
#   'CHILD',
#   'EXAMINED',
#   'STUDY',
#   'CARRIED',
#   'AUGUST',
#   'FEBRUARY',
#   'SOCIAL',
#   'EMOTIONAL',
#   'PROBLEM',
#   'EXPERIENCED',
#   'FAMILY',
#   'MEMBER',
#   'PARTICULARLY',
#   'PATIENT',
#   'MOTHER',
#   'REPORTED',
#   'AGE',
#   'SOCIALLY',
#   'EMBARRASSING',
#   'SYMPTOM',
#   'AWARENESS',
#   'DIFFERENT',
#   'CREATE',
#   'MAJOR',
#   'PROBLEM',
#   'PATIENT',
#   'UNCERTAINTY',
#   'PROGNOSIS',
#   'DOUBT',
#   'PROSPECT',
#   'EMPLOYMENT',
#   'SPECIALLY',
#   'RELEVANT',
#   'TEENAGER',
#   'SUGGESTED',
#   'PATIENT',
#   'GIVEN',
#   'AMPLE',
#   'OPPORTUNITY',
#   'EARLY',
#   'ADOLESCENCE',
#   'ONWARD',
#   'DISCUS',
#   'ASPECT',
#   'DISEASE',
#   'APPROPRIATE',
#   'PROVISION',
#   'MADE',
#   'TOTAL',
#   'CARE',
#   'ADULT',
#   'PATIENT',
#   'MANY',
#   'PROBLEM',
#   'DEPRESSION',
#   'FEELING',
#   'ISOLATION',
#   'PHYSICAL',
#   'DEMAND',
#   'CONSTANT',
#   'TREATMENT',
#   'PARENT',
#   'CHILD',
#   'CYSTIC',
#   'FIBROSIS',
#   'EXPERIENCE',
#   'PROBABLY',
#   'SIMILAR',
#   'CONFRONTING',
#   'PARENT',
#   'CHRONICALLY',
#   'ILL',
#   'HANDICAPPED',
#   'CHILD',
#   'SPECIAL',
#   'DIFFICULTY',
#   'STEM',
#   'GENETIC',
#   'BASIS',
#   'CYSTIC',
#   'FIBROSIS',
#   'KNOWLEDGE',
#   'EVENTUALLY',
#   'FATAL',
#   'OUTCOME',
#   'ROLE',
#   'PROFESSIONAL',
#   'MEMBER',
#   'MEDICAL',
#   'TEAM',
#   'TOUCHED',
#   'PARTICULARLY',
#   'RELATION',
#   'GENETIC',
#   'COUNSELING',
#   'PROVISION',
#   'PRACTICAL',
#   'EMOTIONAL',
#   'SUPPORT',
#   'PARENT',
#   'COMMENT',
#   'MADE',
#   'ESTABLISHMENT',
#   'LAY',
#   'ORGANISATION',
#   'FINANCIAL',
#   'STRAIN',
#   'ASSOCIATED',
#   'OBTAINING',
#   'REGULAR',
#   'MEDICAL',
#   'ATTENTION',
#   'LOOKED',
#   'SUGGESTION',
#   'MADE',
#   'MINIMIZING',
#   'ECONOMIC',
#   'PROBLEM',
#   'CERTAIN',
#   'VULNERABLE',
#   'FAMILY'],
#  '00044 ': ['MEMBRANE',
#   'ASSOCIATED',
#   'ATPASE',
#   'ACTIVITY',
#   'HUMAN',
#   'RED',
#   'BLOOD',
#   'CELL',
#   'EXAMINED',
#   'FOLLOWING',
#   'ADDITION',
#   'SPENT',
#   'FIBROBLAST',
#   'CULTURE',
#   'MEDIUM',
#   'NORMAL',
#   'CYSTIC',
#   'FIBROSIS',
#   'CELL',
#   'LINE',
#   'COMPARISON',
#   'NORMAL',
#   'UNSPENT',
#   'MEDIUM',
#   'CYSTIC',
#   'FIBROSIS',
#   'MEDIUM',
#   'CONSISTENTLY',
#   'DEPRESSED',
#   'ATPASE',
#   'ACTIVITY'],
#  '00045 ': ['CULTURED',
#   'LYMPHOID',
#   'CELL',
#   'HOMOZYGOTE',
#   'HETEROZYGOTE',
#   'CYSTIC',
#   'FIBROSIS',
#   'COULD',
#   'DISTINGUISHED',
#   'NORMAL',
#   'GROWTH',
#   'PATTERN',
#   'GROSS',
#   'CLUMPING',
#   'RELATIVE',
#   'INCREASE',
#   'DERMATAN',
#   'SULFATE',
#   'NORMAL',
#   'TOTAL',
#   'MUCOPOLYSACCHARIDE',
#   'CONTENT',
#   'LINE',
#   'DERIVED',
#   'GENETIC',
#   'MUCOPOLYSACCHARIDOSES',
#   'ALSO',
#   'CHARACTERISTIC',
#   'TOTAL',
#   'MUCOPOLYSACCHARIDE',
#   'CONTENT',
#   'MARKEDLY',
#   'INCREASED',
#   'OBSERVATION',
#   'SUPPORT',
#   'HYPOTHESIS',
#   'CELLULAR',
#   'DISTURBANCE',
#   'CYSTIC',
#   'FIBROSIS',
#   'RESIDES',
#   'CELLULAR',
#   'REGION',
#   'WHOSE',
#   'FUNCTION',
#   'WOULD',
#   'ALTERED',
#   'MUCOPOLYSACCHARIDE',
#   'COMPOSITION'],
#  '00046 ': ['HEREDITARY',
#   'ABNORMALITY',
#   'INTESTINAL',
#   'TRANSPORT',
#   'RARE',
#   'CONDITION',
#   'DISPROPORTIONATE',
#   'IMPORTANCE',
#   'INFORMATION',
#   'GIVE',
#   'REGARDING',
#   'MECHANISM',
#   'INTESTINAL',
#   'ABSORPTION',
#   'MAN',
#   'MAIN',
#   'DISABILITY',
#   'USUALLY',
#   'DIARRHOEA',
#   'MAY',
#   'ABNORMALITY',
#   'LACK',
#   'ABSORPTION',
#   'ESSENTIAL',
#   'NUTRIENT',
#   'OCCASIONALLY',
#   'ABSORPTION',
#   'COMPOUND',
#   'EXCESS',
#   'DUE',
#   'FAILURE',
#   'NORMAL',
#   'CONTROL',
#   'MECHANISM',
#   'DISEASE',
#   'EXPERIMENT',
#   'NATURE',
#   'EXACTLY',
#   'SIMULATED',
#   'LABORATORY',
#   'ANIMAL',
#   'THUS',
#   'MAY',
#   'OCCASION',
#   'GIVE',
#   'INFORMATION',
#   'UNOBTAINABLE',
#   'SOURCE',
#   'OFTEN',
#   'HOWEVER',
#   'CONFIRM',
#   'MECHANISM',
#   'ABSORPTION',
#   'STUDIED',
#   'DETAIL',
#   'SMALLER',
#   'MAMMAL',
#   'PROBABLY',
#   'APPLICABLE',
#   'MAN',
#   'DISEASE',
#   'ASSOCIATED',
#   'DEFECT',
#   'TRANSPORT',
#   'PROXIMAL',
#   'RENAL',
#   'TUBULE',
#   'WELL',
#   'GUT',
#   'FURNISH',
#   'EVIDENCE',
#   'THEREFORE',
#   'TRANSPORT',
#   'PROCESS',
#   'CLOSELY',
#   'RELATED',
#   'GUT',
#   'KIDNEY',
#   'LEAST',
#   'IMPORTANT',
#   'STEP',
#   'TRANSPORT',
#   'IDENTICAL',
#   'TWO',
#   'SITE',
#   'DISORDER',
#   'INCLUDE',
#   'DISORDER',
#   'CARBOHYDRATE',
#   'ABSORPTION',
#   'HEREDITARY',
#   'DEFECT',
#   'AMINO',
#   'ACID',
#   'ABSORPTION',
#   'HEREDITARY',
#   'DEFECT',
#   'ABSORPTION',
#   'FAT',
#   'HEREDITARY',
#   'DISORDER',
#   'INTESTINAL',
#   'ABSORPTION',
#   'ELECTROLYTE',
#   'HEREDITARY',
#   'DEFECT',
#   'VITAMIN',
#   'ABSORPTION'],
#  '00047 ': ['ELASTICITY',
#   'SPUTUM',
#   'ELASTICITY',
#   'SPUTUM',
#   'DETERMINED',
#   'USING',
#   'WEISSENBERG',
#   'RHEOGONIOMETER',
#   'OSCILLATORY',
#   'TESTING',
#   'FREQUENCY',
#   'SPUTUM',
#   'PATIENT',
#   'EITHER',
#   'ASTHMA',
#   'CHRONIC',
#   'BRONCHITIS',
#   'CYSTIC',
#   'FIBROSIS',
#   'BRONCHIECTASIS',
#   'MACROSCOPICALLY',
#   'MUCOID',
#   'MUCOPURULENT',
#   'PURULENT',
#   'VISCOSITY',
#   'PLOT',
#   'SHEAR',
#   'RATE',
#   'RANGE',
#   'TWO',
#   'ZONE',
#   'JUNCTIONAL',
#   'REGION',
#   'DISTINGUISHED',
#   'ZONE',
#   'LOWEST',
#   'SHEAR',
#   'RATE',
#   'ELASTICITY',
#   'INCREASE',
#   'SLOWLY',
#   'CHANGE',
#   'LITTLE',
#   'PLATEAU',
#   'REGION',
#   'ZONE',
#   'INCREASE',
#   'SHARPLY',
#   'CONTRAST',
#   'VISCOSITY',
#   'PLOT',
#   'PLATEAU',
#   'SHOW',
#   'NOTHING',
#   'SAMPLE',
#   'SHOW',
#   'DECREASING',
#   'ELASTICITY',
#   'ALTHOUGH',
#   'VARIANCE',
#   'SAMPLE',
#   'WIDE',
#   'LEVEL',
#   'ELASTICITY',
#   'CHARACTERISTIC',
#   'DISEASE',
#   'ONE',
#   'MACROSCOPIC',
#   'APPEARANCE',
#   'ELASTICITY',
#   'VISCOSITY',
#   'CORRELATED',
#   'SIGNIFICANTLY',
#   'LOWEST',
#   'SHEAR',
#   'RATE',
#   'ASTHMATIC',
#   'BRONCHIECTATIC',
#   'SPUTUM',
#   'RESEMBLE',
#   'CORRELATION',
#   'STILL',
#   'SIGNIFICANT',
#   'HIGHER',
#   'SHEAR',
#   'RATE',
#   'CYSTIC',
#   'FIBROSIS',
#   'CHRONIC',
#   'BRONCHITIC',
#   'SPUTUM',
#   'SINCE',
#   'LAST',
#   'TWO',
#   'MUCOUS',
#   'GLAND',
#   'HYPERTROPHY',
#   'PRESENT',
#   'MAY',
#   'SPUTUM',
#   'HIGHER',
#   'MUCUS',
#   'COMPONENT'],
#  '00048 ': ['CONCENTRATION',
#   'IMMUNOGLOBULIN',
#   'DETERMINED',
#   'USING',
#   'MANCINI',
#   'METHOD',
#   'STANDARD',
#   'SERUM',
#   'TAKEN',
#   'LONG',
#   'TERM',
#   'TREATMENT',
#   'CHILD',
#   'MONTH',
#   'YEAR',
#   'OLD',
#   'SHOWN',
#   'DEPEND',
#   'MARKEDLY',
#   'CLINICAL',
#   'STATE',
#   'CHILD',
#   'PARTICULARLY',
#   'PRESENCE',
#   'PULMONARY',
#   'TRACT',
#   'INFECTIOUS',
#   'PROCESS',
#   'INFECTION',
#   'CAUSED',
#   'RISE',
#   'IMMUNOGLOBULIN',
#   'CONCENTRATION',
#   'PREDOMINANCE',
#   'IGM',
#   'CHILD',
#   'AGED',
#   'YR',
#   'PREDOMINANCE',
#   'IGG',
#   'OLDER',
#   'CHILD',
#   'MEAN',
#   'TITER',
#   'ISOHEMAGGLUTININS',
#   'CHILD',
#   'HIGHER',
#   'HEALTHY',
#   'CHILD',
#   'LOW',
#   'TITER',
#   'DIPHTHERIAL',
#   'STAPHOLOCOCCAL',
#   'ANTIBODY',
#   'FOUND',
#   'CASE',
#   'ANTI',
#   'DIPHTHERIA',
#   'ANTIBODY',
#   'ATTRIBUTED',
#   'FACT',
#   'CHILD',
#   'REGULARLY',
#   'VACCINATED',
#   'OWING',
#   'POOR',
#   'CLINICAL',
#   'CONDITION',
#   'LOW',
#   'TITER',
#   'ANTISTAPHYLOCOCCAL',
#   'ANTIBODY',
#   'WELL',
#   'KNOWN',
#   'FINDING',
#   'COURSE',
#   'CHRONIC',
#   'STAPHYLOCOCCAL',
#   'INFECTION',
#   'APPROPRIATE',
#   'BACTERIOLOGICAL',
#   'TEST',
#   'CHILD',
#   'FURTHERMORE',
#   'LYMPHOCYTE',
#   'SHOWED',
#   'INCREASED',
#   'BLASTIC',
#   'TRANSFORMATION',
#   'STIMULATED',
#   'STAPHYLOCOCCAL',
#   'FILTRATE',
#   'TRANSFORMATION',
#   'PHA',
#   'STIMULATED',
#   'LYMPHOCYTE',
#   'NORMAL'],
#  '00049 ': ['CROSS',
# ...
#   'WORKING',
#   'ABDOMINAL',
#   'MASS',
#   'EVALUATING',
#   'TUMOR',
#   'PATIENT',
#   'BASELINE',
#   'SCAN',
#   'FOUND',
#   'LEAST',
#   'USEFUL',
#   'PATIENT',
#   'FEVER',
#   'UNKNOWN',
#   'ORIGIN',
#   'ABDOMINAL',
#   'PAIN',
#   'DIFFUSE',
#   'LIVER',
#   'DISEASE',
#   'INFLAMMATORY',
#   'CONDITION',
#   'LIVER',
#   'ABSCESS',
#   'FOUND',
#   'FEBRILE',
#   'OTHERWISE',
#   'HEALTHY',
#   'CHILD',
#   'IODINE',
#   'ROSE',
#   'BENGAL',
#   'LIVER',
#   'SCAN',
#   'FOUND',
#   'USEFUL',
#   'DIFFERENTIATE',
#   'POTENTIALLY',
#   'CURABLE',
#   'LESION',
#   'CHOLEDOCHAL',
#   'CYST',
#   'SURGICALLY',
#   'TREATABLE'],
#  '00150 ': ['AMYLASE',
#   'ISOENZYME',
#   'PATTERN',
#   'EVALUATED',
#   'SERUM',
#   'URINE',
#   'DUODENAL',
#   'FLUID',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'CF',
#   'NORMAL',
#   'SUBJECT',
#   'TWO',
#   'THIRD',
#   'CF',
#   'PATIENT',
#   'ABSENT',
#   'PANCREATIC',
#   'ENZYME',
#   'LACKED',
#   'SERUM',
#   'PANCREATIC',
#   'ISOAMYLASE',
#   'BAND',
#   'REMAINDER',
#   'MARKEDLY',
#   'DIMINISHED',
#   'PANCREATIC',
#   'BAND',
#   'COMPARED',
#   'SALIVARY',
#   'ISOAMYLASE',
#   'NORMAL',
#   'SERUM',
#   'PANCREATIC',
#   'BAND',
#   'EQUAL',
#   'GREATER',
#   'SALIVARY',
#   'BAND',
#   'PATIENT',
#   'ABSENT',
#   'ENZYME',
#   'DIAGNOSIS',
#   'ABNORMAL',
#   'PANCREATIC',
#   'FUNCTION',
#   'COULD',
#   'MADE',
#   'EVALUATION',
#   'SERUM',
#   'ISOAMYLASE',
#   'PATTERN',
#   'THEREBY',
#   'AVOIDING',
#   'DUODENAL',
#   'INTUBATION',
#   'COLLECTION',
#   'HOUR',
#   'STOOL',
#   'PROTEOLYTIC',
#   'ENZYME',
#   'ACTIVITY',
#   'PATIENT',
#   'NORMAL',
#   'PANCREATIC',
#   'ENZYME',
#   'ACTIVITY',
#   'NORMAL',
#   'SERUM',
#   'ZYMOGRAMS',
#   'CF',
#   'PATIENT',
#   'LOW',
#   'TOTAL',
#   'SERUM',
#   'AMYLASE',
#   'CONCENTRATION',
#   'TOTAL',
#   'DUODENAL',
#   'FLUID',
#   'AMYLASE',
#   'LEVEL',
#   'MAY',
#   'MISLEADING',
#   'EVALUATION',
#   'PANCREATIC',
#   'FUNCTION',
#   'SINCE',
#   'AMYLASE',
#   'MAY',
#   'SALIVARY',
#   'ORIGIN',
#   'ADVANTAGE',
#   'ISOAMYLASE',
#   'METHOD',
#   'INCLUDE',
#   'SIMPLICITY',
#   'NONINVASIVENESS',
#   'REQUIRING',
#   'SMALL',
#   'BLOOD',
#   'SAMPLE',
#   'SPECIFICITY',
#   'PANCREATIC',
#   'FUNCTION',
#   'INDEPENDENCE',
#   'PANCREATIC',
#   'ENZYME',
#   'MEDICATION'],
#  '00151 ': ['GASTRIC',
#   'MUCOSAL',
#   'BIOPSY',
#   'EIGHT',
#   'NEW',
#   'UNTREATED',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'CF',
#   'TWO',
#   'NORMAL',
#   'SUBJECT',
#   'STUDIED',
#   'QUANTITATIVE',
#   'TECHNIQUE',
#   'ELECTRON',
#   'MICROSCOPY',
#   'EM',
#   'DETERMINE',
#   'WHETHER',
#   'PRESECRETED',
#   'GASTRIC',
#   'MUCUS',
#   'COMPACT',
#   'VISCID',
#   'NORMAL',
#   'ANALYSIS',
#   'VARIANCE',
#   'TECHNIQUE',
#   'SHOW',
#   'DIFFERENCE',
#   'MEAN',
#   'GROUP',
#   'STUDIED',
#   'OBSERVATION',
#   'SUGGEST',
#   'MUCUS',
#   'MAY',
#   'VISCID',
#   'PRIOR',
#   'SECRETION',
#   'ELECTRON',
#   'MICROSCOPY',
#   'GASTRIC',
#   'MUCUS',
#   'APPEAR',
#   'DIAGNOSTIC',
#   'VALUE',
#   'CF'],
#  '00152 ': ['GENTAMICIN',
#   'BROAD',
#   'SPECTRUM',
#   'BACTERICIDAL',
#   'AMINOGLYCOSIDE',
#   'ANTIBIOTIC',
#   'TENTH',
#   'YEAR',
#   'USE',
#   'LEAGUE',
#   'TABLE',
#   'ANTIBIOTIC',
#   'RANKED',
#   'DISC',
#   'SENSITIVITY',
#   'TEST',
#   'URINARY',
#   'TRACT',
#   'PATHOGEN',
#   'STAPH',
#   'AUREUS',
#   'CONFIRM',
#   'REMARKABLE',
#   'EFFECTIVENESS',
#   'BACTERIODES',
#   'SP',
#   'STREPTOCOCCI',
#   'MAJOR',
#   'OMISSION',
#   'SPECTRUM',
#   'MIC',
#   'SENSITIVE',
#   'STRAIN',
#   'USUALLY',
#   'LE',
#   'EQUAL',
#   'MICROG',
#   'ML',
#   'ALTHOUGH',
#   'PSEUDOMONAS',
#   'MAY',
#   'REQUIRE',
#   'GREATER',
#   'EQUAL',
#   'MICROG',
#   'ML',
#   'THERAPEUTIC',
#   'RANGE',
#   'AIMED',
#   'MICROG',
#   'ML',
#   'SERUM',
#   'PEAK',
#   'LEVEL',
#   'MEASURED',
#   'HR',
#   'INTRAMUSCULAR',
#   'MIN',
#   'INTRAVENOUS',
#   'INJECTION',
#   'WORKER',
#   'REGARD',
#   'LEVEL',
#   'MICROG',
#   'ML',
#   'POTENTIALLY',
#   'TOXIC',
#   'TRY',
#   'AVOID',
#   'EXCEEDING'],
#  '00153 ': ['AIM',
#   'THERAPEUTIC',
#   'DIET',
#   'PROVIDE',
#   'NUTRITIONALLY',
#   'ADEQUATE',
#   'DIET',
#   'VARIETY',
#   'NATURAL',
#   'SPECIALLY',
#   'PREPARED',
#   'ARTIFICIAL',
#   'FOOD',
#   'SUBSTITUTE',
#   'TREATMENT',
#   'SPECIFIC',
#   'CLINICAL',
#   'DISORDER',
#   'ROLE',
#   'DIETITIAN',
#   'WORK',
#   'MEMBER',
#   'MEDICAL',
#   'TEAM',
#   'PAEDIATRIC',
#   'DIETETICS',
#   'REQUIRE',
#   'RATHER',
#   'DETAILED',
#   'ADVICE',
#   'HELP',
#   'PARENT',
#   'PARTICULARLY',
#   'DIET',
#   'INVOLVES',
#   'CALCULATION',
#   'RESTRICTION',
#   'SPECIFIC',
#   'NUTRIENT',
#   'DIETARY',
#   'CONSIDERATION',
#   'OBESITY',
#   'DIABETES',
#   'MELLITUS',
#   'COELIAC',
#   'DISEASE',
#   'CYSTIC',
#   'FIBROSIS',
#   'CARBOHYDRATE',
#   'INTOLERANCE',
#   'GALACTOSAEMIA',
#   'PHENYLKETONURIA',
#   'DISCUSSED'],
#  '00154 ': ['PAPER',
#   'ANALYZES',
#   'CELL',
#   'CYCLE',
#   'CYSTIC',
#   'FIBROSIS',
#   'DERIVED',
#   'FIBROBLAST',
#   'STATISTICALLY',
#   'DEMONSTRATES',
#   'FAILURE',
#   'SUPPORT',
#   'NORMAL',
#   'POPULATION',
#   'DOUBLING',
#   'TIME',
#   'VITRO',
#   'INDICATES',
#   'DUE',
#   'LARGELY',
#   'FAILURE',
#   'CYSTIC',
#   'FIBROSIS',
#   'DERIVED',
#   'CELL',
#   'ENTER',
#   'CELL',
#   'CYCLE',
#   'NORMAL',
#   'NUMBER',
#   'EXPLANATION',
#   'SIGNIFICANT',
#   'DIFFERENCE',
#   'BEHAVIOR',
#   'CELL',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'VI',
#   'VI',
#   'EITHER',
#   'NORMAL',
#   'DISEASE',
#   'CONTROL',
#   'FIBROBLAST',
#   'SAVE',
#   'CONCLUDE',
#   'PROCEEDS',
#   'INTRINSIC',
#   'PROPERTY',
#   'CELL'],
#  '00155 ': ['TWENTY',
#   'FIVE',
#   'CHILD',
#   'AGED',
#   'MONTH',
#   'YEAR',
#   'STUDIED',
#   'DETERMINE',
#   'USEFULNESS',
#   'COMPUTER',
#   'ASSISTED',
#   'VENTILATION',
#   'PERFUSION',
#   'SCANNING',
#   'ANALYSIS',
#   'REGIONAL',
#   'PULMONARY',
#   'FUNCTION',
#   'CYSTIC',
#   'FIBROSIS',
#   'VENTILATION',
#   'PERFUSION',
#   'SCINTIPHOTOGRAPHS',
#   'COMPARED',
#   'PATIENT',
#   'RADIOGRAPH',
#   'REGIONAL',
#   'FRACTIONAL',
#   'EXCHANGE',
#   'AIR',
#   'RELATIVE',
#   'REGIONAL',
#   'RATIO',
#   'OBTAINED',
#   'WHOLE',
#   'LUNG',
#   'AIR',
#   'EXCHANGE',
#   'SIGNIFICANTLY',
#   'CORRELATED',
#   'STANDARD',
#   'PULMONARY',
#   'FUNCTION',
#   'TEST',
#   'RADIOGRAPH',
#   'SCORE',
#   'VENTILATION',
#   'PERFUSION',
#   'RATIO',
#   'GRADIENT',
#   'REVERSED',
#   'PAT',
#   'PREDOMINANTLY',
#   'UPPER',
#   'ZONE',
#   'DISEASE',
#   'REGIONAL',
#   'RATIO',
#   'UNEVEN',
#   'DISTRIBUTION',
#   'QUANTITATIVE',
#   'ASSESSMENT',
#   'REGIONAL',
#   'VENTILATION',
#   'PERFUSION',
#   'USEFUL',
#   'TECHNIQUE',
#   'ASSESSING',
#   'SEVERITY',
#   'PULMONARY',
#   'DISEASE',
#   'CHILD',
#   'CYSTIC',
#   'FIBROSIS'],
#  '00156 ': ['ENDOSCOPIC',
#   'PANCREATICOGRAPHIC',
#   'FINDING',
#   'PROVED',
#   'CASE',
#   'PANCREATITIS',
#   'ANALYZED',
#   'PATHOLOGIC',
#   'DUCTOGRAMS',
#   'DEMONSTRATED',
#   'APPROXIMATELY',
#   'SIGNIFICANT',
#   'INFORMATION',
#   'OBTAINED',
#   'MANY',
#   'CASE',
#   'ALLOWING',
#   'PROPER',
#   'DIAGNOSIS',
#   'PRIMARY',
#   'DISEASE',
#   'PROCESS',
#   'COMPLICATION',
#   'THEREOF',
#   'LATTER',
#   'PROCEDURE',
#   'PROVED',
#   'QUITE',
#   'HELPFUL',
#   'ISOLATING',
#   'PATIENT',
#   'COULD',
#   'BENEFIT',
#   'SURGERY'],
#  '00157 ': ['SECTION',
#   'CONSIDERS',
#   'SIGNIFICANCE',
#   'VITAMIN',
#   'TOCOPHEROL',
#   'DEFICIENCY',
#   'VARIETY',
#   'DISEASE',
#   'STATE',
#   'EFFECT',
#   'VITAMIN',
#   'LACK',
#   'UNCLEAR',
#   'CAUSE',
#   'VITAMIN',
#   'DEFICIENCY',
#   'INCLUDE',
#   'DIETARY',
#   'LACK',
#   'INTESTINAL',
#   'MALABSORPTION',
#   'CASE',
#   'HISTORY',
#   'INVOLVING',
#   'CYSTIC',
#   'FIBROSIS',
#   'EXAMINED'],
#  '00158 ': ['ALBUMIN',
#   'MECONIUM',
#   'QUANTITATED',
#   'MEAN',
#   'SINGLE',
#   'RADIAL',
#   'IMMUNODIFFUSION',
#   'TECHNIQUE',
#   'DESCRIBED',
#   'DETAIL',
#   'METHOD',
#   'SHOW',
#   'GOOD',
#   'PRECISION',
#   'ACCURACY',
#   'MATERIAL',
#   'CERTAIN',
#   'CONDITION',
#   'ASSOCIATED',
#   'COLLECTION',
#   'PREPARATION',
#   'ANALYSIS',
#   'OBSERVED',
#   'METHOD',
#   'DISCRIMINATE',
#   'HEALTHY',
#   'NEWBORN',
#   'NEWBORN',
#   'CYSTIC',
#   'FIBROSIS'],
#  '00159 ': ['TOBRAMYCIN',
#   'TREATMENT',
#   'CHRONIC',
#   'PULMONARY',
#   'INFECTION',
#   'CAUSED',
#   'PSEUDOMONAS',
#   'AERUGINOSA',
#   'CHILD',
#   'CYSTIC',
#   'FIBROSIS',
#   'EVALUATED',
#   'INITIALLY',
#   'PATIENT',
#   'RECEIVED',
#   'RECOMMENDED',
#   'DOSE',
#   'MG',
#   'HOUR',
#   'DOSE',
#   'INCREASED',
#   'MG',
#   'HOUR',
#   'APPROXIMATELY',
#   'MG',
#   'KG',
#   'HOUR',
#   'HIGHER',
#   'DOSAGE',
#   'ADMINISTERED',
#   'INTRAMUSCULARLY',
#   'PATIENT',
#   'EIGHT',
#   'RECEIVED',
#   'ADDITIONAL',
#   'THERAPY',
#   'AEROSOL',
#   'CONTAINING',
#   'TOBRAMYCIN',
#   'THERAPY',
#   'POSSIBLE',
#   'ERADICATE',
#   'P',
#   'AERUGINOSA',
#   'RESPIRATORY',
#   'TRACT',
#   'PATIENT',
#   'DISCONTINUING',
#   'THERAPY',
#   'P',
#   'AERUGINOSA',
#   'OCCURRED',
#   'PATIENT',
#   'WITHIN',
#   'ONE',
#   'MONTH',
#   'PATIENT',
#   'SHOWED',
#   'CLINICAL',
#   'IMPROVEMENT',
#   'RELATION',
#   'THERAPY',
#   'TOXIC',
#   'ALLERGIC',
#   'SIDE',
#   'EFFECT',
#   'OBSERVED'],
#  '00160 ': ['THIRTY',
#   'FIVE',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'AGED',
#   'MONTH',
#   'YEAR',
#   'INVESTIGATED',
#   'REGARD',
#   'RESPIRATORY',
#   'SYMPTOM',
#   'RESPIRATORY',
#   'TRACT',
#   'PATHOGEN',
#   'SERUM',
#   'IMMUNOGLOBULIN',
#   'SERUM',
#   'PRECIPITIN',
#   'HAEMOPHILUS',
#   'INFLUENZAE',
#   'COMMONEST',
#   'PATHOGEN',
#   'SUPPLANTED',
#   'ADVANCED',
#   'DISEASE',
#   'PSEUDOMONAS',
#   'AERUGINOSA',
#   'PATIENT',
#   'RESPIRATORY',
#   'INFECTION',
#   'LEVEL',
#   'IGG',
#   'SIGNIFICANTLY',
#   'LOWER',
#   'NORMAL',
#   'CHILD',
#   'COMPARABLE',
#   'AGE',
#   'CHILD',
#   'SEVERE',
#   'RESPIRATORY',
#   'INFECTION',
#   'IMMUNOGLOBULIN',
#   'RAISED',
#   'PRECIPITIN',
#   'PREDOMINANT',
#   'RESPIRATORY',
#   'ORGANISM',
#   'PRESENT',
#   'FINDING',
#   'DIFFER',
#   'PREVALENT',
#   'VIEW',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'NORMAL',
#   'RESPONSE',
#   'INFECTION',
#   'COMMON',
#   'INFECTING',
#   'ORGANISM',
#   'STAPHYLOCOCCUS',
#   'AUREUS'],
#  '00161 ': ['COMPARE',
#   'VITRO',
#   'SUSCEPTIBILITY',
#   'MUCOID',
#   'NONMUCOID',
#   'PSEUDOMONAS',
#   'AERUGINOSA',
#   'GENTAMICIN',
#   'ISOLATES',
#   'MUCOID',
#   'NONMUCOID',
#   'AERUGINOSA',
#   'CULTURED',
#   'THROAT',
#   'SWAB',
#   'SPUTUM',
#   'SPECIMEN',
#   'PATIENT',
#   'DIAGNOSED',
#   'CYSTIC',
#   'FIBROSIS',
#   'MUCOID',
#   'FORM',
#   'AERUGINOSA',
#   'THROAT',
#   'SWAB',
#   'CULTURE',
#   'SUSCEPTIBLE',
#   'GENTAMICIN',
#   'WHEREAS',
#   'MUCOID',
#   'STRAIN',
#   'SPUTUM',
#   'CULTURE',
#   'SUSCEPTIBLE',
#   'NONMUCOID',
#   'STRAIN',
#   'THROAT',
#   'SWAB',
#   'SPUTUM',
#   'CULTURE',
#   'SUSCEPTIBLE',
#   'RESPECTIVELY',
#   'SINCE',
#   'DIFFERENCE',
#   'SUSCEPTIBILITY',
#   'FOUR',
#   'GROUP',
#   'ORGANISM',
#   'SIGNIFICANT',
#   'CONCLUDED',
#   'DATA',
#   'SHOW',
#   'REAL',
#   'DIFFERENCE',
#   'SUSCEPTIBILITY',
#   'GENTAMICIN',
#   'MUCOID',
#   'NONMUCOID',
#   'STRAIN'],
#  '00162 ': ['PURPOSE',
#   'PRESENT',
#   'WORK',
#   'STUDY',
#   'TYPE',
#   'INHERITANCE',
#   'INVOLVED',
#   'MUCOVISCIDOSIS',
#   'ANALYSIS',
#   'GENETIC',
#   'RELATION',
#   'MUCOVISCIDOSIS',
#   'PERFORMED',
#   'FAMILY',
#   'BEAR',
#   'WITNESS',
#   'MONOMERIC',
#   'AUTOSOMAL',
#   'MECHANISM',
#   'TRANSMISSION',
#   'CHARACTER',
#   'CONTRAST',
#   'RECESSIVE',
#   'DISEASE',
#   'PARENTAL',
#   'CONSANGUINITY',
#   'PLAY',
#   'SECONDARY',
#   'ROLE',
#   'MUCOVISCIDOSIS',
#   'APPARENTLY',
#   'EXPLAINED',
#   'WIDE',
#   'DISTRIBUTION',
#   'MUCOVISCIDOSIS',
#   'GENE',
#   'AMONG',
#   'POPULATION',
#   'OBSERVATION',
#   'DESCRIBED',
#   'MAY',
#   'UTILIZED',
#   'MEDICOGENETIC',
#   'CONSULTATION',
#   'GIVEN',
#   'MEMBER',
#   'FAMILY',
#   'CHILD',
#   'SUFFERING',
#   'MUCOVISCIDOSIS'],
#  '00163 ': ['SUGGESTED',
#   'DEVELOPMENT',
#   'GOITER',
#   'HYPOTHYROIDISM',
#   'PATIENT',
#   'RECEIVING',
#   'CHRONIC',
#   'IODIDE',
#   'THERAPY',
#   'INDICATES',
#   'UNDERLYING',
#   'THYROID',
#   'DISEASE',
#   'DOLAN',
#   'GIBSON',
#   'RETROSPECTIVE',
#   'STUDY',
#   'REVIEWED',
#   'RECORD',
#   'CHILD',
#   'CYSTIC',
#   'FIBROSIS',
#   'RECEIVING',
#   'CHRONIC',
#   'EXPECTORANT',
#   'THERAPY',
#   'IODIDE',
#   'REPORTED',
#   'APPROXIMATELY',
#   'PERCENT',
#   'GOITER',
#   'PERCENT',
#   'SUGGESTIVE',
#   'CLINICAL',
#   'FINDING',
#   'HYPOTHYROIDISM',
#   'STUDY',
#   'TOGETHER',
#   'FACT',
#   'THYROID',
#   'LIKE',
#   'LUNG',
#   'PANCREAS',
#   'ENDODERMAL',
#   'ORIGIN',
#   'RAISED',
#   'POSSIBILITY',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'MIGHT',
#   'UNDERLYING',
#   'DEFECT',
#   'THYROID',
#   'FUNCTION',
#   'THYROID',
#   'FUNCTION',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'EVALUATED',
#   'SYSTEMATIC',
#   'FASHION',
#   'PRESENT',
#   'STUDY',
#   'UNDERTAKEN',
#   'EVALUATED',
#   'BASAL',
#   'THYROID',
#   'FUNCTION',
#   'LARGE',
#   'GROUP',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'ADDITION',
#   'OBSERVED',
#   'EFFECT',
#   'CHRONIC',
#   'IODIDE',
#   'ADMINISTRATION',
#   'PRESENT',
#   'STUDY',
#   'STRONGLY',
#   'SUGGESTS',
#   'OFTEN',
#   'OCCURS',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'DERANGEMENT',
#   'THYROID',
#   'HORMONE',
#   'ECONOMY',
#   'FREQUENCY',
#   'IODIDE',
#   'INCREASED',
#   'SERUM',
#   'THYROTROPIN',
#   'DECREASED',
#   'SERUM',
#   'THYROXINE',
#   'CONCENTRATION',
#   'INDUCED',
#   'GOITER',
#   'WITHOUT',
#   'HYPOTHYROIDISM',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'POINT',
#   'STRONGLY',
#   'PRESENCE',
#   'INTRINSIC',
#   'ABNORMALITY',
#   'THYROID',
#   'DISEASE',
#   'NATURE',
#   'ABNORMALITY',
#   'REMAINS',
#   'UNCLEAR'],
#  '00164 ': ['PRELIMINARY',
#   'CLINICAL',
#   'STUDY',
#   'ABILITY',
#   'MULTIVALENT',
#   'HEAT',
#   'KILLED',
#   'WHOLE',
#   'CELL',
#   'GRAM',
#   'NEGATIVE',
#   'BACILLUS',
#   'VACCINE',
#   'TOLERATED',
#   'EVOKE',
#   'ANTIBODY',
#   'RESPONSE',
#   'GROUP',
#   'PATIENT',
#   'MANIFEST',
#   'NEED',
#   'INCREASED',
#   'RESISTANCE',
#   'GRAM',
#   'NEGATIVE',
#   'BACILLUS',
#   'THREE',
#   'GROUP',
#   'PATIENT',
#   'STUDIED',
#   'BURN',
#   'PATIENT',
#   'SEVEN',
#   'SMALL',
#   'CHILD',
#   'CYSTIC',
#   'FIBROSIS',
#   'PATIENT',
#   'UNDERGO',
#   'CORONARY',
#   'VEIN',
#   'GRAFT',
#   'RESULT',
#   'VACCINATION',
#   'DIFFERENT',
#   'THREE',
#   'GROUP',
#   'PATIENT',
#   'VACCINATED'],
#  '00165 ': ['AUTHOR',
#   'ATTEMPTED',
#   'EVALUATE',
#   'METHODOLOGY',
#   'CURRENTLY',
#   'USE',
#   'SUGGESTED',
#   'ROUTINE',
#   'DETERMINATION',
#   'VITAMIN',
#   'BLOOD',
#   'TISSUE',
#   'SPECIAL',
#   'CONSIDERATION',
#   'GIVEN',
#   'EXTRANEOUS',
#   'FACTOR',
#   'CAUSE',
#   'ERRONEOUS',
#   'RESULT',
#   'FLUOROMETRIC',
#   'ANALYSIS',
#   'REVIEW',
#   'OLDER',
#   'CURRENT',
#   'LITERATURE',
#   'DISTRIBUTION',
#   'VITAMIN',
#   'TISSUE',
#   'PRESENTED',
#   'SPECIAL',
#   'CONSIDERATION',
#   'GIVEN',
#   'UPTAKE',
#   'VITAMIN',
#   'LIVER',
#   'STORAGE',
#   'HEPATOCYTES',
#   'KUPFFER',
#   'CELL',
#   'SUBCELLULAR',
#   'ORGANELLE',
#   'DATA',
#   'CONCENTRATION',
#   'VITAMIN',
#   'LIVER',
#   'VICTIM',
#   'ACCIDENTAL',
#   'DEATH',
#   'EFFECT',
#   'DISEASE',
#   'SEVERAL',
#   'ETIOLOGY',
#   'PRESENTED',
#   'MECHANISM',
#   'LIVER',
#   'STORE',
#   'RETINYL',
#   'ESTER',
#   'MOBILIZED',
#   'RELEASED',
#   'PLASMA',
#   'REMAINS',
#   'OBSCURE',
#   'CONSIDERABLE',
#   'INFORMATION',
#   'GAINED',
#   'RECENTLY',
#   'MECHANISM',
#   'RETINOL',
#   'TRANSPORTED',
#   'BLOOD',
#   'STUDY',
#   'LEADING',
#   'ISOLATION',
#   'CHARACTERIZATION',
#   'RETINOL',
#   'TRANSPORT',
#   'PROTEIN',
#   'SUMMARIZED',
#   'METABOLISM',
#   'RETINOL',
#   'BINDING',
#   'PROTEIN',
#   'HEALTH',
#   'DISEASE',
#   'ESPECIALLY',
#   'CYSTIC',
#   'FIBROSIS',
#   'DISCUSSED',
#   'FINALLY',
#   'FACTOR',
#   'IMPORTANCE',
#   'INTERPRETATION',
#   'PLASMA',
#   'LEVEL',
#   'TERM',
#   'VITAMIN',
#   'REVIEWED',
#   'SPECIAL',
#   'ATTENTION',
#   'GIVEN',
#   'EFFECT',
#   'PLASMA',
#   'LEVEL',
#   'RETINOL',
#   'RETINOL',
#   'TRANSPORT',
#   'PROTEIN',
#   'PERIOD',
#   'RAPID',
#   'GROWTH',
#   'CORRELATION',
#   'AGE',
#   'INFLUENCE',
#   'DIETARY',
#   'ADEQUACY',
#   'DISTRIBUTION',
#   'PLASMA',
#   'LEVEL',
#   'VITAMIN'],
#  '00166 ': ['PULMONARY',
#   'MACROPHAGE',
#   'COLLECTED',
#   'BRONCHIAL',
#   'MUCUS',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'CHRONIC',
#   'LUNG',
#   'DISEASE',
#   'INVESTIGATED',
#   'HISTOCHEMICALLY',
#   'ACID',
#   'PHOSPHATASE',
#   'BETA',
#   'GLUCURONIDASE',
#   'BETA',
#   'GLUCOSAMINIDASE',
#   'ACTIVITY',
#   'ALSO',
#   'MUCOPOLYSACCHARIDE',
#   'CONTENT',
#   'MACROPHAGE',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'DECREASED',
#   'BETA',
#   'GLUCURONIDASE',
#   'ACTIVITY',
#   'OBSERVED',
#   'TOGETHER',
#   'LARGE',
#   'CYTOPLASMIC',
#   'VACUOLE',
#   'SUGGESTING',
#   'STORAGE',
#   'PARTIALLY',
#   'DIGESTED',
#   'MATERIAL',
#   'THUS',
#   'SEEMS',
#   'LIKELY',
#   'APART',
#   'INCREASED',
#   'SYNTHESIS',
#   'MUCOPOLYSACCHARIDE',
#   'DESCRIBED',
#   'CYSTIC',
#   'FIBROSIS',
#   'SEVERAL',
#   'AUTHOR',
#   'DEGRADATION',
#   'MUCOSUBSTANCES',
#   'PRODUCED',
#   'IMPAIRED'],
#  '00167 ': ['HL',
#   'FREQUENCY',
#   'PATIENT',
#   'CYSTIC',
#   'FIBROSIS',
#   'UNRELATED',
#   'CONTROL',
#   'COMPARED',
#   'STATISTICALLY',
#   'SIGNIFICANT',
#   'DIFFERENCE',
#   'HL',
#   'FREQUENCY',
#   'COULD',
#   'OBSERVED',
#   'GROUP',
#   'SLIGHTLY',
#   'INCREASED',
#   'HL',
#   'FREQUENCY',
#   'CONSIDERED',
#   'CHANCE',
#   'PHENOMENON',
#   'ACCORDANCE',
#   'PREVIOUSLY',
#   'DEMONSTRATED',
#   'LACKING',
#   'ASSOCIATION',
#   'ABH',
#   'BLOOD',
#   'GROUP',
#   'SUBSTANCE',
#   'CORRELATION',
#   'CERTAIN',
#   'HL',
#   'ANTIGEN',
#   'DEMONSTRABLE']}

# %% [markdown]
# ### Building Inverted Index

# %%
def gli(words, preprocessed_data):
    inverted_index = {}
    for rec_num, text in preprocessed_data.items():
        for word in words:
            if word in text:
                if word not in inverted_index:
                    inverted_index[word] = []
                inverted_index[word].extend([rec_num] * text.count(word))
    return inverted_index

# %%
unique_words_list
# Out:
# ['SIGNIFICANCE',
#  'PSEUDOMONAS',
#  'AERUGINOSA',
#  'INFECTION',
#  'RESPIRATORY',
#  'TRACT',
#  'CYSTIC',
#  'FIBROSIS',
#  'PATIENT',
#  'STUDIED',
#  'MEAN',
#  'IMMUNOELECTROPHORETICAL',
#  'ANALYSIS',
#  'SERUM',
#  'NUMBER',
#  'PRECIPITIN',
#  'CONCENTRATION',
#  'PROTEIN',
#  'ADDITION',
#  'CLINICAL',
#  'RADIOGRAPHICAL',
#  'STATUS',
#  'LUNG',
#  'EVALUATED',
#  'USING',
#  'SCORING',
#  'SYSTEM',
#  'DEMONSTRATED',
#  'MAXIMUM',
#  'ONE',
#  'SIGNIFICANTLY',
#  'CHANGED',
#  'COMPARED',
#  'MATCHED',
#  'CONTROL',
#  'PERSON',
#  'NOTABLY',
#  'IGG',
#  'IGA',
#  'ELEVATED',
#  'ACUTE',
#  'PHASE',
#  'LATTER',
#  'SUGGESTING',
#  'ACTIVE',
#  'TISSUE',
#  'DAMAGE',
#  'HAPTOGLOBIN',
#  'CORRELATED',
#  'MANY',
#  'ACCOMPANIED',
#  'RESULT',
#  'INDICATE',
#  'PROTECTIVE',
#  'VALUE',
#  'SALIVARY',
#  'AMYLASE',
#  'LEVEL',
#  'DETERMINED',
#  'NORMAL',
#  'SUBJECT',
#  'BIRTH',
#  'ADULT',
#  'LIFE',
#  'CHILD',
#  'CONDITION',
#  'SOMETIMES',
#  'ASSOCIATED',
#  'LOW',
#  'PANCREATIC',
#  'MALNUTRITION',
#  'COELIAC',
#  'DISEASE',
#  'MIXED',
#  'SALIVA',
#  'COLLECTED',
#  'CAREFULLY',
#  'STANDARDISED',
#  'MEASURED',
#  'METHOD',
#  'DAHLQVIST',
#  'WIDE',
#  'SCATTER',
#  'ROSE',
#  'REACH',
#  'AGE',
#  'MONTH',
#  'YEAR',
#  'ACTIVITY',
#  'NORMALLY',
#  'TEN',
#  'WEEK',
#  'PREMATURE',
#  'INFANT',
#  'FED',
#  'MILK',
#  'GASTROSTOMY',
#  'THIRTEEN',
#  'MOSTLY',
#  'SIX',
#  'MALNOURISHED',
#  'JEJUNAL',
#  'VILLOUS',
#  'ATROPHY',
#  'UNCERTAIN',
#  'AETIOLOGY',
#  'RECOVERY',
#  'BEGAN',
#  'ARTICLE',
#  'REPORT',
#  'POSSIBILITY',
#  'INSTRUMENTAL',
#  'NEUTRON',
#  'ACTIVATION',
#  'INAA',
#  'SODIUM',
#  'NAIL',
#  'CLIPPING',
#  'DIAGNOSING',
#  'CF',
#  'DETECTING',
#  'HETEROZYGOTE',
#  'SCREENING',
#  'NEONATAL',
#  'PERIOD',
#  'NEWBORN',
#  'TWO',
#  'HEALTHY',
#  'ANALYZED',
#  'DISCRIMINATION',
#  'FOUND',
#  'PRECISE',
#  'INDIVIDUAL',
#  'ACCEPTED',
#  'DIAGNOSTIC',
#  'TEST',
#  'COULD',
#  'DETECTED',
#  'FIRST',
#  'FIVE',
#  'DAY',
#  'BIG',
#  'OVERLAP',
#  'MAKE',
#  'INVALUABLE',
#  'EARLY',
#  'USED',
#  'DEVELOPMENT',
#  'THREE',
#  'OLD',
#  'SAMPLED',
#  'DIFFERENT',
#  'ERROR',
#  'STUDY',
#  'COLLECTION',
#  'ROUTINE',
#  'OUTLINED',
#  'EASILY',
#  'WASHED',
#  'RISK',
#  'CONTAMINATION',
#  'SEEMS',
#  'SMALL',
#  'DISTRIBUTION',
#  'INHOMOGENEOUS',
#  'CONTENT',
#  'VARIES',
#  'ALSO',
#  'GOOD',
#  'EVIDENCE',
#  'INCREASED',
#  'COME',
#  'SWEAT',
#  'BASIC',
#  'INTRINSIC',
#  'PRECISION',
#  'ACCURACY',
#  'DETERMINING',
#  'CONSIDERED',
#  'SATISFACTORY',
#  'CONCLUDED',
#  'SUITABLE',
#  'AID',
#  'DIAGNOSIS',
#  'CAPACITY',
#  'DUODENAL',
#  'JUICE',
#  'HYDROLYSE',
#  'CASEIN',
#  'TRICHLOROACETIC',
#  'ACID',
#  'SOLUBLE',
#  'PEPTIDE',
#  'INVESTIGATED',
#  'GROUP',
#  'ENTEROGENIC',
#  'MALABSORPTION',
#  'COW',
#  'INTOLERANCE',
#  'PROTEOLYTIC',
#  'PER',
#  'ML',
#  'FASTING',
#  'GREAT',
#  'MG',
#  'HOUR',
#  'CORRELATION',
#  'TRYPSIN',
#  'INSUFFICIENCY',
#  'EXTREMELY',
#  'MEASURABLE',
#  'WHEREAS',
#  'WITHIN',
#  'RANGE',
#  'INFLUENCE',
#  'CHRONIC',
#  'P',
#  'OCCURRENCE',
#  'BONE',
#  'MARROW',
#  'DERIVED',
#  'LYMPHOCYTE',
#  'CELL',
#  'THYMUS',
#  'PERIPHERAL',
#  'BLOOD',
#  'SUFFERED',
#  'PRODUCED',
#  'MULTIPLE',
#  'CROSSED',
#  'IMMUNOELECTROPHORESIS',
#  'NEVER',
#  'HARBOURED',
#  'PRESENTED',
#  'DEMONSTRABLE',
#  'BACTERIA',
#  'EXAMINED',
#  'PRESENCE',
#  'SURFACE',
#  'MARKER',
#  'RECEPTOR',
#  'COMPLEMENT',
#  'COMPONENT',
#  'EAC',
#  'ROSETTE',
#  'FORMATION',
#  'IMMUNOGLOBULIN',
#  'IMMUNOFLUORESCENT',
#  'STAINING',
#  'SPONTANEOUS',
#  'BINDING',
#  'SHEEP',
#  'RED',
#  'RATIO',
#  'NEARLY',
#  'IDENTICAL',
#  'TOTAL',
#  'SIGNIFICANT',
#  'HIGHER',
#  'POSITIVELY',
#  'WHERAS',
#  'INSIGNIFICANT',
#  'MONTHLY',
#  'BACTERIOLOGICAL',
#  'EXAMINATION',
#  'TRACHEAL',
#  'SECRETION',
#  'POLYVALENT',
#  'ANTIGEN',
#  'PREVALENCE',
#  'RATE',
#  'HARBOURING',
#  'CENT',
#  'NEWLY',
#  'COLONIZED',
#  'INTERMITTENTLY',
#  'NON',
#  'MUCOID',
#  'STRAIN',
#  'PREDOMINATING',
#  'CHRONICALLY',
#  'ESPECIALLY',
#  'MALE',
#  'FEMALE',
#  'DURATION',
#  'COLONIZATION',
#  'CONTRAST',
#  'ACCORDANCE',
#  'HYPOTHESIS',
#  'SUBSTANCE',
#  'VIRULENCE',
#  'FACTOR',
#  'MIGHT',
#  'INHIBIT',
#  'OPSONIZING',
#  'EFFECT',
#  'DEPENDENT',
#  'LYSIS',
#  'HEREBY',
#  'FAVOURING',
#  'EXPENSE',
#  'SEVENTY',
#  'TREATED',
#  'CLINIC',
#  'FOLLOWED',
#  'DAILY',
#  'IMPRESSION',
#  'OBTAINED',
#  'LABORATORY',
#  'EXPRESSED',
#  'POINT',
#  'STAPHYLOCOCCUS',
#  'AUREUS',
#  'HAEMOPHILUS',
#  'INFLUENZAE',
#  'DIPLOCOCCUS',
#  'PNEUMONIAE',
#  'MISCELLANEOUS',
#  'MAINLY',
#  'ENTEROBACTERIACEAE',
#  'FLUCTUATION',
#  'BACTERIOLOGY',
#  'DESCRIBED',
#  'ADDITIONAL',
#  'EPIDEMIOLOGICAL',
#  'TERM',
#  'ST',
#  'PATTERN',
#  'MINOR',
#  'MODIFICATION',
#  'REGARD',
#  'REFLECTS',
#  'DIFFICULT',
#  'THERAPEUTIC',
#  'PROBLEM',
#  'NEW',
#  'RECOLONIZATION',
#  'REFLECT',
#  'PREVENTION',
#  'INCIDENCE',
#  'SHOW',
#  'STILL',
#  'CONSIDERABLE',
#  'THERAPY',
#  'WELL',
#  'ALTHOUGH',
#  'SPECIE',
#  'MAY',
#  'COLONIZE',
#  'MAIN',
#  'CONCERN',
#  'REASON',
#  'DISCUSSED',
#  'FAMILY',
#  'CELIAC',
#  'SPRUE',
#  'OCCURRED',
#  'SIBSHIP',
#  'COUSIN',
#  'INDEX',
#  'CASE',
#  'DISCOVERED',
#  'GENETICS',
#  'REVIEWED',
#  'ESTIMATED',
#  'LIKELIHOOD',
#  'ASSOCIATION',
#  'OCCURRING',
#  'BASIS',
#  'CHANCE',
#  'EXHIBITED',
#  'FEATURE',
#  'KARTAGENER',
#  'SYNDROME',
#  'AUTHOR',
#  'KNOWLEDGE',
#  'REPRESENTS',
#  'THIRD',
#  'COMBINATION',
#  'EXCLUDED',
#  'MADE',
#  'ALLERGY',
#  'COURSE',
#  'FIFTEEN',
#  'DEFINED',
#  'HISTORY',
#  'PHYSICAL',
#  'POSITIVE',
#  'SKIN',
#  'NASAL',
#  'EOSINOPHILIA',
#  'REVERSIBLE',
#  'AIRWAY',
#  'OBSTRUCTION',
#  'ALLERGIC',
#  'NONALLERGIC',
#  'IGE',
#  'INTERNATIONAL',
#  'UNIT',
#  'IU',
#  'IGM',
#  'SIMILAR',
#  'SHWACHMAN',
#  'SCORE',
#  'BETTER',
#  'MODULATING',
#  'SEVERITY',
#  'TAUSSIG',
#  'ET',
#  'AL',
#  'REPORTED',
#  'BOY',
#  'RUSSELL',
#  'VARIANT',
#  'SILVER',
#  'CONCOMITANT',
#  'WOULD',
#  'LIKE',
#  'DESCRIBE',
#  'ANOTHER',
#  'FINDING',
#  'POSSIBLE',
#  'ENTIRELY',
#  'ACCIDENTAL',
#  'COINCIDENCE',
#  'STATISTICALLY',
#  'RARE',
#  'EVENT',
#  'ESTABLISHMENT',
#  'RELATIONSHIP',
#  'DEPEND',
#  'INTENSIVE',
#  'SEARCH',
#  'BLACK',
#  'WASHINGTON',
#  'DC',
#  'DISCLOSED',
#  'EIGHT',
#  'BORN',
#  'DISTRICT',
#  'COLUMBIA',
#  'DECADE',
#  'CALCULATED',
#  'LEAST',
#  'PATHOLOGICAL',
#  'CHANGE',
#  'WHITE',
#  'GENETIC',
#  'CONSIDERATION',
#  'AUTOSOMAL',
#  'RECESSIVE',
#  'INHERITANCE',
#  'GENERALLY',
#  'PRENATAL',
#  'DISORDER',
#  'RECEIVED',
#  'INCREASING',
#  'ATTENTION',
#  'PAST',
#  'SEVERAL',
#  'RAPID',
#  'EXPANSION',
#  'RELIABLE',
#  'LED',
#  'ADVANCE',
#  'INTRAUTERINE',
#  'LARGE',
#  'INHERITED',
#  'INITIALLY',
#  'DETERMINE',
#  'CHROMOSOMAL',
#  'ABNORMALITY',
#  'DETERMINATION',
#  'FETAL',
#  'SEX',
#  'PREGNANCY',
#  'SEVERE',
#  'LINKED',
#  'SHORTLY',
#  'THEREAFTER',
#  'BECAME',
#  'CLEAR',
#  'TECHNIQUE',
#  'APPLIED',
#  'INBORN',
#  'METABOLISM',
#  'RECENTLY',
#  'DEVELOPED',
#  'PROVE',
#  'CONGENITAL',
#  'MALFORMATION',
#  'DIAGNOSED',
#  'PRIOR',
#  'GOAL',
#  'REVIEW',
#  'DEFINE',
#  'ACHIEVEMENT',
#  'FUTURE',
#  'PRESENT',
#  'LIMITATION',
#  'SECTION',
#  'DEAL',
#  'GENERAL',
#  'APPROACH',
#  'DISCUSSION',
#  'SPECIFIC',
#  'APPLICATION',
#  'INCLUDE',
#  'AMNIOCENTESIS',
#  'DIRECT',
#  'INDIRECT',
#  'VISUALIZATION',
#  'FETUS',
#  'MATERNAL',
#  'URINE',
#  'SAMPLING',
#  'LIPID',
#  'CARBOHYDRATE',
#  'MUCOPOLYSACCHARIDE',
#  'AMINO',
#  'PROVIDE',
#  'PARENT',
#  'WITHOUT',
#  'FEAR',
#  'DEFORMITY',
#  'INCREASE',
#  'DETECTABLE',
#  'UTERO',
#  'POTENTIAL',
#  'TREATMENT',
#  'UNLIMITED',
#  'WOMAN',
#  'COMBINED',
#  'FORM',
#  'ORAL',
#  'CONTRACEPTIVE',
#  'POLYPOID',
#  'CERVICITIS',
#  'POLYP',
#  'RECURRED',
#  'REINSTITUTION',
#  'MEDICATION',
#  'RESOLUTION',
#  'INSTANCE',
#  'DISCONTINUATION',
#  'DRUG',
#  'AFFECTED',
#  'COINCIDENTAL',
#  'DETERIORATION',
#  'THEREFORE',
#  'SUGGESTED',
#  'CONTRACEPTION',
#  'OBSERVED',
#  'CLOSELY',
#  'REGARDING',
#  'PULMONARY',
#  'GYNECOLOGIC',
#  'ATAXIA',
#  'TELANGIECTASIA',
#  'CHARACTERIZED',
#  'PROGRESSIVE',
#  'NEUROLOGIC',
#  'DEGENERATION',
#  'CUTANEOUS',
#  'CONJUNCTIVAL',
#  'TELANGIECTASIS',
#  'IMMUNOLOGIC',
#  'DEFICIENCY',
#  'ROENTGENOLOGIC',
#  'SINUS',
#  'DECREASED',
#  'LYMPHOID',
#  'USUALLY',
#  'SINOPULMONARY',
#  'RESEMBLE',
#  'ADENOIDAL',
#  'MASS',
#  'DIFFERENTIAL',
#  'LONGER',
#  'TARGET',
#  'ORGAN',
#  'LESION',
#  'BRONCHIAL',
#  'LEADING',
#  'BRONCHIECTASIS',
#  'INTERSTITIAL',
#  'INFILTRATES',
#  'CYST',
#  'CHARACTERISTIC',
#  'ROENTGENOGRAPHY',
#  'COMPLICATION',
#  'HYPERTENSION',
#  'PNEUMONITIS',
#  'HEMORRHAGE',
#  'PNEUMOTHORAX',
#  'LITTLE',
#  'EXISTS',
#  'GASTROINTESTINAL',
#  'INVOLVEMENT',
#  'DESPITE',
#  'SIMILARITY',
#  'PATHOGENESIS',
#  'ALWAYS',
#  'MUST',
#  'DIFFERENTIATED',
#  'FAR',
#  'RABBIT',
#  'ALVEOLAR',
#  'MACROPHAGE',
#  'CONCERNED',
#  'HOMOZYGOUS',
#  'EXPERIMENT',
#  'EVEN',
#  'GREATER',
#  'FOURFOLD',
#  'BIGGAR',
#  'ASSOCIATE',
#  'STATE',
#  'REQUIRED',
#  'PHAGOCYTOSIS',
#  'DILUTION',
#  'EITHER',
#  'HANK',
#  'BALANCED',
#  'SALT',
#  'SOLUTION',
#  'HUMAN',
#  'THUS',
#  'DECREASING',
#  'PHAGOCYTIZE',
#  'KILL',
#  'OPPOSITE',
#  'SUSPENSION',
#  'REDUCED',
#  'PHAGOCYTIC',
#  'UNEXPECTED',
#  'HIGH',
#  'LIKELY',
#  'TOXIC',
#  'INHIBITION',
#  'ABSENT',
#  'PREVIOUSLY',
#  'HEATED',
#  'FROZEN',
#  'OBSERVATION',
#  'ABILITY',
#  'FEEL',
#  'DATA',
#  'DEMONSTRATE',
#  'LABILE',
#  'INHIBITOR',
#  'RATHER',
#  'SINCE',
#  'KNOWN',
#  'INCLUDING',
#  'RESPOND',
#  'SHOWN',
#  'ESSENTIAL',
#  'AGREE',
#  'DUE',
#  'NOTE',
#  'STORED',
#  'DEGREE',
#  'PERHAPS',
#  'ACCOUNT',
#  'DIFFERENCE',
#  'ASSAYED',
#  'ARGININE',
#  'RECEIVING',
#  'ESTERASE',
#  'UNTREATED',
#  'LOWER',
#  'CARRIER',
#  'ESTERASES',
#  'PLASMA',
#  'ELECTROFUSING',
#  'POLYACRYLAMIDE',
#  'GEL',
#  'BAND',
#  'WORK',
#  'REPRODUCED',
#  'COBURN',
#  'CONFIRMED',
#  'WORKING',
#  'UNDERSTAND',
#  'DEFECT',
#  'VARIATION',
#  'PH',
#  'CHLORIDE',
#  'EMPLOYED',
#  'TESTED',
#  'ALTER',
#  'MAJOR',
#  'RESULTED',
#  'DR',
#  'RAO',
#  'NEGLECT',
#  'MENTION',
#  'UNABLE',
#  'CONFIRM',
#  'DETECT',
#  'FUNCTION',
#  'ASTHMA',
#  'MEASUREMENT',
#  'CLOSING',
#  'VOLUME',
#  'FLOW',
#  'SPIROMETRY',
#  'BODY',
#  'PLETHYSMOGRAPHY',
#  'ARTERIALIZED',
#  'OXYGEN',
#  'TENSION',
#  'COMPARISON',
#  'LE',
#  'SENSITIVE',
#  'RESIDUAL',
#  'EXPIRATORY',
#  'CURVE',
#  'GAS',
#  'BRONCHOSPASM',
#  'INHALING',
#  'EXTRACT',
#  'SPRINKLED',
#  'FOOD',
#  'RESPONDED',
#  'BRONCHODILATOR',
#  'USE',
#  'FACE',
#  'MASK',
#  'PREPARATION',
#  'MEAL',
#  'PREVENTED',
#  'RECURRENCE',
#  'DATE',
#  'PRECIPITATE',
#  'INHALATION',
#  'SEEN',
#  'RESISTANCE',
#  'PLETHYSMOGRAPHIC',
#  'BRISCOE',
#  'DUBOIS',
#  'CALCULATE',
#  'SRAW',
#  'RANGING',
#  'LOWEST',
#  'RAPIDLY',
#  'SEC',
#  'CM',
#  'DECREASE',
#  'PARALLELED',
#  'SEXUAL',
#  'MATURATION',
#  'YOUNG',
#  'VARIOUS',
#  'CILIATED',
#  'EPITHELIUM',
#  'RHINITIS',
#  'MAINTAINED',
#  'CULTURE',
#  'EXPLANTED',
#  'RETAINED',
#  'MORPHOLOGIC',
#  'INCORPORATED',
#  'GLYCOPROTEIN',
#  'SECRETED',
#  'MEDIUM',
#  'THROUGHOUT',
#  'LABELED',
#  'MUCOUS',
#  'SOLUBILIZED',
#  'REDUCTION',
#  'ALKYLATION',
#  'PURIFIED',
#  'FILTRATION',
#  'CHROMATOGRAPHY',
#  'SEPARATED',
#  'DIETHYLAMINOETHYL',
#  'DEAE',
#  'CELLULOSE',
#  'COLUMN',
#  'FRACTION',
#  'COMPOSITION',
#  'DIFFERED',
#  'ACETYL',
#  'NEURAMINIC',
#  'FUCOSE',
#  'RELATIVE',
#  'INCORPORATION',
#  'GLUCOSAMINE',
#  'INDISTINGUISHABLE',
#  'RESPECT',
#  'HOWEVER',
#  'EXCEEDED',
#  'CORRESPONDING',
#  'PRESSURE',
#  'BEHAVIOR',
#  'ISOVOLUME',
#  'DETECTION',
#  'SEPARATE',
#  'GROSSLY',
#  'ABNORMAL',
#  'EXCESSIVE',
#  'STIFFNESS',
#  'NEAR',
#  'LOSS',
#  'RECOIL',
#  'OFTEN',
#  'ENOUGH',
#  'CAUSE',
#  'DISTURBANCE',
#  'EXCHANGE',
#  'QUANTITATIVELY',
#  'EXPLAINED',
#  'ELASTIC',
#  'MODIFIED',
#  'MILD',
#  'OTHERWISE',
#  'SE',
#  'UPSTREAM',
#  'EFFORT',
#  'SHOWING',
#  'TIME',
#  'CONSTANT',
#  'EMPTYING',
#  'VARIED',
#  'WIDELY',
#  'INVOLVES',
#  'WORSENING',
#  'TRAPPING',
#  'BLAND',
#  'AEROSOL',
#  'PARTICULARLY',
#  'MIST',
#  'TENT',
#  'CONVINCING',
#  'EFFICACY',
#  'SURPRISING',
#  'DEPOSIT',
#  'WATER',
#  'DETRIMENTAL',
#  'BACTERIAL',
#  'ENZYME',
#  'ACTIVATED',
#  'TREATING',
#  'CHLOROFORM',
#  'ELLAGIC',
#  'MANNER',
#  'INHIBITED',
#  'SOYBEAN',
#  'SPITE',
#  'WIDESPREAD',
#  'BREATHING',
#  'EXERCISE',
#  'HELPFUL',
#  'PEDIATRIC',
#  'OBJECTIVE',
#  'DEMONSTRATION',
#  'MANEUVER',
#  'PART',
#  'LACKING',
#  'SPUTUM',
#  'SHORT',
#  'COUGH',
#  'POSTURAL',
#  'DRAINAGE',
#  'LONG',
#  'REMAINS',
#  'UNKNOWN',
#  'SIMPLICITY',
#  'EASE',
#  'FINGERNAIL',
#  'TOENAIL',
#  'MEASURE',
#  'ELECTROLYTE',
#  'PROCEDURE',
#  'CATEGORY',
#  'DISEASED',
#  'INDICATED',
#  'EAR',
#  'NOSE',
#  'THROAT',
#  'SURVEY',
#  'CARRIED',
#  'AGED',
#  'TRANSIENTLY',
#  'DEAF',
#  'EUSTACHIAN',
#  'TUBE',
#  'DYSFUNCTION',
#  'SECRETORY',
#  'OTITIS',
#  'GAVE',
#  'POLYPECTOMY',
#  'THOUGH',
#  'MIDDLE',
#  'NEITHER',
#  'DEAFNESS',
#  'TOCOPHEROL',
#  'PRESUMABLY',
#  'STEATORRHOEA',
#  'MUSCULAR',
#  'WEAKNESS',
#  'WASTING',
#  'BIOCHEMICAL',
#  'CREATINURIA',
#  'CREATINE',
#  'POOR',
#  'DIET',
#  'REVERSAL',
#  'INGESTION',
#  'ESTER',
#  'MUSCLE',
#  'FOCAL',
#  'SKELETAL',
#  'RESEMBLING',
#  'NUTRITIONAL',
#  'DYSTROPHY',
#  'CEROID',
#  'PIGMENT',
#  'SMOOTH',
#  'STRENGTH',
#  'BULB',
#  'ERGOGRAPH',
#  'ATTENDING',
#  'BABY',
#  'HOSPITAL',
#  'PRESBYTERIAN',
#  'MEDICAL',
#  'CENTER',
#  'YORK',
#  'DOUBLE',
#  'BLIND',
#  'HALF',
#  'ORALLY',
#  'REMAINDER',
#  'PLACEBO',
#  'RETURNED',
#  'VISCOSITY',
#  'LIQUEFACTION',
#  'NIGHT',
#  'SLEPT',
#  'MORNING',
#  'FOLLOWING',
#  'RANDOMLY',
#  'ALLOCATED',
#  'SUPPLIED',
#  'JET',
#  'ULTRASONIC',
#  'NEBULIZER',
#  'ANALYSED',
#  'DNA',
#  'PURULENCE',
#  'RELATION',
#  'FURTHERMORE',
#  'CONSISTENT',
#  'EXPECTORATED',
#  'ABSENCE',
#  'STAY',
#  'NEBULIZATION',
#  'SUGGEST',
#  'CONSISTENTLY',
#  'SISTER',
#  'FATAL',
#  'OBSTRUCTIVE',
#  'ORIGIN',
#  'CLINICALLY',
#  'HISTOLOGICALLY',
#  'GLAND',
#  'SHOWED',
#  'EXPECTED',
#  'BOWEL',
#  'SYMPTOM',
#  'PANCREAS',
#  'NECROPSY',
#  'ACETATE',
#  'STRIP',
#  'ELECTROPHORESIS',
#  'SUFFICIENTLY',
#  'DIFFERENTIATE',
#  'MECONIUM',
#  'MARKED',
#  'QUANTITATIVE',
#  'IMMUNOELECTROPHORETIC',
#  'CONTAIN',
#  'ALPHA',
#  'ANTITRYPSIN',
#  'ANTICHYMOTRYPSIN',
#  'SAMPLE',
#  'CONTAINED',
#  'ALBUMIN',
#  'AMOUNT',
#  'VARIETY',
#  'CONFIRMING',
#  'SPECIMEN',
#  'SCREENED',
#  'COEXISTENCE',
#  'PREDISPOSE',
#  'LATER',
#  'LARGELY',
#  ...]

# %%
teste = gli(unique_words_list, pp_data)
print(teste)
# Out:
# {'SIGNIFICANCE': ['00001 ', '00074 ', '00078 ', '00121 ', '00147 ', '00157 '], 'PSEUDOMONAS': ['00001 ', '00001 ', '00001 ', '00007 ', '00008 ', '00018 ', '00018 ', '00061 ', '00061 ', '00062 ', '00062 ', '00062 ', '00062 ', '00062 ', '00079 ', '00080 ', '00081 ', '00081 ', '00081 ', '00081 ', '00082 ', '00082 ', '00082 ', '00123 ', '00123 ', '00123 ', '00135 ', '00148 ', '00152 ', '00159 ', '00160 ', '00161 '], 'AERUGINOSA': ['00001 ', '00001 ', '00001 ', '00006 ', '00006 ', '00006 ', '00006 ', '00006 ', '00006 ', '00007 ', '00007 ', '00007 ', '00007 ', '00007 ', '00007 ', '00008 ', '00008 ', '00008 ', '00008 ', '00008 ', '00018 ', '00018 ', '00062 ', '00079 ', '00080 ', '00080 ', '00081 ', '00110 ', '00123 ', '00123 ', '00135 ', '00148 ', '00159 ', '00159 ', '00159 ', '00160 ', '00161 ', '00161 ', '00161 '], 'INFECTION': ['00001 ', '00001 ', '00001 ', '00006 ', '00006 ', '00006 ', '00016 ', '00018 ', '00048 ', '00048 ', '00057 ', '00058 ', '00058 ', '00061 ', '00062 ', '00062 ', '00062 ', '00062 ', '00062 ', '00062 ', '00062 ', '00062 ', '00062 ', '00079 ', '00081 ', '00104 ', '00111 ', '00111 ', '00111 ', '00111 ', '00111 ', '00111 ', '00111 ', '00123 ', '00133 ', '00146 ', '00159 ', '00160 ', '00160 ', '00160 '], 'RESPIRATORY': ['00001 ', '00001 ', '00001 ', '00006 ', '00006 ', '00007 ', '00007 ', '00008 ', '00011 ', '00011 ', '00011 ', '00015 ', '00017 ', '00025 ', '00025 ', '00031 ', '00037 ', '00056 ', '00080 ', '00099 ', '00103 ', '00110 ', '00118 ', '00133 ', '00135 ', '00148 ', '00148 ', '00159 ', '00160 ', '00160 ', '00160 ', '00160 ', '00160 '], 'TRACT': ['00001 ', '00001 ', '00001 ', '00006 ', '00006 ', '00007 ', '00007 ', '00008 ', '00017 ', '00025 ', '00031 ', '00048 ', '00056 ', '00080 ', '00134 ', '00135 ', '00139 ', '00152 ', '00159 ', '00160 '], 'CYSTIC': ['00001 ', '00002 ', '00002 ', '00003 ', '00004 ', '00006 ', '00007 ', '00007 ', '00008 ', '00008 ', '00008 ', '00009 ', '00010 ', '00010 ', '00011 ', '00012 ', '00012 ', '00013 ', '00014 ', '00015 ', '00015 ', '00016 ', '00017 ', '00017 ', '00019 ', '00019 ', '00019 ', '00019 ', '00019 ', '00019 ', '00019 ', '00019 ', '00019 ', '00019 ', '00019 ', '00020 ', '00021 ', '00021 ', '00022 ', '00023 ', '00023 ', '00023 ', '00024 ', '00024 ', '00026 ', '00026 ', '00026 ', '00027 ', '00028 ', '00029 ', '00029 ', '00030 ', '00030 ', '00030 ', '00031 ', '00032 ', '00032 ', '00034 ', '00034 ', '00034 ', '00037 ', '00037 ', '00038 ', '00039 ', '00040 ', '00040 ', '00041 ', '00043 ', '00043 ', '00043 ', '00044 ', '00044 ', '00045 ', '00045 ', '00047 ', '00047 ', '00049 ', '00050 ', '00050 ', '00051 ', '00051 ', '00051 ', '00052 ', '00052 ', '00052 ', '00053 ', '00053 ', '00053 ', '00054 ', '00055 ', '00056 ', '00057 ', '00057 ', '00058 ', '00059 ', '00061 ', '00062 ', '00063 ', '00064 ', '00064 ', '00064 ', '00065 ', '00065 ', '00065 ', '00065 ', '00066 ', '00067 ', '00067 ', '00067 ', '00068 ', '00069 ', '00069 ', '00069 ', '00069 ', '00070 ', '00070 ', '00071 ', '00071 ', '00072 ', '00073 ', '00073 ', '00074 ', '00074 ', '00075 ', '00076 ', '00077 ', '00077 ', '00077 ', '00077 ', '00078 ', '00080 ', '00080 ', '00082 ', '00083 ', '00083 ', '00084 ', '00085 ', '00088 ', '00088 ', '00089 ', '00090 ', '00091 ', '00092 ', '00093 ', '00093 ', '00094 ', '00094 ', '00095 ', '00095 ', '00095 ', '00095 ', '00096 ', '00096 ', '00096 ', '00097 ', '00097 ', '00098 ', '00098 ', '00098 ', '00098 ', '00099 ', '00099 ', '00099 ', '00100 ', '00101 ', '00102 ', '00103 ', '00103 ', '00103 ', '00103 ', '00103 ', '00104 ', '00105 ', '00108 ', '00109 ', '00109 ', '00110 ', '00111 ', '00111 ', '00112 ', '00112 ', '00112 ', '00112 ', '00112 ', '00113 ', '00115 ', '00116 ', '00116 ', '00118 ', '00119 ', '00121 ', '00121 ', '00122 ', '00122 ', '00123 ', '00125 ', '00125 ', '00125 ', '00125 ', '00126 ', '00126 ', '00127 ', '00129 ', '00130 ', '00130 ', '00130 ', '00133 ', '00133 ', '00133 ', '00133 ', '00135 ', '00135 ', '00135 ', '00135 ', '00137 ', '00138 ', '00138 ', '00139 ', '00140 ', '001 ...

# %% [markdown]
# ### Creating Term-Document matrix

# %%
def term_document_matrix(inverted_index):
    tdm = {}
    for word in inverted_index.keys():
        tdm[word] = len([rec_num for rec_num in inverted_index[word]])
    return tdm

# %%
teste_tdm = term_document_matrix(teste)

teste_tdm
# Out:
# {'SIGNIFICANCE': 6,
#  'PSEUDOMONAS': 32,
#  'AERUGINOSA': 39,
#  'INFECTION': 40,
#  'RESPIRATORY': 33,
#  'TRACT': 20,
#  'CYSTIC': 255,
#  'FIBROSIS': 256,
#  'PATIENT': 274,
#  'STUDIED': 22,
#  'MEAN': 35,
#  'IMMUNOELECTROPHORETICAL': 1,
#  'ANALYSIS': 13,
#  'SERUM': 103,
#  'NUMBER': 37,
#  'PRECIPITIN': 16,
#  'CONCENTRATION': 46,
#  'PROTEIN': 36,
#  'ADDITION': 8,
#  'CLINICAL': 36,
#  'RADIOGRAPHICAL': 1,
#  'STATUS': 6,
#  'LUNG': 37,
#  'EVALUATED': 9,
#  'USING': 20,
#  'SCORING': 2,
#  'SYSTEM': 10,
#  'DEMONSTRATED': 9,
#  'MAXIMUM': 8,
#  'ONE': 39,
#  'SIGNIFICANTLY': 24,
#  'CHANGED': 2,
#  'COMPARED': 9,
#  'MATCHED': 5,
#  'CONTROL': 68,
#  'PERSON': 4,
#  'NOTABLY': 2,
#  'IGG': 10,
#  'IGA': 8,
#  'ELEVATED': 16,
#  'ACUTE': 6,
#  'PHASE': 2,
#  'LATTER': 5,
#  'SUGGESTING': 5,
#  'ACTIVE': 4,
#  'TISSUE': 12,
#  'DAMAGE': 3,
#  'HAPTOGLOBIN': 1,
#  'CORRELATED': 13,
#  'MANY': 18,
#  'ACCOMPANIED': 4,
#  'RESULT': 35,
#  'INDICATE': 5,
#  'PROTECTIVE': 2,
#  'VALUE': 29,
#  'SALIVARY': 15,
#  'AMYLASE': 9,
#  'LEVEL': 49,
#  'DETERMINED': 9,
#  'NORMAL': 117,
#  'SUBJECT': 31,
#  'BIRTH': 8,
#  'ADULT': 18,
#  'LIFE': 7,
#  'CHILD': 98,
#  'CONDITION': 34,
#  'SOMETIMES': 2,
#  'ASSOCIATED': 22,
#  'LOW': 15,
#  'PANCREATIC': 33,
#  'MALNUTRITION': 8,
#  'COELIAC': 13,
#  'DISEASE': 93,
#  'MIXED': 4,
#  'SALIVA': 14,
#  'COLLECTED': 9,
#  'CAREFULLY': 2,
#  'STANDARDISED': 1,
#  'MEASURED': 12,
#  'METHOD': 34,
#  'DAHLQVIST': 1,
#  'WIDE': 5,
#  'SCATTER': 1,
#  'ROSE': 5,
#  'REACH': 1,
#  'AGE': 41,
#  'MONTH': 14,
#  'YEAR': 34,
#  'ACTIVITY': 54,
#  'NORMALLY': 3,
#  'TEN': 3,
#  'WEEK': 4,
#  'PREMATURE': 3,
#  'INFANT': 25,
#  'FED': 3,
#  'MILK': 5,
#  'GASTROSTOMY': 1,
#  'THIRTEEN': 2,
#  'MOSTLY': 2,
#  'SIX': 9,
#  'MALNOURISHED': 2,
#  'JEJUNAL': 4,
#  'VILLOUS': 3,
#  'ATROPHY': 2,
#  'UNCERTAIN': 2,
#  'AETIOLOGY': 1,
#  'RECOVERY': 4,
#  'BEGAN': 2,
#  'ARTICLE': 4,
#  'REPORT': 20,
#  'POSSIBILITY': 6,
#  'INSTRUMENTAL': 2,
#  'NEUTRON': 2,
#  'ACTIVATION': 3,
#  'INAA': 5,
#  'SODIUM': 20,
#  'NAIL': 14,
#  'CLIPPING': 7,
#  'DIAGNOSING': 2,
#  'CF': 127,
#  'DETECTING': 4,
#  'HETEROZYGOTE': 33,
#  'SCREENING': 24,
#  'NEONATAL': 3,
#  'PERIOD': 17,
#  'NEWBORN': 13,
#  'TWO': 24,
#  'HEALTHY': 11,
#  'ANALYZED': 3,
#  'DISCRIMINATION': 1,
#  'FOUND': 55,
#  'PRECISE': 4,
#  'INDIVIDUAL': 13,
#  'ACCEPTED': 3,
#  'DIAGNOSTIC': 8,
#  'TEST': 48,
#  'COULD': 22,
#  'DETECTED': 13,
#  'FIRST': 13,
#  'FIVE': 9,
#  'DAY': 8,
#  'BIG': 1,
#  'OVERLAP': 4,
#  'MAKE': 2,
#  'INVALUABLE': 1,
#  'EARLY': 15,
#  'USED': 17,
#  'DEVELOPMENT': 11,
#  'THREE': 15,
#  'OLD': 6,
#  'SAMPLED': 1,
#  'DIFFERENT': 8,
#  'ERROR': 4,
#  'STUDY': 50,
#  'COLLECTION': 5,
#  'ROUTINE': 6,
#  'OUTLINED': 2,
#  'EASILY': 2,
#  'WASHED': 1,
#  'RISK': 5,
#  'CONTAMINATION': 2,
#  'SEEMS': 8,
#  'SMALL': 13,
#  'DISTRIBUTION': 7,
#  'INHOMOGENEOUS': 1,
#  'CONTENT': 18,
#  'VARIES': 3,
#  'ALSO': 32,
#  'GOOD': 3,
#  'EVIDENCE': 20,
#  'INCREASED': 35,
#  'COME': 1,
#  'SWEAT': 30,
#  'BASIC': 6,
#  'INTRINSIC': 6,
#  'PRECISION': 2,
#  'ACCURACY': 3,
#  'DETERMINING': 2,
#  'CONSIDERED': 6,
#  'SATISFACTORY': 2,
#  'CONCLUDED': 7,
#  'SUITABLE': 3,
#  'AID': 3,
#  'DIAGNOSIS': 34,
#  'CAPACITY': 8,
#  'DUODENAL': 6,
#  'JUICE': 3,
#  'HYDROLYSE': 1,
#  'CASEIN': 2,
#  'TRICHLOROACETIC': 1,
#  'ACID': 38,
#  'SOLUBLE': 1,
#  'PEPTIDE': 1,
#  'INVESTIGATED': 9,
#  'GROUP': 56,
#  'ENTEROGENIC': 2,
#  'MALABSORPTION': 7,
#  'COW': 2,
#  'INTOLERANCE': 4,
#  'PROTEOLYTIC': 4,
#  'PER': 34,
#  'ML': 12,
#  'FASTING': 1,
#  'GREAT': 5,
#  'MG': 12,
#  'HOUR': 11,
#  'CORRELATION': 11,
#  'TRYPSIN': 10,
#  'INSUFFICIENCY': 4,
#  'EXTREMELY': 4,
#  'MEASURABLE': 2,
#  'WHEREAS': 17,
#  'WITHIN': 9,
#  'RANGE': 9,
#  'INFLUENCE': 4,
#  'CHRONIC': 40,
#  'P': 18,
#  'OCCURRENCE': 9,
#  'BONE': 3,
#  'MARROW': 4,
#  'DERIVED': 7,
#  'LYMPHOCYTE': 8,
#  'CELL': 72,
#  'THYMUS': 1,
#  'PERIPHERAL': 7,
#  'BLOOD': 25,
#  'SUFFERED': 1,
#  'PRODUCED': 9,
#  'MULTIPLE': 1,
#  'CROSSED': 4,
#  'IMMUNOELECTROPHORESIS': 4,
#  'NEVER': 2,
#  'HARBOURED': 2,
#  'PRESENTED': 8,
#  'DEMONSTRABLE': 3,
#  'BACTERIA': 6,
#  'EXAMINED': 12,
#  'PRESENCE': 16,
#  'SURFACE': 4,
#  'MARKER': 3,
#  'RECEPTOR': 1,
#  'COMPLEMENT': 9,
#  'COMPONENT': 11,
#  'EAC': 1,
#  'ROSETTE': 2,
#  'FORMATION': 6,
#  'IMMUNOGLOBULIN': 9,
#  'IMMUNOFLUORESCENT': 1,
#  'STAINING': 4,
#  'SPONTANEOUS': 2,
#  'BINDING': 13,
#  'SHEEP': 1,
#  'RED': 4,
#  'RATIO': 13,
#  'NEARLY': 1,
#  'IDENTICAL': 5,
#  'TOTAL': 26,
#  'SIGNIFICANT': 34,
#  'HIGHER': 21,
#  'POSITIVELY': 1,
#  'WHERAS': 1,
#  'INSIGNIFICANT': 1,
#  'MONTHLY': 2,
#  'BACTERIOLOGICAL': 6,
#  'EXAMINATION': 8,
#  'TRACHEAL': 4,
#  'SECRETION': 19,
#  'POLYVALENT': 1,
#  'ANTIGEN': 7,
#  'PREVALENCE': 5,
#  'RATE': 28,
#  'HARBOURING': 1,
#  'CENT': 23,
#  'NEWLY': 1,
#  'COLONIZED': 6,
#  'INTERMITTENTLY': 1,
#  'NON': 6,
#  'MUCOID': 17,
#  'STRAIN': 23,
#  'PREDOMINATING': 5,
#  'CHRONICALLY': 6,
#  'ESPECIALLY': 5,
#  'MALE': 8,
#  'FEMALE': 7,
#  'DURATION': 2,
#  'COLONIZATION': 6,
#  'CONTRAST': 6,
#  'ACCORDANCE': 3,
#  'HYPOTHESIS': 10,
#  'SUBSTANCE': 5,
#  'VIRULENCE': 1,
#  'FACTOR': 23,
#  'MIGHT': 13,
#  'INHIBIT': 1,
#  'OPSONIZING': 1,
#  'EFFECT': 21,
#  'DEPENDENT': 11,
#  'LYSIS': 1,
#  'HEREBY': 1,
#  'FAVOURING': 1,
#  'EXPENSE': 1,
#  'SEVENTY': 1,
#  'TREATED': 9,
#  'CLINIC': 5,
#  'FOLLOWED': 5,
#  'DAILY': 1,
#  'IMPRESSION': 3,
#  'OBTAINED': 15,
#  'LABORATORY': 8,
#  'EXPRESSED': 4,
#  'POINT': 10,
#  'STAPHYLOCOCCUS': 9,
#  'AUREUS': 15,
#  'HAEMOPHILUS': 2,
#  'INFLUENZAE': 5,
#  'DIPLOCOCCUS': 1,
#  'PNEUMONIAE': 4,
#  'MISCELLANEOUS': 3,
#  'MAINLY': 4,
#  'ENTEROBACTERIACEAE': 3,
#  'FLUCTUATION': 1,
#  'BACTERIOLOGY': 2,
#  'DESCRIBED': 13,
#  'ADDITIONAL': 6,
#  'EPIDEMIOLOGICAL': 2,
#  'TERM': 9,
#  'ST': 5,
#  'PATTERN': 11,
#  'MINOR': 8,
#  'MODIFICATION': 3,
#  'REGARD': 9,
#  'REFLECTS': 1,
#  'DIFFICULT': 5,
#  'THERAPEUTIC': 5,
#  'PROBLEM': 17,
#  'NEW': 10,
#  'RECOLONIZATION': 2,
#  'REFLECT': 4,
#  'PREVENTION': 4,
#  'INCIDENCE': 9,
#  'SHOW': 16,
#  'STILL': 3,
#  'CONSIDERABLE': 3,
#  'THERAPY': 35,
#  'WELL': 11,
#  'ALTHOUGH': 19,
#  'SPECIE': 4,
#  'MAY': 53,
#  'COLONIZE': 1,
#  'MAIN': 6,
#  'CONCERN': 2,
#  'REASON': 4,
#  'DISCUSSED': 10,
#  'FAMILY': 11,
#  'CELIAC': 3,
#  'SPRUE': 2,
#  'OCCURRED': 4,
#  'SIBSHIP': 1,
#  'COUSIN': 1,
#  'INDEX': 2,
#  'CASE': 39,
#  'DISCOVERED': 1,
#  'GENETICS': 2,
#  'REVIEWED': 8,
#  'ESTIMATED': 2,
#  'LIKELIHOOD': 1,
#  'ASSOCIATION': 8,
#  'OCCURRING': 4,
#  'BASIS': 6,
#  'CHANCE': 2,
#  'EXHIBITED': 2,
#  'FEATURE': 4,
#  'KARTAGENER': 2,
#  'SYNDROME': 13,
#  'AUTHOR': 5,
#  'KNOWLEDGE': 5,
#  'REPRESENTS': 1,
#  'THIRD': 4,
#  'COMBINATION': 6,
#  'EXCLUDED': 1,
#  'MADE': 12,
#  'ALLERGY': 6,
#  'COURSE': 9,
#  'FIFTEEN': 2,
#  'DEFINED': 2,
#  'HISTORY': 10,
#  'PHYSICAL': 7,
#  'POSITIVE': 12,
#  'SKIN': 16,
#  'NASAL': 6,
#  'EOSINOPHILIA': 1,
#  'REVERSIBLE': 2,
#  'AIRWAY': 9,
#  'OBSTRUCTION': 7,
#  'ALLERGIC': 10,
#  'NONALLERGIC': 2,
#  'IGE': 2,
#  'INTERNATIONAL': 1,
#  'UNIT': 1,
#  'IU': 2,
#  'IGM': 6,
#  'SIMILAR': 21,
#  'SHWACHMAN': 2,
#  'SCORE': 5,
#  'BETTER': 3,
#  'MODULATING': 1,
#  'SEVERITY': 10,
#  'TAUSSIG': 1,
#  'ET': 7,
#  'AL': 7,
#  'REPORTED': 19,
#  'BOY': 1,
#  'RUSSELL': 3,
#  'VARIANT': 2,
#  'SILVER': 2,
#  'CONCOMITANT': 2,
#  'WOULD': 11,
#  'LIKE': 8,
#  'DESCRIBE': 2,
#  'ANOTHER': 7,
#  'FINDING': 27,
#  'POSSIBLE': 20,
#  'ENTIRELY': 3,
#  'ACCIDENTAL': 2,
#  'COINCIDENCE': 1,
#  'STATISTICALLY': 3,
#  'RARE': 9,
#  'EVENT': 1,
#  'ESTABLISHMENT': 3,
#  'RELATIONSHIP': 4,
#  'DEPEND': 3,
#  'INTENSIVE': 1,
#  'SEARCH': 1,
#  'BLACK': 7,
#  'WASHINGTON': 1,
#  'DC': 1,
#  'DISCLOSED': 2,
#  'EIGHT': 7,
#  'BORN': 3,
#  'DISTRICT': 1,
#  'COLUMBIA': 2,
#  'DECADE': 1,
#  'CALCULATED': 3,
#  'LEAST': 6,
#  'PATHOLOGICAL': 3,
#  'CHANGE': 24,
#  'WHITE': 13,
#  'GENETIC': 26,
#  'CONSIDERATION': 4,
#  'AUTOSOMAL': 6,
#  'RECESSIVE': 8,
#  'INHERITANCE': 2,
#  'GENERALLY': 4,
#  'PRENATAL': 8,
#  'DISORDER': 34,
#  'RECEIVED': 6,
#  'INCREASING': 9,
#  'ATTENTION': 5,
#  'PAST': 6,
#  'SEVERAL': 11,
#  'RAPID': 6,
#  'EXPANSION': 1,
#  'RELIABLE': 6,
#  'LED': 1,
#  'ADVANCE': 1,
#  'INTRAUTERINE': 3,
#  'LARGE': 6,
#  'INHERITED': 9,
#  'INITIALLY': 2,
#  'DETERMINE': 7,
#  'CHROMOSOMAL': 3,
#  'ABNORMALITY': 26,
#  'DETERMINATION': 3,
#  'FETAL': 4,
#  'SEX': 5,
#  'PREGNANCY': 1,
#  'SEVERE': 14,
#  'LINKED': 3,
#  'SHORTLY': 1,
#  'THEREAFTER': 2,
#  'BECAME': 1,
#  'CLEAR': 1,
#  'TECHNIQUE': 19,
#  'APPLIED': 2,
#  'INBORN': 4,
#  'METABOLISM': 9,
#  'RECENTLY': 7,
#  'DEVELOPED': 9,
#  'PROVE': 3,
#  'CONGENITAL': 2,
#  'MALFORMATION': 5,
#  'DIAGNOSED': 5,
#  'PRIOR': 3,
#  'GOAL': 2,
#  'REVIEW': 7,
#  'DEFINE': 3,
#  'ACHIEVEMENT': 2,
#  'FUTURE': 3,
#  'PRESENT': 39,
#  'LIMITATION': 2,
#  'SECTION': 2,
#  'DEAL': 1,
#  'GENERAL': 8,
#  'APPROACH': 8,
#  'DISCUSSION': 1,
#  'SPECIFIC': 15,
#  'APPLICATION': 3,
#  'INCLUDE': 9,
#  'AMNIOCENTESIS': 2,
#  'DIRECT': 4,
#  'INDIRECT': 1,
#  'VISUALIZATION': 1,
#  'FETUS': 4,
#  'MATERNAL': 3,
#  'URINE': 10,
#  'SAMPLING': 1,
#  'LIPID': 3,
#  'CARBOHYDRATE': 4,
#  'MUCOPOLYSACCHARIDE': 12,
#  'AMINO': 5,
#  'PROVIDE': 6,
#  'PARENT': 20,
#  'WITHOUT': 11,
#  'FEAR': 1,
#  'DEFORMITY': 1,
#  'INCREASE': 13,
#  'DETECTABLE': 2,
#  'UTERO': 2,
#  'POTENTIAL': 2,
#  'TREATMENT': 22,
#  'UNLIMITED': 1,
#  'WOMAN': 7,
#  'COMBINED': 3,
#  'FORM': 6,
#  'ORAL': 4,
#  'CONTRACEPTIVE': 1,
#  'POLYPOID': 1,
#  'CERVICITIS': 1,
#  'POLYP': 7,
#  'RECURRED': 1,
#  'REINSTITUTION': 1,
#  'MEDICATION': 2,
#  'RESOLUTION': 1,
#  'INSTANCE': 5,
#  'DISCONTINUATION': 1,
#  'DRUG': 3,
#  'AFFECTED': 8,
#  'COINCIDENTAL': 1,
#  'DETERIORATION': 4,
#  'THEREFORE': 8,
#  'SUGGESTED': 14,
#  'CONTRACEPTION': 1,
#  'OBSERVED': 36,
#  'CLOSELY': 5,
#  'REGARDING': 4,
#  'PULMONARY': 36,
#  'GYNECOLOGIC': 1,
#  'ATAXIA': 2,
#  'TELANGIECTASIA': 1,
#  'CHARACTERIZED': 4,
#  'PROGRESSIVE': 2,
#  'NEUROLOGIC': 1,
#  'DEGENERATION': 1,
#  'CUTANEOUS': 1,
#  'CONJUNCTIVAL': 1,
#  'TELANGIECTASIS': 1,
#  'IMMUNOLOGIC': 1,
#  'DEFICIENCY': 25,
#  'ROENTGENOLOGIC': 1,
#  'SINUS': 3,
#  'DECREASED': 9,
#  'LYMPHOID': 2,
#  'USUALLY': 4,
#  'SINOPULMONARY': 1,
#  'RESEMBLE': 3,
#  'ADENOIDAL': 1,
#  'MASS': 5,
#  'DIFFERENTIAL': 2,
#  'LONGER': 3,
#  'TARGET': 1,
#  'ORGAN': 2,
#  'LESION': 7,
#  'BRONCHIAL': 2,
#  'LEADING': 2,
#  'BRONCHIECTASIS': 3,
#  'INTERSTITIAL': 3,
#  'INFILTRATES': 1,
#  'CYST': 2,
#  'CHARACTERISTIC': 11,
#  'ROENTGENOGRAPHY': 1,
#  'COMPLICATION': 5,
#  'HYPERTENSION': 2,
#  'PNEUMONITIS': 1,
#  'HEMORRHAGE': 1,
#  'PNEUMOTHORAX': 1,
#  'LITTLE': 11,
#  'EXISTS': 3,
#  'GASTROINTESTINAL': 4,
#  'INVOLVEMENT': 9,
#  'DESPITE': 4,
#  'SIMILARITY': 1,
#  'PATHOGENESIS': 3,
#  'ALWAYS': 2,
#  'MUST': 8,
#  'DIFFERENTIATED': 1,
#  'FAR': 4,
#  'RABBIT': 4,
#  'ALVEOLAR': 5,
#  'MACROPHAGE': 8,
#  'CONCERNED': 1,
#  'HOMOZYGOUS': 5,
#  'EXPERIMENT': 4,
#  'EVEN': 7,
#  'GREATER': 15,
#  'FOURFOLD': 1,
#  'BIGGAR': 2,
#  'ASSOCIATE': 4,
#  'STATE': 16,
#  'REQUIRED': 6,
#  'PHAGOCYTOSIS': 3,
#  'DILUTION': 2,
#  'EITHER': 11,
#  'HANK': 1,
#  'BALANCED': 1,
#  'SALT': 6,
#  'SOLUTION': 3,
#  'HUMAN': 20,
#  'THUS': 6,
#  'DECREASING': 2,
#  'PHAGOCYTIZE': 1,
#  'KILL': 1,
#  'OPPOSITE': 1,
#  'SUSPENSION': 2,
#  'REDUCED': 9,
#  'PHAGOCYTIC': 2,
#  'UNEXPECTED': 2,
#  'HIGH': 19,
#  'LIKELY': 6,
#  'TOXIC': 3,
#  'INHIBITION': 6,
#  'ABSENT': 4,
#  'PREVIOUSLY': 8,
#  'HEATED': 1,
#  'FROZEN': 1,
#  'OBSERVATION': 10,
#  'ABILITY': 7,
#  'FEEL': 2,
#  'DATA': 16,
#  'DEMONSTRATE': 4,
#  'LABILE': 2,
#  'INHIBITOR': 5,
#  'RATHER': 7,
#  'SINCE': 19,
#  'KNOWN': 9,
#  'INCLUDING': 5,
#  'RESPOND': 2,
#  'SHOWN': 10,
#  'ESSENTIAL': 12,
#  'AGREE': 2,
#  'DUE': 16,
#  'NOTE': 2,
#  'STORED': 2,
#  'DEGREE': 8,
#  'PERHAPS': 4,
#  'ACCOUNT': 4,
#  'DIFFERENCE': 56,
#  'ASSAYED': 3,
#  'ARGININE': 21,
#  'RECEIVING': 9,
#  'ESTERASE': 15,
#  'UNTREATED': 3,
#  'LOWER': 22,
#  'CARRIER': 13,
#  'ESTERASES': 1,
#  'PLASMA': 27,
#  'ELECTROFUSING': 1,
#  'POLYACRYLAMIDE': 5,
#  'GEL': 8,
#  'BAND': 13,
#  'WORK': 4,
#  'REPRODUCED': 1,
#  'COBURN': 1,
#  'CONFIRMED': 7,
#  'WORKING': 2,
#  'UNDERSTAND': 2,
#  'DEFECT': 27,
#  'VARIATION': 9,
#  'PH': 12,
#  'CHLORIDE': 13,
#  'EMPLOYED': 3,
#  'TESTED': 4,
#  'ALTER': 1,
#  'MAJOR': 6,
#  'RESULTED': 2,
#  'DR': 6,
#  'RAO': 3,
#  'NEGLECT': 1,
#  'MENTION': 1,
#  'UNABLE': 3,
#  'CONFIRM': 10,
#  'DETECT': 4,
#  'FUNCTION': 28,
#  'ASTHMA': 14,
#  'MEASUREMENT': 7,
#  'CLOSING': 6,
#  'VOLUME': 29,
#  'FLOW': 17,
#  'SPIROMETRY': 1,
#  'BODY': 10,
#  'PLETHYSMOGRAPHY': 1,
#  'ARTERIALIZED': 2,
#  'OXYGEN': 4,
#  'TENSION': 2,
#  'COMPARISON': 6,
#  'LE': 11,
#  'SENSITIVE': 11,
#  'RESIDUAL': 1,
#  'EXPIRATORY': 4,
#  'CURVE': 8,
#  'GAS': 5,
#  'BRONCHOSPASM': 2,
#  'INHALING': 1,
#  'EXTRACT': 3,
#  'SPRINKLED': 1,
#  'FOOD': 4,
#  'RESPONDED': 1,
#  'BRONCHODILATOR': 1,
#  'USE': 15,
#  'FACE': 3,
#  'MASK': 1,
#  'PREPARATION': 6,
#  'MEAL': 1,
#  'PREVENTED': 1,
#  'RECURRENCE': 1,
#  'DATE': 2,
#  'PRECIPITATE': 2,
#  'INHALATION': 1,
#  'SEEN': 5,
#  'RESISTANCE': 11,
#  'PLETHYSMOGRAPHIC': 1,
#  'BRISCOE': 1,
#  'DUBOIS': 1,
#  'CALCULATE': 1,
#  'SRAW': 6,
#  'RANGING': 1,
#  'LOWEST': 3,
#  'RAPIDLY': 3,
#  'SEC': 5,
#  'CM': 3,
#  'DECREASE': 11,
#  'PARALLELED': 1,
#  'SEXUAL': 2,
#  'MATURATION': 2,
#  'YOUNG': 8,
#  'VARIOUS': 10,
#  'CILIATED': 1,
#  'EPITHELIUM': 3,
#  'RHINITIS': 4,
#  'MAINTAINED': 3,
#  'CULTURE': 33,
#  'EXPLANTED': 1,
#  'RETAINED': 2,
#  'MORPHOLOGIC': 1,
#  'INCORPORATED': 2,
#  'GLYCOPROTEIN': 7,
#  'SECRETED': 2,
#  'MEDIUM': 15,
#  'THROUGHOUT': 1,
#  'LABELED': 2,
#  'MUCOUS': 4,
#  'SOLUBILIZED': 1,
#  'REDUCTION': 4,
#  'ALKYLATION': 1,
#  'PURIFIED': 5,
#  'FILTRATION': 2,
#  'CHROMATOGRAPHY': 4,
#  'SEPARATED': 2,
#  'DIETHYLAMINOETHYL': 1,
#  'DEAE': 2,
#  'CELLULOSE': 2,
#  'COLUMN': 1,
#  'FRACTION': 15,
#  'COMPOSITION': 5,
#  'DIFFERED': 1,
#  'ACETYL': 2,
#  'NEURAMINIC': 1,
#  'FUCOSE': 1,
#  'RELATIVE': 9,
#  'INCORPORATION': 9,
#  'GLUCOSAMINE': 1,
#  'INDISTINGUISHABLE': 3,
#  'RESPECT': 2,
#  'HOWEVER': 22,
#  'EXCEEDED': 1,
#  'CORRESPONDING': 3,
#  'PRESSURE': 4,
#  'BEHAVIOR': 3,
#  'ISOVOLUME': 1,
#  'DETECTION': 8,
#  'SEPARATE': 1,
#  'GROSSLY': 1,
#  'ABNORMAL': 9,
#  'EXCESSIVE': 5,
#  'STIFFNESS': 1,
#  'NEAR': 2,
#  'LOSS': 11,
#  'RECOIL': 4,
#  'OFTEN': 12,
#  'ENOUGH': 5,
#  'CAUSE': 11,
#  'DISTURBANCE': 2,
#  'EXCHANGE': 6,
#  'QUANTITATIVELY': 3,
#  'EXPLAINED': 3,
#  'ELASTIC': 3,
#  'MODIFIED': 3,
#  'MILD': 5,
#  'OTHERWISE': 4,
#  'SE': 1,
#  'UPSTREAM': 1,
#  'EFFORT': 1,
#  'SHOWING': 3,
#  'TIME': 17,
#  'CONSTANT': 8,
#  'EMPTYING': 1,
#  'VARIED': 1,
#  'WIDELY': 3,
#  'INVOLVES': 2,
#  'WORSENING': 1,
#  'TRAPPING': 1,
#  'BLAND': 1,
#  'AEROSOL': 12,
#  'PARTICULARLY': 8,
#  'MIST': 9,
#  'TENT': 8,
#  'CONVINCING': 1,
#  'EFFICACY': 1,
#  'SURPRISING': 1,
#  'DEPOSIT': 3,
#  'WATER': 19,
#  'DETRIMENTAL': 2,
#  'BACTERIAL': 5,
#  'ENZYME': 21,
#  'ACTIVATED': 2,
#  'TREATING': 1,
#  'CHLOROFORM': 2,
#  'ELLAGIC': 2,
#  'MANNER': 2,
#  'INHIBITED': 6,
#  'SOYBEAN': 3,
#  'SPITE': 2,
#  'WIDESPREAD': 2,
#  'BREATHING': 4,
#  'EXERCISE': 1,
#  'HELPFUL': 5,
#  'PEDIATRIC': 2,
#  'OBJECTIVE': 2,
#  'DEMONSTRATION': 5,
#  'MANEUVER': 2,
#  'PART': 5,
#  'LACKING': 2,
#  'SPUTUM': 28,
#  'SHORT': 4,
#  'COUGH': 3,
#  'POSTURAL': 1,
#  'DRAINAGE': 1,
#  'LONG': 5,
#  'REMAINS': 6,
#  'UNKNOWN': 7,
#  'SIMPLICITY': 3,
#  'EASE': 1,
#  'FINGERNAIL': 1,
#  'TOENAIL': 1,
#  'MEASURE': 4,
#  'ELECTROLYTE': 6,
#  'PROCEDURE': 10,
#  'CATEGORY': 2,
#  'DISEASED': 1,
#  'INDICATED': 6,
#  'EAR': 2,
#  'NOSE': 2,
#  'THROAT': 4,
#  'SURVEY': 2,
#  'CARRIED': 5,
#  'AGED': 5,
#  'TRANSIENTLY': 1,
#  'DEAF': 1,
#  'EUSTACHIAN': 1,
#  'TUBE': 3,
#  'DYSFUNCTION': 2,
#  'SECRETORY': 4,
#  'OTITIS': 3,
#  'GAVE': 3,
#  'POLYPECTOMY': 1,
#  'THOUGH': 3,
#  'MIDDLE': 2,
#  'NEITHER': 3,
#  'DEAFNESS': 1,
#  'TOCOPHEROL': 6,
#  'PRESUMABLY': 3,
#  'STEATORRHOEA': 2,
#  'MUSCULAR': 4,
#  'WEAKNESS': 1,
#  'WASTING': 3,
#  'BIOCHEMICAL': 7,
#  'CREATINURIA': 1,
#  'CREATINE': 3,
#  'POOR': 3,
#  'DIET': 8,
#  'REVERSAL': 1,
#  'INGESTION': 2,
#  'ESTER': 2,
#  'MUSCLE': 5,
#  'FOCAL': 4,
#  'SKELETAL': 1,
#  'RESEMBLING': 2,
#  'NUTRITIONAL': 5,
#  'DYSTROPHY': 1,
#  'CEROID': 1,
#  'PIGMENT': 1,
#  'SMOOTH': 1,
#  'STRENGTH': 3,
#  'BULB': 1,
#  'ERGOGRAPH': 1,
#  'ATTENDING': 2,
#  'BABY': 5,
#  'HOSPITAL': 8,
#  'PRESBYTERIAN': 1,
#  'MEDICAL': 4,
#  'CENTER': 2,
#  'YORK': 2,
#  'DOUBLE': 1,
#  'BLIND': 1,
#  'HALF': 2,
#  'ORALLY': 1,
#  'REMAINDER': 2,
#  'PLACEBO': 2,
#  'RETURNED': 1,
#  'VISCOSITY': 13,
#  'LIQUEFACTION': 1,
#  'NIGHT': 2,
#  'SLEPT': 1,
#  'MORNING': 2,
#  'FOLLOWING': 10,
#  'RANDOMLY': 2,
#  'ALLOCATED': 1,
#  'SUPPLIED': 1,
#  'JET': 1,
#  'ULTRASONIC': 2,
#  'NEBULIZER': 2,
#  'ANALYSED': 1,
#  'DNA': 3,
#  'PURULENCE': 1,
#  'RELATION': 11,
#  'FURTHERMORE': 4,
#  'CONSISTENT': 5,
#  'EXPECTORATED': 1,
#  'ABSENCE': 5,
#  'STAY': 1,
#  'NEBULIZATION': 1,
#  'SUGGEST': 18,
#  'CONSISTENTLY': 4,
#  'SISTER': 2,
#  'FATAL': 4,
#  'OBSTRUCTIVE': 2,
#  'ORIGIN': 9,
#  'CLINICALLY': 5,
#  'HISTOLOGICALLY': 1,
#  'GLAND': 26,
#  'SHOWED': 13,
#  'EXPECTED': 3,
#  'BOWEL': 2,
#  'SYMPTOM': 19,
#  'PANCREAS': 10,
#  'NECROPSY': 2,
#  'ACETATE': 1,
#  'STRIP': 2,
#  'ELECTROPHORESIS': 6,
#  'SUFFICIENTLY': 1,
#  'DIFFERENTIATE': 5,
#  'MECONIUM': 19,
#  'MARKED': 6,
#  'QUANTITATIVE': 6,
#  'IMMUNOELECTROPHORETIC': 1,
#  'CONTAIN': 1,
#  'ALPHA': 11,
#  'ANTITRYPSIN': 9,
#  'ANTICHYMOTRYPSIN': 1,
#  'SAMPLE': 18,
#  'CONTAINED': 3,
#  'ALBUMIN': 11,
#  'AMOUNT': 5,
#  'VARIETY': 8,
#  'CONFIRMING': 1,
#  'SPECIMEN': 4,
#  'SCREENED': 3,
#  'COEXISTENCE': 1,
#  'PREDISPOSE': 1,
#  'LATER': 3,
#  'LARGELY': 2,
#  ...}

# %% [markdown]
# #### TF-IDF weights

# %%
from typing import Counter

def tf_idf(preprocessed_data, tdm, type_of_tf='relative'):
    tf_idf = {}
    N = len(preprocessed_data)
    for rec_num, tokens in tqdm(preprocessed_data.items()):
        counter = Counter(tokens)
        words_count = len(tokens)
    
        for token in np.unique(tokens):
            # calculate tf
            if type_of_tf == 'relative':
                tf = counter[token]
                tf = tf / words_count
            else:
                tf = counter[token]
                tf = 1 + np.log(tf)
            
            # calculate idf
            if token in tdm:
                df = tdm[token]
            else:
                df = 0
            idf = 1 + np.log((N)/(df))
            
            # Calculate tf-idf        
            tf_idf[rec_num, token] = tf*idf
    return tf_idf

# %%
tfidf = tf_idf(pp_data, teste_tdm)
tfidf
# Out:
# 100%|██████████| 167/167 [00:00<00:00, 7575.70it/s]
# {('00001 ', 'ACCOMPANIED'): 0.0508784887236222,
#  ('00001 ', 'ACTIVE'): 0.0508784887236222,
#  ('00001 ', 'ACUTE'): 0.0930372977029828,
#  ('00001 ', 'ADDITION'): 0.04342529323373032,
#  ('00001 ', 'AERUGINOSA'): 0.07917523117055189,
#  ('00001 ', 'ANALYSIS'): 0.038204779085539986,
#  ('00001 ', 'CHANGED'): 0.11666336842702818,
#  ('00001 ', 'CLINICAL'): 0.027252417999576832,
#  ('00001 ', 'COMPARED'): 0.042158808979360606,
#  ('00001 ', 'CONCENTRATION'): 0.07385007793315033,
#  ('00001 ', 'CONTROL'): 0.020413829110114502,
#  ('00001 ', 'CORRELATED'): 0.038204779085539986,
#  ('00001 ', 'CYSTIC'): 0.006201400723207839,
#  ('00001 ', 'DAMAGE'): 0.10794368868276658,
#  ('00001 ', 'DEMONSTRATED'): 0.042158808979360606,
#  ('00001 ', 'ELEVATED'): 0.03597209774383843,
#  ('00001 ', 'EVALUATED'): 0.042158808979360606,
#  ('00001 ', 'FIBROSIS'): 0.00615931578427089,
#  ('00001 ', 'HAPTOGLOBIN'): 0.06578487970340598,
#  ('00001 ', 'IGA'): 0.04342529323373032,
#  ('00001 ', 'IGG'): 0.04102590020884634,
#  ('00001 ', 'IMMUNOELECTROPHORETICAL'): 0.06578487970340598,
#  ('00001 ', 'INDICATE'): 0.04847909569873823,
#  ('00001 ', 'INFECTION'): 0.07835852768718769,
#  ('00001 ', 'LATTER'): 0.04847909569873823,
#  ('00001 ', 'LUNG'): 0.02695780537389818,
#  ('00001 ', 'MANY'): 0.06941122697893744,
#  ('00001 ', 'MATCHED'): 0.04847909569873823,
#  ('00001 ', 'MAXIMUM'): 0.04342529323373032,
#  ('00001 ', 'MEAN'): 0.027555330655132708,
#  ('00001 ', 'NOTABLY'): 0.11666336842702818,
#  ('00001 ', 'NUMBER'): 0.08087341612169453,
#  ('00001 ', 'ONE'): 0.0263917437235173,
#  ('00001 ', 'PATIENT'): 0.021714654022739137,
#  ('00001 ', 'PERSON'): 0.0508784887236222,
#  ('00001 ', 'PHASE'): 0.11666336842702818,
#  ('00001 ', 'PRECIPITIN'): 0.21583258646303055,
#  ('00001 ', 'PROTECTIVE'): 0.05833168421351409,
#  ('00001 ', 'PROTEIN'): 0.10900967199830733,
#  ('00001 ', 'PSEUDOMONAS'): 0.08555670676183963,
#  ('00001 ', 'RADIOGRAPHICAL'): 0.06578487970340598,
#  ('00001 ', 'RESPIRATORY'): 0.08456407261129918,
#  ('00001 ', 'RESULT'): 0.027555330655132708,
#  ('00001 ', 'SCORING'): 0.05833168421351409,
#  ('00001 ', 'SERUM'): 0.07974542065522147,
#  ('00001 ', 'SIGNIFICANCE'): 0.0465186488514914,
#  ('00001 ', 'SIGNIFICANTLY'): 0.03161225787170763,
#  ('00001 ', 'STATUS'): 0.0465186488514914,
#  ('00001 ', 'STUDIED'): 0.0325478640758972,
#  ('00001 ', 'SUGGESTING'): 0.09695819139747645,
#  ('00001 ', 'SYSTEM'): 0.04102590020884634,
#  ('00001 ', 'TISSUE'): 0.11719636008479853,
#  ('00001 ', 'TRACT'): 0.10071811415686335,
#  ('00001 ', 'USING'): 0.03357270471895445,
#  ('00001 ', 'VALUE'): 0.029577397660540655,
#  ('00002 ', 'ACTIVITY'): 0.024755927509912568,
#  ('00002 ', 'ADULT'): 0.07506097801210676,
#  ('00002 ', 'AETIOLOGY'): 0.07113946293507856,
#  ('00002 ', 'AGE'): 0.027958392392005205,
#  ('00002 ', 'AMYLASE'): 0.22795169971398463,
#  ('00002 ', 'ASSOCIATED'): 0.035197108826260926,
#  ('00002 ', 'ATROPHY'): 0.063079611998335,
#  ('00002 ', 'BEGAN'): 0.063079611998335,
#  ('00002 ', 'BIRTH'): 0.09391982024969579,
#  ('00002 ', 'CAREFULLY'): 0.063079611998335,
#  ('00002 ', 'CHILD'): 0.07130355040679921,
#  ('00002 ', 'COELIAC'): 0.08262894081291206,
#  ('00002 ', 'COLLECTED'): 0.04559033994279693,
#  ('00002 ', 'CONCENTRATION'): 0.0532407538587828,
#  ('00002 ', 'CONDITION'): 0.060270541576758,
#  ('00002 ', 'CYSTIC'): 0.013412331796705325,
#  ('00002 ', 'DAHLQVIST'): 0.07113946293507856,
#  ('00002 ', 'DETERMINED'): 0.04559033994279693,
#  ('00002 ', 'DISEASE'): 0.03686963533170928,
#  ('00002 ', 'FED'): 0.05836490143893774,
#  ('00002 ', 'FIBROSIS'): 0.013321310882260295,
#  ('00002 ', 'GASTROSTOMY'): 0.07113946293507856,
#  ('00002 ', 'INFANT'): 0.0337106742738204,
#  ('00002 ', 'JEJUNAL'): 0.05501976106159145,
#  ('00002 ', 'LEVEL'): 0.10354295415377342,
#  ('00002 ', 'LIFE'): 0.048512600736760954,
#  ('00002 ', 'LOW'): 0.11895152132492598,
#  ('00002 ', 'MALNOURISHED'): 0.063079611998335,
#  ('00002 ', 'MALNUTRITION'): 0.046959910124847896,
#  ('00002 ', 'MEASURED'): 0.042245199565450635,
#  ('00002 ', 'METHOD'): 0.030135270788379,
#  ('00002 ', 'MILK'): 0.052425068604449475,
#  ('00002 ', 'MIXED'): 0.05501976106159145,
#  ('00002 ', 'MONTH'): 0.0404527498000174,
#  ('00002 ', 'MOSTLY'): 0.063079611998335,
#  ('00002 ', 'NORMAL'): 0.06306138965669764,
#  ('00002 ', 'NORMALLY'): 0.05836490143893774,
#  ('00002 ', 'ONE'): 0.02853990891031522,
#  ('00002 ', 'PANCREATIC'): 0.03048239826686366,
#  ('00002 ', 'PREMATURE'): 0.05836490143893774,
#  ('00002 ', 'REACH'): 0.07113946293507856,
#  ('00002 ', 'RECOVERY'): 0.05501976106159145,
#  ('00002 ', 'ROSE'): 0.15727520581334842,
#  ('00002 ', 'SALIVA'): 0.0404527498000174,
#  ('00002 ', 'SALIVARY'): 0.11895152132492598,
#  ('00002 ', 'SCATTER'): 0.07113946293507856,
#  ('00002 ', 'SIX'): 0.04559033994279693,
#  ('00002 ', 'SOMETIMES'): 0.063079611998335,
#  ('00002 ', 'STANDARDISED'): 0.07113946293507856,
#  ('00002 ', 'SUBJECT'): 0.0624187583239909,
#  ('00002 ', 'TEN'): 0.05836490143893774,
#  ('00002 ', 'THIRTEEN'): 0.063079611998335,
#  ('00002 ', 'UNCERTAIN'): 0.063079611998335,
#  ('00002 ', 'VALUE'): 0.03198486026081722,
#  ('00002 ', 'VILLOUS'): 0.05836490143893774,
#  ('00002 ', 'WEEK'): 0.05501976106159145,
#  ('00002 ', 'WIDE'): 0.052425068604449475,
#  ('00002 ', 'YEAR'): 0.030135270788379,
#  ('00003 ', 'ACCEPTED'): 0.06875865101025541,
#  ('00003 ', 'ACTIVATION'): 0.06875865101025541,
#  ('00003 ', 'ADULT'): 0.0442140007468574,
#  ('00003 ', 'AGE'): 0.06587456837568349,
#  ('00003 ', 'ANALYSIS'): 0.048671841848701616,
#  ('00003 ', 'ANALYZED'): 0.06875865101025541,
#  ('00003 ', 'ARTICLE'): 0.06481780070269677,
#  ('00003 ', 'BIG'): 0.08380813441666787,
#  ('00003 ', 'CF'): 0.10469644322943812,
#  ('00003 ', 'CHILD'): 0.04200072147249816,
#  ('00003 ', 'CLIPPING'): 0.17145549301485377,
#  ('00003 ', 'CONTROL'): 0.052013318006593104,
#  ('00003 ', 'COULD'): 0.04146508711038958,
#  ('00003 ', 'CYSTIC'): 0.00790041461997711,
#  ('00003 ', 'DAY'): 0.05532263384571122,
#  ('00003 ', 'DETECTED'): 0.048671841848701616,
#  ('00003 ', 'DETECTING'): 0.06481780070269677,
#  ('00003 ', 'DIAGNOSING'): 0.07431296755968232,
#  ('00003 ', 'DIAGNOSTIC'): 0.05532263384571122,
#  ('00003 ', 'DISCRIMINATION'): 0.08380813441666787,
#  ('00003 ', 'EARLY'): 0.046711556319377324,
#  ('00003 ', 'FIBROSIS'): 0.007846799560783461,
#  ('00003 ', 'FIRST'): 0.048671841848701616,
#  ('00003 ', 'FIVE'): 0.05370916760384296,
#  ('00003 ', 'FOUND'): 0.028913159276497045,
#  ('00003 ', 'HEALTHY'): 0.05096025396737513,
#  ('00003 ', 'HETEROZYGOTE'): 0.107732311682888,
#  ('00003 ', 'INAA'): 0.12352207945157959,
#  ('00003 ', 'INDIVIDUAL'): 0.048671841848701616,
#  ('00003 ', 'INSTRUMENTAL'): 0.07431296755968232,
#  ('00003 ', 'INVALUABLE'): 0.08380813441666787,
#  ('00003 ', 'LIFE'): 0.057151831004951255,
#  ('00003 ', 'MAKE'): 0.07431296755968232,
#  ('00003 ', 'METHOD'): 0.0710036517205642,
#  ('00003 ', 'NAIL'): 0.1429699924438971,
#  ('00003 ', 'NEONATAL'): 0.06875865101025541,
#  ('00003 ', 'NEUTRON'): 0.07431296755968232,
#  ('00003 ', 'NEWBORN'): 0.14601552554610486,
#  ('00003 ', 'NORMAL'): 0.0185728750358767,
#  ('00003 ', 'ONE'): 0.03362235844228916,
#  ('00003 ', 'OVERLAP'): 0.06481780070269677,
#  ('00003 ', 'PATIENT'): 0.013831937151470818,
#  ('00003 ', 'PERIOD'): 0.04499699271726766,
#  ('00003 ', 'POSSIBILITY'): 0.05926348415326986,
#  ('00003 ', 'PRECISE'): 0.06481780070269677,
#  ('00003 ', 'REPORT'): 0.042770706011818684,
#  ('00003 ', 'SCREENING'): 0.08054630087859752,
#  ('00003 ', 'SODIUM'): 0.042770706011818684,
#  ('00003 ', 'TEST'): 0.030777983582313203,
#  ('00003 ', 'TWO'): 0.04027315043929876,
#  ('00003 ', 'USING'): 0.042770706011818684,
#  ('00003 ', 'VALUE'): 0.037680794279866855,
#  ('00003 ', 'YEAR'): 0.0355018258602821,
#  ('00004 ', 'ACCURACY'): 0.05283559498682785,
#  ('00004 ', 'ACTIVATION'): 0.05283559498682785,
#  ('00004 ', 'AID'): 0.05283559498682785,
#  ('00004 ', 'ALSO'): 0.027918504311758192,
#  ('00004 ', 'ANALYSIS'): 0.03740046794689703,
#  ('00004 ', 'BASIC'): 0.04553930887567052,
#  ('00004 ', 'CF'): 0.06704245926095599,
#  ('00004 ', 'CLIPPING'): 0.17566668056258702,
#  ('00004 ', 'COLLECTION'): 0.09491696631542432,
#  ('00004 ', 'COME'): 0.06439993486754479,
#  ('00004 ', 'CONCENTRATION'): 0.024098446483449058,
#  ('00004 ', 'CONCLUDED'): 0.043916670140646756,
#  ('00004 ', 'CONSIDERED'): 0.04553930887567052,
#  ('00004 ', 'CONTAMINATION'): 0.05710364875638747,
#  ('00004 ', 'CONTENT'): 0.033974968994953586,
#  ('00004 ', 'CONTROL'): 0.03996812857348733,
#  ('00004 ', 'CYSTIC'): 0.006070844918508726,
#  ('00004 ', 'DETERMINING'): 0.05710364875638747,
#  ('00004 ', 'DEVELOPMENT'): 0.039158931995983,
#  ('00004 ', 'DIAGNOSIS'): 0.02728035039790099,
#  ('00004 ', 'DIAGNOSTIC'): 0.042511076534072836,
#  ('00004 ', 'DIFFERENT'): 0.042511076534072836,
#  ('00004 ', 'DISTRIBUTION'): 0.043916670140646756,
#  ('00004 ', 'EASILY'): 0.05710364875638747,
#  ('00004 ', 'ERROR'): 0.049807362645230155,
#  ('00004 ', 'EVIDENCE'): 0.032865910935397515,
#  ('00004 ', 'FIBROSIS'): 0.006029645978286239,
#  ('00004 ', 'GOOD'): 0.05283559498682785,
#  ('00004 ', 'INAA'): 0.1423754494731365,
#  ('00004 ', 'INCREASED'): 0.02697521843081412,
#  ('00004 ', 'INHOMOGENEOUS'): 0.06439993486754479,
#  ('00004 ', 'INSTRUMENTAL'): 0.05710364875638747,
#  ('00004 ', 'INTRINSIC'): 0.04553930887567052,
#  ('00004 ', 'LEVEL'): 0.02343340541374872,
#  ('00004 ', 'METHOD'): 0.05456070079580198,
#  ('00004 ', 'NAIL'): 0.4028242243243838,
#  ('00004 ', 'NEUTRON'): 0.05710364875638747,
#  ('00004 ', 'OLD'): 0.04553930887567052,
#  ('00004 ', 'OUTLINED'): 0.05710364875638747,
#  ('00004 ', 'PATIENT'): 0.015943127558800577,
#  ('00004 ', 'PERSON'): 0.049807362645230155,
#  ('00004 ', 'PRECISE'): 0.09961472529046031,
#  ('00004 ', 'PRECISION'): 0.05710364875638747,
#  ('00004 ', 'RESULT'): 0.02697521843081412,
#  ('00004 ', 'RISK'): 0.04745848315771216,
#  ('00004 ', 'ROUTINE'): 0.09107861775134105,
#  ('00004 ', 'SAMPLED'): 0.06439993486754479,
#  ('00004 ', 'SATISFACTORY'): 0.05710364875638747,
#  ('00004 ', 'SEEMS'): 0.08502215306814567,
#  ('00004 ', 'SMALL'): 0.03740046794689703,
#  ('00004 ', 'SODIUM'): 0.2629272874831801,
#  ('00004 ', 'STUDY'): 0.0232207453367222,
#  ('00004 ', 'SUITABLE'): 0.05283559498682785,
#  ('00004 ', 'SWEAT'): 0.02859785716583789,
#  ('00004 ', 'TEST'): 0.023650450542198567,
#  ('00004 ', 'THREE'): 0.03589414327699521,
#  ('00004 ', 'USED'): 0.06915327301811662,
#  ('00004 ', 'VARIES'): 0.05283559498682785,
#  ('00004 ', 'WASHED'): 0.06439993486754479,
#  ('00004 ', 'YEAR'): 0.02728035039790099,
#  ('00005 ', 'ACID'): 0.0359479369955126,
#  ('00005 ', 'ACTIVITY'): 0.12342085599144817,
#  ('00005 ', 'ADULT'): 0.0935542624498722,
#  ('00005 ', 'CAPACITY'): 0.05852974305415825,
#  ('00005 ', 'CASEIN'): 0.1572419313581684,
#  ('00005 ', 'CHILD'): 0.08887109181137294,
#  ('00005 ', 'COELIAC'): 0.051493397897901715,
#  ('00005 ', 'CONDITION'): 0.03755990272174774,
#  ('00005 ', 'CONTENT'): 0.0467771312249361,
#  ('00005 ', 'CONTROL'): 0.055028582818569524,
#  ('00005 ', 'CORRELATION'): 0.05391447158867224,
#  ('00005 ', 'COW'): 0.0786209656790842,
#  ('00005 ', 'DISEASE'): 0.04595345852937679,
#  ('00005 ', 'DUODENAL'): 0.18809714535603042,
#  ('00005 ', 'ENTEROGENIC'): 0.1572419313581684,
#  ('00005 ', 'EXTREMELY'): 0.06857535436662122,
#  ('00005 ', 'FASTING'): 0.08866657699154717,
#  ('00005 ', 'GOOD'): 0.07274465976447313,
#  ('00005 ', 'GREAT'): 0.06534138985482109,
#  ('00005 ', 'GROUP'): 0.030328146691037765,
#  ('00005 ', 'HEALTHY'): 0.10782894317734448,
#  ('00005 ', 'HOUR'): 0.05391447158867224,
#  ('00005 ', 'HYDROLYSE'): 0.08866657699154717,
#  ('00005 ', 'INFANT'): 0.08403240543618999,
#  ('00005 ', 'INSUFFICIENCY'): 0.06857535436662122,
#  ('00005 ', 'INTOLERANCE'): 0.06857535436662122,
#  ('00005 ', 'INVESTIGATED'): 0.05682274253739907,
#  ('00005 ', 'JUICE'): 0.21823397929341937,
#  ('00005 ', 'LOW'): 0.04941947262774703,
#  ('00005 ', 'MALABSORPTION'): 0.12092996125685339,
#  ('00005 ', 'MEASURABLE'): 0.0786209656790842,
#  ('00005 ', 'MG'): 0.05265343713954717,
#  ('00005 ', 'MILK'): 0.06534138985482109,
#  ('00005 ', 'ML'): 0.10530687427909434,
#  ('00005 ', 'PANCREATIC'): 0.07598510872319637,
#  ('00005 ', 'PATIENT'): 0.007316894290270795,
#  ('00005 ', 'PEPTIDE'): 0.08866657699154717,
#  ('00005 ', 'PER'): 0.03755990272174774,
#  ('00005 ', 'PROTEIN'): 0.036731519912473115,
#  ('00005 ', 'PROTEOLYTIC'): 0.2057260630998637,
#  ('00005 ', 'RANGE'): 0.05682274253739907,
#  ('00005 ', 'SOLUBLE'): 0.08866657699154717,
#  ('00005 ', 'TRICHLOROACETIC'): 0.08866657699154717,
#  ('00005 ', 'TRYPSIN'): 0.11059155708471621,
#  ('00005 ', 'WHEREAS'): 0.04760551403421071,
#  ('00005 ', 'WITHIN'): 0.05682274253739907,
#  ('00006 ', 'AERUGINOSA'): 0.12695338791140218,
#  ('00006 ', 'BACTERIA'): 0.03729512364817845,
#  ('00006 ', 'BINDING'): 0.030629693577200155,
#  ('00006 ', 'BLOOD'): 0.04998479288876818,
#  ('00006 ', 'BONE'): 0.04327053037714349,
#  ('00006 ', 'CELL'): 0.14286163138453706,
#  ('00006 ', 'CHRONIC'): 0.06282192305955565,
#  ('00006 ', 'COMPLEMENT'): 0.03379973478517703,
#  ('00006 ', 'COMPONENT'): 0.032069814996710216,
#  ('00006 ', 'CORRELATED'): 0.030629693577200155,
#  ('00006 ', 'CORRELATION'): 0.032069814996710216,
#  ('00006 ', 'CROSSED'): 0.04079051251117987,
#  ('00006 ', 'CYSTIC'): 0.004971812648778698,
#  ('00006 ', 'DEMONSTRABLE'): 0.04327053037714349,
#  ('00006 ', 'DEMONSTRATED'): 0.03379973478517703,
#  ('00006 ', 'DERIVED'): 0.07193247695450762,
#  ('00006 ', 'EAC'): 0.05274132596910996,
#  ('00006 ', 'EXAMINED'): 0.031319716919213404,
#  ('00006 ', 'FIBROSIS'): 0.004938072137389592,
#  ('00006 ', 'FORMATION'): 0.0745902472963569,
#  ('00006 ', 'GROUP'): 0.07216007316143468,
#  ('00006 ', 'HARBOURED'): 0.046765919240144914,
#  ('00006 ', 'HIGHER'): 0.026495442885287344,
#  ('00006 ', 'IDENTICAL'): 0.038866861206747025,
#  ('00006 ', 'IMMUNOELECTROPHORESIS'): 0.04079051251117987,
#  ('00006 ', 'IMMUNOFLUORESCENT'): 0.05274132596910996,
#  ('00006 ', 'IMMUNOGLOBULIN'): 0.03379973478517703,
#  ('00006 ', 'INFECTION'): 0.06282192305955565,
#  ('00006 ', 'INFLUENCE'): 0.04079051251117987,
#  ('00006 ', 'INSIGNIFICANT'): 0.05274132596910996,
#  ('00006 ', 'LYMPHOCYTE'): 0.10444531734664446,
#  ('00006 ', 'MARKER'): 0.08654106075428698,
#  ('00006 ', 'MARROW'): 0.04079051251117987,
#  ('00006 ', 'MEAN'): 0.022091773714890874,
#  ('00006 ', 'MULTIPLE'): 0.05274132596910996,
#  ('00006 ', 'NEARLY'): 0.05274132596910996,
#  ('00006 ', 'NEVER'): 0.046765919240144914,
#  ('00006 ', 'NUMBER'): 0.0864508930956045,
#  ('00006 ', 'OCCURRENCE'): 0.03379973478517703,
#  ('00006 ', 'ONE'): 0.021158897985233696,
#  ('00006 ', 'P'): 0.16694596833727193,
#  ('00006 ', 'PATIENT'): 0.021761452846064004,
#  ('00006 ', 'PER'): 0.02234166627414305,
#  ('00006 ', 'PERIPHERAL'): 0.03596623847725381,
#  ('00006 ', 'POSITIVELY'): 0.05274132596910996,
#  ('00006 ', 'PRECIPITIN'): 0.08651909715974933,
#  ('00006 ', 'PRESENCE'): 0.057679398106499545,
#  ('00006 ', 'PRESENTED'): 0.03481510578221482,
#  ('00006 ', 'PRODUCED'): 0.03379973478517703,
#  ('00006 ', 'RATIO'): 0.030629693577200155,
#  ('00006 ', 'RECEPTOR'): 0.05274132596910996,
#  ('00006 ', 'RED'): 0.04079051251117987,
#  ('00006 ', 'RESPIRATORY'): 0.045198038809487494,
#  ('00006 ', 'ROSETTE'): 0.09353183848028983,
#  ('00006 ', 'SERUM'): 0.012786765725751029,
#  ('00006 ', 'SHEEP'): 0.05274132596910996,
#  ('00006 ', 'SIGNIFICANT'): 0.02234166627414305,
#  ('00006 ', 'SIGNIFICANTLY'): 0.025344310190248354,
#  ('00006 ', 'SPONTANEOUS'): 0.046765919240144914,
#  ('00006 ', 'STAINING'): 0.04079051251117987,
#  ('00006 ', 'STUDIED'): 0.026094408267745166,
#  ('00006 ', 'SUFFERED'): 0.05274132596910996,
#  ('00006 ', 'SURFACE'): 0.1223715375335396,
#  ('00006 ', 'THYMUS'): 0.05274132596910996,
#  ('00006 ', 'TOTAL'): 0.07396286054470533,
#  ('00006 ', 'TRACT'): 0.05383209549763386,
#  ('00006 ', 'WHERAS'): 0.05274132596910996,
#  ('00006 ', 'WHEREAS'): 0.028317073003108095,
#  ('00007 ', 'ACCORDANCE'): 0.0369072170863871,
#  ('00007 ', 'AERUGINOSA'): 0.10828377204207833,
#  ('00007 ', 'ANTIGEN'): 0.030677085760010603,
#  ('00007 ', 'ASSOCIATED'): 0.022256995287194405,
#  ('00007 ', 'BACTERIOLOGICAL'): 0.03181054664109338,
#  ('00007 ', 'CELL'): 0.027078348432363234,
#  ('00007 ', 'CENT'): 0.02193014409182063,
#  ('00007 ', 'CHRONIC'): 0.017861134987520726,
#  ('00007 ', 'CHRONICALLY'): 0.12724218656437353,
#  ('00007 ', 'COLONIZATION'): 0.03181054664109338,
#  ('00007 ', 'COLONIZED'): 0.19086327984656032,
#  ('00007 ', 'COMPLEMENT'): 0.028829185552062764,
#  ('00007 ', 'CONTRAST'): 0.03181054664109338,
#  ('00007 ', 'CORRELATED'): 0.026125326874670722,
#  ('00007 ', 'COULD'): 0.022256995287194405,
#  ('00007 ', 'CROSSED'): 0.03479190773012401,
#  ('00007 ', 'CYSTIC'): 0.008481327459681309,
#  ('00007 ', 'DEPENDENT'): 0.02735366573248812,
#  ('00007 ', 'DURATION'): 0.03988857817541772,
#  ('00007 ', 'EFFECT'): 0.022599054225686265,
#  ('00007 ', 'ESPECIALLY'): 0.033151146323401874,
#  ('00007 ', 'EXAMINATION'): 0.029695237284830287,
#  ('00007 ', 'EXPENSE'): 0.04498524862071144,
#  ('00007 ', 'FACTOR'): 0.02193014409182063,
#  ('00007 ', 'FAVOURING'): 0.04498524862071144,
#  ('00007 ', 'FEMALE'): 0.061354171520021206,
#  ('00007 ', 'FIBROSIS'): 0.008423770116723421,
#  ('00007 ', 'HARBOURING'): 0.04498524862071144,
#  ('00007 ', 'HEREBY'): 0.04498524862071144,
#  ('00007 ', 'HIGHER'): 0.04519810845137253,
#  ('00007 ', 'HYPOTHESIS'): 0.028054475878108158,
#  ('00007 ', 'IMMUNOELECTROPHORESIS'): 0.03479190773012401,
#  ('00007 ', 'INHIBIT'): 0.04498524862071144,
#  ('00007 ', 'INTERMITTENTLY'): 0.04498524862071144,
#  ('00007 ', 'INVESTIGATED'): 0.028829185552062764,
#  ('00007 ', 'LYSIS'): 0.04498524862071144,
#  ('00007 ', 'MALE'): 0.059390474569660574,
#  ('00007 ', 'MEAN'): 0.03768596692540208,
#  ('00007 ', 'MIGHT'): 0.026125326874670722,
#  ('00007 ', 'MONTHLY'): 0.03988857817541772,
#  ('00007 ', 'MUCOID'): 0.24152797561474554,
#  ('00007 ', 'NEWLY'): 0.04498524862071144,
#  ('00007 ', 'NON'): 0.09543163992328016,
#  ('00007 ', 'NUMBER'): 0.05530314484792347,
#  ('00007 ', 'OCCURRENCE'): 0.11531674220825106,
#  ('00007 ', 'ONE'): 0.036094590680692776,
#  ('00007 ', 'OPSONIZING'): 0.04498524862071144,
#  ('00007 ', 'P'): 0.11866257553384524,
#  ('00007 ', 'PATIENT'): 0.03341023054601591,
#  ('00007 ', 'PER'): 0.01905612711618084,
#  ('00007 ', 'PERIOD'): 0.024152797561474555,
#  ('00007 ', 'POLYVALENT'): 0.04498524862071144,
#  ('00007 ', 'PRECIPITIN'): 0.12299283419768287,
#  ('00007 ', 'PREDOMINATING'): 0.06630229264680375,
#  ('00007 ', 'PRESENTED'): 0.029695237284830287,
#  ('00007 ', 'PREVALENCE'): 0.033151146323401874,
#  ('00007 ', 'PSEUDOMONAS'): 0.019501896394242855,
#  ('00007 ', 'RATE'): 0.02048374486942317,
#  ('00007 ', 'RESPIRATORY'): 0.03855126839632757,
#  ('00007 ', 'RESULT'): 0.01884298346270104,
#  ('00007 ', 'SECRETION'): 0.02333496200919349,
#  ('00007 ', 'SERUM'): 0.021812718002751755,
#  ('00007 ', 'SIGNIFICANTLY'): 0.0432344115010119,
#  ('00007 ', 'STRAIN'): 0.17544115273456504,
#  ('00007 ', 'SUBSTANCE'): 0.033151146323401874,
#  ('00007 ', 'TRACHEAL'): 0.03479190773012401,
#  ('00007 ', 'TRACT'): 0.045915610865628884,
#  ('00007 ', 'VIRULENCE'): 0.04498524862071144,
#  ('00007 ', 'WHEREAS'): 0.024152797561474555,
#  ('00007 ', 'YEAR'): 0.03811225423236168,
#  ('00008 ', 'ADDITIONAL'): 0.024034635239937225,
#  ('00008 ', 'AERUGINOSA'): 0.06817867128575301,
#  ('00008 ', 'AGE'): 0.02671579717458275,
#  ('00008 ', 'ALTHOUGH'): 0.01763086018472397,
#  ('00008 ', 'AUREUS'): 0.09472065586984847,
#  ('00008 ', 'BACTERIA'): 0.04806927047987445,
#  ('00008 ', 'BACTERIOLOGICAL'): 0.04806927047987445,
#  ('00008 ', 'BACTERIOLOGY'): 0.030138036843648946,
#  ('00008 ', 'CENT'): 0.28168051744605166,
#  ('00008 ', 'CHRONIC'): 0.013495079768348994,
#  ('00008 ', 'CLINIC'): 0.025047532777681417,
#  ('00008 ', 'CLINICAL'): 0.014080415966448028,
#  ('00008 ', 'COLONIZATION'): 0.07210390571981166,
#  ('00008 ', 'COLONIZE'): 0.03398885451342642,
#  ('00008 ', 'CONCERN'): 0.030138036843648946,
#  ('00008 ', 'CONSIDERABLE'): 0.027885452909714697,
#  ('00008 ', 'CONTRAST'): 0.024034635239937225,
#  ('00008 ', 'CYSTIC'): 0.00961217112097215,
#  ('00008 ', 'DAILY'): 0.03398885451342642,
#  ('00008 ', 'DEPENDENT'): 0.020667214108991028,
#  ('00008 ', 'DESCRIBED'): 0.019739135860862324,
#  ('00008 ', 'DIFFICULT'): 0.025047532777681417,
#  ('00008 ', 'DIPLOCOCCUS'): 0.03398885451342642,
#  ('00008 ', 'DISCUSSED'): 0.021196715107903944,
#  ('00008 ', 'ENTEROBACTERIACEAE'): 0.08365635872914409,
#  ('00008 ', 'EPIDEMIOLOGICAL'): 0.030138036843648946,
#  ('00008 ', 'ESPECIALLY'): 0.025047532777681417,
#  ('00008 ', 'EXAMINATION'): 0.044872803008187995,
#  ('00008 ', 'EXPRESSED'): 0.02628721917387147,
#  ('00008 ', 'FIBROSIS'): 0.009546939465619879,
#  ('00008 ', 'FLUCTUATION'): 0.03398885451342642,
#  ('00008 ', 'FOLLOWED'): 0.05009506555536283,
#  ('00008 ', 'FOUND'): 0.011725892373246024,
#  ('00008 ', 'GROUP'): 0.02325157912979562,
#  ('00008 ', 'HAEMOPHILUS'): 0.030138036843648946,
#  ('00008 ', 'HARBOURED'): 0.030138036843648946,
#  ('00008 ', 'IMPRESSION'): 0.027885452909714697,
#  ('00008 ', 'INCIDENCE'): 0.021782051306002977,
#  ('00008 ', 'INFLUENZAE'): 0.10019013111072567,
#  ('00008 ', 'LABORATORY'): 0.022436401504093997,
#  ('00008 ', 'MAIN'): 0.024034635239937225,
#  ('00008 ', 'MAINLY'): 0.0788616575216144,
#  ('00008 ', 'MANY'): 0.017931233636225504,
#  ('00008 ', 'MAY'): 0.011931677215914628,
#  ('00008 ', 'MEAN'): 0.014236920838485231,
#  ('00008 ', 'MINOR'): 0.022436401504093997,
#  ('00008 ', 'MISCELLANEOUS'): 0.055770905819429395,
#  ('00008 ', 'MODIFICATION'): 0.027885452909714697,
#  ('00008 ', 'MONTHLY'): 0.030138036843648946,
#  ('00008 ', 'MUCOID'): 0.018248780379780775,
#  ('00008 ', 'NEW'): 0.04239343021580789,
#  ('00008 ', 'OBTAINED'): 0.018944131173969696,
#  ('00008 ', 'ONE'): 0.02727146851430121,
#  ('00008 ', 'P'): 0.07172493454490202,
#  ('00008 ', 'PATIENT'): 0.011219237911748553,
#  ('00008 ', 'PATTERN'): 0.020667214108991028,
#  ('00008 ', 'PER'): 0.2591633287800594,
#  ('00008 ', 'PERIOD'): 0.03649756075956155,
#  ('00008 ', 'PNEUMONIAE'): 0.0788616575216144,
#  ('00008 ', 'POINT'): 0.021196715107903944,
#  ('00008 ', 'PREDOMINATING'): 0.05009506555536283,
#  ('00008 ', 'PREVALENCE'): 0.07514259833304425,
#  ('00008 ', 'PREVENTION'): 0.05257443834774294,
#  ('00008 ', 'PROBLEM'): 0.0729951215191231,
#  ('00008 ', 'PSEUDOMONAS'): 0.014734766164539047,
#  ('00008 ', 'RATE'): 0.06190642893870114,
#  ('00008 ', 'REASON'): 0.02628721917387147,
#  ('00008 ', 'RECOLONIZATION'): 0.06027607368729789,
#  ('00008 ', 'REFLECT'): 0.02628721917387147,
#  ('00008 ', 'REFLECTS'): 0.03398885451342642,
#  ('00008 ', 'REGARD'): 0.0871282052240119,
#  ('00008 ', 'RESPIRATORY'): 0.014563812505279305,
#  ('00008 ', 'RESULT'): 0.014236920838485231,
#  ('00008 ', 'RISK'): 0.025047532777681417,
#  ('00008 ', 'SECRETION'): 0.01763086018472397,
#  ('00008 ', 'SEVENTY'): 0.03398885451342642,
#  ('00008 ', 'SHOW'): 0.01858558383431652,
#  ('00008 ', 'SPECIE'): 0.02628721917387147,
#  ('00008 ', 'ST'): 0.10019013111072567,
#  ('00008 ', 'STAPHYLOCOCCUS'): 0.021782051306002977,
#  ('00008 ', 'STILL'): 0.027885452909714697,
#  ('00008 ', 'STRAIN'): 0.016569442202708923,
#  ('00008 ', 'STUDY'): 0.012255393372158939,
#  ('00008 ', 'TERM'): 0.021782051306002977,
#  ('00008 ', 'THERAPEUTIC'): 0.025047532777681417,
#  ('00008 ', 'THERAPY'): 0.014236920838485231,
#  ('00008 ', 'TRACHEAL'): 0.02628721917387147,
#  ('00008 ', 'TRACT'): 0.017345897438126468,
#  ('00008 ', 'TREATED'): 0.021782051306002977,
#  ('00008 ', 'WELL'): 0.020667214108991028,
#  ('00008 ', 'YEAR'): 0.0143979627100033,
#  ('00009 ', 'ALSO'): 0.09823177443026031,
#  ('00009 ', 'ASSOCIATION'): 0.1495760100272933,
#  ('00009 ', 'BASIS'): 0.16023090159958148,
#  ('00009 ', 'CASE'): 0.09090489504767069,
#  ('00009 ', 'CELIAC'): 0.37180603879619595,
#  ('00009 ', 'CHANCE'): 0.20092024562432628,
#  ('00009 ', 'CONDITION'): 0.09598641806668866,
#  ('00009 ', 'COUSIN'): 0.22659236342284278,
#  ('00009 ', 'CYSTIC'): 0.021360380268826997,
#  ('00009 ', 'DISCOVERED'): 0.22659236342284278,
#  ('00009 ', 'ESTIMATED'): 0.20092024562432628,
#  ('00009 ', 'FAMILY'): 0.275562854786547,
#  ('00009 ', 'FIBROSIS'): 0.02121542103471084,
#  ('00009 ', 'GENETICS'): 0.20092024562432628,
#  ('00009 ', 'INCIDENCE'): 0.14521367537335317,
#  ('00009 ', 'INDEX'): 0.20092024562432628,
#  ('00009 ', 'LIKELIHOOD'): 0.22659236342284278,
#  ('00009 ', 'OCCURRED'): 0.17524812782580979,
#  ('00009 ', 'OCCURRING'): 0.17524812782580979,
#  ('00009 ', 'PRESENTED'): 0.1495760100272933,
#  ('00009 ', 'REVIEWED'): 0.1495760100272933,
#  ('00009 ', 'SIBSHIP'): 0.22659236342284278,
#  ('00009 ', 'SPRUE'): 0.40184049124865256,
#  ('00009 ', 'WITHIN'): 0.14521367537335317,
#  ('00010 ', 'AUTHOR'): 0.22542779499913276,
#  ('00010 ', 'COMBINATION'): 0.216311717159435,
#  ('00010 ', 'CYSTIC'): 0.0576730267258329,
#  ('00010 ', 'DIAGNOSIS'): 0.1295816643900297,
#  ('00010 ', 'EXCLUDED'): 0.30589969062083777,
#  ('00010 ', 'EXHIBITED'): 0.2712423315928405,
#  ('00010 ', 'FEATURE'): 0.23658497256484323,
#  ('00010 ', 'FIBROSIS'): 0.057281636793719275,
#  ('00010 ', 'KARTAGENER'): 0.542484663185681,
#  ('00010 ', 'KNOWLEDGE'): 0.22542779499913276,
#  ('00010 ', 'MADE'): 0.18165435813143774,
#  ('00010 ', 'PATIENT'): 0.025243285301434243,
#  ('00010 ', 'REPORT'): 0.15611307694313822,
#  ('00010 ', 'REPRESENTS'): 0.30589969062083777,
#  ('00010 ', 'SYNDROME'): 0.35530444549552187,
#  ('00010 ', 'THIRD'): 0.23658497256484323,
#  ('00011 ', 'AGE'): 0.03082591981682625,
#  ('00011 ', 'AIRWAY'): 0.050266272244622254,
#  ('00011 ', 'ALLERGIC'): 0.14674648920856576,
#  ('00011 ', 'ALLERGY'): 0.22185817144557435,
#  ('00011 ', 'BETTER'): 0.06435104517626468,
#  ('00011 ', 'CF'): 0.0979851327660126,
#  ('00011 ', 'CLINICAL'): 0.03249326761488006,
#  ('00011 ', 'COMPARED'): 0.10053254448924451,
#  ('00011 ', 'CONDITION'): 0.0332260677923153,
#  ('00011 ', 'CONTROL'): 0.02433956547744421,
#  ('00011 ', 'COURSE'): 0.050266272244622254,
#  ('00011 ', 'CYSTIC'): 0.0073939777853631915,
#  ('00011 ', 'DEFINED'): 0.06954931579303603,
#  ('00011 ', 'DISEASE'): 0.020325568195685886,
#  ('00011 ', 'EFFECT'): 0.07880695832547005,
#  ('00011 ', 'ELEVATED'): 0.04288980884842274,
#  ('00011 ', 'EOSINOPHILIA'): 0.07843581810790712,
#  ('00011 ', 'EXAMINATION'): 0.051776311163293835,
#  ('00011 ', 'FIBROSIS'): 0.0073437995889383675,
#  ('00011 ', 'FIFTEEN'): 0.06954931579303603,
#  ('00011 ', 'GROUP'): 0.026828745149764174,
#  ('00011 ', 'HIGHER'): 0.039403479162735025,
#  ('00011 ', 'HISTORY'): 0.04891549640285525,
#  ('00011 ', 'IGA'): 0.051776311163293835,
#  ('00011 ', 'IGE'): 0.06954931579303603,
#  ('00011 ', 'IGG'): 0.04891549640285525,
#  ('00011 ', 'IGM'): 0.05546454286139359,
#  ('00011 ', 'IMMUNOGLOBULIN'): 0.050266272244622254,
#  ('00011 ', 'INTERNATIONAL'): 0.07843581810790712,
#  ('00011 ', 'IU'): 0.13909863158607205,
#  ('00011 ', 'LEVEL'): 0.0570813721616956,
#  ('00011 ', 'MATCHED'): 0.057801998717726344,
#  ('00011 ', 'MEAN'): 0.03285443270419668,
#  ('00011 ', 'MODULATING'): 0.07843581810790712,
#  ('00011 ', 'NASAL'): 0.05546454286139359,
#  ('00011 ', 'NONALLERGIC'): 0.13909863158607205,
#  ('00011 ', 'NORMAL'): 0.0173823061233205,
#  ('00011 ', 'OBSTRUCTION'): 0.05348825209437746,
#  ('00011 ', 'PATIENT'): 0.03236318628389005,
#  ('00011 ', 'PERIPHERAL'): 0.05348825209437746,
#  ('00011 ', 'PHYSICAL'): 0.05348825209437746,
#  ('00011 ', 'POSITIVE'): 0.046578040546522495,
#  ('00011 ', 'PREVALENCE'): 0.057801998717726344,
#  ('00011 ', 'RESPIRATORY'): 0.10082639426731826,
#  ('00011 ', 'REVERSIBLE'): 0.06954931579303603,
#  ('00011 ', 'SCORE'): 0.057801998717726344,
#  ('00011 ', 'SERUM'): 0.019016215694706656,
#  ('00011 ', 'SEVERITY'): 0.04891549640285525,
#  ('00011 ', 'SHWACHMAN'): 0.06954931579303603,
#  ('00011 ', 'SIGNIFICANTLY'): 0.037691538231651396,
#  ('00011 ', 'SIMILAR'): 0.039403479162735025,
#  ('00011 ', 'SKIN'): 0.04288980884842274,
#  ('00011 ', 'STUDIED'): 0.038807068705877426,
#  ('00011 ', 'SUGGESTING'): 0.057801998717726344,
#  ('00011 ', 'TEST'): 0.028805035916780304,
#  ('00011 ', 'TWO'): 0.037691538231651396,
#  ('00011 ', 'UNIT'): 0.07843581810790712,
#  ('00012 ', 'ACCIDENTAL'): 0.09863357512466926,
#  ('00012 ', 'ACCORDANCE'): 0.09126148224997536,
#  ('00012 ', 'AL'): 0.07585606660657167,
#  ('00012 ', 'ALTHOUGH'): 0.057700996968187535,
#  ('00012 ', 'ANOTHER'): 0.07585606660657167,
#  ('00012 ', 'BOY'): 0.1112362511348501,
#  ('00012 ', 'CASE'): 0.08925207877407668,
#  ('00012 ', 'CLINICAL'): 0.046081361344739,
#  ('00012 ', 'COINCIDENCE'): 0.1112362511348501,
#  ('00012 ', 'COMBINATION'): 0.07865880623979454,
#  ('00012 ', 'CONCOMITANT'): 0.09863357512466926,
#  ('00012 ', 'CONDITION'): 0.04712060523273807,
#  ('00012 ', 'COURSE'): 0.07128671336510065,
#  ('00012 ', 'CYSTIC'): 0.020972009718484688,
#  ('00012 ', 'DEPEND'): 0.09126148224997536,
#  ('00012 ', 'DESCRIBE'): 0.09863357512466926,
#  ('00012 ', 'DEVELOPMENT'): 0.06763815526578881,
#  ('00012 ', 'DISEASE'): 0.028825351259336347,
#  ('00012 ', 'ENTIRELY'): 0.09126148224997536,
#  ('00012 ', 'ESTABLISHMENT'): 0.09126148224997536,
#  ('00012 ', 'ET'): 0.07585606660657167,
#  ('00012 ', 'EVENT'): 0.1112362511348501,
#  ('00012 ', 'FIBROSIS'): 0.020829686106807008,
#  ('00012 ', 'FINDING'): 0.051311944480225934,
#  ('00012 ', 'LIKE'): 0.07342822310430762,
#  ('00012 ', 'OLD'): 0.07865880623979454,
#  ('00012 ', 'PATIENT'): 0.027538129419746444,
#  ('00012 ', 'PATTERN'): 0.06763815526578881,
#  ('00012 ', 'POSSIBLE'): 0.11353678323137324,
#  ('00012 ', 'RARE'): 0.07128671336510065,
#  ('00012 ', 'RELATIONSHIP'): 0.08603089911448844,
#  ('00012 ', 'REPORT'): 0.05676839161568662,
#  ('00012 ', 'REPORTED'): 0.057700996968187535,
#  ('00012 ', 'RUSSELL'): 0.2737844467499261,
#  ('00012 ', 'SILVER'): 0.19726715024933852,
#  ('00012 ', 'SIMILAR'): 0.05588129772169694,
#  ('00012 ', 'STATISTICALLY'): 0.09126148224997536,
#  ('00012 ', 'SYNDROME'): 0.12920161654382611,
#  ('00012 ', 'TAUSSIG'): 0.1112362511348501,
#  ('00012 ', 'TWO'): 0.05345345421943289,
#  ('00012 ', 'VARIANT'): 0.09863357512466926,
#  ('00012 ', 'WOULD'): 0.20291446579736644,
#  ('00012 ', 'YEAR'): 0.04712060523273807,
#  ('00013 ', 'ACCEPTED'): 0.11672980287787547,
#  ('00013 ', 'AUTOSOMAL'): 0.10061010100438837,
#  ('00013 ', 'BLACK'): 0.4851260073676095,
#  ('00013 ', 'BORN'): 0.11672980287787547,
#  ('00013 ', 'CALCULATED'): 0.11672980287787547,
#  ('00013 ', 'CF'): 0.08887023669475562,
#  ('00013 ', 'CHANGE'): 0.06837069725741417,
#  ('00013 ', 'CLINICAL'): 0.05894127613861965,
#  ('00013 ', 'COLUMBIA'): 0.12615922399667,
#  ('00013 ', 'CONSIDERATION'): 0.1100395221231829,
#  ('00013 ', 'COURSE'): 0.09118067988559386,
#  ('00013 ', 'CYSTIC'): 0.013412331796705325,
#  ('00013 ', 'DC'): 0.1422789258701571,
#  ('00013 ', 'DECADE'): 0.1422789258701571,
#  ('00013 ', 'DISCLOSED'): 0.12615922399667,
#  ('00013 ', 'DISEASE'): 0.03686963533170928,
#  ('00013 ', 'DISTRICT'): 0.1422789258701571,
#  ('00013 ', 'EIGHT'): 0.09702520147352191,
#  ('00013 ', 'FIBROSIS'): 0.013321310882260295,
#  ('00013 ', 'GENERALLY'): 0.1100395221231829,
#  ('00013 ', 'GENETIC'): 0.06650923893942495,
#  ('00013 ', 'INCIDENCE'): 0.09118067988559386,
#  ('00013 ', 'INHERITANCE'): 0.12615922399667,
#  ('00013 ', 'INTENSIVE'): 0.1422789258701571,
#  ('00013 ', 'LEAST'): 0.10061010100438837,
#  ('00013 ', 'NEWBORN'): 0.08262894081291206,
#  ('00013 ', 'ONE'): 0.05707981782063044,
#  ('00013 ', 'PATHOLOGICAL'): 0.11672980287787547,
#  ('00013 ', 'PATIENT'): 0.011741062930899647,
#  ('00013 ', 'PERIOD'): 0.0763902434502451,
#  ('00013 ', 'POINT'): 0.08873043533541185,
#  ('00013 ', 'RECESSIVE'): 0.09391982024969579,
#  ('00013 ', 'SEARCH'): 0.1422789258701571,
#  ('00013 ', 'SIMILAR'): 0.07147607848124028,
#  ('00013 ', 'WASHINGTON'): 0.1422789258701571,
#  ('00013 ', 'WHITE'): 0.1652578816258241,
#  ('00014 ', 'ABNORMALITY'): 0.046376712557761185,
#  ('00014 ', 'ACHIEVEMENT'): 0.02932349530733411,
#  ('00014 ', 'ACID'): 0.013407608933461457,
#  ('00014 ', 'ADDITION'): 0.02183001227425362,
#  ('00014 ', 'ADVANCE'): 0.033070236823874354,
#  ('00014 ', 'AMINO'): 0.024370572432338675,
#  ('00014 ', 'AMNIOCENTESIS'): 0.02932349530733411,
#  ('00014 ', 'ANALYSIS'): 0.01920564570246064,
#  ('00014 ', 'APPLICATION'): 0.0542635840405259,
#  ('00014 ', 'APPLIED'): 0.02932349530733411,
#  ('00014 ', 'APPROACH'): 0.06549003682276086,
#  ('00014 ', 'ATTENTION'): 0.024370572432338675,
#  ('00014 ', 'BASIC'): 0.023385050503722703,
#  ('00014 ', 'BASIS'): 0.023385050503722703,
#  ('00014 ', 'BECAME'): 0.033070236823874354,
#  ('00014 ', 'BIRTH'): 0.02183001227425362,
#  ('00014 ', 'BLOOD'): 0.015670908040802997,
#  ('00014 ', 'CARBOHYDRATE'): 0.025576753790793865,
#  ('00014 ', 'CHILD'): 0.0165732576621209,
#  ('00014 ', 'CHROMOSOMAL'): 0.08139537606078885,
#  ('00014 ', 'CLEAR'): 0.033070236823874354,
#  ('00014 ', 'CONGENITAL'): 0.02932349530733411,
#  ('00014 ', 'COULD'): 0.03272379847630746,
#  ('00014 ', 'CYSTIC'): 0.003117460904099076,
#  ('00014 ', 'DEAL'): 0.033070236823874354,
#  ('00014 ', 'DEFINE'): 0.02713179202026295,
#  ('00014 ', 'DEFORMITY'): 0.033070236823874354,
#  ('00014 ', 'DETECTABLE'): 0.02932349530733411,
#  ('00014 ', 'DETERMINATION'): 0.02713179202026295,
#  ('00014 ', 'DETERMINE'): 0.022551803585737527,
#  ('00014 ', 'DEVELOPED'): 0.021193347216651545,
#  ('00014 ', 'DEVELOPMENT'): 0.04021728150938795,
#  ('00014 ', 'DIAGNOSED'): 0.024370572432338675,
#  ('00014 ', 'DIAGNOSIS'): 0.14008828582705912,
#  ('00014 ', 'DIAGNOSTIC'): 0.02183001227425362,
#  ('00014 ', 'DIRECT'): 0.025576753790793865,
#  ('00014 ', 'DISCUSSION'): 0.033070236823874354,
#  ('00014 ', 'DISEASE'): 0.008569699023045942,
#  ('00014 ', 'DISORDER'): 0.1821147715751769,
#  ('00014 ', 'ERROR'): 0.07673026137238159,
#  ('00014 ', 'EXPANSION'): 0.033070236823874354,
#  ('00014 ', 'FEAR'): 0.033070236823874354,
#  ('00014 ', 'FETAL'): 0.05115350758158773,
#  ('00014 ', 'FETUS'): 0.025576753790793865,
#  ('00014 ', 'FIBROSIS'): 0.0030963046915523933,
#  ('00014 ', 'FIRST'): 0.01920564570246064,
#  ('00014 ', 'FOLLOWED'): 0.024370572432338675,
#  ('00014 ', 'FUTURE'): 0.02713179202026295,
#  ('00014 ', 'GENERAL'): 0.02183001227425362,
#  ('00014 ', 'GENETIC'): 0.09275342511552237,
#  ('00014 ', 'GOAL'): 0.05864699061466822,
#  ('00014 ', 'GREAT'): 0.024370572432338675,
#  ('00014 ', 'INBORN'): 0.07673026137238159,
#  ('00014 ', 'INCLUDE'): 0.04238669443330309,
#  ('00014 ', 'INCREASE'): 0.01920564570246064,
#  ('00014 ', 'INCREASING'): 0.021193347216651545,
#  ('00014 ', 'INDIRECT'): 0.033070236823874354,
#  ('00014 ', 'INHERITED'): 0.021193347216651545,
#  ('00014 ', 'INITIALLY'): 0.02932349530733411,
#  ('00014 ', 'INTRAUTERINE'): 0.08139537606078885,
#  ('00014 ', 'KNOWLEDGE'): 0.024370572432338675,
#  ('00014 ', 'LARGE'): 0.023385050503722703,
#  ('00014 ', 'LED'): 0.033070236823874354,
#  ('00014 ', 'LIMITATION'): 0.02932349530733411,
#  ('00014 ', 'LINKED'): 0.0542635840405259,
#  ('00014 ', 'LIPID'): 0.02713179202026295,
#  ('00014 ', 'MALFORMATION'): 0.024370572432338675,
#  ('00014 ', 'MATERNAL'): 0.02713179202026295,
#  ('00014 ', 'MAY'): 0.011609199453322342,
#  ('00014 ', 'METABOLISM'): 0.14835343051656083,
#  ('00014 ', 'METHOD'): 0.028017657165411828,
#  ('00014 ', 'MISCELLANEOUS'): 0.02713179202026295,
#  ('00014 ', 'MUCOPOLYSACCHARIDE'): 0.019638308987182457,
#  ('00014 ', 'NEW'): 0.02062383091579843,
#  ('00014 ', 'NUMBER'): 0.08131056972235234,
#  ('00014 ', 'PARENT'): 0.016877089399258187,
#  ('00014 ', 'PAST'): 0.04677010100744541,
#  ('00014 ', 'POTENTIAL'): 0.02932349530733411,
#  ('00014 ', 'PREGNANCY'): 0.033070236823874354,
#  ('00014 ', 'PRENATAL'): 0.15281008591977532,
#  ('00014 ', 'PRESENCE'): 0.018083270757713373,
#  ('00014 ', 'PRESENT'): 0.013267200898849236,
#  ('00014 ', 'PRIOR'): 0.02713179202026295,
#  ('00014 ', 'PROVE'): 0.02713179202026295,
#  ('00014 ', 'PROVIDE'): 0.023385050503722703,
#  ('00014 ', 'RAPID'): 0.04677010100744541,
#  ('00014 ', 'RECEIVED'): 0.023385050503722703,
#  ('00014 ', 'RECENTLY'): 0.022551803585737527,
#  ('00014 ', 'RECESSIVE'): 0.04366002454850724,
#  ('00014 ', 'RELIABLE'): 0.023385050503722703,
#  ('00014 ', 'REVIEW'): 0.022551803585737527,
#  ('00014 ', 'RISK'): 0.024370572432338675,
#  ('00014 ', 'SAMPLING'): 0.033070236823874354,
#  ('00014 ', 'SECTION'): 0.02932349530733411,
#  ('00014 ', 'SEVERAL'): 0.020108640754693975,
#  ('00014 ', 'SEVERE'): 0.03761012413839456,
#  ('00014 ', 'SEX'): 0.024370572432338675,
#  ('00014 ', 'SHORTLY'): 0.033070236823874354,
#  ('00014 ', 'SPECIFIC'): 0.03686425525745454,
#  ('00014 ', 'SYNDROME'): 0.01920564570246064,
#  ('00014 ', 'TECHNIQUE'): 0.0686174018000068,
#  ('00014 ', 'THEREAFTER'): 0.02932349530733411,
#  ('00014 ', 'TISSUE'): 0.019638308987182457,
#  ('00014 ', 'TREATMENT'): 0.01636189923815373,
#  ('00014 ', 'UNLIMITED'): 0.033070236823874354,
#  ('00014 ', 'URINE'): 0.02062383091579843,
#  ('00014 ', 'USED'): 0.035511140198492316,
#  ('00014 ', 'UTERO'): 0.02932349530733411,
#  ('00014 ', 'VALUE'): 0.014868637742866384,
#  ('00014 ', 'VISUALIZATION'): 0.033070236823874354,
#  ('00014 ', 'WITHOUT'): 0.020108640754693975,
#  ('00014 ', 'YEAR'): 0.014008828582705914,
#  ('00015 ', 'ACUTE'): 0.0961385409597489,
#  ('00015 ', 'AFFECTED'): 0.08974560601637599,
#  ('00015 ', 'CERVICITIS'): 0.13595541805370567,
#  ('00015 ', 'CLINIC'): 0.10019013111072567,
#  ('00015 ', 'CLOSELY'): 0.10019013111072567,
#  ('00015 ', 'COINCIDENTAL'): 0.13595541805370567,
#  ('00015 ', 'COMBINED'): 0.11154181163885879,
#  ('00015 ', 'CONTRACEPTION'): 0.13595541805370567,
#  ('00015 ', 'CONTRACEPTIVE'): 0.13595541805370567,
#  ('00015 ', 'CYSTIC'): 0.025632456322592402,
#  ('00015 ', 'DETERIORATION'): 0.10514887669548588,
#  ('00015 ', 'DEVELOPED'): 0.0871282052240119,
#  ('00015 ', 'DISCONTINUATION'): 0.13595541805370567,
#  ('00015 ', 'DRUG'): 0.11154181163885879,
#  ('00015 ', 'FIBROSIS'): 0.02545850524165301,
#  ('00015 ', 'FORM'): 0.0961385409597489,
#  ('00015 ', 'GYNECOLOGIC'): 0.13595541805370567,
#  ('00015 ', 'INSTANCE'): 0.10019013111072567,
#  ('00015 ', 'MEDICATION'): 0.12055214737459578,
#  ('00015 ', 'OBSERVED'): 0.05632166386579211,
#  ('00015 ', 'ONE'): 0.05454293702860242,
#  ('00015 ', 'ORAL'): 0.21029775339097176,
#  ('00015 ', 'PATIENT'): 0.011219237911748553,
#  ('00015 ', 'POLYP'): 0.18542594059384188,
#  ('00015 ', 'POLYPOID'): 0.13595541805370567,
#  ('00015 ', 'PULMONARY'): 0.05632166386579211,
#  ('00015 ', 'RECURRED'): 0.13595541805370567,
#  ('00015 ', 'REGARDING'): 0.10514887669548588,
#  ('00015 ', 'REINSTITUTION'): 0.13595541805370567,
#  ('00015 ', 'RESOLUTION'): 0.13595541805370567,
#  ('00015 ', 'RESPIRATORY'): 0.05825525002111722,
#  ('00015 ', 'STATUS'): 0.1922770819194978,
#  ('00015 ', 'SUGGESTED'): 0.07730969961781103,
#  ('00015 ', 'THEREFORE'): 0.08974560601637599,
#  ('00015 ', 'THREE'): 0.07577652469587878,
#  ('00015 ', 'USED'): 0.0729951215191231,
#  ('00015 ', 'USING'): 0.06938358975250587,
#  ('00015 ', 'WOMAN'): 0.2781389108907628,
#  ('00016 ', 'ABNORMALITY'): 0.08171135069700779,
#  ('00016 ', 'ADENOIDAL'): 0.1747998232119073,
#  ('00016 ', 'AID'): 0.1434109006785327,
#  ('00016 ', 'ATAXIA'): 0.3099912361061034,
#  ('00016 ', 'CHARACTERIZED'): 0.13519141289419612,
#  ('00016 ', 'CHRONIC'): 0.06940326738008053,
#  ('00016 ', 'CONJUNCTIVAL'): 0.1747998232119073,
#  ('00016 ', 'CUTANEOUS'): 0.1747998232119073,
#  ('00016 ', 'CYSTIC'): 0.016478007635952256,
#  ('00016 ', 'DECREASED'): 0.11202197814515816,
#  ('00016 ', 'DEFICIENCY'): 0.08283194250138727,
#  ('00016 ', 'DEGENERATION'): 0.1747998232119073,
#  ('00016 ', 'DIFFERENTIAL'): 0.1549956180530517,
#  ('00016 ', 'EVIDENCE'): 0.08920747253893611,
#  ('00016 ', 'FIBROSIS'): 0.01636618194106265,
#  ('00016 ', 'IMMUNOLOGIC'): 0.1747998232119073,
#  ('00016 ', 'INFECTION'): 0.06940326738008053,
#  ('00016 ', 'LYMPHOID'): 0.1549956180530517,
#  ('00016 ', 'MASS'): 0.12881588285664727,
#  ('00016 ', 'MAY'): 0.06136291139613237,
#  ('00016 ', 'NEUROLOGIC'): 0.1747998232119073,
#  ('00016 ', 'PRESENT'): 0.07012663332248882,
#  ('00016 ', 'PROGRESSIVE'): 0.1549956180530517,
#  ('00016 ', 'PULMONARY'): 0.072413567827447,
#  ('00016 ', 'RESEMBLE'): 0.1434109006785327,
#  ('00016 ', 'ROENTGENOLOGIC'): 0.1747998232119073,
#  ('00016 ', 'SINOPULMONARY'): 0.1747998232119073,
#  ('00016 ', 'SINUS'): 0.1434109006785327,
#  ('00016 ', 'SMALL'): 0.10151555585586337,
#  ('00016 ', 'SYNDROME'): 0.10151555585586337,
#  ('00016 ', 'TELANGIECTASIA'): 0.1747998232119073,
#  ('00016 ', 'TELANGIECTASIS'): 0.1747998232119073,
#  ('00016 ', 'TISSUE'): 0.10380249036082156,
#  ('00016 ', 'USUALLY'): 0.13519141289419612,
#  ('00017 ', 'ADULT'): 0.12179705866115435,
#  ('00017 ', 'ALWAYS'): 0.10235559682748697,
#  ('00017 ', 'BASIC'): 0.08162706307903207,
#  ('00017 ', 'BRONCHIAL'): 0.10235559682748697,
#  ('00017 ', 'BRONCHIECTASIS'): 0.09470531176884237,
#  ('00017 ', 'CHANGE'): 0.05547056569941149,
#  ('00017 ', 'CHARACTERISTIC'): 0.07019053848336575,
#  ('00017 ', 'CHILD'): 0.028925025165022322,
#  ('00017 ', 'CHRONIC'): 0.04583234638307205,
#  ('00017 ', 'COMPLICATION'): 0.08506709245250292,
#  ('00017 ', 'CONDITION'): 0.04889874127925649,
#  ('00017 ', 'CORRELATION'): 0.07019053848336575,
#  ('00017 ', 'CYST'): 0.10235559682748697,
#  ('00017 ', 'CYSTIC'): 0.021763406311635054,
#  ('00017 ', 'DESPITE'): 0.08927734813767668,
#  ('00017 ', 'DIFFERENTIATED'): 0.11543384551729727,
#  ('00017 ', 'DISEASE'): 0.029913100363462248,
#  ('00017 ', 'EXISTS'): 0.09470531176884237,
#  ('00017 ', 'FIBROSIS'): 0.021615711997629912,
#  ('00017 ', 'GASTROINTESTINAL'): 0.08927734813767668,
#  ('00017 ', 'HEMORRHAGE'): 0.11543384551729727,
#  ('00017 ', 'HYPERTENSION'): 0.10235559682748697,
#  ('00017 ', 'INCLUDE'): 0.07397677802038746,
#  ('00017 ', 'INFILTRATES'): 0.11543384551729727,
#  ('00017 ', 'INTERSTITIAL'): 0.18941062353768473,
#  ('00017 ', 'INVOLVEMENT'): 0.07397677802038746,
#  ('00017 ', 'LEADING'): 0.10235559682748697,
#  ('00017 ', 'LESION'): 0.07871855968606493,
#  ('00017 ', 'LIKE'): 0.0761990994478664,
#  ('00017 ', 'LITTLE'): 0.07019053848336575,
#  ('00017 ', 'LONGER'): 0.09470531176884237,
#  ('00017 ', 'LUNG'): 0.04730331886363265,
#  ('00017 ', 'MAIN'): 0.08162706307903207,
#  ('00017 ', 'MUST'): 0.0761990994478664,
#  ('00017 ', 'OBSTRUCTION'): 0.07871855968606493,
#  ('00017 ', 'ORGAN'): 0.10235559682748697,
#  ('00017 ', 'PANCREATIC'): 0.049462004734910844,
#  ('00017 ', 'PATHOGENESIS'): 0.09470531176884237,
#  ('00017 ', 'PNEUMONITIS'): 0.11543384551729727,
#  ('00017 ', 'PNEUMOTHORAX'): 0.11543384551729727,
#  ('00017 ', 'PULMONARY'): 0.09564056128153377,
#  ('00017 ', 'RARE'): 0.07397677802038746,
#  ('00017 ', 'RESEMBLE'): 0.09470531176884237,
#  ('00017 ', 'RESPIRATORY'): 0.049462004734910844,
#  ('00017 ', 'ROENTGENOGRAPHY'): 0.11543384551729727,
#  ('00017 ', 'SIMILARITY'): 0.11543384551729727,
#  ('00017 ', 'TARGET'): 0.11543384551729727,
#  ('00017 ', 'TRACT'): 0.05891059507288234,
#  ('00018 ', 'ABILITY'): 0.028575915502475627,
#  ('00018 ', 'ABSENT'): 0.032408900351348385,
#  ('00018 ', 'ACCOUNT'): 0.032408900351348385,
#  ('00018 ', 'ACTIVITY'): 0.029164517340444944,
#  ('00018 ', 'AERUGINOSA'): 0.03362235844228916,
#  ('00018 ', 'AGREE'): 0.03715648377984116,
#  ('00018 ', 'ALSO'): 0.01816615006587006,
#  ('00018 ', 'ALVEOLAR'): 0.15440259931447448,
#  ('00018 ', 'ASSOCIATE'): 0.06481780070269677,
#  ('00018 ', 'BALANCED'): 0.04190406720833394,
#  ('00018 ', 'BIGGAR'): 0.07431296755968232,
#  ('00018 ', 'CAPACITY'): 0.02766131692285561,
#  ('00018 ', 'CF'): 0.04362351801226588,
#  ('00018 ', 'CONCENTRATION'): 0.09408297599702713,
#  ('00018 ', 'CONCERNED'): 0.04190406720833394,
#  ('00018 ', 'DATA'): 0.022913733494362834,
#  ('00018 ', 'DECREASING'): 0.03715648377984116,
#  ('00018 ', 'DEFICIENCY'): 0.0397139450349117,
#  ('00018 ', 'DEGREE'): 0.02766131692285561,
#  ('00018 ', 'DEMONSTRATE'): 0.032408900351348385,
#  ('00018 ', 'DIFFERENCE'): 0.014333165216997299,
#  ('00018 ', 'DILUTION'): 0.07431296755968232,
#  ('00018 ', 'DUE'): 0.022913733494362834,
#  ('00018 ', 'EFFECT'): 0.021051173799269397,
#  ('00018 ', 'EITHER'): 0.025480126983687564,
#  ('00018 ', 'ELEVATED'): 0.022913733494362834,
#  ('00018 ', 'ESSENTIAL'): 0.024884158648142155,
#  ('00018 ', 'EVEN'): 0.028575915502475627,
#  ('00018 ', 'EXPERIMENT'): 0.06481780070269677,
#  ('00018 ', 'FAR'): 0.032408900351348385,
#  ('00018 ', 'FEEL'): 0.03715648377984116,
#  ('00018 ', 'FOURFOLD'): 0.04190406720833394,
#  ('00018 ', 'FROZEN'): 0.04190406720833394,
#  ('00018 ', 'GREATER'): 0.023355778159688662,
#  ('00018 ', 'HANK'): 0.04190406720833394,
#  ('00018 ', 'HEATED'): 0.04190406720833394,
#  ('00018 ', 'HIGH'): 0.021736676940070646,
#  ('00018 ', 'HOMOZYGOUS'): 0.09264155958868468,
#  ('00018 ', 'HOUR'): 0.025480126983687564,
#  ('00018 ', 'HUMAN'): 0.1069267650295467,
#  ('00018 ', 'IGA'): 0.08298395076856684,
#  ('00018 ', 'IMMUNOGLOBULIN'): 0.02685458380192148,
#  ('00018 ', 'INCLUDING'): 0.030880519862894897,
#  ('00018 ', 'INCREASED'): 0.03510473631407317,
#  ('00018 ', 'INCREASING'): 0.05370916760384296,
#  ('00018 ', 'INFECTION'): 0.016637769577416566,
#  ('00018 ', 'INHIBITION'): 0.05926348415326986,
#  ('00018 ', 'INHIBITOR'): 0.030880519862894897,
#  ('00018 ', 'KILL'): 0.04190406720833394,
#  ('00018 ', 'KNOWN'): 0.02685458380192148,
#  ('00018 ', 'LABILE'): 0.03715648377984116,
#  ('00018 ', 'LIKELY'): 0.02963174207663493,
#  ('00018 ', 'MACROPHAGE'): 0.16596790153713367,
#  ('00018 ', 'MAY'): 0.014710286978524882,
#  ('00018 ', 'NORMAL'): 0.0371457500717534,
#  ('00018 ', 'NOTE'): 0.03715648377984116,
#  ('00018 ', 'OBSERVATION'): 0.026132936434402117,
#  ('00018 ', 'OLD'): 0.02963174207663493,
#  ('00018 ', 'OPPOSITE'): 0.04190406720833394,
#  ('00018 ', 'PATIENT'): 0.0034579842878677044,
#  ('00018 ', 'PERHAPS'): 0.032408900351348385,
#  ('00018 ', 'PHAGOCYTIC'): 0.07431296755968232,
#  ('00018 ', 'PHAGOCYTIZE'): 0.04190406720833394,
#  ('00018 ', 'PHAGOCYTOSIS'): 0.10313797651538312,
#  ('00018 ', 'PRESENCE'): 0.022913733494362834,
#  ('00018 ', 'PREVIOUSLY'): 0.02766131692285561,
#  ('00018 ', 'PSEUDOMONAS'): 0.03633230013174012,
#  ('00018 ', 'PULMONARY'): 0.017359416944935924,
#  ('00018 ', 'RABBIT'): 0.12963560140539354,
#  ('00018 ', 'RATHER'): 0.028575915502475627,
#  ('00018 ', 'REDUCED'): 0.05370916760384296,
#  ('00018 ', 'REQUIRED'): 0.02963174207663493,
#  ('00018 ', 'RESPOND'): 0.03715648377984116,
#  ('00018 ', 'RESULT'): 0.017552368157036584,
#  ('00018 ', 'SALT'): 0.02963174207663493,
#  ('00018 ', 'SECRETION'): 0.021736676940070646,
#  ('00018 ', 'SERUM'): 0.10159348110870679,
#  ('00018 ', 'SHOWN'): 0.026132936434402117,
#  ('00018 ', 'SINCE'): 0.021736676940070646,
#  ('00018 ', 'SOLUTION'): 0.034379325505127706,
#  ('00018 ', 'STATE'): 0.022913733494362834,
#  ('00018 ', 'STORED'): 0.03715648377984116,
#  ('00018 ', 'SUSPENSION'): 0.03715648377984116,
#  ('00018 ', 'THUS'): 0.02963174207663493,
#  ('00018 ', 'TOXIC'): 0.034379325505127706,
#  ('00018 ', 'UNEXPECTED'): 0.03715648377984116,
#  ('00018 ', 'USED'): 0.06749548907590149,
#  ('00018 ', 'WELL'): 0.025480126983687564,
#  ('00019 ', 'ACTIVITY'): 0.08631120672374923,
#  ('00019 ', 'ALTER'): 0.041337796029842944,
#  ('00019 ', 'ANOTHER'): 0.028189754482171907,
#  ...}
